# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
import os

os.environ["LANGCHAIN_API_KEY"] = ""
os.environ["LANGSMITH_API_KEY"] = os.environ["LANGCHAIN_API_KEY"]
os.environ["LANGCHAIN_ENDPOINT"] = ""
os.environ["OPENAI_API_KEY"] = ""
os.environ["GOOGLE_API_KEY"] = ""

# %%
import os
import google.generativeai as genai
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from pprint import pprint

from langchain_teddynote import logging
from models import sample_name_searcher, get_rag_instance

from utils import save_output2json
from prompt import load_system_prompt, load_invoke_input

# %%
# .env 파일 로드
#load_dotenv(dotenv_path=".env")

# API 키 가져오기
#OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
#LANGCHAIN_API_KEY = os.getenv("LANGCHAIN_API_KEY")

# LangSmith 추적 기능을 활성화합니다. (선택적)
os.environ["LANGCHAIN_TRACING_V2"] = "true"

# %%
from main import main

# %%
from types import SimpleNamespace
from main import main

args = SimpleNamespace(
    config_folder="./config",  # config.yaml 있는 폴더
    data_folder="./data/input_data",   # paper_039.pdf 있는 폴더
    hyper_param_method=None
)

relevance_rag_output = main(args)
# Out:
# ## ./config/config.yaml를 불러왔습니다.
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# Extract-All-Papers : relevance-rag
# #####    1번째 논문    #####
# ##       rag method     : relevance-rag
# ##       Sample Names    : ['NCM622-600', 'NCM622-700', 'NCM622-800']
# ##          Category Name   : CAM (Cathode Active Material)
# ##          ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
# DEBUG: Raw Response: None
#         RELEVANCE CHECK : 응답 생성 실패 (Response is None) -> 'no'로 처리
# DEBUG: Raw Response: None
#         RELEVANCE CHECK : 응답 생성 실패 (Response is None) -> 'no'로 처리
# DEBUG: Raw Response: binary_score='yes'
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_001_output/category-1-paper_001_output-260113201403.json를 저장했습니다.
# {'NCM622-600': {'Stoichiometry information': {'Li ratio': 1.0,
#                                               'Ni ratio': 0.6,
#                                               'Co ratio': 0.2,
#                                               'Mn ratio': 0.2,
#                                               'O ratio': 2.0},
#                 'Commercial NCM used': 'no',
#                 'Lithium source': 'Li2CO3',
#                 'Synthesis method': 'template method',
#                 'Crystallization method': 'Calcination',
#                 'Crystallization final temperature': 600,
#                 'Crystallization final duration (hours)': 12,
#                 'Doping': None,
#                 'Coating': None},
#  'NCM622-700': {'Stoichiometry information': {'Li ratio': 1.0,
#                                               'Ni ratio': 0.6,
#                                               'Co ratio': 0.2,
#                                               'Mn ratio': 0.2,
#                                               'O ratio': 2.0},
#                 'Commercial NCM used': 'no',
#                 'Lithium source': 'Li2CO3',
#                 'Synthesis method': 'template method',
#                 'Crystallization method': 'Calcination',
#                 'Crystallization final temperature': 700,
#                 'Crystallization final duration (hours)': 12,
#                 'Doping': None,
#                 'Coating': None},
#  'NCM622-800': {'Stoichiometry information': {'Li ratio': 1.0,
#                                               'Ni ratio': 0.6,
#                                               'Co ratio': 0.2,
#                                               'Mn ratio': 0.2,
#                                               'O ratio': 2.0},
#                 'Commercial NCM used': 'no',
#                 'Lithium source': 'Li2CO3',
#                 'Synthesis method': 'template method',
#                 'Crystallization method': 'Calcination',
#                 'Crystallization final temperature': 800,
#                 'Crystallization final duration (hours)': 12,
#                 'Doping': None,
#                 'Coating': None}}
# ##          Category Name   : Electrode (half-cell)
# ##          ./config/relevance-rag/c2-question.yaml를 불러왔습니다.
# DEBUG: Raw Response: binary_score='yes'
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_001_output/category-2-paper_001_output-260113201435.json를 저장했습니다.
# {'NCM622-600': {'Active material to Conductive additive to Binder ratio': None,
#                 'Electrolyte': [{'Salt': 'LiPF6',
#                                  'Concentration': '1.2',
#                                  'Solvent': 'EC:EMC',
#                                  'Solvent ratio': '3:7'}],
#                 'Additive': 'VC, 2%',
#                 'Loading density (mass loading of NCM)': '3'},
#  'NCM622-700': {'Active material to Conductive additive to Binder ratio': None,
#                 'Electrolyte': [{'Salt': 'LiPF6',
#                                  'Concentration': '1.2',
#                                  'Solvent': 'EC:EMC',
#                                  'Solvent ratio': '3:7'}],
#                 'Additive': 'VC, 2%',
#                 'Loading density (mass loading of NCM)': '3'},
#  'NCM622-800': {'Active material to Conductive additive to Binder ratio': None,
#                 'Electrolyte': [{'Salt': 'LiPF6',
#                                  'Concentration': '1.2',
#                                  'Solvent': 'EC:EMC',
#                                  'Solvent ratio': '3:7'}],
#                 'Additive': 'VC, 2%',
#                 'Loading density (mass loading of NCM)': '3'}}
# ##          Category Name   : Morphological Properties
# ##          ./config/relevance-rag/c3-question.yaml를 불러왔습니다.
# DEBUG: Raw Response: binary_score='yes'
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_001_output/category-3-paper_001_output-260113201546.json를 저장했습니다.
# {'Particle size': {'NCM622-600': None, 'NCM622-700': None, 'NCM622-800': None},
#  'Particle shape': {'NCM622-600': None,
#                     'NCM622-700': 'distinct hollow multi-shell layer '
#                                   'structure; cubic morphology of the '
#                                   'multi-shell layer',
#                     'NCM622-800': None},
#  'Particle distribution': {'NCM622-600': None,
#                            'NCM622-700': None,
#                            'NCM622-800': None},
#  'Coating layer characteristics': {'NCM622-600': None,
#                                    'NCM622-700': None,
#                                    'NCM622-800': None},
#  'Crystal structure and lattice characteristics': {'NCM622-600': None,
#                                                    'NCM622-700': 'lattice '
#                                                                  'spacing of '
#                                                                  '0.483 nm '
#                                                                  'corresponds '
#                                                                  'to the (003) '
#                                                                  'crystal '
#                                                                  'plane',
#                                                    'NCM622-800': None}}
# ##          Category Name   : Cathode Performance
# ##          ./config/relevance-rag/c4-question.yaml를 불러왔습니다.
# DEBUG: Raw Response: binary_score='yes'
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_001_output/category-4-paper_001_output-260113201801.json를 저장했습니다.
# {'NCM622-600': [{'Voltage range': '2.8-4.3 V',
#                  'Temperature': 25,
#                  'C-rate and Specific capacity': [{'C-rate': '0.1',
#                                                    'Capacity': 190.0},
#                                                   {'C-rate': '0.2',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.5',
#                                                    'Capacity': None},
#                                                   {'C-rate': '1.0',
#                                                    'Capacity': None},
#                                                   {'C-rate': '2.0',
#                                                    'Capacity': None},
#                                                   {'Other C-rates and performance': []}]},
#                 {'Voltage range': '2.8-4.5 V',
#                  'Temperature': 25,
#                  'C-rate and Specific capacity': [{'C-rate': '0.1',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.2',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.5',
#                                                    'Capacity': 139.0},
#                                                   {'C-rate': '1.0',
#                                                    'Capacity': None},
#                                                   {'C-rate': '2.0',
#                                                    'Capacity': None},
#                                                   {'Other C-rates and performance': []}]},
#                 {'Voltage range': None,
#                  'Temperature': 25,
#                  'C-rate and Specific capacity': [{'C-rate': '0.1',
#                                                    'Capacity': 180.7},
#                                                   {'C-rate': '0.2',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.5',
#                                                    'Capacity': None},
#                                                   {'C-rate': '1.0',
#                                                    'Capacity': None},
#                                                   {'C-rate': '2.0',
#                                                    'Capacity': None},
#                                                   {'Other C-rates and performance': []}]}],
#  'NCM622-700': [{'Voltage range': '2.8-4.3 V',
#                  'Temperature': 25,
#                  'C-rate and Specific capacity': [{'C-rate': '0.1',
#                                                    'Capacity': 218.17},
#                                                   {'C-rate': '0.2',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.5',
#                                                    'Capacity': None},
#                                                   {'C-rate': '1.0',
#                                                    'Capacity': None},
#                                                   {'C-rate': '2.0',
#                                                    'Capacity': None},
#                                                   {'Other C-rates and performance': []}]},
#                 {'Voltage range': '2.8-4.5 V',
#                  'Temperature': 25,
#                  'C-rate and Specific capacity': [{'C-rate': '0.1',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.2',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.5',
#                                                    'Capacity': 164.2},
#                                                   {'C-rate': '1.0',
#                                                    'Capacity': None},
#                                                   {'C-rate': '2.0',
#                                                    'Capacity': None},
#                                                   {'Other C-rates and performance': []}]},
#                 {'Voltage range': None,
#                  'Temperature': 25,
#                  'C-rate and Specific capacity': [{'C-rate': '0.1',
#                                                    'Capacity': 206.8},
#                                                   {'C-rate': '0.2',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.5',
#                                                    'Capacity': None},
#                                                   {'C-rate': '1.0',
#                                                    'Capacity': 168.4},
#                                                   {'C-rate': '2.0',
#                                                    'Capacity': None},
#                                                   {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                       'Capacity': 126.1}]}]}],
#  'NCM622-800': [{'Voltage range': '2.8-4.3 V',
#                  'Temperature': 25,
#                  'C-rate and Specific capacity': [{'C-rate': '0.1',
#                                                    'Capacity': 204.39},
#                                                   {'C-rate': '0.2',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.5',
#                                                    'Capacity': None},
#                                                   {'C-rate': '1.0',
#                                                    'Capacity': None},
#                                                   {'C-rate': '2.0',
#                                                    'Capacity': None},
#                                                   {'Other C-rates and performance': []}]},
#                 {'Voltage range': '2.8-4.5 V',
#                  'Temperature': 25,
#                  'C-rate and Specific capacity': [{'C-rate': '0.1',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.2',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.5',
#                                                    'Capacity': 151.3},
#                                                   {'C-rate': '1.0',
#                                                    'Capacity': None},
#                                                   {'C-rate': '2.0',
#                                                    'Capacity': None},
#                                                   {'Other C-rates and performance': []}]},
#                 {'Voltage range': None,
#                  'Temperature': 25,
#                  'C-rate and Specific capacity': [{'C-rate': '0.1',
#                                                    'Capacity': 195.3},
#                                                   {'C-rate': '0.2',
#                                                    'Capacity': None},
#                                                   {'C-rate': '0.5',
#                                                    'Capacity': None},
#                                                   {'C-rate': '1.0',
#                                                    'Capacity': None},
#                                                   {'C-rate': '2.0',
#                                                    'Capacity': None},
#                                                   {'Other C-rates and performance': []}]}]}
# 코드 실행 시간: 405.3022 초
