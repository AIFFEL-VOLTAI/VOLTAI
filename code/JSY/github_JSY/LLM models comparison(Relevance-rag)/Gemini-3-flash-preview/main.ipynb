# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
import os

os.environ["LANGCHAIN_API_KEY"] = ""
os.environ["LANGSMITH_API_KEY"] = os.environ["LANGCHAIN_API_KEY"]
os.environ["LANGCHAIN_ENDPOINT"] = ""
os.environ["OPENAI_API_KEY"] = ""
os.environ["GOOGLE_API_KEY"] = ""

# %%
import os
import google.generativeai as genai
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from pprint import pprint

from langchain_teddynote import logging
from models import sample_name_searcher, get_rag_instance

from utils import save_output2json
from prompt import load_system_prompt, load_invoke_input

# %%
# .env 파일 로드
#load_dotenv(dotenv_path=".env")

# API 키 가져오기
#OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
#LANGCHAIN_API_KEY = os.getenv("LANGCHAIN_API_KEY")

# LangSmith 추적 기능을 활성화합니다. (선택적)
os.environ["LANGCHAIN_TRACING_V2"] = "true"

# %%
from main import main

# %%
from types import SimpleNamespace
from main import main

args = SimpleNamespace(
    config_folder="./config",  # config.yaml 있는 폴더
    data_folder="./data/input_data",   # paper_039.pdf 있는 폴더
    hyper_param_method=None
)

relevance_rag_output = main(args)
# Out:
# ## ./config/config.yaml를 불러왔습니다.
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# Extract-All-Papers : relevance-rag
# #####    56번째 논문    #####
# ##       rag method     : relevance-rag
# ##       Sample Names    : ['pristine NCM', 'M-NCM', 'MP-NCM']
# ##          Category Name   : CAM (Cathode Active Material)
# ##          ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_056_output/category-1-paper_056_output-251223172722.json를 저장했습니다.
# {'pristine NCM': {'Stoichiometry information': {'Li ratio': 1.05,
#                                                 'Ni ratio': 0.8,
#                                                 'Co ratio': 0.1,
#                                                 'Mn ratio': 0.1,
#                                                 'O ratio': 2.0},
#                   'Commercial NCM used': 'no',
#                   'Lithium source': 'LiOH',
#                   'Synthesis method': 'co-precipitation',
#                   'Crystallization method': 'sintering',
#                   'Crystallization final temperature': 750,
#                   'Crystallization final duration (hours)': 15,
#                   'Doping': None,
#                   'Coating': None},
#  'M-NCM': {'Stoichiometry information': {'Li ratio': 1.05,
#                                          'Ni ratio': 0.8,
#                                          'Co ratio': 0.1,
#                                          'Mn ratio': 0.1,
#                                          'O ratio': 2.0},
#            'Commercial NCM used': 'no',
#            'Lithium source': 'LiOH',
#            'Synthesis method': 'blending',
#            'Crystallization method': 'sintering',
#            'Crystallization final temperature': 750,
#            'Crystallization final duration (hours)': 15,
#            'Doping': 'Mg',
#            'Coating': 'Li3PO4'},
#  'MP-NCM': {'Stoichiometry information': {'Li ratio': 1.05,
#                                           'Ni ratio': 0.8,
#                                           'Co ratio': 0.1,
#                                           'Mn ratio': 0.1,
#                                           'O ratio': 2.0},
#             'Commercial NCM used': 'no',
#             'Lithium source': 'LiOH',
#             'Synthesis method': 'blending',
#             'Crystallization method': 'sintering',
#             'Crystallization final temperature': 750,
#             'Crystallization final duration (hours)': 15,
#             'Doping': 'Mg',
#             'Coating': 'Li3PO4'}}
# ##          Category Name   : Electrode (half-cell)
# ##          ./config/relevance-rag/c2-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_056_output/category-2-paper_056_output-251223172748.json를 저장했습니다.
# {'pristine NCM': {'Active material to Conductive additive to Binder ratio': '96:2:2',
#                   'Electrolyte': [{'Salt': 'LiPF6',
#                                    'Concentration': '1',
#                                    'Solvent': 'DMC:EC:EMC',
#                                    'Solvent ratio': '1:1:1'}],
#                   'Additive': None,
#                   'Loading density (mass loading of NCM)': None},
#  'M-NCM': {'Active material to Conductive additive to Binder ratio': '96:2:2',
#            'Electrolyte': [{'Salt': 'LiPF6',
#                             'Concentration': '1',
#                             'Solvent': 'DMC:EC:EMC',
#                             'Solvent ratio': '1:1:1'}],
#            'Additive': None,
#            'Loading density (mass loading of NCM)': None},
#  'MP-NCM': {'Active material to Conductive additive to Binder ratio': '96:2:2',
#             'Electrolyte': [{'Salt': 'LiPF6',
#                              'Concentration': '1',
#                              'Solvent': 'DMC:EC:EMC',
#                              'Solvent ratio': '1:1:1'}],
#             'Additive': None,
#             'Loading density (mass loading of NCM)': None}}
# ##          Category Name   : Morphological Properties
# ##          ./config/relevance-rag/c3-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_056_output/category-3-paper_056_output-251223172913.json를 저장했습니다.
# {'Particle size': {'pristine NCM': 'secondary particles are about 11.7 μm, '
#                                    'primary particles have average diameters '
#                                    'of 170 to 230 nm',
#                    'M-NCM': 'secondary particles are about 11.7 μm, primary '
#                             'particles have average diameters of 170 to 230 nm',
#                    'MP-NCM': None},
#  'Particle shape': {'pristine NCM': 'spherical secondary particles, damaged by '
#                                     'intergranular cracking along the grain '
#                                     'boundaries',
#                     'M-NCM': 'spherical secondary particles',
#                     'MP-NCM': 'mechanical integrity without any cracks or '
#                               'defects'},
#  'Particle distribution': {'pristine NCM': 'composed of primary particles',
#                            'M-NCM': 'composed of primary particles',
#                            'MP-NCM': None},
#  'Coating layer characteristics': {'pristine NCM': None,
#                                    'M-NCM': 'thin Li3PO4 coating layer with '
#                                             'about 1.8 nm thickness',
#                                    'MP-NCM': None},
#  'Crystal structure and lattice characteristics': {'pristine NCM': None,
#                                                    'M-NCM': None,
#                                                    'MP-NCM': None}}
# ##          Category Name   : Cathode Performance
# ##          ./config/relevance-rag/c4-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_056_output/category-4-paper_056_output-251223172957.json를 저장했습니다.
# {'pristine NCM': [{'Voltage range': '3.0-4.3',
#                    'Temperature': 25,
#                    'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                      'Capacity': 199.1},
#                                                     {'C-rate': 0.2,
#                                                      'Capacity': None},
#                                                     {'C-rate': 0.5,
#                                                      'Capacity': 199.3},
#                                                     {'C-rate': 1.0,
#                                                      'Capacity': None},
#                                                     {'C-rate': 2.0,
#                                                      'Capacity': None},
#                                                     {'Other C-rates and performance': [{'C-rate': 4.0,
#                                                                                         'Capacity': 169.8},
#                                                                                        {'C-rate': 5.0,
#                                                                                         'Capacity': 159.0},
#                                                                                        {'C-rate': 6.0,
#                                                                                         'Capacity': 151.3}]}]}],
#  'M-NCM': [{'Voltage range': '3.0-4.3',
#             'Temperature': 25,
#             'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 203.5},
#                                              {'C-rate': 0.2, 'Capacity': None},
#                                              {'C-rate': 0.5, 'Capacity': 202.2},
#                                              {'C-rate': 1.0, 'Capacity': None},
#                                              {'C-rate': 2.0, 'Capacity': None},
#                                              {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                  'Capacity': 180.0},
#                                                                                 {'C-rate': 6.0,
#                                                                                  'Capacity': 168.9}]}]}],
#  'MP-NCM': [{'Voltage range': None,
#              'Temperature': None,
#              'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None},
#                                               {'C-rate': 0.2, 'Capacity': None},
#                                               {'C-rate': 0.5, 'Capacity': None},
#                                               {'C-rate': 1.0, 'Capacity': None},
#                                               {'C-rate': 2.0, 'Capacity': None},
#                                               {'Other C-rates and performance': [{'C-rate': None,
#                                                                                   'Capacity': None}]}]}]}
# 코드 실행 시간: 229.7288 초
