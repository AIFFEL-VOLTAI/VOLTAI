# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
import os

os.environ["LANGCHAIN_API_KEY"] = ""
os.environ["LANGSMITH_API_KEY"] = os.environ["LANGCHAIN_API_KEY"]
os.environ["LANGCHAIN_ENDPOINT"] = ""
os.environ["OPENAI_API_KEY"] = ""  # Replace with your actual OpenAI API key
os.environ["GOOGLE_API_KEY"] = ""

# %%
import os
import google.generativeai as genai
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from pprint import pprint

from langchain_teddynote import logging
from models import sample_name_searcher, get_rag_instance

from utils import save_output2json
from prompt import load_system_prompt, load_invoke_input

# %%
# .env 파일 로드
#load_dotenv(dotenv_path=".env")

# API 키 가져오기
#OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
#LANGCHAIN_API_KEY = os.getenv("LANGCHAIN_API_KEY")

# LangSmith 추적 기능을 활성화합니다. (선택적)
os.environ["LANGCHAIN_TRACING_V2"] = "true"

# %%
from main import main

# %%
from types import SimpleNamespace
from main import main

args = SimpleNamespace(
    config_folder="./config",  # config.yaml 있는 폴더
    data_folder="./data/input_data",   # paper_039.pdf 있는 폴더
    hyper_param_method=None
)

relevance_rag_output = main(args)
# Out:
# ## ./config/config.yaml를 불러왔습니다.
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# Extract-All-Papers : relevance-rag
# #####    11번째 논문    #####
# ##       rag method     : relevance-rag
# ##       Sample Names    : ['NR0', 'NR1', 'NR3', 'NR5']
# ##          Category Name   : CAM (Cathode Active Material)
# ##          ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_011_output/category-1-paper_011_output-260303182258.json를 저장했습니다.
# {'NR0': {'Stoichiometry information': {'Li ratio': 1,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2},
#          'Commercial NCM used': 'no',
#          'Lithium source': 'lithium nitrate',
#          'Synthesis method': 'solution combustion',
#          'Crystallization method': 'calcination',
#          'Crystallization final temperature': 850,
#          'Crystallization final duration (hours)': 15,
#          'Doping': None,
#          'Coating': None},
#  'NR1': {'Stoichiometry information': {'Li ratio': 1,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2},
#          'Commercial NCM used': 'no',
#          'Lithium source': 'lithium nitrate',
#          'Synthesis method': 'solution combustion',
#          'Crystallization method': 'calcination',
#          'Crystallization final temperature': 850,
#          'Crystallization final duration (hours)': 15,
#          'Doping': None,
#          'Coating': 'Reduced graphene oxide'},
#  'NR3': {'Stoichiometry information': {'Li ratio': 1,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2},
#          'Commercial NCM used': 'no',
#          'Lithium source': 'lithium nitrate',
#          'Synthesis method': 'solution combustion',
#          'Crystallization method': 'calcination',
#          'Crystallization final temperature': 850,
#          'Crystallization final duration (hours)': 15,
#          'Doping': None,
#          'Coating': 'Reduced graphene oxide'},
#  'NR5': {'Stoichiometry information': {'Li ratio': 1,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2},
#          'Commercial NCM used': 'no',
#          'Lithium source': 'lithium nitrate',
#          'Synthesis method': 'solution combustion',
#          'Crystallization method': 'calcination',
#          'Crystallization final temperature': 850,
#          'Crystallization final duration (hours)': 15,
#          'Doping': None,
#          'Coating': 'Reduced graphene oxide'}}
# ##          Category Name   : Electrode (half-cell)
# ##          ./config/relevance-rag/c2-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_011_output/category-2-paper_011_output-260303182436.json를 저장했습니다.
# {'NR0': {'Active material to Conductive additive to Binder ratio': None,
#          'Electrolyte': [{'Salt': 'LiPF6',
#                           'Concentration': '1',
#                           'Solvent': 'EC:DMC',
#                           'Solvent ratio': '1:1'}],
#          'Additive': None,
#          'Loading density (mass loading of NCM)': None},
#  'NR1': {'Active material to Conductive additive to Binder ratio': None,
#          'Electrolyte': [{'Salt': 'LiPF6',
#                           'Concentration': '1',
#                           'Solvent': 'EC:DMC',
#                           'Solvent ratio': '1:1'}],
#          'Additive': None,
#          'Loading density (mass loading of NCM)': None},
#  'NR3': {'Active material to Conductive additive to Binder ratio': None,
#          'Electrolyte': [{'Salt': 'LiPF6',
#                           'Concentration': '1',
#                           'Solvent': 'EC:DMC',
#                           'Solvent ratio': '1:1'}],
#          'Additive': None,
#          'Loading density (mass loading of NCM)': None},
#  'NR5': {'Active material to Conductive additive to Binder ratio': None,
#          'Electrolyte': [{'Salt': 'LiPF6',
#                           'Concentration': '1',
#                           'Solvent': 'EC:DMC',
#                           'Solvent ratio': '1:1'}],
#          'Additive': None,
#          'Loading density (mass loading of NCM)': None}}
# ##          Category Name   : Morphological Properties
# ##          ./config/relevance-rag/c3-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_011_output/category-3-paper_011_output-260303182739.json를 저장했습니다.
# {'Particle size': {'NR0': '200e300 nm', 'NR1': None, 'NR3': None, 'NR5': None},
#  'Particle shape': {'NR0': 'faceted morphology; regular polyhedrons with '
#                            'smooth surfaces',
#                     'NR1': None,
#                     'NR3': None,
#                     'NR5': None},
#  'Particle distribution': {'NR0': 'uniform distribution of the particle size '
#                                   'with no significant agglomeration',
#                            'NR1': None,
#                            'NR3': None,
#                            'NR5': None},
#  'Coating layer characteristics': {'NR0': None,
#                                    'NR1': None,
#                                    'NR3': None,
#                                    'NR5': None},
#  'Crystal structure and lattice characteristics': {'NR0': None,
#                                                    'NR1': None,
#                                                    'NR3': None,
#                                                    'NR5': None}}
# ##          Category Name   : Cathode Performance
# ##          ./config/relevance-rag/c4-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_011_output/category-4-paper_011_output-260303182953.json를 저장했습니다.
# {'NR0': [{'Voltage range': '2.5-4.3',
#           'Temperature': 25,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 155.3},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': None},
#                                            {'C-rate': 1.0, 'Capacity': 123},
#                                            {'C-rate': 2.0, 'Capacity': None},
#                                            {'Other C-rates and performance': [{'C-rate': 0.05,
#                                                                                'Capacity': 167.64},
#                                                                               {'C-rate': 5.0,
#                                                                                'Capacity': 45.5}]}]}],
#  'NR1': [{'Voltage range': '2.5-4.3',
#           'Temperature': 25,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 154.6},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': None},
#                                            {'C-rate': 1.0, 'Capacity': None},
#                                            {'C-rate': 2.0, 'Capacity': None},
#                                            {'Other C-rates and performance': [{'C-rate': 0.05,
#                                                                                'Capacity': 169.21},
#                                                                               {'C-rate': 5.0,
#                                                                                'Capacity': 47.0}]}]}],
#  'NR3': [{'Voltage range': '2.5-4.3',
#           'Temperature': 25,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 166.5},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': None},
#                                            {'C-rate': 1.0, 'Capacity': None},
#                                            {'C-rate': 2.0, 'Capacity': None},
#                                            {'Other C-rates and performance': [{'C-rate': 0.05,
#                                                                                'Capacity': 172.46},
#                                                                               {'C-rate': 5.0,
#                                                                                'Capacity': 75.4}]}]}],
#  'NR5': [{'Voltage range': '2.5-4.3',
#           'Temperature': 25,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 175},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': None},
#                                            {'C-rate': 1.0, 'Capacity': None},
#                                            {'C-rate': 2.0, 'Capacity': None},
#                                            {'Other C-rates and performance': [{'C-rate': 0.05,
#                                                                                'Capacity': 186.64},
#                                                                               {'C-rate': 5.0,
#                                                                                'Capacity': 95.4}]}]}]}
# #####    16번째 논문    #####
# ##       rag method     : relevance-rag
# ##       Sample Names    : ['NCM', 'NCM/C']
# ##          Category Name   : CAM (Cathode Active Material)
# ##          ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_016_output/category-1-paper_016_output-260303183149.json를 저장했습니다.
# {'NCM': {'Stoichiometry information': {'Li ratio': 1.01,
#                                        'Ni ratio': 0.35,
#                                        'Co ratio': 0.32,
#                                        'Mn ratio': 0.32},
#          'Commercial NCM used': 'no',
#          'Lithium source': 'LiAc',
#          'Synthesis method': 'sol-gel',
#          'Crystallization method': 'heat-treated',
#          'Crystallization final temperature': 850,
#          'Crystallization final duration (hours)': 10,
#          'Doping': None,
#          'Coating': None},
#  'NCM/C': {'Stoichiometry information': {'Li ratio': 1.03,
#                                          'Ni ratio': 0.32,
#                                          'Co ratio': 0.33,
#                                          'Mn ratio': 0.34},
#            'Commercial NCM used': 'no',
#            'Lithium source': 'LiAc',
#            'Synthesis method': 'one-step method',
#            'Crystallization method': 'sintered',
#            'Crystallization final temperature': 850,
#            'Crystallization final duration (hours)': 10,
#            'Doping': None,
#            'Coating': 'Carbon'}}
# ##          Category Name   : Electrode (half-cell)
# ##          ./config/relevance-rag/c2-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_016_output/category-2-paper_016_output-260303183321.json를 저장했습니다.
# {'NCM': {'Active material to Conductive additive to Binder ratio': '80:15:5',
#          'Electrolyte': [{'Salt': 'LiPF6',
#                           'Concentration': '1',
#                           'Solvent': 'EC:DMC',
#                           'Solvent ratio': '1:1'}],
#          'Additive': None,
#          'Loading density (mass loading of NCM)': '5'},
#  'NCM/C': {'Active material to Conductive additive to Binder ratio': '80:15:5',
#            'Electrolyte': [{'Salt': 'LiPF6',
#                             'Concentration': '1',
#                             'Solvent': 'EC:DMC',
#                             'Solvent ratio': '1:1'}],
#            'Additive': None,
#            'Loading density (mass loading of NCM)': '5'}}
# ##          Category Name   : Morphological Properties
# ##          ./config/relevance-rag/c3-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_016_output/category-3-paper_016_output-260303183443.json를 저장했습니다.
# {'Particle size': {'NCM': 'range from 50 to 200 nm',
#                    'NCM/C': 'diameter of about 150 nm'},
#  'Particle shape': {'NCM': 'irregular particle shape',
#                     'NCM/C': 'irregular particle shape'},
#  'Particle distribution': {'NCM': 'almost every particle in NCM can be '
#                                   'identified clearly',
#                            'NCM/C': 'particles aggregating together'},
#  'Coating layer characteristics': {'NCM': None,
#                                    'NCM/C': 'homogeneously coated by carbon '
#                                             'with a thickness about 10 nm'},
#  'Crystal structure and lattice characteristics': {'NCM': None, 'NCM/C': None}}
# ##          Category Name   : Cathode Performance
# ##          ./config/relevance-rag/c4-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_016_output/category-4-paper_016_output-260303183616.json를 저장했습니다.
# {'NCM': [{'Voltage range': '2.5-4.5',
#           'Temperature': 30,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': 175.7},
#                                            {'C-rate': 1.0, 'Capacity': 154.8},
#                                            {'C-rate': 2.0, 'Capacity': 143.5},
#                                            {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                'Capacity': 101.7},
#                                                                               {'C-rate': 10.0,
#                                                                                'Capacity': 71.5},
#                                                                               {'C-rate': 20.0,
#                                                                                'Capacity': 44.5},
#                                                                               {'C-rate': 40.0,
#                                                                                'Capacity': 13.2}]}]}],
#  'NCM/C': [{'Voltage range': '2.5-4.5',
#             'Temperature': 30,
#             'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None},
#                                              {'C-rate': 0.2, 'Capacity': None},
#                                              {'C-rate': 0.5, 'Capacity': 191.2},
#                                              {'C-rate': 1.0, 'Capacity': 178.9},
#                                              {'C-rate': 2.0, 'Capacity': 163.5},
#                                              {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                  'Capacity': 135.8},
#                                                                                 {'C-rate': 10.0,
#                                                                                  'Capacity': 109.4},
#                                                                                 {'C-rate': 20.0,
#                                                                                  'Capacity': 81.9},
#                                                                                 {'C-rate': 40.0,
#                                                                                  'Capacity': 54.6}]}]}]}
# #####    22번째 논문    #####
# ##       rag method     : relevance-rag
# ##       Sample Names    : ['Pristine', 'V-0.005', 'V-0.01', 'V-0.02']
# ##          Category Name   : CAM (Cathode Active Material)
# ##          ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_022_output/category-1-paper_022_output-260303183855.json를 저장했습니다.
# {'Pristine': {'Stoichiometry information': {'Li ratio': 1.0,
#                                             'Ni ratio': 0.84,
#                                             'Co ratio': 0.1,
#                                             'Mn ratio': 0.06,
#                                             'O ratio': 2.0},
#               'Commercial NCM used': 'no',
#               'Lithium source': 'LiOH',
#               'Synthesis method': 'solid-state reaction',
#               'Crystallization method': None,
#               'Crystallization final temperature': 760,
#               'Crystallization final duration (hours)': 15,
#               'Doping': None,
#               'Coating': None},
#  'V-0.005': {'Stoichiometry information': {'Li ratio': 1.0,
#                                            'Ni ratio': 0.84,
#                                            'Co ratio': 0.1,
#                                            'Mn ratio': 0.06,
#                                            'O ratio': 2.0},
#              'Commercial NCM used': 'no',
#              'Lithium source': 'LiOH',
#              'Synthesis method': 'solid-state reaction',
#              'Crystallization method': None,
#              'Crystallization final temperature': 760,
#              'Crystallization final duration (hours)': 15,
#              'Doping': 'V',
#              'Coating': None},
#  'V-0.01': {'Stoichiometry information': {'Li ratio': 1.0,
#                                           'Ni ratio': 0.84,
#                                           'Co ratio': 0.1,
#                                           'Mn ratio': 0.06,
#                                           'O ratio': 2.0},
#             'Commercial NCM used': 'no',
#             'Lithium source': 'LiOH',
#             'Synthesis method': 'solid-state reaction',
#             'Crystallization method': None,
#             'Crystallization final temperature': 760,
#             'Crystallization final duration (hours)': 15,
#             'Doping': 'V',
#             'Coating': None},
#  'V-0.02': {'Stoichiometry information': {'Li ratio': 1.0,
#                                           'Ni ratio': 0.84,
#                                           'Co ratio': 0.1,
#                                           'Mn ratio': 0.06,
#                                           'O ratio': 2.0},
#             'Commercial NCM used': 'no',
#             'Lithium source': 'LiOH',
#             'Synthesis method': 'solid-state reaction',
#             'Crystallization method': None,
#             'Crystallization final temperature': 760,
#             'Crystallization final duration (hours)': 15,
#             'Doping': 'V',
#             'Coating': None}}
# ##          Category Name   : Electrode (half-cell)
# ##          ./config/relevance-rag/c2-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_022_output/category-2-paper_022_output-260303183954.json를 저장했습니다.
# {'Pristine': {'Active material to Conductive additive to Binder ratio': '96:2:2',
#               'Electrolyte': [{'Salt': 'LiPF6',
#                                'Concentration': '1',
#                                'Solvent': 'EC:DMC:EMC',
#                                'Solvent ratio': '1:1:1'}],
#               'Additive': None,
#               'Loading density (mass loading of NCM)': '14.5'},
#  'V-0.005': {'Active material to Conductive additive to Binder ratio': '96:2:2',
#              'Electrolyte': [{'Salt': 'LiPF6',
#                               'Concentration': '1',
#                               'Solvent': 'EC:DMC:EMC',
#                               'Solvent ratio': '1:1:1'}],
#              'Additive': None,
#              'Loading density (mass loading of NCM)': '14.5'},
#  'V-0.01': {'Active material to Conductive additive to Binder ratio': '96:2:2',
#             'Electrolyte': [{'Salt': 'LiPF6',
#                              'Concentration': '1',
#                              'Solvent': 'EC:DMC:EMC',
#                              'Solvent ratio': '1:1:1'}],
#             'Additive': None,
#             'Loading density (mass loading of NCM)': '14.5'},
#  'V-0.02': {'Active material to Conductive additive to Binder ratio': '96:2:2',
#             'Electrolyte': [{'Salt': 'LiPF6',
#                              'Concentration': '1',
#                              'Solvent': 'EC:DMC:EMC',
#                              'Solvent ratio': '1:1:1'}],
#             'Additive': None,
#             'Loading density (mass loading of NCM)': '14.5'}}
# ##          Category Name   : Morphological Properties
# ##          ./config/relevance-rag/c3-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_022_output/category-3-paper_022_output-260303184056.json를 저장했습니다.
# {'Particle size': {'Pristine': 'primary particles have similar size (500 nm)',
#                    'V-0.005': 'primary particles have similar size (500 nm)',
#                    'V-0.01': 'primary particles have similar size (500 nm)',
#                    'V-0.02': 'primary particles have similar size (500 nm)'},
#  'Particle shape': {'Pristine': 'spherical morphology',
#                     'V-0.005': 'spherical morphology',
#                     'V-0.01': 'spherical morphology',
#                     'V-0.02': 'spherical morphology'},
#  'Particle distribution': {'Pristine': 'composed of numerous primary particles',
#                            'V-0.005': 'composed of numerous primary particles',
#                            'V-0.01': 'composed of numerous primary particles',
#                            'V-0.02': 'composed of numerous primary particles'},
#  'Coating layer characteristics': {'Pristine': None,
#                                    'V-0.005': None,
#                                    'V-0.01': None,
#                                    'V-0.02': None},
#  'Crystal structure and lattice characteristics': {'Pristine': None,
#                                                    'V-0.005': None,
#                                                    'V-0.01': None,
#                                                    'V-0.02': None}}
# ##          Category Name   : Cathode Performance
# ##          ./config/relevance-rag/c4-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_022_output/category-4-paper_022_output-260303184250.json를 저장했습니다.
# {'Pristine': [{'Voltage range': '3.0–4.3',
#                'Temperature': 25,
#                'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                  'Capacity': 204.6},
#                                                 {'C-rate': 0.2,
#                                                  'Capacity': None},
#                                                 {'C-rate': 0.5,
#                                                  'Capacity': None},
#                                                 {'C-rate': 1.0,
#                                                  'Capacity': None},
#                                                 {'C-rate': 2.0,
#                                                  'Capacity': None},
#                                                 {'Other C-rates and performance': []}]}],
#  'V-0.005': [{'Voltage range': '3.0–4.3',
#               'Temperature': 25,
#               'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                 'Capacity': 204.4},
#                                                {'C-rate': 0.2,
#                                                 'Capacity': None},
#                                                {'C-rate': 0.5,
#                                                 'Capacity': None},
#                                                {'C-rate': 1.0,
#                                                 'Capacity': None},
#                                                {'C-rate': 2.0,
#                                                 'Capacity': None},
#                                                {'Other C-rates and performance': []}]}],
#  'V-0.01': [{'Voltage range': '3.0–4.3',
#              'Temperature': 25,
#              'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                'Capacity': 203.9},
#                                               {'C-rate': 0.2, 'Capacity': None},
#                                               {'C-rate': 0.5, 'Capacity': None},
#                                               {'C-rate': 1.0, 'Capacity': None},
#                                               {'C-rate': 2.0, 'Capacity': None},
#                                               {'Other C-rates and performance': []}]}],
#  'V-0.02': [{'Voltage range': '3.0–4.3',
#              'Temperature': 25,
#              'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                'Capacity': 200.9},
#                                               {'C-rate': 0.2, 'Capacity': None},
#                                               {'C-rate': 0.5, 'Capacity': None},
#                                               {'C-rate': 1.0, 'Capacity': None},
#                                               {'C-rate': 2.0, 'Capacity': None},
#                                               {'Other C-rates and performance': []}]}]}
# #####    35번째 논문    #####
# ##       rag method     : relevance-rag
# ##       Sample Names    : ['S1bare', 'S2wash', 'S3coat']
# ##          Category Name   : CAM (Cathode Active Material)
# ##          ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_035_output/category-1-paper_035_output-260303184505.json를 저장했습니다.
# {'S1bare': {'Stoichiometry information': {'Li ratio': 1.0,
#                                           'Ni ratio': 0.85,
#                                           'Co ratio': 0.1,
#                                           'Mn ratio': 0.05,
#                                           'O ratio': 2.0},
#             'Commercial NCM used': 'no',
#             'Lithium source': 'LiOH',
#             'Synthesis method': 'coprecipitation',
#             'Crystallization method': 'Heat treatment',
#             'Crystallization final temperature': 750,
#             'Crystallization final duration (hours)': 12,
#             'Doping': None,
#             'Coating': None},
#  'S2wash': {'Stoichiometry information': {'Li ratio': 1.0,
#                                           'Ni ratio': 0.85,
#                                           'Co ratio': 0.1,
#                                           'Mn ratio': 0.05,
#                                           'O ratio': 2.0},
#             'Commercial NCM used': 'no',
#             'Lithium source': 'LiOH',
#             'Synthesis method': 'coprecipitation',
#             'Crystallization method': 'Heat treatment',
#             'Crystallization final temperature': 750,
#             'Crystallization final duration (hours)': 12,
#             'Doping': None,
#             'Coating': None},
#  'S3coat': {'Stoichiometry information': {'Li ratio': 1.0,
#                                           'Ni ratio': 0.85,
#                                           'Co ratio': 0.1,
#                                           'Mn ratio': 0.05,
#                                           'O ratio': 2.0},
#             'Commercial NCM used': 'no',
#             'Lithium source': 'LiOH',
#             'Synthesis method': 'coprecipitation',
#             'Crystallization method': 'Heat treatment',
#             'Crystallization final temperature': 750,
#             'Crystallization final duration (hours)': 12,
#             'Doping': None,
#             'Coating': 'H3BO3'}}
# ##          Category Name   : Electrode (half-cell)
# ##          ./config/relevance-rag/c2-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_035_output/category-2-paper_035_output-260303184629.json를 저장했습니다.
# {'S1bare': {'Active material to Conductive additive to Binder ratio': '96.5:1.5:2',
#             'Electrolyte': [{'Salt': 'LiPF6',
#                              'Concentration': '1',
#                              'Solvent': 'EC:DMC',
#                              'Solvent ratio': '1:1'}],
#             'Additive': None,
#             'Loading density (mass loading of NCM)': '12'},
#  'S2wash': {'Active material to Conductive additive to Binder ratio': '96.5:1.5:2',
#             'Electrolyte': [{'Salt': 'LiPF6',
#                              'Concentration': '1',
#                              'Solvent': 'EC:DMC',
#                              'Solvent ratio': '1:1'}],
#             'Additive': None,
#             'Loading density (mass loading of NCM)': '12'},
#  'S3coat': {'Active material to Conductive additive to Binder ratio': '96.5:1.5:2',
#             'Electrolyte': [{'Salt': 'LiPF6',
#                              'Concentration': '1',
#                              'Solvent': 'EC:DMC',
#                              'Solvent ratio': '1:1'}],
#             'Additive': None,
#             'Loading density (mass loading of NCM)': '12'}}
# ##          Category Name   : Morphological Properties
# ##          ./config/relevance-rag/c3-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_035_output/category-3-paper_035_output-260303184847.json를 저장했습니다.
# {'Particle size': {'S1bare': 'agglomerates ∼ 20 μm in size formed by clusters '
#                              'of crystallites ∼ 0.3 – 0.5 μm in size',
#                    'S2wash': None,
#                    'S3coat': None},
#  'Particle shape': {'S1bare': 'globular agglomerates; spherical agglomerates',
#                     'S2wash': None,
#                     'S3coat': None},
#  'Particle distribution': {'S1bare': 'formed by clusters of crystallites; '
#                                      'fairly dense packing of crystallites',
#                            'S2wash': None,
#                            'S3coat': None},
#  'Coating layer characteristics': {'S1bare': None,
#                                    'S2wash': None,
#                                    'S3coat': None},
#  'Crystal structure and lattice characteristics': {'S1bare': None,
#                                                    'S2wash': None,
#                                                    'S3coat': None}}
# ##          Category Name   : Cathode Performance
# ##          ./config/relevance-rag/c4-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_035_output/category-4-paper_035_output-260303185122.json를 저장했습니다.
# {'S1bare': [{'Voltage range': '3.0-4.3',
#              'Temperature': None,
#              'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None},
#                                               {'C-rate': 0.2, 'Capacity': None},
#                                               {'C-rate': 0.5, 'Capacity': None},
#                                               {'C-rate': 1.0, 'Capacity': None},
#                                               {'C-rate': 2.0, 'Capacity': None},
#                                               {'Other C-rates and performance': []}]}],
#  'S2wash': [{'Voltage range': '3.0-4.3',
#              'Temperature': None,
#              'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None},
#                                               {'C-rate': 0.2, 'Capacity': None},
#                                               {'C-rate': 0.5, 'Capacity': None},
#                                               {'C-rate': 1.0, 'Capacity': None},
#                                               {'C-rate': 2.0, 'Capacity': None},
#                                               {'Other C-rates and performance': []}]}],
#  'S3coat': [{'Voltage range': '3.0-4.3',
#              'Temperature': None,
#              'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None},
#                                               {'C-rate': 0.2, 'Capacity': None},
#                                               {'C-rate': 0.5, 'Capacity': None},
#                                               {'C-rate': 1.0, 'Capacity': None},
#                                               {'C-rate': 2.0, 'Capacity': None},
#                                               {'Other C-rates and performance': []}]}]}
# #####    39번째 논문    #####
# ##       rag method     : relevance-rag
# ##       Sample Names    : ['N92', 'WN92']
# ##          Category Name   : CAM (Cathode Active Material)
# ##          ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_039_output/category-1-paper_039_output-260303185423.json를 저장했습니다.
# {'N92': {'Stoichiometry information': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.92,
#                                        'Co ratio': 0.04,
#                                        'Mn ratio': 0.04,
#                                        'O ratio': 2.0},
#          'Commercial NCM used': 'no',
#          'Lithium source': 'LiOH',
#          'Synthesis method': 'solid-phase method',
#          'Crystallization method': 'calcination',
#          'Crystallization final temperature': 780,
#          'Crystallization final duration (hours)': 10,
#          'Doping': None,
#          'Coating': None},
#  'WN92': {'Stoichiometry information': {'Li ratio': 1.0,
#                                         'Ni ratio': 0.91,
#                                         'Co ratio': 0.04,
#                                         'Mn ratio': 0.04,
#                                         'W ratio': 0.01,
#                                         'O ratio': 2.0},
#           'Commercial NCM used': 'no',
#           'Lithium source': 'LiOH',
#           'Synthesis method': 'solid-phase method',
#           'Crystallization method': 'calcination',
#           'Crystallization final temperature': 780,
#           'Crystallization final duration (hours)': 10,
#           'Doping': 'W',
#           'Coating': None}}
# ##          Category Name   : Electrode (half-cell)
# ##          ./config/relevance-rag/c2-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_039_output/category-2-paper_039_output-260303185607.json를 저장했습니다.
# {'N92': {'Active material to Conductive additive to Binder ratio': '8:1:1',
#          'Electrolyte': [{'Salt': None,
#                           'Concentration': None,
#                           'Solvent': None,
#                           'Solvent ratio': None}],
#          'Additive': None,
#          'Loading density (mass loading of NCM)': None},
#  'WN92': {'Active material to Conductive additive to Binder ratio': '8:1:1',
#           'Electrolyte': [{'Salt': None,
#                            'Concentration': None,
#                            'Solvent': None,
#                            'Solvent ratio': None}],
#           'Additive': None,
#           'Loading density (mass loading of NCM)': None}}
# ##          Category Name   : Morphological Properties
# ##          ./config/relevance-rag/c3-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_039_output/category-3-paper_039_output-260303185746.json를 저장했습니다.
# {'Particle size': {'N92': None, 'WN92': None},
#  'Particle shape': {'N92': 'granular particles', 'WN92': 'granular particles'},
#  'Particle distribution': {'N92': None, 'WN92': None},
#  'Coating layer characteristics': {'N92': None, 'WN92': None},
#  'Crystal structure and lattice characteristics': {'N92': None,
#                                                    'WN92': 'retrieved into the '
#                                                            'NCM-layered '
#                                                            'structure with a '
#                                                            'space group of '
#                                                            'R-3m'}}
# ##          Category Name   : Cathode Performance
# ##          ./config/relevance-rag/c4-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_039_output/category-4-paper_039_output-260303190101.json를 저장했습니다.
# {'N92': [{'Voltage range': '2.8–4.3',
#           'Temperature': None,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 211.93},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': 191.47},
#                                            {'C-rate': 1.0, 'Capacity': None},
#                                            {'C-rate': 2.0, 'Capacity': None},
#                                            {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                'Capacity': 64.19}]}]}],
#  'WN92': [{'Voltage range': '2.8–4.3',
#            'Temperature': None,
#            'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 210.83},
#                                             {'C-rate': 0.2, 'Capacity': None},
#                                             {'C-rate': 0.5, 'Capacity': 190.1},
#                                             {'C-rate': 1.0, 'Capacity': None},
#                                             {'C-rate': 2.0, 'Capacity': None},
#                                             {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                 'Capacity': 159.11}]}]}]}
# #####    40번째 논문    #####
# ##       rag method     : relevance-rag
# ##       Sample Names    : ['SC-NCM83']
# ##          Category Name   : CAM (Cathode Active Material)
# ##          ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_040_output/category-1-paper_040_output-260303190325.json를 저장했습니다.
# {'SC-NCM83': {'Stoichiometry information': {'Li ratio': 1.0,
#                                             'Ni ratio': 0.83,
#                                             'Co ratio': 0.11,
#                                             'Mn ratio': 0.06,
#                                             'O ratio': 2.0},
#               'Commercial NCM used': 'no',
#               'Lithium source': 'Li2CO3',
#               'Synthesis method': 'Solid-state reaction',
#               'Crystallization method': None,
#               'Crystallization final temperature': 975,
#               'Crystallization final duration (hours)': 9,
#               'Doping': None,
#               'Coating': None}}
# ##          Category Name   : Electrode (half-cell)
# ##          ./config/relevance-rag/c2-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_040_output/category-2-paper_040_output-260303190411.json를 저장했습니다.
# {'SC-NCM83': {'Active material to Conductive additive to Binder ratio': '90:5:5',
#               'Electrolyte': [{'Salt': 'LiPF6',
#                                'Concentration': '1',
#                                'Solvent': 'EC:DEC',
#                                'Solvent ratio': '50:50'}],
#               'Additive': None,
#               'Loading density (mass loading of NCM)': '5'}}
# ##          Category Name   : Morphological Properties
# ##          ./config/relevance-rag/c3-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_040_output/category-3-paper_040_output-260303190714.json를 저장했습니다.
# {'Particle size': {'SC-NCM83': '2–3 μm'},
#  'Particle shape': {'SC-NCM83': None},
#  'Particle distribution': {'SC-NCM83': None},
#  'Coating layer characteristics': {'SC-NCM83': None},
#  'Crystal structure and lattice characteristics': {'SC-NCM83': None}}
# ##          Category Name   : Cathode Performance
# ##          ./config/relevance-rag/c4-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_040_output/category-4-paper_040_output-260303190924.json를 저장했습니다.
# {'SC-NCM83': [{'Voltage range': '3.0–4.3',
#                'Temperature': 25,
#                'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                  'Capacity': None},
#                                                 {'C-rate': 0.2,
#                                                  'Capacity': None},
#                                                 {'C-rate': 0.5,
#                                                  'Capacity': None},
#                                                 {'C-rate': 1.0,
#                                                  'Capacity': 162},
#                                                 {'C-rate': 2.0,
#                                                  'Capacity': None},
#                                                 {'Other C-rates and performance': [{'C-rate': 0.05,
#                                                                                     'Capacity': 199}]}]}]}
# #####    41번째 논문    #####
# ##       rag method     : relevance-rag
# ##       Sample Names    : ['pristine NCM-811', 'g-C3N4NSs@NCM-811', 'thin g-C3N4@NCM-811', 'thick g-C3N4@NCM-811']
# ##          Category Name   : CAM (Cathode Active Material)
# ##          ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_041_output/category-1-paper_041_output-260303191258.json를 저장했습니다.
# {'pristine NCM-811': {'Stoichiometry information': {'Li ratio': 1.0,
#                                                     'Ni ratio': 0.8,
#                                                     'Co ratio': 0.1,
#                                                     'Mn ratio': 0.1,
#                                                     'O ratio': 2.0},
#                       'Commercial NCM used': 'yes',
#                       'Lithium source': None,
#                       'Synthesis method': None,
#                       'Crystallization method': None,
#                       'Crystallization final temperature': None,
#                       'Crystallization final duration (hours)': None,
#                       'Doping': None,
#                       'Coating': None},
#  'g-C3N4NSs@NCM-811': {'Stoichiometry information': {'Li ratio': 1.0,
#                                                      'Ni ratio': 0.8,
#                                                      'Co ratio': 0.1,
#                                                      'Mn ratio': 0.1,
#                                                      'O ratio': 2.0},
#                        'Commercial NCM used': 'yes',
#                        'Lithium source': None,
#                        'Synthesis method': 'sonication-assisted liquid '
#                                            'exfoliation method',
#                        'Crystallization method': None,
#                        'Crystallization final temperature': None,
#                        'Crystallization final duration (hours)': None,
#                        'Doping': None,
#                        'Coating': 'g-C3N4 nanosheets'},
#  'thin g-C3N4@NCM-811': {'Stoichiometry information': {'Li ratio': 1.0,
#                                                        'Ni ratio': 0.8,
#                                                        'Co ratio': 0.1,
#                                                        'Mn ratio': 0.1,
#                                                        'O ratio': 2.0},
#                          'Commercial NCM used': 'yes',
#                          'Lithium source': None,
#                          'Synthesis method': 'chemical vapor-assisted coating '
#                                              'method',
#                          'Crystallization method': None,
#                          'Crystallization final temperature': 550,
#                          'Crystallization final duration (hours)': 4,
#                          'Doping': None,
#                          'Coating': 'g-C3N4'},
#  'thick g-C3N4@NCM-811': {'Stoichiometry information': {'Li ratio': 1.0,
#                                                         'Ni ratio': 0.8,
#                                                         'Co ratio': 0.1,
#                                                         'Mn ratio': 0.1,
#                                                         'O ratio': 2.0},
#                           'Commercial NCM used': 'yes',
#                           'Lithium source': None,
#                           'Synthesis method': 'chemical vapor-assisted coating '
#                                               'method',
#                           'Crystallization method': None,
#                           'Crystallization final temperature': 550,
#                           'Crystallization final duration (hours)': 4,
#                           'Doping': None,
#                           'Coating': 'g-C3N4'}}
# ##          Category Name   : Electrode (half-cell)
# ##          ./config/relevance-rag/c2-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_041_output/category-2-paper_041_output-260303191451.json를 저장했습니다.
# {'pristine NCM-811': {'Active material to Conductive additive to Binder ratio': '80:10:10',
#                       'Electrolyte': [{'Salt': 'LiPF6',
#                                        'Concentration': '1.0',
#                                        'Solvent': 'EC:DMC',
#                                        'Solvent ratio': '3:7'}],
#                       'Additive': 'FEC, 5.0%',
#                       'Loading density (mass loading of NCM)': None},
#  'g-C3N4NSs@NCM-811': {'Active material to Conductive additive to Binder ratio': '80:10:10',
#                        'Electrolyte': [{'Salt': 'LiPF6',
#                                         'Concentration': '1.0',
#                                         'Solvent': 'EC:DMC',
#                                         'Solvent ratio': '3:7'}],
#                        'Additive': 'FEC, 5.0%',
#                        'Loading density (mass loading of NCM)': None},
#  'thin g-C3N4@NCM-811': {'Active material to Conductive additive to Binder ratio': '80:10:10',
#                          'Electrolyte': [{'Salt': 'LiPF6',
#                                           'Concentration': '1.0',
#                                           'Solvent': 'EC:DMC',
#                                           'Solvent ratio': '3:7'}],
#                          'Additive': 'FEC, 5.0%',
#                          'Loading density (mass loading of NCM)': None},
#  'thick g-C3N4@NCM-811': {'Active material to Conductive additive to Binder ratio': '80:10:10',
#                           'Electrolyte': [{'Salt': 'LiPF6',
#                                            'Concentration': '1.0',
#                                            'Solvent': 'EC:DMC',
#                                            'Solvent ratio': '3:7'}],
#                           'Additive': 'FEC, 5.0%',
#                           'Loading density (mass loading of NCM)': None}}
# ##          Category Name   : Morphological Properties
# ##          ./config/relevance-rag/c3-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_041_output/category-3-paper_041_output-260303191854.json를 저장했습니다.
# {'Particle size': {'pristine NCM-811': 'diameter ranging from 10 to 20 μm',
#                    'g-C3N4NSs@NCM-811': None,
#                    'thin g-C3N4@NCM-811': None,
#                    'thick g-C3N4@NCM-811': None},
#  'Particle shape': {'pristine NCM-811': 'spherical in shape',
#                     'g-C3N4NSs@NCM-811': 'particle structure is preserved; '
#                                          'overall shape is similar to the '
#                                          'pristine sample',
#                     'thin g-C3N4@NCM-811': 'particle structure is preserved',
#                     'thick g-C3N4@NCM-811': 'particle structure is preserved'},
#  'Particle distribution': {'pristine NCM-811': 'large spherical particle is '
#                                                'formed by the assembly of '
#                                                'small nanosized primary '
#                                                'particles',
#                            'g-C3N4NSs@NCM-811': None,
#                            'thin g-C3N4@NCM-811': None,
# ...
# ##       Sample Names    : ['pristine NCM622', 'polymer/γ-Al2O3-coated NCM622']
# ##          Category Name   : CAM (Cathode Active Material)
# ##          ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_044_output/category-1-paper_044_output-260303193147.json를 저장했습니다.
# {'pristine NCM622': {'Stoichiometry information': {'Li ratio': 1.0,
#                                                    'Ni ratio': 0.6,
#                                                    'Co ratio': 0.2,
#                                                    'Mn ratio': 0.2,
#                                                    'O ratio': 2.0},
#                      'Commercial NCM used': 'no',
#                      'Lithium source': 'LiOH',
#                      'Synthesis method': 'coprecipitation',
#                      'Crystallization method': 'sintering',
#                      'Crystallization final temperature': 875,
#                      'Crystallization final duration (hours)': 12,
#                      'Doping': None,
#                      'Coating': None},
#  'polymer/γ-Al2O3-coated NCM622': {'Stoichiometry information': {'Li ratio': 1.0,
#                                                                  'Ni ratio': 0.6,
#                                                                  'Co ratio': 0.2,
#                                                                  'Mn ratio': 0.2,
#                                                                  'O ratio': 2.0},
#                                    'Commercial NCM used': 'no',
#                                    'Lithium source': 'LiOH',
#                                    'Synthesis method': 'coprecipitation',
#                                    'Crystallization method': 'sintering',
#                                    'Crystallization final temperature': 875,
#                                    'Crystallization final duration (hours)': 12,
#                                    'Doping': None,
#                                    'Coating': 'γ-Al2O3'}}
# ##          Category Name   : Electrode (half-cell)
# ##          ./config/relevance-rag/c2-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_044_output/category-2-paper_044_output-260303193313.json를 저장했습니다.
# {'pristine NCM622': {'Active material to Conductive additive to Binder ratio': '90:4:6',
#                      'Electrolyte': [{'Salt': 'LiPF6',
#                                       'Concentration': '1.0',
#                                       'Solvent': 'EC:EMC',
#                                       'Solvent ratio': '3:7'}],
#                      'Additive': 'VC, 2%',
#                      'Loading density (mass loading of NCM)': '9.0'},
#  'polymer/γ-Al2O3-coated NCM622': {'Active material to Conductive additive to Binder ratio': '90:4:6',
#                                    'Electrolyte': [{'Salt': 'LiPF6',
#                                                     'Concentration': '1.0',
#                                                     'Solvent': 'EC:EMC',
#                                                     'Solvent ratio': '3:7'}],
#                                    'Additive': 'VC, 2%',
#                                    'Loading density (mass loading of NCM)': '9.0'}}
# ##          Category Name   : Morphological Properties
# ##          ./config/relevance-rag/c3-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_044_output/category-3-paper_044_output-260303193449.json를 저장했습니다.
# {'Particle size': {'pristine NCM622': None,
#                    'polymer/γ-Al2O3-coated NCM622': None},
#  'Particle shape': {'pristine NCM622': 'irregular particle surface',
#                     'polymer/γ-Al2O3-coated NCM622': 'no visible change to the '
#                                                      'morphology after '
#                                                      'calcination'},
#  'Particle distribution': {'pristine NCM622': None,
#                            'polymer/γ-Al2O3-coated NCM622': None},
#  'Coating layer characteristics': {'pristine NCM622': None,
#                                    'polymer/γ-Al2O3-coated NCM622': 'uniform '
#                                                                     'coating '
#                                                                     'of the '
#                                                                     'γ-Al2O3 '
#                                                                     'layer on '
#                                                                     'the '
#                                                                     'particle '
#                                                                     'surface; '
#                                                                     'layer was '
#                                                                     'around '
#                                                                     '7.8 nm on '
#                                                                     'the '
#                                                                     'particle '
#                                                                     'surface'},
#  'Crystal structure and lattice characteristics': {'pristine NCM622': None,
#                                                    'polymer/γ-Al2O3-coated NCM622': None}}
# ##          Category Name   : Cathode Performance
# ##          ./config/relevance-rag/c4-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_044_output/category-4-paper_044_output-260303193757.json를 저장했습니다.
# {'pristine NCM622': [{'Voltage range': '3.0-4.55 V',
#                       'Temperature': 25,
#                       'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                         'Capacity': 196.07},
#                                                        {'C-rate': 0.5,
#                                                         'Capacity': None},
#                                                        {'C-rate': 1.0,
#                                                         'Capacity': None},
#                                                        {'C-rate': 2.0,
#                                                         'Capacity': None},
#                                                        {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                            'Capacity': 155.9}]}]},
#                      {'Voltage range': '2.75-4.5 V',
#                       'Temperature': 25,
#                       'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                         'Capacity': None},
#                                                        {'C-rate': 0.5,
#                                                         'Capacity': 175.5},
#                                                        {'C-rate': 1.0,
#                                                         'Capacity': None},
#                                                        {'C-rate': 2.0,
#                                                         'Capacity': None},
#                                                        {'Other C-rates and performance': []}]}],
#  'polymer/γ-Al2O3-coated NCM622': [{'Voltage range': '3.0-4.55 V',
#                                     'Temperature': 25,
#                                     'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                                       'Capacity': 203.97},
#                                                                      {'C-rate': 0.5,
#                                                                       'Capacity': None},
#                                                                      {'C-rate': 1.0,
#                                                                       'Capacity': None},
#                                                                      {'C-rate': 2.0,
#                                                                       'Capacity': None},
#                                                                      {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                                          'Capacity': 177.7}]}]},
#                                    {'Voltage range': '2.75-4.5 V',
#                                     'Temperature': 25,
#                                     'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                                       'Capacity': None},
#                                                                      {'C-rate': 0.5,
#                                                                       'Capacity': 188.7},
#                                                                      {'C-rate': 1.0,
#                                                                       'Capacity': None},
#                                                                      {'C-rate': 2.0,
#                                                                       'Capacity': None},
#                                                                      {'Other C-rates and performance': []}]}]}
# #####    56번째 논문    #####
# ##       rag method     : relevance-rag
# ##       Sample Names    : ['pristine NCM', 'M-NCM']
# ##          Category Name   : CAM (Cathode Active Material)
# ##          ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_056_output/category-1-paper_056_output-260303194051.json를 저장했습니다.
# {'pristine NCM': {'Stoichiometry information': {'Li ratio': 1.0,
#                                                 'Ni ratio': 0.8,
#                                                 'Co ratio': 0.1,
#                                                 'Mn ratio': 0.1,
#                                                 'O ratio': 2.0},
#                   'Commercial NCM used': 'no',
#                   'Lithium source': 'LiOH·H2O',
#                   'Synthesis method': 'Solid-state reaction',
#                   'Crystallization method': None,
#                   'Crystallization final temperature': 750,
#                   'Crystallization final duration (hours)': 15,
#                   'Doping': None,
#                   'Coating': None},
#  'M-NCM': {'Stoichiometry information': {'Li ratio': 1.0,
#                                          'Ni ratio': 0.8,
#                                          'Co ratio': 0.1,
#                                          'Mn ratio': 0.1,
#                                          'O ratio': 2.0},
#            'Commercial NCM used': 'no',
#            'Lithium source': 'LiOH·H2O',
#            'Synthesis method': 'Solid-state reaction',
#            'Crystallization method': None,
#            'Crystallization final temperature': 750,
#            'Crystallization final duration (hours)': 15,
#            'Doping': 'Mg',
#            'Coating': 'Li3PO4'}}
# ##          Category Name   : Electrode (half-cell)
# ##          ./config/relevance-rag/c2-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_056_output/category-2-paper_056_output-260303194209.json를 저장했습니다.
# {'pristine NCM': {'Active material to Conductive additive to Binder ratio': '96:2:2',
#                   'Electrolyte': [{'Salt': 'LiPF6',
#                                    'Concentration': '1',
#                                    'Solvent': 'DMC:EC:EMC',
#                                    'Solvent ratio': '1:1:1'}],
#                   'Additive': None,
#                   'Loading density (mass loading of NCM)': None},
#  'M-NCM': {'Active material to Conductive additive to Binder ratio': '96:2:2',
#            'Electrolyte': [{'Salt': 'LiPF6',
#                             'Concentration': '1',
#                             'Solvent': 'DMC:EC:EMC',
#                             'Solvent ratio': '1:1:1'}],
#            'Additive': None,
#            'Loading density (mass loading of NCM)': None}}
# ##          Category Name   : Morphological Properties
# ##          ./config/relevance-rag/c3-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_056_output/category-3-paper_056_output-260303194527.json를 저장했습니다.
# {'Particle size': {'pristine NCM': 'secondary particles (about 11.7 μm), '
#                                    'primary particles with average diameters '
#                                    'of 170 to 230 nm',
#                    'M-NCM': 'secondary particles (about 11.7 μm), primary '
#                             'particles with average diameters of 170 to 230 '
#                             'nm'},
#  'Particle shape': {'pristine NCM': 'spherical secondary particles',
#                     'M-NCM': 'spherical secondary particles'},
#  'Particle distribution': {'pristine NCM': 'composing of the primary particles',
#                            'M-NCM': 'composing of the primary particles'},
#  'Coating layer characteristics': {'pristine NCM': None,
#                                    'M-NCM': 'thin Li3PO4 coating layer with '
#                                             'about 1.8 nm thickness'},
#  'Crystal structure and lattice characteristics': {'pristine NCM': None,
#                                                    'M-NCM': None}}
# ##          Category Name   : Cathode Performance
# ##          ./config/relevance-rag/c4-question.yaml를 불러왔습니다.
#         RELEVANCE CHECK : yes
# ##       ./output/json/relevance-rag/paper_056_output/category-4-paper_056_output-260303194815.json를 저장했습니다.
# {'pristine NCM': [{'Voltage range': '3.0-4.3 V',
#                    'Temperature': 25,
#                    'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                      'Capacity': 199.1},
#                                                     {'C-rate': 0.2,
#                                                      'Capacity': None},
#                                                     {'C-rate': 0.5,
#                                                      'Capacity': 199.3},
#                                                     {'C-rate': 1.0,
#                                                      'Capacity': None},
#                                                     {'C-rate': 2.0,
#                                                      'Capacity': None},
#                                                     {'Other C-rates and performance': [{'C-rate': 4.0,
#                                                                                         'Capacity': 169.8},
#                                                                                        {'C-rate': 5.0,
#                                                                                         'Capacity': 159.0},
#                                                                                        {'C-rate': 6.0,
#                                                                                         'Capacity': 151.3}]}]}],
#  'M-NCM': [{'Voltage range': '3.0-4.3 V',
#             'Temperature': 25,
#             'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 203.5},
#                                              {'C-rate': 0.2, 'Capacity': None},
#                                              {'C-rate': 0.5, 'Capacity': 202.2},
#                                              {'C-rate': 1.0, 'Capacity': None},
#                                              {'C-rate': 2.0, 'Capacity': None},
#                                              {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                  'Capacity': 180.0},
#                                                                                 {'C-rate': 6.0,
#                                                                                  'Capacity': 168.9}]}]}]}
# 코드 실행 시간: 5270.7884 초
