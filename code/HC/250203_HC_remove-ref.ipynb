# %%
import re
import unicodedata
from pdfminer.high_level import extract_text
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pprint import pprint

# %%
path = "../../data/input_data/paper_008.pdf"

# %%
pdf_miner_doc = extract_text(path)

# %%
print(pdf_miner_doc)
# Out:
# Cite This: J. Phys. Chem. C 2017, 121, 26163-26171
#
# Article
#
# pubs.acs.org/JPCC
#
# Between Scylla and Charybdis: Balancing Among Structural Stability
# and Energy Density of Layered NCM Cathode Materials for Advanced
# Lithium-Ion Batteries
# Lea de Biasi,*,†
# Pascal Hartmann,*,†,⊥
#
# Aleksandr O. Kondrakov,
# †,∥
# and Jürgen Janek
#
# Torsten Brezesinski,*,†
#
# Holger Geßwein,
#
# †,⊥
#
# ‡,§
#
# †
# Battery and Electrochemistry Laboratory, Institute of Nanotechnology and
# Technology, Hermann-von-Helmholtz-Platz 1, 76344 Eggenstein-Leopoldshafen, Germany
# §
# Helmholtz Institute Ulm for Electrochemical Energy Storage, Helmholtzstraße 11, 89081 Ulm, Germany
# ⊥
# BASF SE, 67056 Ludwigshafen, Germany
# Institute of Physical Chemistry, Justus-Liebig-University Giessen, Heinrich-Buﬀ-Ring 17, 35392 Giessen, Germany
# *S Supporting Information
#
# ∥
#
# ‡
# Institute for Applied Materials, Karlsruhe Institute of
#
# ABSTRACT: Two major strategies are currently pursued to
# improve the energy density of
# lithium-ion batteries using
# LiNixCoyMnzO2 (NCM) cathode materials. One is to increase
# the fraction of redox active Ni (≥80%), which allows larger
# amounts of Li to be extracted at a given cutoﬀ voltage (Umax).
# The other is to increase Umax,
# in particular for medium-Ni
# content NCM materials. However, the accompanying lattice
# changes ultimately lead to capacity fading in both cases. Here
# the structural changes occurring in Li1.02NixCoyMnzO2 (with x
# = 1/3, 0.5, 0.6, 0.7, 0.8 and 0.85) during cycling operation in
# the voltage range between 3.0 and 4.6 V vs Li are quantiﬁed by
# means of operando X-ray diﬀraction combined with detailed Rietveld analysis. All samples show a large decrease in unit cell
# volume upon charging, ranging from 2.4% for NCM111 (33% Ni) to 8.0% for NCM851005 (85% Ni). To make a fair
# comparison of the structural stability of the diﬀerent NCM materials, energy densities as a function of Umax are estimated and
# correlated with X-ray diﬀraction results. It is shown that NCMs with a lower Ni content allow for speciﬁc energies similar to that
# of, e.g., Ni-rich NCM811 (80% Ni) when operated at suﬃciently high Umax, but still undergo less pronounced changes in
# structure. Nevertheless, as indicated by charge/discharge tests, the capacity retention of low- and medium-Ni content NCMs
# cycled to high Umax is also strongly aﬀected by factors other than stability of the layered crystal lattice (electrolyte decomposition
# etc.). Overall, it is demonstrated that the complexity of the degradation processes needs to be better understood to identify
# optimal cycling conditions for speciﬁc cathode compositions.
#
# ■ INTRODUCTION
#
# The continuous development of optimized lithium-ion batteries
# (LIBs) is indispensable on the way to sustainable, cost-eﬃcient
# and long-range electric vehicles (EVs). Besides the quest for
# high power performance and good safety characteristics,
# increasing the energy density appears to be a prime goal in
# the development of next-generation LIBs.1 Layered LiCoO2
# (LCO) is the state-of-the-art cathode material for commercial
# application in consumer electronics for more than 25 years.
# However, because of the high price of cobalt metal, the speciﬁc
# costs ($/kWh) of LCO-based LIBs do not allow for the
# introduction of EVs into the mass market. Layered lithium
# transition metal (TM) oxides of the general formula LiTMO2
# (with TM = 3d transition metals such as Ni, Co and Mn),2−4
# so-called NCMs, allow to cut the costs and surpass the energy
# density limit of LCO cells due to the synergetic eﬀect of the
# diﬀerent TMs.5 Current 18650 cells comprising LCO and
#
# NCM cathode materials reach practical values of 740 Wh/L
# (250 Wh/kg) and 770 Wh/L (270 Wh/kg), respectively. While
# Ni increases the speciﬁc capacity, Mn has a stabilizing eﬀect on
# the layered α-NaFeO2-type crystal structure and Co tends to
# mix less with Li and further reduces the amount of Ni in the Li
# layers.2,6 Extraction of Li proceeds mainly through oxidation of
# Ni and Co,7 yet the Ni ions are believed to be the main redox
# active species in the voltage range between 3.0 and 4.2 V (vs
# graphite).8 Thus, increasing substitution of Ni by both Mn and
# Co leads to a decrease in speciﬁc capacity.9 For example,
# LiNi1/3Co1/3Mn1/3O2 (NCM111) delivers a speciﬁc capacity of
# about 150 mAh/g for Umax = 4.2 V (when cycled against
# graphite, or Umax = 4.3 V when cycled against lithium), which is
#
# June 28, 2017
#
# Received:
# Revised: October 26, 2017
# Published: October 31, 2017
#
# © 2017 American Chemical Society
#
# 26163
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# Downloaded via CHUNG-ANG UNIV on December 23, 2024 at 08:17:45 (UTC).See https://pubs.acs.org/sharingguidelines for options on how to legitimately share published articles.The Journal of Physical Chemistry C
#
# not suﬃcient for long-range EVs though. In recent years, it has
# been demonstrated that high-Ni LiNixCoyMnzO2 (x ≫ 1/3)
# allow for much higher degrees of delithiation, and therefore
# speciﬁc capacities in excess of 150 mAh/g.10 Nevertheless,
# increasing the Ni content is associated with a decrease in
# capacity retention, which is a major drawback so far.11 Part of
# the reason for this is the fact that Ni-rich materials suﬀer from
# larger volumetric changes with delithiation,
# leading to more
# failure.10,12−15 Besides,
# severe degradation and mechanical
# increasing the Ni content results in increased surface reactivity
# (electrolyte decomposition).16−18
#
# Another strategy to improve the energy density is to increase
# the charge cutoﬀ voltage to over 4.3 V vs Li. For the sake of
# clarity, all voltages are given with respect to Li/Li+ in the
# following (note that the voltage diﬀerence among cells using
# graphite [full-cell geometry] and lithium metal anodes [half-cell
# geometry] is around −100 mV). As an example, NCM111 has
# been reported to deliver a speciﬁc capacity of about 200 mAh/g
# in the voltage range from 2.5 to 4.6 V.2 However, charging
# NCM cathode materials to higher states of charge (SOC) is
# accompanied by more pronounced changes
# in lattice
# structure.10,13,19
#
# From both industrial and scientiﬁc points of view,
# the
# question what cathode composition and voltage range provides
# the optimum in terms of energy density, costs, stability and
# safety is yet to be answered. For automotive applications, in
# important
# particular, energy density is one of
# parameters.
# In literature, electrode materials for LIBs are
# often benchmarked for a given voltage range or degree of
# (de)lithiation. For example, Ishidzu et al. studied and compared
# the volume changes of NCMs of diﬀerent composition in the
# voltage range of 2.5−4.5 V.13 Nevertheless, from a techno-
# logical point of view, the mere evaluation of, e.g., cycling
# stability for a given maximum cell voltage may not be suﬃcient.
# Cells using low-Ni NCMs typically last signiﬁcantly longer than
# high-Ni NCM-based cells when operated in the same voltage
# range. However, for the latter, a signiﬁcantly lower maximum
# cell voltage would be required for achieving similar energy
# densities.
#
# the most
#
# In this work, we show that NCM111 and NCM811 cells
# provide virtually the same energy density at 4.6 and 4.3 V,
# respectively. Furthermore, we demonstrate that
# is very
# important to analyze both the performance and structural
# degradation of diﬀerent Ni content NCM cathodes for a given
# energy level rather than voltage range in a reference-type LIB.
# To allow for a reasonable performance assessment, we estimate
# the energy densities as a function of Umax for a variety of NCMs
# and correlate the results with structural properties of
# the
# materials from operando X-ray diﬀraction.
#
# it
#
# ■ EXPERIMENTAL SECTION
#
# Li1.02NixMnyCozO2 (x + y + z = 1) cathode materials with x:y:z
# = 1:1:1 (NCM111), 5:2:3 (NCM523), 6:2:2 (NCM622), 7:2:1
# (NCM721), 8:1:1 (NCM811) and 85:10:5 (NCM851005)
# were obtained from BASF SE (Ludwigshafen, Germany). All
# electrodes were prepared by slurry casting onto Al foil using a
# KTF-S roll-to-roll coater (Mathis AG). For NCM622,
# NCM721, NCM811 and NCM851005, slurries were obtained
# by dispersing cathode material (94 wt %), Super C65 (1 wt %,
# Timcal) and SFG6L (2 wt %, Timcal) conductive carbon
# additives as well as Solef 5130 PVDF binder (3 wt %, Solvay) in
# 1-ethyl-2-pyrrolidone (NEP). For NCM111 and NCM523,
# slurries were obtained by dispersing cathode material (93 wt
#
# Article
#
# %), Super C65 (1.5 wt %) and SFG6L (2.5 wt %) conductive
# carbon additives as well as Solef 5130 PVDF binder (3 wt %) in
# NEP.
#
# Electrochemical characterization was conducted at 25 °C on
# coin-type cells. The cells were assembled inside an Ar-ﬁlled
# glovebox (MBraun) by stacking cathode, glass microﬁber
# separator (GF/D, GE Healthcare Life Sciences, Whatman) and
# lithium foil anode (Albemarle Germany GmbH) of diameters
# 13, 17, and 13 mm, respectively, using 250 μL of either LP30 (1
# M LiPF6 in a 1:1 [wt/wt] mixture of ethylene carbonate and
# dimethyl carbonate) or LP47 (1 M LiPF6 in a 3:7 [w/w]
# mixture of ethylene carbonate and diethyl carbonate) as
# loadings were 2.0 mAh/
# electrolytes (BASF SE). The areal
# cm2 at C/10 and Umax = 4.3 V. The energy densities were
# calculated from the speciﬁc capacity and average discharge
# voltage and are given as average of two cycles from two to four
# cells. Powder X-ray diﬀraction (XRD) was performed using a
# laboratory diﬀractometer optimized for battery research.20 The
# diﬀractometer is equipped with a molybdenum microfocus
# rotating anode (Mo−Kα
# 1,2) and a Pilatus 300 K−W area
# detector. The high brilliance of
# the primary beam allows
# penetration of pouch cells, so that measurements can be
# performed under realistic conditions (without using custom
# cells or X-ray windows). For operando XRD, pouch cells were
# assembled inside a dry room with dew point below −50 °C by
# stacking cathode (20 mm × 40 mm), Celgard 2500
# polypropylene separator (30 mm × 50 mm) and lithium foil
# anode (24 mm × 44 mm) using 250 μL of LP47 (see Figure S1
# for comparison of the cyclability of pouch cells and standard
# coin cells). Prior to XRD, the electrodes were galvanostatically
# cycled in the voltage range between 3.0 and 4.3 V for three
# cycles. Then, the cells were inserted into the diﬀractometer and
# charged/discharged at C/10 during the measurement. A
# constant voltage step at the cutoﬀ voltages was applied for 1
# h to allow for thermodynamic equilibration of the electrode
# materials. 2D diﬀraction images were collected in transmission
# geometry with an exposure time of 75 s. The intensity of two
# consecutive images was added up and then integrated to obtain
# 1D patterns for further evaluation, resulting in a total time
# resolution of 150 s. Data analysis was performed by Rietveld
# reﬁnement using TOPAS-Academic version 5. The instrumen-
# tal resolution function was determined from an annealed CeO2
# sample and described by means of a (Thompson-Cox-
# Hastings) pseudo-Voigt proﬁle function.21 The analysis
# comprised reﬁnement of lattice parameters a and c and atomic
# coordinate z of the oxygen position. Both lithium (occ3a = 1.00,
# occ3b = 0.02) and oxygen occupancy parameters (occ6c = 1.00)
# were ﬁxed during reﬁnement. Broadening eﬀects (apparent
# crystallite size, microstrain etc.) were accounted for by
# convolution-based proﬁle ﬁtting as implemented in TOPAS.
# This approach is equivalent
# to the double-Voigt method
# described by Balzar et al. and is based on the integral breadth of
# the diﬀraction lines.22,23 Background reﬁnement was made
# using a 10-term Chebyshev polynomial function. Zero-point
# correction was used to correct for sample displacement errors
# of both the cathode material and Al current collector.24 The
# VESTA software package was used to generate crystal structure
# images.25
#
# ■ RESULTS AND DISCUSSION
#
# Electrochemical Characteristics. Electrochemical testing
# was performed on Li1.02NixCoyMnzO2 cathode materials with
# x:y:z = 1:1:1 (NCM111), 5:2:3 (NCM523), 6:2:2 (NCM622),
#
# 26164
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# Article
#
# 7:2:1 (NCM721), 8:1:1 (NCM811),
# and 85:10:5
# (NCM851005) using coin-type cells with a lithium metal
# counter electrode. Figure 1a shows charge/discharge curves
#
# Figure 2. (a) Speciﬁc discharge capacity as a function of Umax for the
# diﬀerent Ni content NCM-based cells. (b) Maximum gravimetric
# energy densities calculated from the speciﬁc capacity and average
# discharge voltage.
#
# Figure 1. (a) Charge/discharge curves at C/5 in the voltage range
# between 3.0 and 4.6 V and (b) the corresponding diﬀerential capacity
# plots for the diﬀerent Ni content NCM-based cells.
#
# obtained at C/5 between 3.0 and 4.6 V. As is seen, the higher
# the Ni content the more Li can be extracted, and therefore the
# higher the speciﬁc capacity (see also Figure 2a). Besides, the
# voltage proﬁles show diﬀerent features depending on the Ni
# content due to diﬀerent redox behavior, as indicated by the
# diﬀerential capacity curves in Figure 1b. While in the ternary
# system of LiNiO2, LiCoO2 and LiMnO2 the TMs are formally
# in the trivalent state (i.e., Ni3+, Co3+ and Mn3+), charge transfer
# is assumed to occur between Ni and Mn in the LiNixCoyMnzO2
# phase. The reason is the diﬀerence in electronegativity.26,27
# Theoretical calculations suggest
# formal oxidation states of
# mixed divalent and trivalent Ni, trivalent Co, and tetravalent
# Mn.26−28 However, the main redox active species are believed
# to be Ni2+ and Ni3+, and their concentration depends on the
# overall TM ratio.
#
# All samples show characteristic redox peaks in the voltage
# range of 3.6−3.8 V (Figure 1b). The peak splitting indicates the
# presence of two Ni redox pairs (namely, Ni2+/Ni3+ and Ni3+/
# Ni4+) with cycling, and their shape and area ratio point to
# diﬀerent contributions depending on the Ni content.26,27 The
# peaks shift toward lower voltage with increasing Ni content,
# leading to a decrease in the average charge/discharge voltages.
# This phenomenon has been observed before and attributed to
# the lower redox potential of Ni than Co.13,29 Kim et al. showed
# that the electrochemical equilibrium potentials of these redox
# reactions also vary with Mn content in the structure.26 Using
# experimental GITT and computational calculations they found
# that high-Ni NCMs exhibit redox activity at lower relative
# voltages. However, less Mn also leads to lower voltages for the
# same Ni content. The Ni-rich samples, in particular NCM811
# and NCM851005, further show features in the high-voltage
#
# similar
#
# to that of
#
# region above 3.9 V, which we believe are due to multiphase
# transitions caused by slight distortions in the crystal structure.
# Such transformations have been observed for LiNiO2 during
# delithiation and are likely to occur in high-Ni NCMs as well.30
# Both NCM811 and NCM851005 show an additional voltage
# plateau around 4.2 V, appearing as a distinct peak in the
# diﬀerential capacity curves. This peak is not seen for the other
# NCM materials, and its origin has not yet been clearly resolved.
# Figure 2a depicts the speciﬁc capacity of the NCM cathodes
# after charging to 4.3 V ≤ Umax
# ≤ 4.6 V. As expected, both
# NCM811 and NCM851005 provide the highest values,
# irrespective of the Umax. At 4.3 V these cathode materials
# deliver capacities
# the widely used
# LiNi0.8Co0.15Al0.05O2 (NCA).31,32 The gravimetric energy
# density (GED) calculated as the product of speciﬁc charge
# and average discharge voltage is shown in Figure 2b. The GED
# increases with both increasing Ni content and Umax.
#
# To make a fair comparison among the diﬀerent NCM
# materialsalso with respect to their structural stability (see
# below)Umax
# required to achieve the speciﬁc energy of
# NCM811 operated at 4.3 V (≈750 Wh/kg) was calculated
# for each composition. According to our estimates, NCM111,
# NCM523, NCM622, NCM721, and NCM851005 need to be
# operated at around 4.6, 4.55, 4.45, 4.4, and 4.25 V, respectively
# (Figure 3). The obtained Umax values agree well with the
# technological
# roadmaps of some cell manufacturers (e.g.,
# NCM622 at 4.35 V in full-cells). Both NCM811 and
# NCM851005 oﬀer the highest energy densities when Umax is
# limited to 4.3 V, as is currently the case in commercial high-
# performance LIBs. However, similar GEDs can be achieved
# with the low- and medium-Ni NCM materials when increasing
# the maximum operation voltage. Thus,
# is of upmost
# importance to identify the optimum in terms of materials
# speciﬁc
# composition and operating voltage range for
#
# it
#
# 26165
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# Article
#
# Figure 3. Charge cutoﬀ voltage as a function of Ni content required to
# achieve the gravimetric energy density of NCM811 at Umax = 4.3 V.
#
# applications. From a scientiﬁc point of view, this means that the
# major degradation processes need to be better understood. In
# the following we focus on the (crystallographic) volume
# changes of NCMs occurring in the voltage range between 3.0
# and 4.6 V since these are known to cause mechanical stress,
# which in turn leads to material fracture and fatigue.
# Structural Characteristics. An overview of
#
# the NCM
# materials employed in this work and their composition are
# given in Table 1. The samples exhibit a well-developed layered
# crystalline structure of α-NaFeO2-type (space group R3m̅ , Z =
# 3). It can be viewed as a stacking of alternating layers, in which
# TM and Li ions occupy octahedral sites in a cubic close-packed
# oxygen lattice (Figure 4). The Ni, Co and Mn ions are
# statistically distributed over the 3b site in ﬁrst approximation. Li
# ions (Wyckoﬀ site 3a) are located in the interslabs between the
# TM layers. We assume that 2% of the 3b site in the TM layer
# are occupied by Li ions because of the small Li excess.
#
# The lattice parameters of the pristine materials are given in
# Table 2. An increase in a with increasing Ni content
# is
# observed, which is due to the larger ionic radii of Ni2+ (0.69 Å)
# and Ni3+ (0.56 Å) compared to Co3+ (0.545 Å) and Mn4+
# (0.530 Å).33 In contrast, c decreases, which is somewhat
# surprising and seems to be related to the content of all three
# TMs (rather than Ni only). For example, substitution of Mn by
# Co is known to cause a decrease in both lattice parameters.34
# To gain insight into the evolution of the host structure with
# cycling, a series of operando XRD measurements were
# performed on the diﬀerent NCM materials. Prior to XRD,
# the cells were cycled between 3.0 and 4.3 V ﬁrst at C/10 for
# two cycles and then at C/5 for another cycle. The Li content δ
# per formula unit was around 1.02 for the pristine samples. To
# estimate δ at the beginning and end of the fourth charge cycle,
# we assumed that Coulombic eﬃciencies of less than 100% are a
# result of Li loss from the cathode material only. This loss of
#
# Figure 4. Crystal structure and schematic of the unit cell of layered
# LiNixCoyMnzO2.
#
# Table 2. Lattice Parameters and Oxygen Coordinate for the
# Diﬀerent Ni Content NCM Cathode Materials
#
# sample
#
# NCM111
# NCM523
# NCM622
# NCM721
# NCM811
# NCM851005
#
# a (Å)
#
# 2.8575(1)
# 2.8659(1)
# 2.8661(1)
# 2.8647(1)
# 2.8688(1)
# 2.8700(1)
#
# c (Å)
#
# 14.2166(5)
# 14.2234(3)
# 14.2062(3)
# 14.1808(4)
# 14.1867(4)
# 14.1795(3)
#
# z
#
# 0.2401(1)
# 0.2406(1)
# 0.2403(1)
# 0.2403(1)
# 0.2416(1)
# 0.2409(1)
#
# active Li during precycling was taken into account when
# calculating the amount of transferred Li+ ions. The NCM cells
# exhibited open-circuit voltages ranging from 3.57 to 3.65 V
# prior to the fourth cycle. As can be seen from Table 1, δ was
# ≤0.21 after charging (note that a constant voltage step at Umax
# = 4.6 V was applied for 1 h).
#
# Figure 5 depicts contour plots of operando XRD patterns for
# the reﬂection positions and
# NCM622. The evolution of
# intensities is shown together with the voltage proﬁle. We
# note that Bragg reﬂections other than those originating from
# the cathode material can be assigned to aluminum (from the
# current collector and pouch cell foil). A distinct hkl-dependent
# shift is observed during cycling. The reﬂections with h = k = 0
# and l ≠ 0 (e.g., 003) ﬁrst shift to lower 2θ values in the charge
# cycle. However, when the cell reaches a voltage of about 4.0 V,
# they shift back to the initial positions or to even larger 2θ
# values. In contrast, the reﬂections with h ≠ 0, k ≠ 0 and l = 0
# (e.g., 110) show the opposite trend in that they shift almost
# exclusively toward larger 2θ values. Reverse shifts are observed
# upon discharge, and all reﬂections virtually reach their initial
# positions at the end of the cycle. This leads us to conclude that
# the layered structure is well preserved. However, a slight
#
# Table 1. Composition of the Diﬀerent Ni Content NCM Cathode Materials before Cycling and at the Beginning and End of the
# Fourth Charge Cycle
#
# sample
#
# NCM111
# NCM523
# NCM622
# NCM721
# NCM811
# NCM851005
#
# pristine state
#
# Li1.02Ni1/3Co1/3Mn1/3O2
# Li1.02Ni0.5Co0.2Mn0.3O2
# Li1.02Ni0.6Co0.2Mn0.2O2
# Li1.02Ni0.7Co0.2Mn0.1O2
# Li1.02Ni0.8Co0.1Mn0.1O2
# Li1.02Ni0.85Co0.1Mn0.05O2
#
# cycled state (3.0 V)
#
# Li0.94Ni1/3Co1/3Mn1/3O2
# Li0.93Ni0.5Co0.2Mn0.3O2
# Li0.93Ni0.6Co0.2Mn0.2O2
# Li0.91Ni0.7Co0.2Mn0.1O2
# Li0.90Ni0.8Co0.1Mn0.1O2
# Li0.89Ni0.85Co0.1Mn0.05O2
#
# cycled state (4.6 V)
#
# Li0.21Ni1/3Co1/3Mn1/3O2
# Li0.19Ni0.5Co0.2Mn0.3O2
# Li0.18Ni0.6Co0.2Mn0.2O2
# Li0.13Ni0.7Co0.2Mn0.1O2
# Li0.11Ni0.8Co0.1Mn0.1O2
# Li0.09Ni0.85Co0.1Mn0.05O2
#
# 26166
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# Article
#
# Figure 5. Contour plots of operando XRD patterns obtained on a NCM622-based cell showing the evolution of the reﬂection positions and
# intensities in the fourth charge/discharge cycle at C/10.
#
# broadening of the Bragg reﬂections occurs above 3.9 V and
# becomes more pronounced with further charging. During
# discharge a decrease in full width at half-maximum (fwhm) is
# observed below 3.8 V. As an example, Δfwhm003 is found to be
# 0.002° after the charge/discharge cycle, thus emphasizing the
# high reversibility of the (de)lithiation process.
#
# Structural multiphase transitions from hexagonal to mono-
# clinic (H1 → M), monoclinic to hexagonal (M → H2) and
# hexagonal to hexagonal (H2 → H3) typically occur when
# Li1−xNiO2 is delithiated with charging to 4.3 V, as indicated by
# the splitting of the original H1 10l and 11l reﬂections.30,35 It
# should be noted that the monoclinic modiﬁcation diﬀers only
# marginally from the hexagonal arrangement, and this break in
# symmetry leads to the appearance of additional reﬂections.
# those assigned to the
# However, Yang et al. showed that
# monoclinic phase can also be interpreted alternatively as two
# coexisting hexagonal phases.36 In both cases, nevertheless, the
# 2θ positions of the newly formed phase−whether hexagonal or
# monoclinic−would hardly diﬀer
# the initial
# reﬂections (Figure S2). Overall, we believe that this eﬀect
# contributes to the observed broadening of the reﬂections.
#
# from those of
#
# Analogous XRD measurements were conducted on all NCM
# cathode materials. Figure 6 depicts contour plots of operando
# XRD patterns in the 2θ range around the 003 reﬂection
# obtained during charge (see also contour plots for selected 2θ
# ranges in Figure S3). Degradation of the layered structure is not
# observed in the voltage range studied, and the Bragg reﬂections
# show similar trends in the evolution with time. Again, the 003
# reﬂection initially shifts to lower 2θ values and then to higher
# angles. Besides, the minimum in 2θ is similar at 8.4−8.5° for all
# samples. However, there are also signiﬁcant diﬀerences. For
# example, the turning point (from decrease to increase) is at
# lower cell voltage for the high-Ni NCMs. Furthermore, the
# total shift in 2θ to higher angles is much less pronounced for
# the low- and medium-Ni NCMs (i.e., NCM111 and NCM523),
# with the position of the 003 reﬂection (8.6° 2θ) being virtually
# the 003
# identical before and after charging.
#
# In contrast,
#
# Figure 6. Contour plots of operando XRD patterns in the 2θ range of
# the 003 reﬂection obtained on the diﬀerent Ni content NCM-based
# cells during the charge cycle.
#
# reﬂection shifts to signiﬁcantly larger 2θ values in the high-
# voltage region with increasing Ni content and the ﬁnal position
# is much diﬀerent from the starting value.
#
# 26167
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# Article
#
# Parts a and b of Figure 7 show the relative changes in lattice
# parameters a and c versus the voltage with delithiation (charge)
#
# materials, the severe change along the c-direction presumably
# causes structural instability of the lattice.
#
# Because of the excellent time resolution of only 150 s per
# pattern we were able to directly correlate structural with
# electrochemical features. As mentioned above, both NCM811
# and NCM851005 show a subtle plateau in the voltage proﬁle
# above 4.1 V, appearing as a peak in the diﬀerential capacity
# curves. On the basis of the XRD data we calculated the
# “diﬀerential unit cell volume”, which is the ﬁrst derivative of the
# to cell voltage (Figure 8).
# unit cell volume with respect
#
# Figure 7. Relative changes in lattice parameters (a) a and (b) c as a
# function of cell voltage during delithiation for the diﬀerent Ni content
# NCM materials.
#
# obtained from Rietveld reﬁnement (Figure S4 plots the same
# data against the Li content). Rietveld reﬁnement results for
# each operando XRD measurement at diﬀerent SOC are given in
# Table S1, while Figure S5 shows selected Rietveld plots for
# NCM622. Both a and c strongly change with the voltage. The
# a-axis shrinks linearly at ﬁrst, then levels oﬀ between 4.3 and 4.4
# V and ﬁnally increases again slightly. The magnitude of the
# latter increase is larger for the Ni-rich NCMs. In contrast, the c-
# axis ﬁrst shows an increase by about 1.5%,
# followed by a
# decrease for all samples. This shrinkage always occurs when δ
# approaches 0.4 (Figure S4), and it is particularly severe for
# high-Ni NCMs (LiNixCoyMnzO2 with x ≥ 0.8). The general
# trends observed are in agreement with the study by Ishidzu et
# al.13
#
# It has been shown that the lattice parameter a reﬂects the
# TM−TM distance (in the TM layer).37,38 The ionic radii of the
# TMs decrease with increasing oxidation state, and therefore the
# decrease in lattice parameter a is likely associated with the
# oxidation of the TMs. The lattice parameter c represents the
# interslab distance of the Li layers.37,38 The initial increase is
# usually interpreted as a result of increasing Coulomb repulsion
# with Li extraction from the interlayer galleries. It has also been
# reported that lithium interacts electrostatically with oxygen.38
# This interaction is apparently accompanied by partial charge
# transfer, which in turn is believed to eﬀectively screen the
# electrostatic repulsion between the oxygen layers. The
# screening eﬀect
# reduced with increasing degree of
# delithiation, resulting in increased repulsion and expansion
# along the c-axis. When most of the lithium is removed, a
# contraction of the interslab distance is observed and with that a
# decrease in lattice parameter c.19 In particular for Ni-rich NCM
#
# is
#
# Figure 8. Diﬀerential capacity (black) and unit cell volume plots
# (blue) in the voltage range between 3.8 and 4.6 V for (a) NCM811
# and (b) NCM851005.
#
# Interestingly, a distinct peak is observed in the high-voltage
# region as in the case of the diﬀerential capacity curves. Even
# more interestingly, the peaks in the diﬀerential capacity and
# unit cell volume curves correlate with each other in terms of
# position (4.22 V for NCM811; 4.20 V for NCM851005) and
# relative height. This result thus provides evidence that the
# appearance of the redox peak around 4.2 V is due to structural
# eﬀects, and we take it as an indication of an undesired phase
# transformation.
#
# From a practical point of view, it is important to note that the
# relative changes in lattice parameters a and c during charge lead
# to a large decrease in unit cell volume. As is shown in Figures
# 9a and S6, this decrease is more severe as the Ni content rises
# or, in other words, the total change in unit cell volume increases
# with increasing Ni content. Also,
# the change is highly
# anisotropic, resulting in signiﬁcant strain in the NCM particles
# (see also Figure S7 for the evolution of c/a ratio with cell
# voltage). All NCM materials employed in this work are found
# to exhibit the most pronounced changes in unit cell volume at
# high SOC. This is apparent from the change in slope of the ΔV
# vs U curves, with the onset correlating with the collapse of the
# c-axis when δ ≈ 0.4 (see Figures 7b and S4). It is believed that
# lattice changes with cycling are the major source of mechanical
#
# 26168
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# Article
#
# Figure 9. (a) Relative changes in unit cell volume as a function of cell
# voltage for the diﬀerent Ni content NCM materials. (b) Relative
# changes in unit cell volume for Umax = 4.3 V (empty circles) and Umax
# required to achieve the gravimetric energy density of NCM811 at 4.3
# V (solid circles).
#
# fracture, among
# stress in the particles and cause material
# others.12,15,39,40 Breakage of particles ultimately leads
# to
# disconnection of a fraction of active cathode material (i.e.,
# loss of electrical contact) and creates new and reactive surfaces,
# thereby accelerating degradation. Consequently,
# is a
# reasonable concern whether high-Ni NCMs have an intrinsic
# disadvantage over medium-Ni NCMs when it comes to cycling
# stability and longevity.
#
# it
#
# To better compare the microstructural stability among the
# diﬀerent NCM samples, the relative unit cell volume changes
# with delithiation were evaluated in more detail. Figure 9b shows
# the corresponding data for Umax = 4.3 V and when operating
# the cathode materials at a similar speciﬁc energy or, more
# speciﬁcally, when charging to Umax required to achieve the
# gravimetric energy density of NCM811 at 4.3 V (Figure 3).
# Interestingly, the relative change in unit cell volume increases in
# a linear fashion with increasing Ni content when Umax
# is
# adjusted for each composition−as opposed to when the cutoﬀ
# voltage is set at 4.3 V. From these data, it is evident that Ni-rich
# NCM materials are more prone to structural changes/
# mechanical deformation and therefore likely to fracture during
# operation (due to structural
# stress associated with the
# continuous shrinking and swelling of the primary crystallites
# in the secondary cathode particles).
#
# Finally, the cycling performance of the diﬀerent Ni content
# NCMs was evaluated based on our speciﬁc energy concept
# (Figure 10, parts a and b). Noh et al. performed similar
# experiments using half-cells, but focused on the stability in the
# 3.0−4.3 V range.10 They found that the capacity retention
# signiﬁcantly decreases with increasing Ni content (Figure 10b),
# which was explained by lower structural stability of high-Ni
# NCMs. At ﬁrst glance, this result is not surprising and is also in
# agreement with our data, showing a nonlinear increase in
#
# Figure 10. (a) Capacity retention based on the second cycle discharge
# capacity for the diﬀerent Ni content NCM-based cells cycled between
# 3.0 V and Umax required to achieve the gravimetric energy density of
# NCM811 at 4.3 V (i.e., 4.6 V, 4.55 V, 4.45 V, 4.4 and 4.25 V for
# NCM111, NCM523, NCM622, NCM721 and NCM851005,
# respectively). After the ﬁrst cycle at C/10 was completed, the C-
# rates were set to C/4 charge and C/2 discharge for the subsequent
# cycles. (b) Comparison of the capacity retention after 100 cycles
# achieved by tailoring Umax and the results of Noh et al. for Umax = 4.3
# V.10
#
# relative volume change with increasing Ni content (Figure 9b)
# when the voltage on charge is limited to Umax = 4.3 V; so more
# structural degradation is expected when Umax is not tailored to
# the speciﬁc energy. However, when doing so, we ﬁnd that Ni-
# rich NCMs show better capacity retention than samples with a
# low Ni content, although they have a clear disadvantage in
# terms of structural stability. This result provides evidence that
# the cycle life is also strongly aﬀected by factors other than
# stability of the lattice structure. Particularly when the charge
# cutoﬀ voltage is increased beyond the stability limit of organic
# electrolytes, electrolyte oxidation occurs (and with that gas
# evolution).41,42 For example, Dahn and co-workers showed
# recently that ethylene carbonate-containing electrolytes sig-
# niﬁcantly reduce the cell performance and life at high
# voltages.43,44 Ultimately, this means that new electrolytes and
# additives are needed for high-voltage battery applications.
#
# Overall, it is not entirely clear which NCM cell chemistry
# provides the optimum in terms of energy density and cycling
# stability. To answer this question it is important to better
# understand the diﬀerent LIB degradation processes and how
# they aﬀect each other. Clearly, for high-Ni NCMs, improving
# the structural stability is one of the major challenges toward
# commercialization, while for medium-Ni NCMs,
# the high
# (surface) reactivity toward oxidative electrolyte decomposition
# at high operating voltage must be addressed.
#
# 26169
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# ■ CONCLUSION
#
# A comparative study of the electrochemical and structural
# properties of a series of Li1.02NixCoyMnzO2 cathode materials
# with x = 1/3, 0.5, 0.6, 0.7, 0.8, and 0.85 in Li cells was
# performed in an attempt to identify the composition providing
# the optimum in energy density and stability. It is shown that
# high-Ni NCMs (NCM811 and NCM851005) oﬀer the highest
# energy densities in the state-of-the-art voltage range of 3.0−4.3
# V. However, it is important to note that low- and medium-Ni
# NCMs, in principle, would be capable of delivering competitive
# energy densities if the maximum cell voltage could be increased
# without inducing deleterious side reactions (e.g., NCM111 and
# NCM622 at 4.6 and 4.45 V, respectively).
#
# in terms of mechanical
#
# Operando X-ray diﬀraction revealed that, irrespective of the
# Ni content, all NCM materials are subjected to structural
# changes during operation. Yet, most importantly, it was found
# that the total change in unit cell volume increases virtually
# linearly with increasing Ni content for similar energy densities
# (here based on that of NCM811 at 4.3 V). This leads us to the
# assumption that increasing the Ni content results in major
# challenges
# strain and structural
# degradation. However, galvanostatic charge/discharge tests
# indicated that Ni-rich NCMs
# show better capacity
# retention than low- and medium-Ni NCMs charged to higher
# cutoﬀ voltages. This result emphasizes that each and every
# NCM cathode material has its own issues, especially when
# approaching the desired speciﬁc energy range required for
# application in electric vehicles. Thus, from a scientiﬁc point of
# view, it is a must to recognize and understand the (cell-voltage-
# dependent) limiting factors of the diﬀerent Ni content NCMs
# and to ﬁnd solutions to optimize their performance. Besides,
# the presence and interplay of degradation processes such as
# electrolyte decomposition and transition metal dissolution, to
# name a few, need to be thoroughly investigated when dealing
# with full-cells.
#
# still
#
# ■ ASSOCIATED CONTENT
#
# *S Supporting Information
# The Supporting Information is available free of charge on the
# ACS Publications website at DOI: 10.1021/acs.jpcc.7b06363.
# Comparison of NCM622-based pouch and coin cell
# voltage proﬁles, simulated diﬀraction patterns, contour
# plots of operando XRD patterns for selected 2θ ranges,
# relative changes in lattice parameters and unit cell
# volume versus the Li content, changes in c/a ratio as a
# function of cell voltage, Rietveld plots for NCM622, and
# summary of Rietveld reﬁnement results for each operando
# XRD measurement (PDF)
#
# ■ AUTHOR INFORMATION
#
# Corresponding Authors
# *(L.d.B.) Telephone: +49 721 60826870. E-mail: lea.biasi@kit.
# edu.
# *(T.B.) Telephone: +49 721 60828827. E-mail:
# brezesinski@kit.edu.
# *(P.H.) Telephone: +49 621 6048636. E-mail: pascal.
# hartmann@basf.com.
# ORCID
# Aleksandr O. Kondrakov: 0000-0003-1465-2854
# Torsten Brezesinski: 0000-0002-4336-263X
#
# torsten.
#
# Article
#
# Notes
# The authors declare no competing ﬁnancial interest.
#
# ■ ACKNOWLEDGMENTS
#
# This study is part of the projects being funded within the BASF
# International Network for Batteries and Electrochemistry.
#
# ■ REFERENCES
#
# (1) Armand, M.; Tarascon, J.-M. Building Better Batteries. Nature
# 2008, 451, 652−657.
# (2) Yabuuchi, N.; Ohzuku, T. Novel Lithium Insertion Material of
# LiCo1/3Ni1/3Mn1/3O2 for Advanced Lithium-Ion Batteries. J. Power
# Sources 2003, 119−121, 171−174.
# (3) Lu, Z.; MacNeil, D. D.; Dahn, J. R. Layered Cathode Materials
# Li[NixLi(1/3−2x/3)Mn(2/3−x/3)]O2 for Lithium-Ion Batteries. Electrochem.
# Solid-State Lett. 2001, 4, A191.
# (4) Lu, Z.; MacNeil, D. D.; Dahn, J. R. Layered Li[NixCo1−2xMnx]O2
# Cathode Materials for Lithium-Ion Batteries. Electrochem. Solid-State
# Lett. 2001, 4, A200.
# (5) Manthiram, A.; Knight, J. C.; Myung, S.-T.; Oh, S.-M.; Sun, Y.-K.
# Nickel-Rich and Lithium-Rich Layered Oxide Cathodes: Progress and
# Perspectives. Adv. Energy Mater. 2016, 6, 1501010.
# (6) MacNeil, D. D.; Lu, Z.; Dahn, J. R. Structure and Electro-
# chemistry of Li[NixCo1−2xMnx]O2 (0 ≤ x ≤ 1/2). J. Electrochem. Soc.
# 2002, 149, A1332.
# (7) Kobayashi, H.; Arachi, Y.; Emura, S.; Kageyama, H.; Tatsumi, K.;
# Kamiyama, T. Investigation on Lithium de-Intercalation Mechanism
# for Li1−yNi1/3Mn1/3Co1/3O2. J. Power Sources 2005, 146, 640−644.
# (8) Jeon, Y.-A.; Kim, S.-K.; Kim, Y.-S.; Won, D.-H.; Kim, B.-I.; No,
# K.-S. A First Principles Investigation of New Cathode Materials for
# Advanced Lithium Batteries. J. Electroceram. 2006, 17, 667−671.
# (9) Jouanneau, S.; Eberman, K. W.; Krause, L. J.; Dahn, J. R.
# Synthesis, Characterization, and Electrochemical Behavior of Im-
# proved Li[NixCo1−2xMnx]O2 (0.1 ≤ x ≤ 0.5). J. Electrochem. Soc. 2003,
# 150, A1637.
# (10) Noh, H.-J.; Youn, S.; Yoon, C. S.; Sun, Y.-K. Comparison of the
# Structural and Electrochemical Properties of Layered Li[NixCoyMnz]-
# O2 (x = 1/3, 0.5, 0.6, 0.7, 0.8 and 0.85) Cathode Material for Lithium-
# Ion Batteries. J. Power Sources 2013, 233, 121−130.
# (11) Liu, Z.; Yu, A.; Lee, J. Y. Synthesis and Characterization of
# LiNi1‑x‑yCoxMnyO2 as the Cathode Materials of Secondary Lithium
# Batteries. J. Power Sources 1999, 81−82, 416−419.
# (12) Kim, H.-R.; Woo, S.-G.; Kim, J.-H.; Cho, W.; Kim, Y.-J. Capacity
# Fading Behavior of Ni-Rich Layered Cathode Materials in Li-Ion Full
# Cells. J. Electroanal. Chem. 2016, 782, 168−173.
# (13) Ishidzu, K.; Oka, Y.; Nakamura, T. Lattice Volume Change
# during Charge/discharge Reaction and Cycle Performance of
# Li[NixCoyMnz]O2. Solid State Ionics 2016, 288, 176−179.
# (14) Ghanty, C.; Markovsky, B.; Erickson, E. M.; Talianker, M.; Haik,
# O.; Tal-Yossef, Y.; Mor, A.; Aurbach, D.; Lampert, J.; Volkov, A.; et al.
# Li+-Ion Extraction/Insertion of Ni-Rich Li1+x(NiyCozMnz)wO2
# (0.005<x < 0.03; y: z = 8:1,w≈1) Electrodes: In Situ XRD and
# Raman Spectroscopy Study. ChemElectroChem 2015, 2, 1479−1486.
# (15) Kondrakov, A. O.; Schmidt, A.; Xu, J.; Geßwein, H.; Mönig, R.;
# Hartmann, P.; Sommer, H.; Brezesinski, T.; Janek, J. Anisotropic
# Lattice Strain and Mechanical Degradation of High- and Low-Nickel
# NCM Cathode Materials for Li-Ion Batteries. J. Phys. Chem. C 2017,
# 121, 3286−3294.
# (16) Bak, S.-M.; Hu, E.; Zhou, Y.; Yu, X.; Senanayake, S. D.; Cho, S.-
# J.; Kim, K.-B.; Chung, K. Y.; Yang, X.-Q.; Nam, K.-W. Structural
# Changes and Thermal Stability of Charged LiNixMnyCozO2 Cathode
# Materials Studied by Combined In Situ Time-Resolved XRD and Mass
# Spectroscopy. ACS Appl. Mater. Interfaces 2014, 6, 22594−22601.
# (17) Woo, S.-G.; Han, J.-H.; Kim, K. J.; Kim, J.-H.; Yu, J.-S.; Kim, Y.-
# J. Surface Modification by Sulfated Zirconia on High-Capacity Nickel-
# Based Cathode Materials for Li-Ion Batteries. Electrochim. Acta 2015,
# 153, 115−121.
#
# 26170
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# Article
#
# (36) Yang, X. Q.; Sun, X.; McBreen, J. New Findings on the Phase
# Transitions in Li1‑xNiO2:
# In Situ Synchrotron X-Ray Diffraction
# Studies. Electrochem. Commun. 1999, 1, 227−232.
# (37) Zhang, X.; Mauger, A.; Lu, Q.; Groult, H.; Perrigaud, L.;
# Julien, C. M. Synthesis and Characterization of
# Gendron, F.;
# LiNi1/3Mn1/3Co1/3O2 by Wet-Chemical Method. Electrochim. Acta
# 2010, 55, 6440−6449.
# (38) Van der Ven, A.; Aydinol, M. K.; Ceder, G.; Kresse, G.; Hafner,
# J. First-Principles Investigation of Phase Stability in LixCoO2. Phys.
# Rev. B: Condens. Matter Mater. Phys. 1998, 58, 2975−2987.
# (39) Watanabe, S.; Kinoshita, M.; Hosokawa, T.; Morigaki, K.;
# Nakura, K. Capacity Fading of LiAlyNi1−x−yCoxO2 Cathode for
# Lithium-Ion Batteries during Accelerated Calendar and Cycle Life
# Tests (effect of Depth of Discharge in Charge−discharge Cycling on
# the Suppression of the Micro-Crack Generation of LiAlyNi1−x−yCoxO2
# Particle). J. Power Sources 2014, 260, 50−56.
# (40) Sun, G.; Sui, T.; Song, B.; Zheng, H.; Lu, L.; Korsunsky, A. M.
# On the Fragmentation of Active Material Secondary Particles in
# Lithium Ion Battery Cathodes Induced by Charge Cycling. Extreme
# Mech. Lett. 2016, 9, 449−458.
# (41) Michalak, B.; Sommer, H.; Mannes, D.; Kaestner, A.;
# Brezesinski, T.; Janek, J. Gas Evolution in Operating Lithium-Ion
# Batteries Studied In Situ by Neutron Imaging. Sci. Rep. 2015, 5, 15627.
# (42) Berkes, B. B.; Schiele, A.; Sommer, H.; Brezesinski, T.; Janek, J.
# On the Gassing Behavior of Lithium-Ion Batteries with NCM523
# Cathodes. J. Solid State Electrochem. 2016, 20, 2961−2967.
# (43) Petibon, R.; Xia, J.; Ma, L.; Bauer, M. K.; Nelson, K. J.; Dahn, J.
# R. Electrolyte System for High Voltage Li-Ion Cells. J. Electrochem. Soc.
# 2016, 163, A2571−A2578.
# (44) Xia, J.; Petibon, R.; Xiong, D.; Ma, L.; Dahn, J. R. Enabling
# Linear Alkyl Carbonate Electrolytes for High Voltage Li-Ion Cells. J.
# Power Sources 2016, 328, 124−135.
#
# (18) Zhao, X.; Zhuang, Q.-C.; Wu, C.; Wu, K.; Xu, J.-M.; Zhang, M.-
# Y.; Sun, X.-L. Impedance Studies on the Capacity Fading Mechanism
# of Li(Ni0.5Co0. 2Mn0. 3)O2 Cathode with High-Voltage and High-
# Temperature. J. Electrochem. Soc. 2015, 162, A2770−A2779.
# (19) Kondrakov, A. O.; Geßwein, H.; Galdina, K.; de Biasi, L.;
# Meded, V.; Filatova, E. O.; Schumacher, G.; Wenzel, W.; Hartmann,
# P.; Brezesinski, T. Charge-Transfer-Induced Lattice Collapse in Ni-
# Rich NCM Cathode Materials during Delithiation. J. Phys. Chem. C
# 2017, 121, 24381−24388.
# (20) de Biasi, L.; Lieser, G.; Rana, J.; Indris, S.; Dräger, C.; Glatthaar,
# S.; Mönig, R.; Ehrenberg, H.; Schumacher, G.; Binder, J. R.; et al.
# Unravelling the Mechanism of Lithium Insertion into and Extraction
# from Trirutile-Type LiNiFeF6 Cathode Material for Li-Ion Batteries.
# CrystEngComm 2015, 17, 6163−6174.
# (21) Thompson, P.; Cox, D. E.; Hastings, J. B. Rietveld Refinement
# of Debye−Scherrer Synchrotron X-Ray Data from Al2O3. J. Appl.
# Crystallogr. 1987, 20, 79−83.
# (22) Balzar, D.; Ledbetter, H. Voigt-Function Modeling in Fourier
# Analysis of Size- and Strain-Broadened X-Ray Diffraction Peaks. J.
# Appl. Crystallogr. 1993, 26, 97−103.
# (23) Balzar, D.; Audebrand, N.; Daymond, M. R.; Fitch, A.; Hewat,
# A.; Langford, J. I.; Le Bail, A.; Louër, D.; Masson, O.; McCowan, C.
# N.; et al. Size−strain Line-Broadening Analysis of the Ceria Round-
# Robin Sample. J. Appl. Crystallogr. 2004, 37, 911−924.
# (24) Norby, P. Synchrotron Powder Diffraction Using Imaging
# Plates: Crystal Structure Determination and Rietveld Refinement. J.
# Appl. Crystallogr. 1997, 30, 21−30.
# (25) Momma, K.;
# Izumi, F. VESTA 3 for Three-Dimensional
# Visualization of Crystal, Volumetric and Morphology Data. J. Appl.
# Crystallogr. 2011, 44, 1272−1276.
# (26) Kim, D.; Lim, J.-M.; Lim, Y.-G.; Yu, J.-S.; Park, M.-S.; Cho, M.;
# Cho, K. Design of Nickel-Rich Layered Oxides Using d Electronic
# Donor for Redox Reactions. Chem. Mater. 2015, 27, 6450−6456.
# (27) Koyama, Y.; Yabuuchi, N.; Tanaka, I.; Adachi, H.; Ohzuku, T.
# Solid-State Chemistry and Electrochemistry of LiCo1/3Ni1/3Mn1/3O2
# for Advanced Lithium-Ion Batteries. J. Electrochem. Soc. 2004, 151,
# A1545.
# (28) Schipper, F.; Dixit, M.; Kovacheva, D.; Talianker, M.; Haik, O.;
# Grinblat, J.; Erickson, E. M.; Ghanty, C.; Major, D. T.; Markovsky, B.;
# et al. Stabilizing Nickel-Rich Layered Cathode Materials by a High-
# Charge Cation Doping Strategy: Zirconium-Doped Li-
# Ni0.6Co0.2Mn0.2O2. J. Mater. Chem. A 2016, 4, 16073−16084.
# (29) Luo, G.; Zhao, J.; Ke, X.; Zhang, P.; Sun, H.; Wang, B. Structure,
# Electrode Voltage and Activation Energy of LiMnxCoyNi1‑x‑yO2 Solid
# Solutions as Cathode Materials for Li Batteries from First-Principles. J.
# Electrochem. Soc. 2012, 159, A1203−A1208.
# (30) Li, W.; Reimers, J. N.; Dahn, J. R. In Situ X-Ray Diffraction and
# Electrochemical Studies of Li1‑xNiO2. Solid State Ionics 1993, 67, 123−
# 130.
# (31) Lee, K. K.; Yoon, W. S.; Kim, K. B.; Lee, K. Y.; Hong, S. T.
# Characterization of LiNi0.85Co0.10M0.05O2 (M = Al, Fe) as a Cathode
# Material for Lithium Secondary Batteries. J. Power Sources 2001, 97-98,
# 308−312.
# (32) Myung, S.-T.; Cho, M. H.; Hong, H. T.; Kang, T. H.; Kim, C.-S.
# Electrochemical Evaluation of Mixed Oxide Electrode for Li-Ion
# Secondary Batteries: Li1.1Mn1.9O4 and LiNi0.8Co0.15Al0.05O2. J. Power
# Sources 2005, 146, 222−225.
# (33) Shannon, R. D. Revised Effective Ionic Radii and Systematic
# Studies of Interatomic Distances in Halides and Chalcogenides. Acta
# Crystallogr., Sect. A: Cryst. Phys., Diffr., Theor. Gen. Crystallogr. 1976, 32,
# 751−767.
# (34) Park, B.-C.; Bang, H. J.; Yoon, C. S.; Myung, S.-T.; Prakash, J.;
# Sun, Y.-K. Structural Transformation of Li[Ni0.5−xCo2xMn0.5−x]O2]
# (2x ≤ 0.1) Charged in High-Voltage Range (4.5 V). J. Electrochem. Soc.
# 2007, 154, A520.
# (35) Ohzuku, T.; Ueda, A.; Nagayama, M. Electrochemistry and
# Structural Chemistry of LiNiO2 (R-3m) for 4 V Secondary Lithium
# Cells. J. Electrochem. Soc. 1993, 140, 1862−1870.
#
# 26171
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171

# %%
def remove_last_section_from_pdf(file_path: str) -> str:
    """
    PDF 파일에서 조건에 따라 특정 섹션 이후를 제외하고 본문 텍스트만 반환합니다.

    Args:
        file_path (str): PDF 파일 경로.

    Returns:
        str: 특정 섹션 제외된 본문 텍스트.
    """
    full_text = extract_text(file_path)
    #  = ""
    
    # # PDF의 모든 페이지에서 텍스트 추출
    # for page in doc:
    #     full_text += page.get_text() + "\n"
    
    # for page in doc:
    #     blocks = page.get_text("blocks") # 블록 단위 추출
    #     blocks.sort(key=lambda b: (b[1], b[0])) # 좌표 기준 정렬 (y, x)

    # for block in blocks:
    #     text += block[4] + "\n\n" # 문단 구분을 위해 두 줄 바꿈 추가    
    
    # Unicode 정규화
    full_text = unicodedata.normalize("NFKD", full_text)

    # 특정 단어가 있는지 확인
    contains_advancedsciencenews = "www.advancedsciencenews.com" in full_text
    contains_chemelectrochem = "www.chemelectrochem.org" in full_text
    contains_materialsviews = "www.MaterialsViews.com" in full_text

    # print("조건 확인:")
    # print(f"Contains 'www.advancedsciencenews.com': {contains_advancedsciencenews}")
    # print(f"Contains 'ChemElectroChem': {contains_chemelectrochem}")
    # print(f"Contains 'www.MaterialsViews.com': {contains_materialsviews}")

    # 조건에 따라 키워드 설정
    if contains_materialsviews:
        keyword = "Acknowledgements"
    elif contains_advancedsciencenews or contains_chemelectrochem:
        keyword = "Conflict of Interest"
    else:
        keyword = "References"

    # 키워드로 시작하는 부분 중 가장 마지막 부분 찾기
    if keyword == "Conflict of Interest":
        keyword_pattern = r"(?i)c[ o]*n[ f]*l[ i]*c[ t]*[\uFB00]*[ o]*f[ i]*n[ t]*e[ r]*e[ s]*t"
    else:
        keyword_pattern = "(?i)" + keyword.replace(" ", r"\s*")

    matches = list(re.finditer(keyword_pattern, full_text))

    if matches:
        # 마지막 매치의 시작 위치를 기준으로 텍스트를 잘라냄
        last_match = matches[-1]
        full_text = full_text[:last_match.start()]

    return full_text

# %%
preprocessed_text = remove_last_section_from_pdf(path)

# %%
print(preprocessed_text)
# Out:
# Cite This: J. Phys. Chem. C 2017, 121, 26163-26171
#
# Article
#
# pubs.acs.org/JPCC
#
# Between Scylla and Charybdis: Balancing Among Structural Stability
# and Energy Density of Layered NCM Cathode Materials for Advanced
# Lithium-Ion Batteries
# Lea de Biasi,*,†
# Pascal Hartmann,*,†,⊥
#
# Aleksandr O. Kondrakov,
# †,∥
# and Jürgen Janek
#
# Torsten Brezesinski,*,†
#
# Holger Geßwein,
#
# †,⊥
#
# ‡,§
#
# †
# Battery and Electrochemistry Laboratory, Institute of Nanotechnology and
# Technology, Hermann-von-Helmholtz-Platz 1, 76344 Eggenstein-Leopoldshafen, Germany
# §
# Helmholtz Institute Ulm for Electrochemical Energy Storage, Helmholtzstraße 11, 89081 Ulm, Germany
# ⊥
# BASF SE, 67056 Ludwigshafen, Germany
# Institute of Physical Chemistry, Justus-Liebig-University Giessen, Heinrich-Buff-Ring 17, 35392 Giessen, Germany
# *S Supporting Information
#
# ∥
#
# ‡
# Institute for Applied Materials, Karlsruhe Institute of
#
# ABSTRACT: Two major strategies are currently pursued to
# improve the energy density of
# lithium-ion batteries using
# LiNixCoyMnzO2 (NCM) cathode materials. One is to increase
# the fraction of redox active Ni (≥80%), which allows larger
# amounts of Li to be extracted at a given cutoff voltage (Umax).
# The other is to increase Umax,
# in particular for medium-Ni
# content NCM materials. However, the accompanying lattice
# changes ultimately lead to capacity fading in both cases. Here
# the structural changes occurring in Li1.02NixCoyMnzO2 (with x
# = 1/3, 0.5, 0.6, 0.7, 0.8 and 0.85) during cycling operation in
# the voltage range between 3.0 and 4.6 V vs Li are quantified by
# means of operando X-ray diffraction combined with detailed Rietveld analysis. All samples show a large decrease in unit cell
# volume upon charging, ranging from 2.4% for NCM111 (33% Ni) to 8.0% for NCM851005 (85% Ni). To make a fair
# comparison of the structural stability of the different NCM materials, energy densities as a function of Umax are estimated and
# correlated with X-ray diffraction results. It is shown that NCMs with a lower Ni content allow for specific energies similar to that
# of, e.g., Ni-rich NCM811 (80% Ni) when operated at sufficiently high Umax, but still undergo less pronounced changes in
# structure. Nevertheless, as indicated by charge/discharge tests, the capacity retention of low- and medium-Ni content NCMs
# cycled to high Umax is also strongly affected by factors other than stability of the layered crystal lattice (electrolyte decomposition
# etc.). Overall, it is demonstrated that the complexity of the degradation processes needs to be better understood to identify
# optimal cycling conditions for specific cathode compositions.
#
# ■ INTRODUCTION
#
# The continuous development of optimized lithium-ion batteries
# (LIBs) is indispensable on the way to sustainable, cost-efficient
# and long-range electric vehicles (EVs). Besides the quest for
# high power performance and good safety characteristics,
# increasing the energy density appears to be a prime goal in
# the development of next-generation LIBs.1 Layered LiCoO2
# (LCO) is the state-of-the-art cathode material for commercial
# application in consumer electronics for more than 25 years.
# However, because of the high price of cobalt metal, the specific
# costs ($/kWh) of LCO-based LIBs do not allow for the
# introduction of EVs into the mass market. Layered lithium
# transition metal (TM) oxides of the general formula LiTMO2
# (with TM = 3d transition metals such as Ni, Co and Mn),2−4
# so-called NCMs, allow to cut the costs and surpass the energy
# density limit of LCO cells due to the synergetic effect of the
# different TMs.5 Current 18650 cells comprising LCO and
#
# NCM cathode materials reach practical values of 740 Wh/L
# (250 Wh/kg) and 770 Wh/L (270 Wh/kg), respectively. While
# Ni increases the specific capacity, Mn has a stabilizing effect on
# the layered α-NaFeO2-type crystal structure and Co tends to
# mix less with Li and further reduces the amount of Ni in the Li
# layers.2,6 Extraction of Li proceeds mainly through oxidation of
# Ni and Co,7 yet the Ni ions are believed to be the main redox
# active species in the voltage range between 3.0 and 4.2 V (vs
# graphite).8 Thus, increasing substitution of Ni by both Mn and
# Co leads to a decrease in specific capacity.9 For example,
# LiNi1/3Co1/3Mn1/3O2 (NCM111) delivers a specific capacity of
# about 150 mAh/g for Umax = 4.2 V (when cycled against
# graphite, or Umax = 4.3 V when cycled against lithium), which is
#
# June 28, 2017
#
# Received:
# Revised: October 26, 2017
# Published: October 31, 2017
#
# © 2017 American Chemical Society
#
# 26163
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# Downloaded via CHUNG-ANG UNIV on December 23, 2024 at 08:17:45 (UTC).See https://pubs.acs.org/sharingguidelines for options on how to legitimately share published articles.The Journal of Physical Chemistry C
#
# not sufficient for long-range EVs though. In recent years, it has
# been demonstrated that high-Ni LiNixCoyMnzO2 (x ≫ 1/3)
# allow for much higher degrees of delithiation, and therefore
# specific capacities in excess of 150 mAh/g.10 Nevertheless,
# increasing the Ni content is associated with a decrease in
# capacity retention, which is a major drawback so far.11 Part of
# the reason for this is the fact that Ni-rich materials suffer from
# larger volumetric changes with delithiation,
# leading to more
# failure.10,12−15 Besides,
# severe degradation and mechanical
# increasing the Ni content results in increased surface reactivity
# (electrolyte decomposition).16−18
#
# Another strategy to improve the energy density is to increase
# the charge cutoff voltage to over 4.3 V vs Li. For the sake of
# clarity, all voltages are given with respect to Li/Li+ in the
# following (note that the voltage difference among cells using
# graphite [full-cell geometry] and lithium metal anodes [half-cell
# geometry] is around −100 mV). As an example, NCM111 has
# been reported to deliver a specific capacity of about 200 mAh/g
# in the voltage range from 2.5 to 4.6 V.2 However, charging
# NCM cathode materials to higher states of charge (SOC) is
# accompanied by more pronounced changes
# in lattice
# structure.10,13,19
#
# From both industrial and scientific points of view,
# the
# question what cathode composition and voltage range provides
# the optimum in terms of energy density, costs, stability and
# safety is yet to be answered. For automotive applications, in
# important
# particular, energy density is one of
# parameters.
# In literature, electrode materials for LIBs are
# often benchmarked for a given voltage range or degree of
# (de)lithiation. For example, Ishidzu et al. studied and compared
# the volume changes of NCMs of different composition in the
# voltage range of 2.5−4.5 V.13 Nevertheless, from a techno-
# logical point of view, the mere evaluation of, e.g., cycling
# stability for a given maximum cell voltage may not be sufficient.
# Cells using low-Ni NCMs typically last significantly longer than
# high-Ni NCM-based cells when operated in the same voltage
# range. However, for the latter, a significantly lower maximum
# cell voltage would be required for achieving similar energy
# densities.
#
# the most
#
# In this work, we show that NCM111 and NCM811 cells
# provide virtually the same energy density at 4.6 and 4.3 V,
# respectively. Furthermore, we demonstrate that
# is very
# important to analyze both the performance and structural
# degradation of different Ni content NCM cathodes for a given
# energy level rather than voltage range in a reference-type LIB.
# To allow for a reasonable performance assessment, we estimate
# the energy densities as a function of Umax for a variety of NCMs
# and correlate the results with structural properties of
# the
# materials from operando X-ray diffraction.
#
# it
#
# ■ EXPERIMENTAL SECTION
#
# Li1.02NixMnyCozO2 (x + y + z = 1) cathode materials with x:y:z
# = 1:1:1 (NCM111), 5:2:3 (NCM523), 6:2:2 (NCM622), 7:2:1
# (NCM721), 8:1:1 (NCM811) and 85:10:5 (NCM851005)
# were obtained from BASF SE (Ludwigshafen, Germany). All
# electrodes were prepared by slurry casting onto Al foil using a
# KTF-S roll-to-roll coater (Mathis AG). For NCM622,
# NCM721, NCM811 and NCM851005, slurries were obtained
# by dispersing cathode material (94 wt %), Super C65 (1 wt %,
# Timcal) and SFG6L (2 wt %, Timcal) conductive carbon
# additives as well as Solef 5130 PVDF binder (3 wt %, Solvay) in
# 1-ethyl-2-pyrrolidone (NEP). For NCM111 and NCM523,
# slurries were obtained by dispersing cathode material (93 wt
#
# Article
#
# %), Super C65 (1.5 wt %) and SFG6L (2.5 wt %) conductive
# carbon additives as well as Solef 5130 PVDF binder (3 wt %) in
# NEP.
#
# Electrochemical characterization was conducted at 25 °C on
# coin-type cells. The cells were assembled inside an Ar-filled
# glovebox (MBraun) by stacking cathode, glass microfiber
# separator (GF/D, GE Healthcare Life Sciences, Whatman) and
# lithium foil anode (Albemarle Germany GmbH) of diameters
# 13, 17, and 13 mm, respectively, using 250 μL of either LP30 (1
# M LiPF6 in a 1:1 [wt/wt] mixture of ethylene carbonate and
# dimethyl carbonate) or LP47 (1 M LiPF6 in a 3:7 [w/w]
# mixture of ethylene carbonate and diethyl carbonate) as
# loadings were 2.0 mAh/
# electrolytes (BASF SE). The areal
# cm2 at C/10 and Umax = 4.3 V. The energy densities were
# calculated from the specific capacity and average discharge
# voltage and are given as average of two cycles from two to four
# cells. Powder X-ray diffraction (XRD) was performed using a
# laboratory diffractometer optimized for battery research.20 The
# diffractometer is equipped with a molybdenum microfocus
# rotating anode (Mo−Kα
# 1,2) and a Pilatus 300 K−W area
# detector. The high brilliance of
# the primary beam allows
# penetration of pouch cells, so that measurements can be
# performed under realistic conditions (without using custom
# cells or X-ray windows). For operando XRD, pouch cells were
# assembled inside a dry room with dew point below −50 °C by
# stacking cathode (20 mm × 40 mm), Celgard 2500
# polypropylene separator (30 mm × 50 mm) and lithium foil
# anode (24 mm × 44 mm) using 250 μL of LP47 (see Figure S1
# for comparison of the cyclability of pouch cells and standard
# coin cells). Prior to XRD, the electrodes were galvanostatically
# cycled in the voltage range between 3.0 and 4.3 V for three
# cycles. Then, the cells were inserted into the diffractometer and
# charged/discharged at C/10 during the measurement. A
# constant voltage step at the cutoff voltages was applied for 1
# h to allow for thermodynamic equilibration of the electrode
# materials. 2D diffraction images were collected in transmission
# geometry with an exposure time of 75 s. The intensity of two
# consecutive images was added up and then integrated to obtain
# 1D patterns for further evaluation, resulting in a total time
# resolution of 150 s. Data analysis was performed by Rietveld
# refinement using TOPAS-Academic version 5. The instrumen-
# tal resolution function was determined from an annealed CeO2
# sample and described by means of a (Thompson-Cox-
# Hastings) pseudo-Voigt profile function.21 The analysis
# comprised refinement of lattice parameters a and c and atomic
# coordinate z of the oxygen position. Both lithium (occ3a = 1.00,
# occ3b = 0.02) and oxygen occupancy parameters (occ6c = 1.00)
# were fixed during refinement. Broadening effects (apparent
# crystallite size, microstrain etc.) were accounted for by
# convolution-based profile fitting as implemented in TOPAS.
# This approach is equivalent
# to the double-Voigt method
# described by Balzar et al. and is based on the integral breadth of
# the diffraction lines.22,23 Background refinement was made
# using a 10-term Chebyshev polynomial function. Zero-point
# correction was used to correct for sample displacement errors
# of both the cathode material and Al current collector.24 The
# VESTA software package was used to generate crystal structure
# images.25
#
# ■ RESULTS AND DISCUSSION
#
# Electrochemical Characteristics. Electrochemical testing
# was performed on Li1.02NixCoyMnzO2 cathode materials with
# x:y:z = 1:1:1 (NCM111), 5:2:3 (NCM523), 6:2:2 (NCM622),
#
# 26164
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# Article
#
# 7:2:1 (NCM721), 8:1:1 (NCM811),
# and 85:10:5
# (NCM851005) using coin-type cells with a lithium metal
# counter electrode. Figure 1a shows charge/discharge curves
#
# Figure 2. (a) Specific discharge capacity as a function of Umax for the
# different Ni content NCM-based cells. (b) Maximum gravimetric
# energy densities calculated from the specific capacity and average
# discharge voltage.
#
# Figure 1. (a) Charge/discharge curves at C/5 in the voltage range
# between 3.0 and 4.6 V and (b) the corresponding differential capacity
# plots for the different Ni content NCM-based cells.
#
# obtained at C/5 between 3.0 and 4.6 V. As is seen, the higher
# the Ni content the more Li can be extracted, and therefore the
# higher the specific capacity (see also Figure 2a). Besides, the
# voltage profiles show different features depending on the Ni
# content due to different redox behavior, as indicated by the
# differential capacity curves in Figure 1b. While in the ternary
# system of LiNiO2, LiCoO2 and LiMnO2 the TMs are formally
# in the trivalent state (i.e., Ni3+, Co3+ and Mn3+), charge transfer
# is assumed to occur between Ni and Mn in the LiNixCoyMnzO2
# phase. The reason is the difference in electronegativity.26,27
# Theoretical calculations suggest
# formal oxidation states of
# mixed divalent and trivalent Ni, trivalent Co, and tetravalent
# Mn.26−28 However, the main redox active species are believed
# to be Ni2+ and Ni3+, and their concentration depends on the
# overall TM ratio.
#
# All samples show characteristic redox peaks in the voltage
# range of 3.6−3.8 V (Figure 1b). The peak splitting indicates the
# presence of two Ni redox pairs (namely, Ni2+/Ni3+ and Ni3+/
# Ni4+) with cycling, and their shape and area ratio point to
# different contributions depending on the Ni content.26,27 The
# peaks shift toward lower voltage with increasing Ni content,
# leading to a decrease in the average charge/discharge voltages.
# This phenomenon has been observed before and attributed to
# the lower redox potential of Ni than Co.13,29 Kim et al. showed
# that the electrochemical equilibrium potentials of these redox
# reactions also vary with Mn content in the structure.26 Using
# experimental GITT and computational calculations they found
# that high-Ni NCMs exhibit redox activity at lower relative
# voltages. However, less Mn also leads to lower voltages for the
# same Ni content. The Ni-rich samples, in particular NCM811
# and NCM851005, further show features in the high-voltage
#
# similar
#
# to that of
#
# region above 3.9 V, which we believe are due to multiphase
# transitions caused by slight distortions in the crystal structure.
# Such transformations have been observed for LiNiO2 during
# delithiation and are likely to occur in high-Ni NCMs as well.30
# Both NCM811 and NCM851005 show an additional voltage
# plateau around 4.2 V, appearing as a distinct peak in the
# differential capacity curves. This peak is not seen for the other
# NCM materials, and its origin has not yet been clearly resolved.
# Figure 2a depicts the specific capacity of the NCM cathodes
# after charging to 4.3 V ≤ Umax
# ≤ 4.6 V. As expected, both
# NCM811 and NCM851005 provide the highest values,
# irrespective of the Umax. At 4.3 V these cathode materials
# deliver capacities
# the widely used
# LiNi0.8Co0.15Al0.05O2 (NCA).31,32 The gravimetric energy
# density (GED) calculated as the product of specific charge
# and average discharge voltage is shown in Figure 2b. The GED
# increases with both increasing Ni content and Umax.
#
# To make a fair comparison among the different NCM
# materialsalso with respect to their structural stability (see
# below)Umax
# required to achieve the specific energy of
# NCM811 operated at 4.3 V (≈750 Wh/kg) was calculated
# for each composition. According to our estimates, NCM111,
# NCM523, NCM622, NCM721, and NCM851005 need to be
# operated at around 4.6, 4.55, 4.45, 4.4, and 4.25 V, respectively
# (Figure 3). The obtained Umax values agree well with the
# technological
# roadmaps of some cell manufacturers (e.g.,
# NCM622 at 4.35 V in full-cells). Both NCM811 and
# NCM851005 offer the highest energy densities when Umax is
# limited to 4.3 V, as is currently the case in commercial high-
# performance LIBs. However, similar GEDs can be achieved
# with the low- and medium-Ni NCM materials when increasing
# the maximum operation voltage. Thus,
# is of upmost
# importance to identify the optimum in terms of materials
# specific
# composition and operating voltage range for
#
# it
#
# 26165
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# Article
#
# Figure 3. Charge cutoff voltage as a function of Ni content required to
# achieve the gravimetric energy density of NCM811 at Umax = 4.3 V.
#
# applications. From a scientific point of view, this means that the
# major degradation processes need to be better understood. In
# the following we focus on the (crystallographic) volume
# changes of NCMs occurring in the voltage range between 3.0
# and 4.6 V since these are known to cause mechanical stress,
# which in turn leads to material fracture and fatigue.
# Structural Characteristics. An overview of
#
# the NCM
# materials employed in this work and their composition are
# given in Table 1. The samples exhibit a well-developed layered
# crystalline structure of α-NaFeO2-type (space group R3m̅ , Z =
# 3). It can be viewed as a stacking of alternating layers, in which
# TM and Li ions occupy octahedral sites in a cubic close-packed
# oxygen lattice (Figure 4). The Ni, Co and Mn ions are
# statistically distributed over the 3b site in first approximation. Li
# ions (Wyckoff site 3a) are located in the interslabs between the
# TM layers. We assume that 2% of the 3b site in the TM layer
# are occupied by Li ions because of the small Li excess.
#
# The lattice parameters of the pristine materials are given in
# Table 2. An increase in a with increasing Ni content
# is
# observed, which is due to the larger ionic radii of Ni2+ (0.69 Å)
# and Ni3+ (0.56 Å) compared to Co3+ (0.545 Å) and Mn4+
# (0.530 Å).33 In contrast, c decreases, which is somewhat
# surprising and seems to be related to the content of all three
# TMs (rather than Ni only). For example, substitution of Mn by
# Co is known to cause a decrease in both lattice parameters.34
# To gain insight into the evolution of the host structure with
# cycling, a series of operando XRD measurements were
# performed on the different NCM materials. Prior to XRD,
# the cells were cycled between 3.0 and 4.3 V first at C/10 for
# two cycles and then at C/5 for another cycle. The Li content δ
# per formula unit was around 1.02 for the pristine samples. To
# estimate δ at the beginning and end of the fourth charge cycle,
# we assumed that Coulombic efficiencies of less than 100% are a
# result of Li loss from the cathode material only. This loss of
#
# Figure 4. Crystal structure and schematic of the unit cell of layered
# LiNixCoyMnzO2.
#
# Table 2. Lattice Parameters and Oxygen Coordinate for the
# Different Ni Content NCM Cathode Materials
#
# sample
#
# NCM111
# NCM523
# NCM622
# NCM721
# NCM811
# NCM851005
#
# a (Å)
#
# 2.8575(1)
# 2.8659(1)
# 2.8661(1)
# 2.8647(1)
# 2.8688(1)
# 2.8700(1)
#
# c (Å)
#
# 14.2166(5)
# 14.2234(3)
# 14.2062(3)
# 14.1808(4)
# 14.1867(4)
# 14.1795(3)
#
# z
#
# 0.2401(1)
# 0.2406(1)
# 0.2403(1)
# 0.2403(1)
# 0.2416(1)
# 0.2409(1)
#
# active Li during precycling was taken into account when
# calculating the amount of transferred Li+ ions. The NCM cells
# exhibited open-circuit voltages ranging from 3.57 to 3.65 V
# prior to the fourth cycle. As can be seen from Table 1, δ was
# ≤0.21 after charging (note that a constant voltage step at Umax
# = 4.6 V was applied for 1 h).
#
# Figure 5 depicts contour plots of operando XRD patterns for
# the reflection positions and
# NCM622. The evolution of
# intensities is shown together with the voltage profile. We
# note that Bragg reflections other than those originating from
# the cathode material can be assigned to aluminum (from the
# current collector and pouch cell foil). A distinct hkl-dependent
# shift is observed during cycling. The reflections with h = k = 0
# and l ≠ 0 (e.g., 003) first shift to lower 2θ values in the charge
# cycle. However, when the cell reaches a voltage of about 4.0 V,
# they shift back to the initial positions or to even larger 2θ
# values. In contrast, the reflections with h ≠ 0, k ≠ 0 and l = 0
# (e.g., 110) show the opposite trend in that they shift almost
# exclusively toward larger 2θ values. Reverse shifts are observed
# upon discharge, and all reflections virtually reach their initial
# positions at the end of the cycle. This leads us to conclude that
# the layered structure is well preserved. However, a slight
#
# Table 1. Composition of the Different Ni Content NCM Cathode Materials before Cycling and at the Beginning and End of the
# Fourth Charge Cycle
#
# sample
#
# NCM111
# NCM523
# NCM622
# NCM721
# NCM811
# NCM851005
#
# pristine state
#
# Li1.02Ni1/3Co1/3Mn1/3O2
# Li1.02Ni0.5Co0.2Mn0.3O2
# Li1.02Ni0.6Co0.2Mn0.2O2
# Li1.02Ni0.7Co0.2Mn0.1O2
# Li1.02Ni0.8Co0.1Mn0.1O2
# Li1.02Ni0.85Co0.1Mn0.05O2
#
# cycled state (3.0 V)
#
# Li0.94Ni1/3Co1/3Mn1/3O2
# Li0.93Ni0.5Co0.2Mn0.3O2
# Li0.93Ni0.6Co0.2Mn0.2O2
# Li0.91Ni0.7Co0.2Mn0.1O2
# Li0.90Ni0.8Co0.1Mn0.1O2
# Li0.89Ni0.85Co0.1Mn0.05O2
#
# cycled state (4.6 V)
#
# Li0.21Ni1/3Co1/3Mn1/3O2
# Li0.19Ni0.5Co0.2Mn0.3O2
# Li0.18Ni0.6Co0.2Mn0.2O2
# Li0.13Ni0.7Co0.2Mn0.1O2
# Li0.11Ni0.8Co0.1Mn0.1O2
# Li0.09Ni0.85Co0.1Mn0.05O2
#
# 26166
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# Article
#
# Figure 5. Contour plots of operando XRD patterns obtained on a NCM622-based cell showing the evolution of the reflection positions and
# intensities in the fourth charge/discharge cycle at C/10.
#
# broadening of the Bragg reflections occurs above 3.9 V and
# becomes more pronounced with further charging. During
# discharge a decrease in full width at half-maximum (fwhm) is
# observed below 3.8 V. As an example, Δfwhm003 is found to be
# 0.002° after the charge/discharge cycle, thus emphasizing the
# high reversibility of the (de)lithiation process.
#
# Structural multiphase transitions from hexagonal to mono-
# clinic (H1 → M), monoclinic to hexagonal (M → H2) and
# hexagonal to hexagonal (H2 → H3) typically occur when
# Li1−xNiO2 is delithiated with charging to 4.3 V, as indicated by
# the splitting of the original H1 10l and 11l reflections.30,35 It
# should be noted that the monoclinic modification differs only
# marginally from the hexagonal arrangement, and this break in
# symmetry leads to the appearance of additional reflections.
# those assigned to the
# However, Yang et al. showed that
# monoclinic phase can also be interpreted alternatively as two
# coexisting hexagonal phases.36 In both cases, nevertheless, the
# 2θ positions of the newly formed phase−whether hexagonal or
# monoclinic−would hardly differ
# the initial
# reflections (Figure S2). Overall, we believe that this effect
# contributes to the observed broadening of the reflections.
#
# from those of
#
# Analogous XRD measurements were conducted on all NCM
# cathode materials. Figure 6 depicts contour plots of operando
# XRD patterns in the 2θ range around the 003 reflection
# obtained during charge (see also contour plots for selected 2θ
# ranges in Figure S3). Degradation of the layered structure is not
# observed in the voltage range studied, and the Bragg reflections
# show similar trends in the evolution with time. Again, the 003
# reflection initially shifts to lower 2θ values and then to higher
# angles. Besides, the minimum in 2θ is similar at 8.4−8.5° for all
# samples. However, there are also significant differences. For
# example, the turning point (from decrease to increase) is at
# lower cell voltage for the high-Ni NCMs. Furthermore, the
# total shift in 2θ to higher angles is much less pronounced for
# the low- and medium-Ni NCMs (i.e., NCM111 and NCM523),
# with the position of the 003 reflection (8.6° 2θ) being virtually
# the 003
# identical before and after charging.
#
# In contrast,
#
# Figure 6. Contour plots of operando XRD patterns in the 2θ range of
# the 003 reflection obtained on the different Ni content NCM-based
# cells during the charge cycle.
#
# reflection shifts to significantly larger 2θ values in the high-
# voltage region with increasing Ni content and the final position
# is much different from the starting value.
#
# 26167
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# Article
#
# Parts a and b of Figure 7 show the relative changes in lattice
# parameters a and c versus the voltage with delithiation (charge)
#
# materials, the severe change along the c-direction presumably
# causes structural instability of the lattice.
#
# Because of the excellent time resolution of only 150 s per
# pattern we were able to directly correlate structural with
# electrochemical features. As mentioned above, both NCM811
# and NCM851005 show a subtle plateau in the voltage profile
# above 4.1 V, appearing as a peak in the differential capacity
# curves. On the basis of the XRD data we calculated the
# “differential unit cell volume”, which is the first derivative of the
# to cell voltage (Figure 8).
# unit cell volume with respect
#
# Figure 7. Relative changes in lattice parameters (a) a and (b) c as a
# function of cell voltage during delithiation for the different Ni content
# NCM materials.
#
# obtained from Rietveld refinement (Figure S4 plots the same
# data against the Li content). Rietveld refinement results for
# each operando XRD measurement at different SOC are given in
# Table S1, while Figure S5 shows selected Rietveld plots for
# NCM622. Both a and c strongly change with the voltage. The
# a-axis shrinks linearly at first, then levels off between 4.3 and 4.4
# V and finally increases again slightly. The magnitude of the
# latter increase is larger for the Ni-rich NCMs. In contrast, the c-
# axis first shows an increase by about 1.5%,
# followed by a
# decrease for all samples. This shrinkage always occurs when δ
# approaches 0.4 (Figure S4), and it is particularly severe for
# high-Ni NCMs (LiNixCoyMnzO2 with x ≥ 0.8). The general
# trends observed are in agreement with the study by Ishidzu et
# al.13
#
# It has been shown that the lattice parameter a reflects the
# TM−TM distance (in the TM layer).37,38 The ionic radii of the
# TMs decrease with increasing oxidation state, and therefore the
# decrease in lattice parameter a is likely associated with the
# oxidation of the TMs. The lattice parameter c represents the
# interslab distance of the Li layers.37,38 The initial increase is
# usually interpreted as a result of increasing Coulomb repulsion
# with Li extraction from the interlayer galleries. It has also been
# reported that lithium interacts electrostatically with oxygen.38
# This interaction is apparently accompanied by partial charge
# transfer, which in turn is believed to effectively screen the
# electrostatic repulsion between the oxygen layers. The
# screening effect
# reduced with increasing degree of
# delithiation, resulting in increased repulsion and expansion
# along the c-axis. When most of the lithium is removed, a
# contraction of the interslab distance is observed and with that a
# decrease in lattice parameter c.19 In particular for Ni-rich NCM
#
# is
#
# Figure 8. Differential capacity (black) and unit cell volume plots
# (blue) in the voltage range between 3.8 and 4.6 V for (a) NCM811
# and (b) NCM851005.
#
# Interestingly, a distinct peak is observed in the high-voltage
# region as in the case of the differential capacity curves. Even
# more interestingly, the peaks in the differential capacity and
# unit cell volume curves correlate with each other in terms of
# position (4.22 V for NCM811; 4.20 V for NCM851005) and
# relative height. This result thus provides evidence that the
# appearance of the redox peak around 4.2 V is due to structural
# effects, and we take it as an indication of an undesired phase
# transformation.
#
# From a practical point of view, it is important to note that the
# relative changes in lattice parameters a and c during charge lead
# to a large decrease in unit cell volume. As is shown in Figures
# 9a and S6, this decrease is more severe as the Ni content rises
# or, in other words, the total change in unit cell volume increases
# with increasing Ni content. Also,
# the change is highly
# anisotropic, resulting in significant strain in the NCM particles
# (see also Figure S7 for the evolution of c/a ratio with cell
# voltage). All NCM materials employed in this work are found
# to exhibit the most pronounced changes in unit cell volume at
# high SOC. This is apparent from the change in slope of the ΔV
# vs U curves, with the onset correlating with the collapse of the
# c-axis when δ ≈ 0.4 (see Figures 7b and S4). It is believed that
# lattice changes with cycling are the major source of mechanical
#
# 26168
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# Article
#
# Figure 9. (a) Relative changes in unit cell volume as a function of cell
# voltage for the different Ni content NCM materials. (b) Relative
# changes in unit cell volume for Umax = 4.3 V (empty circles) and Umax
# required to achieve the gravimetric energy density of NCM811 at 4.3
# V (solid circles).
#
# fracture, among
# stress in the particles and cause material
# others.12,15,39,40 Breakage of particles ultimately leads
# to
# disconnection of a fraction of active cathode material (i.e.,
# loss of electrical contact) and creates new and reactive surfaces,
# thereby accelerating degradation. Consequently,
# is a
# reasonable concern whether high-Ni NCMs have an intrinsic
# disadvantage over medium-Ni NCMs when it comes to cycling
# stability and longevity.
#
# it
#
# To better compare the microstructural stability among the
# different NCM samples, the relative unit cell volume changes
# with delithiation were evaluated in more detail. Figure 9b shows
# the corresponding data for Umax = 4.3 V and when operating
# the cathode materials at a similar specific energy or, more
# specifically, when charging to Umax required to achieve the
# gravimetric energy density of NCM811 at 4.3 V (Figure 3).
# Interestingly, the relative change in unit cell volume increases in
# a linear fashion with increasing Ni content when Umax
# is
# adjusted for each composition−as opposed to when the cutoff
# voltage is set at 4.3 V. From these data, it is evident that Ni-rich
# NCM materials are more prone to structural changes/
# mechanical deformation and therefore likely to fracture during
# operation (due to structural
# stress associated with the
# continuous shrinking and swelling of the primary crystallites
# in the secondary cathode particles).
#
# Finally, the cycling performance of the different Ni content
# NCMs was evaluated based on our specific energy concept
# (Figure 10, parts a and b). Noh et al. performed similar
# experiments using half-cells, but focused on the stability in the
# 3.0−4.3 V range.10 They found that the capacity retention
# significantly decreases with increasing Ni content (Figure 10b),
# which was explained by lower structural stability of high-Ni
# NCMs. At first glance, this result is not surprising and is also in
# agreement with our data, showing a nonlinear increase in
#
# Figure 10. (a) Capacity retention based on the second cycle discharge
# capacity for the different Ni content NCM-based cells cycled between
# 3.0 V and Umax required to achieve the gravimetric energy density of
# NCM811 at 4.3 V (i.e., 4.6 V, 4.55 V, 4.45 V, 4.4 and 4.25 V for
# NCM111, NCM523, NCM622, NCM721 and NCM851005,
# respectively). After the first cycle at C/10 was completed, the C-
# rates were set to C/4 charge and C/2 discharge for the subsequent
# cycles. (b) Comparison of the capacity retention after 100 cycles
# achieved by tailoring Umax and the results of Noh et al. for Umax = 4.3
# V.10
#
# relative volume change with increasing Ni content (Figure 9b)
# when the voltage on charge is limited to Umax = 4.3 V; so more
# structural degradation is expected when Umax is not tailored to
# the specific energy. However, when doing so, we find that Ni-
# rich NCMs show better capacity retention than samples with a
# low Ni content, although they have a clear disadvantage in
# terms of structural stability. This result provides evidence that
# the cycle life is also strongly affected by factors other than
# stability of the lattice structure. Particularly when the charge
# cutoff voltage is increased beyond the stability limit of organic
# electrolytes, electrolyte oxidation occurs (and with that gas
# evolution).41,42 For example, Dahn and co-workers showed
# recently that ethylene carbonate-containing electrolytes sig-
# nificantly reduce the cell performance and life at high
# voltages.43,44 Ultimately, this means that new electrolytes and
# additives are needed for high-voltage battery applications.
#
# Overall, it is not entirely clear which NCM cell chemistry
# provides the optimum in terms of energy density and cycling
# stability. To answer this question it is important to better
# understand the different LIB degradation processes and how
# they affect each other. Clearly, for high-Ni NCMs, improving
# the structural stability is one of the major challenges toward
# commercialization, while for medium-Ni NCMs,
# the high
# (surface) reactivity toward oxidative electrolyte decomposition
# at high operating voltage must be addressed.
#
# 26169
#
# DOI: 10.1021/acs.jpcc.7b06363
# J. Phys. Chem. C 2017, 121, 26163−26171
#
# The Journal of Physical Chemistry C
#
# ■ CONCLUSION
#
# A comparative study of the electrochemical and structural
# properties of a series of Li1.02NixCoyMnzO2 cathode materials
# with x = 1/3, 0.5, 0.6, 0.7, 0.8, and 0.85 in Li cells was
# performed in an attempt to identify the composition providing
# the optimum in energy density and stability. It is shown that
# high-Ni NCMs (NCM811 and NCM851005) offer the highest
# energy densities in the state-of-the-art voltage range of 3.0−4.3
# V. However, it is important to note that low- and medium-Ni
# NCMs, in principle, would be capable of delivering competitive
# energy densities if the maximum cell voltage could be increased
# without inducing deleterious side reactions (e.g., NCM111 and
# NCM622 at 4.6 and 4.45 V, respectively).
#
# in terms of mechanical
#
# Operando X-ray diffraction revealed that, irrespective of the
# Ni content, all NCM materials are subjected to structural
# changes during operation. Yet, most importantly, it was found
# that the total change in unit cell volume increases virtually
# linearly with increasing Ni content for similar energy densities
# (here based on that of NCM811 at 4.3 V). This leads us to the
# assumption that increasing the Ni content results in major
# challenges
# strain and structural
# degradation. However, galvanostatic charge/discharge tests
# indicated that Ni-rich NCMs
# show better capacity
# retention than low- and medium-Ni NCMs charged to higher
# cutoff voltages. This result emphasizes that each and every
# NCM cathode material has its own issues, especially when
# approaching the desired specific energy range required for
# application in electric vehicles. Thus, from a scientific point of
# view, it is a must to recognize and understand the (cell-voltage-
# dependent) limiting factors of the different Ni content NCMs
# and to find solutions to optimize their performance. Besides,
# the presence and interplay of degradation processes such as
# electrolyte decomposition and transition metal dissolution, to
# name a few, need to be thoroughly investigated when dealing
# with full-cells.
#
# still
#
# ■ ASSOCIATED CONTENT
#
# *S Supporting Information
# The Supporting Information is available free of charge on the
# ACS Publications website at DOI: 10.1021/acs.jpcc.7b06363.
# Comparison of NCM622-based pouch and coin cell
# voltage profiles, simulated diffraction patterns, contour
# plots of operando XRD patterns for selected 2θ ranges,
# relative changes in lattice parameters and unit cell
# volume versus the Li content, changes in c/a ratio as a
# function of cell voltage, Rietveld plots for NCM622, and
# summary of Rietveld refinement results for each operando
# XRD measurement (PDF)
#
# ■ AUTHOR INFORMATION
#
# Corresponding Authors
# *(L.d.B.) Telephone: +49 721 60826870. E-mail: lea.biasi@kit.
# edu.
# *(T.B.) Telephone: +49 721 60828827. E-mail:
# brezesinski@kit.edu.
# *(P.H.) Telephone: +49 621 6048636. E-mail: pascal.
# hartmann@basf.com.
# ORCID
# Aleksandr O. Kondrakov: 0000-0003-1465-2854
# Torsten Brezesinski: 0000-0002-4336-263X
#
# torsten.
#
# Article
#
# Notes
# The authors declare no competing financial interest.
#
# ■ ACKNOWLEDGMENTS
#
# This study is part of the projects being funded within the BASF
# International Network for Batteries and Electrochemistry.
#
# ■

# %%
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    separators=["\n\n"],
    chunk_size=500,
    chunk_overlap=100
)
texts = text_splitter.split_text(preprocessed_text)

# %%
len(texts)
# Out:
# 26

# %%
texts
# Out:
# ['Cite This: J. Phys. Chem. C 2017, 121, 26163-26171\n\nArticle\n\npubs.acs.org/JPCC\n\nBetween Scylla and Charybdis: Balancing Among Structural Stability\nand Energy Density of Layered NCM Cathode Materials for Advanced\nLithium-Ion Batteries\nLea de Biasi,*,†\nPascal Hartmann,*,†,⊥\n\nAleksandr O. Kondrakov,\n†,∥\nand Jürgen Janek\n\nTorsten Brezesinski,*,†\n\nHolger Geßwein,\n\n†,⊥\n\n‡,§\n\n†\nBattery and Electrochemistry Laboratory, Institute of Nanotechnology and\nTechnology, Hermann-von-Helmholtz-Platz 1, 76344 Eggenstein-Leopoldshafen, Germany\n§\nHelmholtz Institute Ulm for Electrochemical Energy Storage, Helmholtzstraße 11, 89081 Ulm, Germany\n⊥\nBASF SE, 67056 Ludwigshafen, Germany\nInstitute of Physical Chemistry, Justus-Liebig-University Giessen, Heinrich-Buff-Ring 17, 35392 Giessen, Germany\n*S Supporting Information\n\n∥\n\n‡\nInstitute for Applied Materials, Karlsruhe Institute of',
#  '∥\n\n‡\nInstitute for Applied Materials, Karlsruhe Institute of\n\nABSTRACT: Two major strategies are currently pursued to\nimprove the energy density of\nlithium-ion batteries using\nLiNixCoyMnzO2 (NCM) cathode materials. One is to increase\nthe fraction of redox active Ni (≥80%), which allows larger\namounts of Li to be extracted at a given cutoff voltage (Umax).\nThe other is to increase Umax,\nin particular for medium-Ni\ncontent NCM materials. However, the accompanying lattice\nchanges ultimately lead to capacity fading in both cases. Here\nthe structural changes occurring in Li1.02NixCoyMnzO2 (with x\n= 1/3, 0.5, 0.6, 0.7, 0.8 and 0.85) during cycling operation in\nthe voltage range between 3.0 and 4.6 V vs Li are quantified by\nmeans of operando X-ray diffraction combined with detailed Rietveld analysis. All samples show a large decrease in unit cell\nvolume upon charging, ranging from 2.4% for NCM111 (33% Ni) to 8.0% for NCM851005 (85% Ni). To make a fair\ncomparison of the structural stability of the different NCM materials, energy densities as a function of Umax are estimated and\ncorrelated with X-ray diffraction results. It is shown that NCMs with a lower Ni content allow for specific energies similar to that\nof, e.g., Ni-rich NCM811 (80% Ni) when operated at sufficiently high Umax, but still undergo less pronounced changes in\nstructure. Nevertheless, as indicated by charge/discharge tests, the capacity retention of low- and medium-Ni content NCMs\ncycled to high Umax is also strongly affected by factors other than stability of the layered crystal lattice (electrolyte decomposition\netc.). Overall, it is demonstrated that the complexity of the degradation processes needs to be better understood to identify\noptimal cycling conditions for specific cathode compositions.\n\n■ INTRODUCTION',
#  '■ INTRODUCTION\n\nThe continuous development of optimized lithium-ion batteries\n(LIBs) is indispensable on the way to sustainable, cost-efficient\nand long-range electric vehicles (EVs). Besides the quest for\nhigh power performance and good safety characteristics,\nincreasing the energy density appears to be a prime goal in\nthe development of next-generation LIBs.1 Layered LiCoO2\n(LCO) is the state-of-the-art cathode material for commercial\napplication in consumer electronics for more than 25 years.\nHowever, because of the high price of cobalt metal, the specific\ncosts ($/kWh) of LCO-based LIBs do not allow for the\nintroduction of EVs into the mass market. Layered lithium\ntransition metal (TM) oxides of the general formula LiTMO2\n(with TM = 3d transition metals such as Ni, Co and Mn),2−4\nso-called NCMs, allow to cut the costs and surpass the energy\ndensity limit of LCO cells due to the synergetic effect of the\ndifferent TMs.5 Current 18650 cells comprising LCO and\n\nNCM cathode materials reach practical values of 740 Wh/L\n(250 Wh/kg) and 770 Wh/L (270 Wh/kg), respectively. While\nNi increases the specific capacity, Mn has a stabilizing effect on\nthe layered α-NaFeO2-type crystal structure and Co tends to\nmix less with Li and further reduces the amount of Ni in the Li\nlayers.2,6 Extraction of Li proceeds mainly through oxidation of\nNi and Co,7 yet the Ni ions are believed to be the main redox\nactive species in the voltage range between 3.0 and 4.2 V (vs\ngraphite).8 Thus, increasing substitution of Ni by both Mn and\nCo leads to a decrease in specific capacity.9 For example,\nLiNi1/3Co1/3Mn1/3O2 (NCM111) delivers a specific capacity of\nabout 150 mAh/g for Umax = 4.2 V (when cycled against\ngraphite, or Umax = 4.3 V when cycled against lithium), which is\n\nJune 28, 2017',
#  'June 28, 2017\n\nReceived:\nRevised: October 26, 2017\nPublished: October 31, 2017\n\n© 2017 American Chemical Society\n\n26163\n\nDOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171\n\nDownloaded via CHUNG-ANG UNIV on December 23, 2024 at 08:17:45 (UTC).See https://pubs.acs.org/sharingguidelines for options on how to legitimately share published articles.\x0cThe Journal of Physical Chemistry C\n\nnot sufficient for long-range EVs though. In recent years, it has\nbeen demonstrated that high-Ni LiNixCoyMnzO2 (x ≫ 1/3)\nallow for much higher degrees of delithiation, and therefore\nspecific capacities in excess of 150 mAh/g.10 Nevertheless,\nincreasing the Ni content is associated with a decrease in\ncapacity retention, which is a major drawback so far.11 Part of\nthe reason for this is the fact that Ni-rich materials suffer from\nlarger volumetric changes with delithiation,\nleading to more\nfailure.10,12−15 Besides,\nsevere degradation and mechanical\nincreasing the Ni content results in increased surface reactivity\n(electrolyte decomposition).16−18\n\nAnother strategy to improve the energy density is to increase\nthe charge cutoff voltage to over 4.3 V vs Li. For the sake of\nclarity, all voltages are given with respect to Li/Li+ in the\nfollowing (note that the voltage difference among cells using\ngraphite [full-cell geometry] and lithium metal anodes [half-cell\ngeometry] is around −100 mV). As an example, NCM111 has\nbeen reported to deliver a specific capacity of about 200 mAh/g\nin the voltage range from 2.5 to 4.6 V.2 However, charging\nNCM cathode materials to higher states of charge (SOC) is\naccompanied by more pronounced changes\nin lattice\nstructure.10,13,19',
#  'From both industrial and scientific points of view,\nthe\nquestion what cathode composition and voltage range provides\nthe optimum in terms of energy density, costs, stability and\nsafety is yet to be answered. For automotive applications, in\nimportant\nparticular, energy density is one of\nparameters.\nIn literature, electrode materials for LIBs are\noften benchmarked for a given voltage range or degree of\n(de)lithiation. For example, Ishidzu et al. studied and compared\nthe volume changes of NCMs of different composition in the\nvoltage range of 2.5−4.5 V.13 Nevertheless, from a techno-\nlogical point of view, the mere evaluation of, e.g., cycling\nstability for a given maximum cell voltage may not be sufficient.\nCells using low-Ni NCMs typically last significantly longer than\nhigh-Ni NCM-based cells when operated in the same voltage\nrange. However, for the latter, a significantly lower maximum\ncell voltage would be required for achieving similar energy\ndensities.\n\nthe most\n\nIn this work, we show that NCM111 and NCM811 cells\nprovide virtually the same energy density at 4.6 and 4.3 V,\nrespectively. Furthermore, we demonstrate that\nis very\nimportant to analyze both the performance and structural\ndegradation of different Ni content NCM cathodes for a given\nenergy level rather than voltage range in a reference-type LIB.\nTo allow for a reasonable performance assessment, we estimate\nthe energy densities as a function of Umax for a variety of NCMs\nand correlate the results with structural properties of\nthe\nmaterials from operando X-ray diffraction.\n\nit\n\n■ EXPERIMENTAL SECTION',
#  'it\n\n■ EXPERIMENTAL SECTION\n\nLi1.02NixMnyCozO2 (x + y + z = 1) cathode materials with x:y:z\n= 1:1:1 (NCM111), 5:2:3 (NCM523), 6:2:2 (NCM622), 7:2:1\n(NCM721), 8:1:1 (NCM811) and 85:10:5 (NCM851005)\nwere obtained from BASF SE (Ludwigshafen, Germany). All\nelectrodes were prepared by slurry casting onto Al foil using a\nKTF-S roll-to-roll coater (Mathis AG). For NCM622,\nNCM721, NCM811 and NCM851005, slurries were obtained\nby dispersing cathode material (94 wt %), Super C65 (1 wt %,\nTimcal) and SFG6L (2 wt %, Timcal) conductive carbon\nadditives as well as Solef 5130 PVDF binder (3 wt %, Solvay) in\n1-ethyl-2-pyrrolidone (NEP). For NCM111 and NCM523,\nslurries were obtained by dispersing cathode material (93 wt\n\nArticle\n\n%), Super C65 (1.5 wt %) and SFG6L (2.5 wt %) conductive\ncarbon additives as well as Solef 5130 PVDF binder (3 wt %) in\nNEP.',
#  '\n\nElectrochemical characterization was conducted at 25 °C on\ncoin-type cells. The cells were assembled inside an Ar-filled\nglovebox (MBraun) by stacking cathode, glass microfiber\nseparator (GF/D, GE Healthcare Life Sciences, Whatman) and\nlithium foil anode (Albemarle Germany GmbH) of diameters\n13, 17, and 13 mm, respectively, using 250 μL of either LP30 (1\nM LiPF6 in a 1:1 [wt/wt] mixture of ethylene carbonate and\ndimethyl carbonate) or LP47 (1 M LiPF6 in a 3:7 [w/w]\nmixture of ethylene carbonate and diethyl carbonate) as\nloadings were 2.0 mAh/\nelectrolytes (BASF SE). The areal\ncm2 at C/10 and Umax = 4.3 V. The energy densities were\ncalculated from the specific capacity and average discharge\nvoltage and are given as average of two cycles from two to four\ncells. Powder X-ray diffraction (XRD) was performed using a\nlaboratory diffractometer optimized for battery research.20 The\ndiffractometer is equipped with a molybdenum microfocus\nrotating anode (Mo−Kα\n1,2) and a Pilatus 300 K−W area\ndetector. The high brilliance of\nthe primary beam allows\npenetration of pouch cells, so that measurements can be\nperformed under realistic conditions (without using custom\ncells or X-ray windows). For operando XRD, pouch cells were\nassembled inside a dry room with dew point below −50 °C by\nstacking cathode (20 mm × 40 mm), Celgard 2500\npolypropylene separator (30 mm × 50 mm) and lithium foil\nanode (24 mm × 44 mm) using 250 μL of LP47 (see Figure S1\nfor comparison of the cyclability of pouch cells and standard\ncoin cells). Prior to XRD, the electrodes were galvanostatically\ncycled in the voltage range between 3.0 and 4.3 V for three\ncycles. Then, the cells were inserted into the diffractometer and\ncharged/discharged at C/10 during the measurement. A\nconstant voltage step at the cutoff voltages was applied for 1\nh to allow for thermodynamic equilibration of the electrode\nmaterials. 2D diffraction images were collected in transmission\ngeometry with an exposure time of 75 s. The intensity of two\nconsecutive images was added up and then integrated to obtain\n1D patterns for further evaluation, resulting in a total time\nresolution of 150 s. Data analysis was performed by Rietveld\nrefinement using TOPAS-Academic version 5. The instrumen-\ntal resolution function was determined from an annealed CeO2\nsample and described by means of a (Thompson-Cox-\nHastings) pseudo-Voigt profile function.21 The analysis\ncomprised refinement of lattice parameters a and c and atomic\ncoordinate z of the oxygen position. Both lithium (occ3a = 1.00,\nocc3b = 0.02) and oxygen occupancy parameters (occ6c = 1.00)\nwere fixed during refinement. Broadening effects (apparent\ncrystallite size, microstrain etc.) were accounted for by\nconvolution-based profile fitting as implemented in TOPAS.\nThis approach is equivalent\nto the double-Voigt method\ndescribed by Balzar et al. and is based on the integral breadth of\nthe diffraction lines.22,23 Background refinement was made\nusing a 10-term Chebyshev polynomial function. Zero-point\ncorrection was used to correct for sample displacement errors\nof both the cathode material and Al current collector.24 The\nVESTA software package was used to generate crystal structure\nimages.25',
#  '■ RESULTS AND DISCUSSION\n\nElectrochemical Characteristics. Electrochemical testing\nwas performed on Li1.02NixCoyMnzO2 cathode materials with\nx:y:z = 1:1:1 (NCM111), 5:2:3 (NCM523), 6:2:2 (NCM622),\n\n26164\n\nDOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171\n\n\x0cThe Journal of Physical Chemistry C\n\nArticle\n\n7:2:1 (NCM721), 8:1:1 (NCM811),\nand 85:10:5\n(NCM851005) using coin-type cells with a lithium metal\ncounter electrode. Figure 1a shows charge/discharge curves\n\nFigure 2. (a) Specific discharge capacity as a function of Umax for the\ndifferent Ni content NCM-based cells. (b) Maximum gravimetric\nenergy densities calculated from the specific capacity and average\ndischarge voltage.\n\nFigure 1. (a) Charge/discharge curves at C/5 in the voltage range\nbetween 3.0 and 4.6 V and (b) the corresponding differential capacity\nplots for the different Ni content NCM-based cells.',
#  'Figure 1. (a) Charge/discharge curves at C/5 in the voltage range\nbetween 3.0 and 4.6 V and (b) the corresponding differential capacity\nplots for the different Ni content NCM-based cells.\n\nobtained at C/5 between 3.0 and 4.6 V. As is seen, the higher\nthe Ni content the more Li can be extracted, and therefore the\nhigher the specific capacity (see also Figure 2a). Besides, the\nvoltage profiles show different features depending on the Ni\ncontent due to different redox behavior, as indicated by the\ndifferential capacity curves in Figure 1b. While in the ternary\nsystem of LiNiO2, LiCoO2 and LiMnO2 the TMs are formally\nin the trivalent state (i.e., Ni3+, Co3+ and Mn3+), charge transfer\nis assumed to occur between Ni and Mn in the LiNixCoyMnzO2\nphase. The reason is the difference in electronegativity.26,27\nTheoretical calculations suggest\nformal oxidation states of\nmixed divalent and trivalent Ni, trivalent Co, and tetravalent\nMn.26−28 However, the main redox active species are believed\nto be Ni2+ and Ni3+, and their concentration depends on the\noverall TM ratio.',
#  'All samples show characteristic redox peaks in the voltage\nrange of 3.6−3.8 V (Figure 1b). The peak splitting indicates the\npresence of two Ni redox pairs (namely, Ni2+/Ni3+ and Ni3+/\nNi4+) with cycling, and their shape and area ratio point to\ndifferent contributions depending on the Ni content.26,27 The\npeaks shift toward lower voltage with increasing Ni content,\nleading to a decrease in the average charge/discharge voltages.\nThis phenomenon has been observed before and attributed to\nthe lower redox potential of Ni than Co.13,29 Kim et al. showed\nthat the electrochemical equilibrium potentials of these redox\nreactions also vary with Mn content in the structure.26 Using\nexperimental GITT and computational calculations they found\nthat high-Ni NCMs exhibit redox activity at lower relative\nvoltages. However, less Mn also leads to lower voltages for the\nsame Ni content. The Ni-rich samples, in particular NCM811\nand NCM851005, further show features in the high-voltage\n\nsimilar\n\nto that of',
#  'similar\n\nto that of\n\nregion above 3.9 V, which we believe are due to multiphase\ntransitions caused by slight distortions in the crystal structure.\nSuch transformations have been observed for LiNiO2 during\ndelithiation and are likely to occur in high-Ni NCMs as well.30\nBoth NCM811 and NCM851005 show an additional voltage\nplateau around 4.2 V, appearing as a distinct peak in the\ndifferential capacity curves. This peak is not seen for the other\nNCM materials, and its origin has not yet been clearly resolved.\nFigure 2a depicts the specific capacity of the NCM cathodes\nafter charging to 4.3 V ≤ Umax\n≤ 4.6 V. As expected, both\nNCM811 and NCM851005 provide the highest values,\nirrespective of the Umax. At 4.3 V these cathode materials\ndeliver capacities\nthe widely used\nLiNi0.8Co0.15Al0.05O2 (NCA).31,32 The gravimetric energy\ndensity (GED) calculated as the product of specific charge\nand average discharge voltage is shown in Figure 2b. The GED\nincreases with both increasing Ni content and Umax.',
#  'To make a fair comparison among the different NCM\nmaterials\ue0d5also with respect to their structural stability (see\nbelow)\ue0d5Umax\nrequired to achieve the specific energy of\nNCM811 operated at 4.3 V (≈750 Wh/kg) was calculated\nfor each composition. According to our estimates, NCM111,\nNCM523, NCM622, NCM721, and NCM851005 need to be\noperated at around 4.6, 4.55, 4.45, 4.4, and 4.25 V, respectively\n(Figure 3). The obtained Umax values agree well with the\ntechnological\nroadmaps of some cell manufacturers (e.g.,\nNCM622 at 4.35 V in full-cells). Both NCM811 and\nNCM851005 offer the highest energy densities when Umax is\nlimited to 4.3 V, as is currently the case in commercial high-\nperformance LIBs. However, similar GEDs can be achieved\nwith the low- and medium-Ni NCM materials when increasing\nthe maximum operation voltage. Thus,\nis of upmost\nimportance to identify the optimum in terms of materials\nspecific\ncomposition and operating voltage range for\n\nit\n\n26165\n\nDOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171\n\n\x0cThe Journal of Physical Chemistry C\n\nArticle\n\nFigure 3. Charge cutoff voltage as a function of Ni content required to\nachieve the gravimetric energy density of NCM811 at Umax = 4.3 V.\n\napplications. From a scientific point of view, this means that the\nmajor degradation processes need to be better understood. In\nthe following we focus on the (crystallographic) volume\nchanges of NCMs occurring in the voltage range between 3.0\nand 4.6 V since these are known to cause mechanical stress,\nwhich in turn leads to material fracture and fatigue.\nStructural Characteristics. An overview of',
#  'applications. From a scientific point of view, this means that the\nmajor degradation processes need to be better understood. In\nthe following we focus on the (crystallographic) volume\nchanges of NCMs occurring in the voltage range between 3.0\nand 4.6 V since these are known to cause mechanical stress,\nwhich in turn leads to material fracture and fatigue.\nStructural Characteristics. An overview of\n\nthe NCM\nmaterials employed in this work and their composition are\ngiven in Table 1. The samples exhibit a well-developed layered\ncrystalline structure of α-NaFeO2-type (space group R3m̅ , Z =\n3). It can be viewed as a stacking of alternating layers, in which\nTM and Li ions occupy octahedral sites in a cubic close-packed\noxygen lattice (Figure 4). The Ni, Co and Mn ions are\nstatistically distributed over the 3b site in first approximation. Li\nions (Wyckoff site 3a) are located in the interslabs between the\nTM layers. We assume that 2% of the 3b site in the TM layer\nare occupied by Li ions because of the small Li excess.',
#  'The lattice parameters of the pristine materials are given in\nTable 2. An increase in a with increasing Ni content\nis\nobserved, which is due to the larger ionic radii of Ni2+ (0.69 Å)\nand Ni3+ (0.56 Å) compared to Co3+ (0.545 Å) and Mn4+\n(0.530 Å).33 In contrast, c decreases, which is somewhat\nsurprising and seems to be related to the content of all three\nTMs (rather than Ni only). For example, substitution of Mn by\nCo is known to cause a decrease in both lattice parameters.34\nTo gain insight into the evolution of the host structure with\ncycling, a series of operando XRD measurements were\nperformed on the different NCM materials. Prior to XRD,\nthe cells were cycled between 3.0 and 4.3 V first at C/10 for\ntwo cycles and then at C/5 for another cycle. The Li content δ\nper formula unit was around 1.02 for the pristine samples. To\nestimate δ at the beginning and end of the fourth charge cycle,\nwe assumed that Coulombic efficiencies of less than 100% are a\nresult of Li loss from the cathode material only. This loss of\n\nFigure 4. Crystal structure and schematic of the unit cell of layered\nLiNixCoyMnzO2.\n\nTable 2. Lattice Parameters and Oxygen Coordinate for the\nDifferent Ni Content NCM Cathode Materials\n\nsample\n\nNCM111\nNCM523\nNCM622\nNCM721\nNCM811\nNCM851005\n\na (Å)\n\n2.8575(1)\n2.8659(1)\n2.8661(1)\n2.8647(1)\n2.8688(1)\n2.8700(1)\n\nc (Å)\n\n14.2166(5)\n14.2234(3)\n14.2062(3)\n14.1808(4)\n14.1867(4)\n14.1795(3)\n\nz',
#  'c (Å)\n\n14.2166(5)\n14.2234(3)\n14.2062(3)\n14.1808(4)\n14.1867(4)\n14.1795(3)\n\nz\n\n0.2401(1)\n0.2406(1)\n0.2403(1)\n0.2403(1)\n0.2416(1)\n0.2409(1)\n\nactive Li during precycling was taken into account when\ncalculating the amount of transferred Li+ ions. The NCM cells\nexhibited open-circuit voltages ranging from 3.57 to 3.65 V\nprior to the fourth cycle. As can be seen from Table 1, δ was\n≤0.21 after charging (note that a constant voltage step at Umax\n= 4.6 V was applied for 1 h).\n\nFigure 5 depicts contour plots of operando XRD patterns for\nthe reflection positions and\nNCM622. The evolution of\nintensities is shown together with the voltage profile. We\nnote that Bragg reflections other than those originating from\nthe cathode material can be assigned to aluminum (from the\ncurrent collector and pouch cell foil). A distinct hkl-dependent\nshift is observed during cycling. The reflections with h = k = 0\nand l ≠ 0 (e.g., 003) first shift to lower 2θ values in the charge\ncycle. However, when the cell reaches a voltage of about 4.0 V,\nthey shift back to the initial positions or to even larger 2θ\nvalues. In contrast, the reflections with h ≠ 0, k ≠ 0 and l = 0\n(e.g., 110) show the opposite trend in that they shift almost\nexclusively toward larger 2θ values. Reverse shifts are observed\nupon discharge, and all reflections virtually reach their initial\npositions at the end of the cycle. This leads us to conclude that\nthe layered structure is well preserved. However, a slight\n\nTable 1. Composition of the Different Ni Content NCM Cathode Materials before Cycling and at the Beginning and End of the\nFourth Charge Cycle\n\nsample',
#  'Table 1. Composition of the Different Ni Content NCM Cathode Materials before Cycling and at the Beginning and End of the\nFourth Charge Cycle\n\nsample\n\nNCM111\nNCM523\nNCM622\nNCM721\nNCM811\nNCM851005\n\npristine state\n\nLi1.02Ni1/3Co1/3Mn1/3O2\nLi1.02Ni0.5Co0.2Mn0.3O2\nLi1.02Ni0.6Co0.2Mn0.2O2\nLi1.02Ni0.7Co0.2Mn0.1O2\nLi1.02Ni0.8Co0.1Mn0.1O2\nLi1.02Ni0.85Co0.1Mn0.05O2\n\ncycled state (3.0 V)\n\nLi0.94Ni1/3Co1/3Mn1/3O2\nLi0.93Ni0.5Co0.2Mn0.3O2\nLi0.93Ni0.6Co0.2Mn0.2O2\nLi0.91Ni0.7Co0.2Mn0.1O2\nLi0.90Ni0.8Co0.1Mn0.1O2\nLi0.89Ni0.85Co0.1Mn0.05O2\n\ncycled state (4.6 V)\n\nLi0.21Ni1/3Co1/3Mn1/3O2\nLi0.19Ni0.5Co0.2Mn0.3O2\nLi0.18Ni0.6Co0.2Mn0.2O2\nLi0.13Ni0.7Co0.2Mn0.1O2\nLi0.11Ni0.8Co0.1Mn0.1O2\nLi0.09Ni0.85Co0.1Mn0.05O2\n\n26166\n\nDOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171',
#  '26166\n\nDOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171\n\n\x0cThe Journal of Physical Chemistry C\n\nArticle\n\nFigure 5. Contour plots of operando XRD patterns obtained on a NCM622-based cell showing the evolution of the reflection positions and\nintensities in the fourth charge/discharge cycle at C/10.\n\nbroadening of the Bragg reflections occurs above 3.9 V and\nbecomes more pronounced with further charging. During\ndischarge a decrease in full width at half-maximum (fwhm) is\nobserved below 3.8 V. As an example, Δfwhm003 is found to be\n0.002° after the charge/discharge cycle, thus emphasizing the\nhigh reversibility of the (de)lithiation process.\n\nStructural multiphase transitions from hexagonal to mono-\nclinic (H1 → M), monoclinic to hexagonal (M → H2) and\nhexagonal to hexagonal (H2 → H3) typically occur when\nLi1−xNiO2 is delithiated with charging to 4.3 V, as indicated by\nthe splitting of the original H1 10l and 11l reflections.30,35 It\nshould be noted that the monoclinic modification differs only\nmarginally from the hexagonal arrangement, and this break in\nsymmetry leads to the appearance of additional reflections.\nthose assigned to the\nHowever, Yang et al. showed that\nmonoclinic phase can also be interpreted alternatively as two\ncoexisting hexagonal phases.36 In both cases, nevertheless, the\n2θ positions of the newly formed phase−whether hexagonal or\nmonoclinic−would hardly differ\nthe initial\nreflections (Figure S2). Overall, we believe that this effect\ncontributes to the observed broadening of the reflections.\n\nfrom those of',
#  'from those of\n\nAnalogous XRD measurements were conducted on all NCM\ncathode materials. Figure 6 depicts contour plots of operando\nXRD patterns in the 2θ range around the 003 reflection\nobtained during charge (see also contour plots for selected 2θ\nranges in Figure S3). Degradation of the layered structure is not\nobserved in the voltage range studied, and the Bragg reflections\nshow similar trends in the evolution with time. Again, the 003\nreflection initially shifts to lower 2θ values and then to higher\nangles. Besides, the minimum in 2θ is similar at 8.4−8.5° for all\nsamples. However, there are also significant differences. For\nexample, the turning point (from decrease to increase) is at\nlower cell voltage for the high-Ni NCMs. Furthermore, the\ntotal shift in 2θ to higher angles is much less pronounced for\nthe low- and medium-Ni NCMs (i.e., NCM111 and NCM523),\nwith the position of the 003 reflection (8.6° 2θ) being virtually\nthe 003\nidentical before and after charging.\n\nIn contrast,\n\nFigure 6. Contour plots of operando XRD patterns in the 2θ range of\nthe 003 reflection obtained on the different Ni content NCM-based\ncells during the charge cycle.\n\nreflection shifts to significantly larger 2θ values in the high-\nvoltage region with increasing Ni content and the final position\nis much different from the starting value.\n\n26167\n\nDOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171\n\n\x0cThe Journal of Physical Chemistry C\n\nArticle\n\nParts a and b of Figure 7 show the relative changes in lattice\nparameters a and c versus the voltage with delithiation (charge)\n\nmaterials, the severe change along the c-direction presumably\ncauses structural instability of the lattice.',
#  'The Journal of Physical Chemistry C\n\nArticle\n\nParts a and b of Figure 7 show the relative changes in lattice\nparameters a and c versus the voltage with delithiation (charge)\n\nmaterials, the severe change along the c-direction presumably\ncauses structural instability of the lattice.\n\nBecause of the excellent time resolution of only 150 s per\npattern we were able to directly correlate structural with\nelectrochemical features. As mentioned above, both NCM811\nand NCM851005 show a subtle plateau in the voltage profile\nabove 4.1 V, appearing as a peak in the differential capacity\ncurves. On the basis of the XRD data we calculated the\n“differential unit cell volume”, which is the first derivative of the\nto cell voltage (Figure 8).\nunit cell volume with respect\n\nFigure 7. Relative changes in lattice parameters (a) a and (b) c as a\nfunction of cell voltage during delithiation for the different Ni content\nNCM materials.\n\nobtained from Rietveld refinement (Figure S4 plots the same\ndata against the Li content). Rietveld refinement results for\neach operando XRD measurement at different SOC are given in\nTable S1, while Figure S5 shows selected Rietveld plots for\nNCM622. Both a and c strongly change with the voltage. The\na-axis shrinks linearly at first, then levels off between 4.3 and 4.4\nV and finally increases again slightly. The magnitude of the\nlatter increase is larger for the Ni-rich NCMs. In contrast, the c-\naxis first shows an increase by about 1.5%,\nfollowed by a\ndecrease for all samples. This shrinkage always occurs when δ\napproaches 0.4 (Figure S4), and it is particularly severe for\nhigh-Ni NCMs (LiNixCoyMnzO2 with x ≥ 0.8). The general\ntrends observed are in agreement with the study by Ishidzu et\nal.13',
#  'It has been shown that the lattice parameter a reflects the\nTM−TM distance (in the TM layer).37,38 The ionic radii of the\nTMs decrease with increasing oxidation state, and therefore the\ndecrease in lattice parameter a is likely associated with the\noxidation of the TMs. The lattice parameter c represents the\ninterslab distance of the Li layers.37,38 The initial increase is\nusually interpreted as a result of increasing Coulomb repulsion\nwith Li extraction from the interlayer galleries. It has also been\nreported that lithium interacts electrostatically with oxygen.38\nThis interaction is apparently accompanied by partial charge\ntransfer, which in turn is believed to effectively screen the\nelectrostatic repulsion between the oxygen layers. The\nscreening effect\nreduced with increasing degree of\ndelithiation, resulting in increased repulsion and expansion\nalong the c-axis. When most of the lithium is removed, a\ncontraction of the interslab distance is observed and with that a\ndecrease in lattice parameter c.19 In particular for Ni-rich NCM\n\nis\n\nFigure 8. Differential capacity (black) and unit cell volume plots\n(blue) in the voltage range between 3.8 and 4.6 V for (a) NCM811\nand (b) NCM851005.\n\nInterestingly, a distinct peak is observed in the high-voltage\nregion as in the case of the differential capacity curves. Even\nmore interestingly, the peaks in the differential capacity and\nunit cell volume curves correlate with each other in terms of\nposition (4.22 V for NCM811; 4.20 V for NCM851005) and\nrelative height. This result thus provides evidence that the\nappearance of the redox peak around 4.2 V is due to structural\neffects, and we take it as an indication of an undesired phase\ntransformation.',
#  'From a practical point of view, it is important to note that the\nrelative changes in lattice parameters a and c during charge lead\nto a large decrease in unit cell volume. As is shown in Figures\n9a and S6, this decrease is more severe as the Ni content rises\nor, in other words, the total change in unit cell volume increases\nwith increasing Ni content. Also,\nthe change is highly\nanisotropic, resulting in significant strain in the NCM particles\n(see also Figure S7 for the evolution of c/a ratio with cell\nvoltage). All NCM materials employed in this work are found\nto exhibit the most pronounced changes in unit cell volume at\nhigh SOC. This is apparent from the change in slope of the ΔV\nvs U curves, with the onset correlating with the collapse of the\nc-axis when δ ≈ 0.4 (see Figures 7b and S4). It is believed that\nlattice changes with cycling are the major source of mechanical\n\n26168\n\nDOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171\n\n\x0cThe Journal of Physical Chemistry C\n\nArticle\n\nFigure 9. (a) Relative changes in unit cell volume as a function of cell\nvoltage for the different Ni content NCM materials. (b) Relative\nchanges in unit cell volume for Umax = 4.3 V (empty circles) and Umax\nrequired to achieve the gravimetric energy density of NCM811 at 4.3\nV (solid circles).\n\nfracture, among\nstress in the particles and cause material\nothers.12,15,39,40 Breakage of particles ultimately leads\nto\ndisconnection of a fraction of active cathode material (i.e.,\nloss of electrical contact) and creates new and reactive surfaces,\nthereby accelerating degradation. Consequently,\nis a\nreasonable concern whether high-Ni NCMs have an intrinsic\ndisadvantage over medium-Ni NCMs when it comes to cycling\nstability and longevity.\n\nit',
#  'it\n\nTo better compare the microstructural stability among the\ndifferent NCM samples, the relative unit cell volume changes\nwith delithiation were evaluated in more detail. Figure 9b shows\nthe corresponding data for Umax = 4.3 V and when operating\nthe cathode materials at a similar specific energy or, more\nspecifically, when charging to Umax required to achieve the\ngravimetric energy density of NCM811 at 4.3 V (Figure 3).\nInterestingly, the relative change in unit cell volume increases in\na linear fashion with increasing Ni content when Umax\nis\nadjusted for each composition−as opposed to when the cutoff\nvoltage is set at 4.3 V. From these data, it is evident that Ni-rich\nNCM materials are more prone to structural changes/\nmechanical deformation and therefore likely to fracture during\noperation (due to structural\nstress associated with the\ncontinuous shrinking and swelling of the primary crystallites\nin the secondary cathode particles).\n\nFinally, the cycling performance of the different Ni content\nNCMs was evaluated based on our specific energy concept\n(Figure 10, parts a and b). Noh et al. performed similar\nexperiments using half-cells, but focused on the stability in the\n3.0−4.3 V range.10 They found that the capacity retention\nsignificantly decreases with increasing Ni content (Figure 10b),\nwhich was explained by lower structural stability of high-Ni\nNCMs. At first glance, this result is not surprising and is also in\nagreement with our data, showing a nonlinear increase in',
#  'Figure 10. (a) Capacity retention based on the second cycle discharge\ncapacity for the different Ni content NCM-based cells cycled between\n3.0 V and Umax required to achieve the gravimetric energy density of\nNCM811 at 4.3 V (i.e., 4.6 V, 4.55 V, 4.45 V, 4.4 and 4.25 V for\nNCM111, NCM523, NCM622, NCM721 and NCM851005,\nrespectively). After the first cycle at C/10 was completed, the C-\nrates were set to C/4 charge and C/2 discharge for the subsequent\ncycles. (b) Comparison of the capacity retention after 100 cycles\nachieved by tailoring Umax and the results of Noh et al. for Umax = 4.3\nV.10\n\nrelative volume change with increasing Ni content (Figure 9b)\nwhen the voltage on charge is limited to Umax = 4.3 V; so more\nstructural degradation is expected when Umax is not tailored to\nthe specific energy. However, when doing so, we find that Ni-\nrich NCMs show better capacity retention than samples with a\nlow Ni content, although they have a clear disadvantage in\nterms of structural stability. This result provides evidence that\nthe cycle life is also strongly affected by factors other than\nstability of the lattice structure. Particularly when the charge\ncutoff voltage is increased beyond the stability limit of organic\nelectrolytes, electrolyte oxidation occurs (and with that gas\nevolution).41,42 For example, Dahn and co-workers showed\nrecently that ethylene carbonate-containing electrolytes sig-\nnificantly reduce the cell performance and life at high\nvoltages.43,44 Ultimately, this means that new electrolytes and\nadditives are needed for high-voltage battery applications.',
#  'Overall, it is not entirely clear which NCM cell chemistry\nprovides the optimum in terms of energy density and cycling\nstability. To answer this question it is important to better\nunderstand the different LIB degradation processes and how\nthey affect each other. Clearly, for high-Ni NCMs, improving\nthe structural stability is one of the major challenges toward\ncommercialization, while for medium-Ni NCMs,\nthe high\n(surface) reactivity toward oxidative electrolyte decomposition\nat high operating voltage must be addressed.\n\n26169\n\nDOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171\n\n\x0cThe Journal of Physical Chemistry C\n\n■ CONCLUSION\n\nA comparative study of the electrochemical and structural\nproperties of a series of Li1.02NixCoyMnzO2 cathode materials\nwith x = 1/3, 0.5, 0.6, 0.7, 0.8, and 0.85 in Li cells was\nperformed in an attempt to identify the composition providing\nthe optimum in energy density and stability. It is shown that\nhigh-Ni NCMs (NCM811 and NCM851005) offer the highest\nenergy densities in the state-of-the-art voltage range of 3.0−4.3\nV. However, it is important to note that low- and medium-Ni\nNCMs, in principle, would be capable of delivering competitive\nenergy densities if the maximum cell voltage could be increased\nwithout inducing deleterious side reactions (e.g., NCM111 and\nNCM622 at 4.6 and 4.45 V, respectively).\n\nin terms of mechanical',
#  'in terms of mechanical\n\nOperando X-ray diffraction revealed that, irrespective of the\nNi content, all NCM materials are subjected to structural\nchanges during operation. Yet, most importantly, it was found\nthat the total change in unit cell volume increases virtually\nlinearly with increasing Ni content for similar energy densities\n(here based on that of NCM811 at 4.3 V). This leads us to the\nassumption that increasing the Ni content results in major\nchallenges\nstrain and structural\ndegradation. However, galvanostatic charge/discharge tests\nindicated that Ni-rich NCMs\nshow better capacity\nretention than low- and medium-Ni NCMs charged to higher\ncutoff voltages. This result emphasizes that each and every\nNCM cathode material has its own issues, especially when\napproaching the desired specific energy range required for\napplication in electric vehicles. Thus, from a scientific point of\nview, it is a must to recognize and understand the (cell-voltage-\ndependent) limiting factors of the different Ni content NCMs\nand to find solutions to optimize their performance. Besides,\nthe presence and interplay of degradation processes such as\nelectrolyte decomposition and transition metal dissolution, to\nname a few, need to be thoroughly investigated when dealing\nwith full-cells.\n\nstill\n\n■ ASSOCIATED CONTENT\n\n*S Supporting Information\nThe Supporting Information is available free of charge on the\nACS Publications website at DOI: 10.1021/acs.jpcc.7b06363.\nComparison of NCM622-based pouch and coin cell\nvoltage profiles, simulated diffraction patterns, contour\nplots of operando XRD patterns for selected 2θ ranges,\nrelative changes in lattice parameters and unit cell\nvolume versus the Li content, changes in c/a ratio as a\nfunction of cell voltage, Rietveld plots for NCM622, and\nsummary of Rietveld refinement results for each operando\nXRD measurement (PDF)\n\n■ AUTHOR INFORMATION',
#  '■ AUTHOR INFORMATION\n\nCorresponding Authors\n*(L.d.B.) Telephone: +49 721 60826870. E-mail: lea.biasi@kit.\nedu.\n*(T.B.) Telephone: +49 721 60828827. E-mail:\nbrezesinski@kit.edu.\n*(P.H.) Telephone: +49 621 6048636. E-mail: pascal.\nhartmann@basf.com.\nORCID\nAleksandr O. Kondrakov: 0000-0003-1465-2854\nTorsten Brezesinski: 0000-0002-4336-263X\n\ntorsten.\n\nArticle\n\nNotes\nThe authors declare no competing financial interest.\n\n■ ACKNOWLEDGMENTS\n\nThis study is part of the projects being funded within the BASF\nInternational Network for Batteries and Electrochemistry.\n\n■']

# %%
pdf_miner_doc.split(sep="\n\n")
# Out:
# ['Cite This: J. Phys. Chem. C 2017, 121, 26163-26171',
#  'Article',
#  'pubs.acs.org/JPCC',
#  'Between Scylla and Charybdis: Balancing Among Structural Stability\nand Energy Density of Layered NCM Cathode Materials for Advanced\nLithium-Ion Batteries\nLea de Biasi,*,†\nPascal Hartmann,*,†,⊥',
#  'Aleksandr O. Kondrakov,\n†,∥\nand Jürgen Janek',
#  'Torsten Brezesinski,*,†',
#  'Holger Geßwein,',
#  '†,⊥',
#  '‡,§',
#  '†\nBattery and Electrochemistry Laboratory, Institute of Nanotechnology and\nTechnology, Hermann-von-Helmholtz-Platz 1, 76344 Eggenstein-Leopoldshafen, Germany\n§\nHelmholtz Institute Ulm for Electrochemical Energy Storage, Helmholtzstraße 11, 89081 Ulm, Germany\n⊥\nBASF SE, 67056 Ludwigshafen, Germany\nInstitute of Physical Chemistry, Justus-Liebig-University Giessen, Heinrich-Buﬀ-Ring 17, 35392 Giessen, Germany\n*S Supporting Information',
#  '∥',
#  '‡\nInstitute for Applied Materials, Karlsruhe Institute of',
#  'ABSTRACT: Two major strategies are currently pursued to\nimprove the energy density of\nlithium-ion batteries using\nLiNixCoyMnzO2 (NCM) cathode materials. One is to increase\nthe fraction of redox active Ni (≥80%), which allows larger\namounts of Li to be extracted at a given cutoﬀ voltage (Umax).\nThe other is to increase Umax,\nin particular for medium-Ni\ncontent NCM materials. However, the accompanying lattice\nchanges ultimately lead to capacity fading in both cases. Here\nthe structural changes occurring in Li1.02NixCoyMnzO2 (with x\n= 1/3, 0.5, 0.6, 0.7, 0.8 and 0.85) during cycling operation in\nthe voltage range between 3.0 and 4.6 V vs Li are quantiﬁed by\nmeans of operando X-ray diﬀraction combined with detailed Rietveld analysis. All samples show a large decrease in unit cell\nvolume upon charging, ranging from 2.4% for NCM111 (33% Ni) to 8.0% for NCM851005 (85% Ni). To make a fair\ncomparison of the structural stability of the diﬀerent NCM materials, energy densities as a function of Umax are estimated and\ncorrelated with X-ray diﬀraction results. It is shown that NCMs with a lower Ni content allow for speciﬁc energies similar to that\nof, e.g., Ni-rich NCM811 (80% Ni) when operated at suﬃciently high Umax, but still undergo less pronounced changes in\nstructure. Nevertheless, as indicated by charge/discharge tests, the capacity retention of low- and medium-Ni content NCMs\ncycled to high Umax is also strongly aﬀected by factors other than stability of the layered crystal lattice (electrolyte decomposition\netc.). Overall, it is demonstrated that the complexity of the degradation processes needs to be better understood to identify\noptimal cycling conditions for speciﬁc cathode compositions.',
#  '■ INTRODUCTION',
#  'The continuous development of optimized lithium-ion batteries\n(LIBs) is indispensable on the way to sustainable, cost-eﬃcient\nand long-range electric vehicles (EVs). Besides the quest for\nhigh power performance and good safety characteristics,\nincreasing the energy density appears to be a prime goal in\nthe development of next-generation LIBs.1 Layered LiCoO2\n(LCO) is the state-of-the-art cathode material for commercial\napplication in consumer electronics for more than 25 years.\nHowever, because of the high price of cobalt metal, the speciﬁc\ncosts ($/kWh) of LCO-based LIBs do not allow for the\nintroduction of EVs into the mass market. Layered lithium\ntransition metal (TM) oxides of the general formula LiTMO2\n(with TM = 3d transition metals such as Ni, Co and Mn),2−4\nso-called NCMs, allow to cut the costs and surpass the energy\ndensity limit of LCO cells due to the synergetic eﬀect of the\ndiﬀerent TMs.5 Current 18650 cells comprising LCO and',
#  'NCM cathode materials reach practical values of 740 Wh/L\n(250 Wh/kg) and 770 Wh/L (270 Wh/kg), respectively. While\nNi increases the speciﬁc capacity, Mn has a stabilizing eﬀect on\nthe layered α-NaFeO2-type crystal structure and Co tends to\nmix less with Li and further reduces the amount of Ni in the Li\nlayers.2,6 Extraction of Li proceeds mainly through oxidation of\nNi and Co,7 yet the Ni ions are believed to be the main redox\nactive species in the voltage range between 3.0 and 4.2 V (vs\ngraphite).8 Thus, increasing substitution of Ni by both Mn and\nCo leads to a decrease in speciﬁc capacity.9 For example,\nLiNi1/3Co1/3Mn1/3O2 (NCM111) delivers a speciﬁc capacity of\nabout 150 mAh/g for Umax = 4.2 V (when cycled against\ngraphite, or Umax = 4.3 V when cycled against lithium), which is',
#  'June 28, 2017',
#  'Received:\nRevised: October 26, 2017\nPublished: October 31, 2017',
#  '© 2017 American Chemical Society',
#  '26163',
#  'DOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171',
#  'Downloaded via CHUNG-ANG UNIV on December 23, 2024 at 08:17:45 (UTC).See https://pubs.acs.org/sharingguidelines for options on how to legitimately share published articles.\x0cThe Journal of Physical Chemistry C',
#  'not suﬃcient for long-range EVs though. In recent years, it has\nbeen demonstrated that high-Ni LiNixCoyMnzO2 (x ≫ 1/3)\nallow for much higher degrees of delithiation, and therefore\nspeciﬁc capacities in excess of 150 mAh/g.10 Nevertheless,\nincreasing the Ni content is associated with a decrease in\ncapacity retention, which is a major drawback so far.11 Part of\nthe reason for this is the fact that Ni-rich materials suﬀer from\nlarger volumetric changes with delithiation,\nleading to more\nfailure.10,12−15 Besides,\nsevere degradation and mechanical\nincreasing the Ni content results in increased surface reactivity\n(electrolyte decomposition).16−18',
#  'Another strategy to improve the energy density is to increase\nthe charge cutoﬀ voltage to over 4.3 V vs Li. For the sake of\nclarity, all voltages are given with respect to Li/Li+ in the\nfollowing (note that the voltage diﬀerence among cells using\ngraphite [full-cell geometry] and lithium metal anodes [half-cell\ngeometry] is around −100 mV). As an example, NCM111 has\nbeen reported to deliver a speciﬁc capacity of about 200 mAh/g\nin the voltage range from 2.5 to 4.6 V.2 However, charging\nNCM cathode materials to higher states of charge (SOC) is\naccompanied by more pronounced changes\nin lattice\nstructure.10,13,19',
#  'From both industrial and scientiﬁc points of view,\nthe\nquestion what cathode composition and voltage range provides\nthe optimum in terms of energy density, costs, stability and\nsafety is yet to be answered. For automotive applications, in\nimportant\nparticular, energy density is one of\nparameters.\nIn literature, electrode materials for LIBs are\noften benchmarked for a given voltage range or degree of\n(de)lithiation. For example, Ishidzu et al. studied and compared\nthe volume changes of NCMs of diﬀerent composition in the\nvoltage range of 2.5−4.5 V.13 Nevertheless, from a techno-\nlogical point of view, the mere evaluation of, e.g., cycling\nstability for a given maximum cell voltage may not be suﬃcient.\nCells using low-Ni NCMs typically last signiﬁcantly longer than\nhigh-Ni NCM-based cells when operated in the same voltage\nrange. However, for the latter, a signiﬁcantly lower maximum\ncell voltage would be required for achieving similar energy\ndensities.',
#  'the most',
#  'In this work, we show that NCM111 and NCM811 cells\nprovide virtually the same energy density at 4.6 and 4.3 V,\nrespectively. Furthermore, we demonstrate that\nis very\nimportant to analyze both the performance and structural\ndegradation of diﬀerent Ni content NCM cathodes for a given\nenergy level rather than voltage range in a reference-type LIB.\nTo allow for a reasonable performance assessment, we estimate\nthe energy densities as a function of Umax for a variety of NCMs\nand correlate the results with structural properties of\nthe\nmaterials from operando X-ray diﬀraction.',
#  'it',
#  '■ EXPERIMENTAL SECTION',
#  'Li1.02NixMnyCozO2 (x + y + z = 1) cathode materials with x:y:z\n= 1:1:1 (NCM111), 5:2:3 (NCM523), 6:2:2 (NCM622), 7:2:1\n(NCM721), 8:1:1 (NCM811) and 85:10:5 (NCM851005)\nwere obtained from BASF SE (Ludwigshafen, Germany). All\nelectrodes were prepared by slurry casting onto Al foil using a\nKTF-S roll-to-roll coater (Mathis AG). For NCM622,\nNCM721, NCM811 and NCM851005, slurries were obtained\nby dispersing cathode material (94 wt %), Super C65 (1 wt %,\nTimcal) and SFG6L (2 wt %, Timcal) conductive carbon\nadditives as well as Solef 5130 PVDF binder (3 wt %, Solvay) in\n1-ethyl-2-pyrrolidone (NEP). For NCM111 and NCM523,\nslurries were obtained by dispersing cathode material (93 wt',
#  'Article',
#  '%), Super C65 (1.5 wt %) and SFG6L (2.5 wt %) conductive\ncarbon additives as well as Solef 5130 PVDF binder (3 wt %) in\nNEP.',
#  'Electrochemical characterization was conducted at 25 °C on\ncoin-type cells. The cells were assembled inside an Ar-ﬁlled\nglovebox (MBraun) by stacking cathode, glass microﬁber\nseparator (GF/D, GE Healthcare Life Sciences, Whatman) and\nlithium foil anode (Albemarle Germany GmbH) of diameters\n13, 17, and 13 mm, respectively, using 250 μL of either LP30 (1\nM LiPF6 in a 1:1 [wt/wt] mixture of ethylene carbonate and\ndimethyl carbonate) or LP47 (1 M LiPF6 in a 3:7 [w/w]\nmixture of ethylene carbonate and diethyl carbonate) as\nloadings were 2.0 mAh/\nelectrolytes (BASF SE). The areal\ncm2 at C/10 and Umax = 4.3 V. The energy densities were\ncalculated from the speciﬁc capacity and average discharge\nvoltage and are given as average of two cycles from two to four\ncells. Powder X-ray diﬀraction (XRD) was performed using a\nlaboratory diﬀractometer optimized for battery research.20 The\ndiﬀractometer is equipped with a molybdenum microfocus\nrotating anode (Mo−Kα\n1,2) and a Pilatus 300 K−W area\ndetector. The high brilliance of\nthe primary beam allows\npenetration of pouch cells, so that measurements can be\nperformed under realistic conditions (without using custom\ncells or X-ray windows). For operando XRD, pouch cells were\nassembled inside a dry room with dew point below −50 °C by\nstacking cathode (20 mm × 40 mm), Celgard 2500\npolypropylene separator (30 mm × 50 mm) and lithium foil\nanode (24 mm × 44 mm) using 250 μL of LP47 (see Figure S1\nfor comparison of the cyclability of pouch cells and standard\ncoin cells). Prior to XRD, the electrodes were galvanostatically\ncycled in the voltage range between 3.0 and 4.3 V for three\ncycles. Then, the cells were inserted into the diﬀractometer and\ncharged/discharged at C/10 during the measurement. A\nconstant voltage step at the cutoﬀ voltages was applied for 1\nh to allow for thermodynamic equilibration of the electrode\nmaterials. 2D diﬀraction images were collected in transmission\ngeometry with an exposure time of 75 s. The intensity of two\nconsecutive images was added up and then integrated to obtain\n1D patterns for further evaluation, resulting in a total time\nresolution of 150 s. Data analysis was performed by Rietveld\nreﬁnement using TOPAS-Academic version 5. The instrumen-\ntal resolution function was determined from an annealed CeO2\nsample and described by means of a (Thompson-Cox-\nHastings) pseudo-Voigt proﬁle function.21 The analysis\ncomprised reﬁnement of lattice parameters a and c and atomic\ncoordinate z of the oxygen position. Both lithium (occ3a = 1.00,\nocc3b = 0.02) and oxygen occupancy parameters (occ6c = 1.00)\nwere ﬁxed during reﬁnement. Broadening eﬀects (apparent\ncrystallite size, microstrain etc.) were accounted for by\nconvolution-based proﬁle ﬁtting as implemented in TOPAS.\nThis approach is equivalent\nto the double-Voigt method\ndescribed by Balzar et al. and is based on the integral breadth of\nthe diﬀraction lines.22,23 Background reﬁnement was made\nusing a 10-term Chebyshev polynomial function. Zero-point\ncorrection was used to correct for sample displacement errors\nof both the cathode material and Al current collector.24 The\nVESTA software package was used to generate crystal structure\nimages.25',
#  '■ RESULTS AND DISCUSSION',
#  'Electrochemical Characteristics. Electrochemical testing\nwas performed on Li1.02NixCoyMnzO2 cathode materials with\nx:y:z = 1:1:1 (NCM111), 5:2:3 (NCM523), 6:2:2 (NCM622),',
#  '26164',
#  'DOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171',
#  '\x0cThe Journal of Physical Chemistry C',
#  'Article',
#  '7:2:1 (NCM721), 8:1:1 (NCM811),\nand 85:10:5\n(NCM851005) using coin-type cells with a lithium metal\ncounter electrode. Figure 1a shows charge/discharge curves',
#  'Figure 2. (a) Speciﬁc discharge capacity as a function of Umax for the\ndiﬀerent Ni content NCM-based cells. (b) Maximum gravimetric\nenergy densities calculated from the speciﬁc capacity and average\ndischarge voltage.',
#  'Figure 1. (a) Charge/discharge curves at C/5 in the voltage range\nbetween 3.0 and 4.6 V and (b) the corresponding diﬀerential capacity\nplots for the diﬀerent Ni content NCM-based cells.',
#  'obtained at C/5 between 3.0 and 4.6 V. As is seen, the higher\nthe Ni content the more Li can be extracted, and therefore the\nhigher the speciﬁc capacity (see also Figure 2a). Besides, the\nvoltage proﬁles show diﬀerent features depending on the Ni\ncontent due to diﬀerent redox behavior, as indicated by the\ndiﬀerential capacity curves in Figure 1b. While in the ternary\nsystem of LiNiO2, LiCoO2 and LiMnO2 the TMs are formally\nin the trivalent state (i.e., Ni3+, Co3+ and Mn3+), charge transfer\nis assumed to occur between Ni and Mn in the LiNixCoyMnzO2\nphase. The reason is the diﬀerence in electronegativity.26,27\nTheoretical calculations suggest\nformal oxidation states of\nmixed divalent and trivalent Ni, trivalent Co, and tetravalent\nMn.26−28 However, the main redox active species are believed\nto be Ni2+ and Ni3+, and their concentration depends on the\noverall TM ratio.',
#  'All samples show characteristic redox peaks in the voltage\nrange of 3.6−3.8 V (Figure 1b). The peak splitting indicates the\npresence of two Ni redox pairs (namely, Ni2+/Ni3+ and Ni3+/\nNi4+) with cycling, and their shape and area ratio point to\ndiﬀerent contributions depending on the Ni content.26,27 The\npeaks shift toward lower voltage with increasing Ni content,\nleading to a decrease in the average charge/discharge voltages.\nThis phenomenon has been observed before and attributed to\nthe lower redox potential of Ni than Co.13,29 Kim et al. showed\nthat the electrochemical equilibrium potentials of these redox\nreactions also vary with Mn content in the structure.26 Using\nexperimental GITT and computational calculations they found\nthat high-Ni NCMs exhibit redox activity at lower relative\nvoltages. However, less Mn also leads to lower voltages for the\nsame Ni content. The Ni-rich samples, in particular NCM811\nand NCM851005, further show features in the high-voltage',
#  'similar',
#  'to that of',
#  'region above 3.9 V, which we believe are due to multiphase\ntransitions caused by slight distortions in the crystal structure.\nSuch transformations have been observed for LiNiO2 during\ndelithiation and are likely to occur in high-Ni NCMs as well.30\nBoth NCM811 and NCM851005 show an additional voltage\nplateau around 4.2 V, appearing as a distinct peak in the\ndiﬀerential capacity curves. This peak is not seen for the other\nNCM materials, and its origin has not yet been clearly resolved.\nFigure 2a depicts the speciﬁc capacity of the NCM cathodes\nafter charging to 4.3 V ≤ Umax\n≤ 4.6 V. As expected, both\nNCM811 and NCM851005 provide the highest values,\nirrespective of the Umax. At 4.3 V these cathode materials\ndeliver capacities\nthe widely used\nLiNi0.8Co0.15Al0.05O2 (NCA).31,32 The gravimetric energy\ndensity (GED) calculated as the product of speciﬁc charge\nand average discharge voltage is shown in Figure 2b. The GED\nincreases with both increasing Ni content and Umax.',
#  'To make a fair comparison among the diﬀerent NCM\nmaterials\ue0d5also with respect to their structural stability (see\nbelow)\ue0d5Umax\nrequired to achieve the speciﬁc energy of\nNCM811 operated at 4.3 V (≈750 Wh/kg) was calculated\nfor each composition. According to our estimates, NCM111,\nNCM523, NCM622, NCM721, and NCM851005 need to be\noperated at around 4.6, 4.55, 4.45, 4.4, and 4.25 V, respectively\n(Figure 3). The obtained Umax values agree well with the\ntechnological\nroadmaps of some cell manufacturers (e.g.,\nNCM622 at 4.35 V in full-cells). Both NCM811 and\nNCM851005 oﬀer the highest energy densities when Umax is\nlimited to 4.3 V, as is currently the case in commercial high-\nperformance LIBs. However, similar GEDs can be achieved\nwith the low- and medium-Ni NCM materials when increasing\nthe maximum operation voltage. Thus,\nis of upmost\nimportance to identify the optimum in terms of materials\nspeciﬁc\ncomposition and operating voltage range for',
#  'it',
#  '26165',
#  'DOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171',
#  '\x0cThe Journal of Physical Chemistry C',
#  'Article',
#  'Figure 3. Charge cutoﬀ voltage as a function of Ni content required to\nachieve the gravimetric energy density of NCM811 at Umax = 4.3 V.',
#  'applications. From a scientiﬁc point of view, this means that the\nmajor degradation processes need to be better understood. In\nthe following we focus on the (crystallographic) volume\nchanges of NCMs occurring in the voltage range between 3.0\nand 4.6 V since these are known to cause mechanical stress,\nwhich in turn leads to material fracture and fatigue.\nStructural Characteristics. An overview of',
#  'the NCM\nmaterials employed in this work and their composition are\ngiven in Table 1. The samples exhibit a well-developed layered\ncrystalline structure of α-NaFeO2-type (space group R3m̅ , Z =\n3). It can be viewed as a stacking of alternating layers, in which\nTM and Li ions occupy octahedral sites in a cubic close-packed\noxygen lattice (Figure 4). The Ni, Co and Mn ions are\nstatistically distributed over the 3b site in ﬁrst approximation. Li\nions (Wyckoﬀ site 3a) are located in the interslabs between the\nTM layers. We assume that 2% of the 3b site in the TM layer\nare occupied by Li ions because of the small Li excess.',
#  'The lattice parameters of the pristine materials are given in\nTable 2. An increase in a with increasing Ni content\nis\nobserved, which is due to the larger ionic radii of Ni2+ (0.69 Å)\nand Ni3+ (0.56 Å) compared to Co3+ (0.545 Å) and Mn4+\n(0.530 Å).33 In contrast, c decreases, which is somewhat\nsurprising and seems to be related to the content of all three\nTMs (rather than Ni only). For example, substitution of Mn by\nCo is known to cause a decrease in both lattice parameters.34\nTo gain insight into the evolution of the host structure with\ncycling, a series of operando XRD measurements were\nperformed on the diﬀerent NCM materials. Prior to XRD,\nthe cells were cycled between 3.0 and 4.3 V ﬁrst at C/10 for\ntwo cycles and then at C/5 for another cycle. The Li content δ\nper formula unit was around 1.02 for the pristine samples. To\nestimate δ at the beginning and end of the fourth charge cycle,\nwe assumed that Coulombic eﬃciencies of less than 100% are a\nresult of Li loss from the cathode material only. This loss of',
#  'Figure 4. Crystal structure and schematic of the unit cell of layered\nLiNixCoyMnzO2.',
#  'Table 2. Lattice Parameters and Oxygen Coordinate for the\nDiﬀerent Ni Content NCM Cathode Materials',
#  'sample',
#  'NCM111\nNCM523\nNCM622\nNCM721\nNCM811\nNCM851005',
#  'a (Å)',
#  '2.8575(1)\n2.8659(1)\n2.8661(1)\n2.8647(1)\n2.8688(1)\n2.8700(1)',
#  'c (Å)',
#  '14.2166(5)\n14.2234(3)\n14.2062(3)\n14.1808(4)\n14.1867(4)\n14.1795(3)',
#  'z',
#  '0.2401(1)\n0.2406(1)\n0.2403(1)\n0.2403(1)\n0.2416(1)\n0.2409(1)',
#  'active Li during precycling was taken into account when\ncalculating the amount of transferred Li+ ions. The NCM cells\nexhibited open-circuit voltages ranging from 3.57 to 3.65 V\nprior to the fourth cycle. As can be seen from Table 1, δ was\n≤0.21 after charging (note that a constant voltage step at Umax\n= 4.6 V was applied for 1 h).',
#  'Figure 5 depicts contour plots of operando XRD patterns for\nthe reﬂection positions and\nNCM622. The evolution of\nintensities is shown together with the voltage proﬁle. We\nnote that Bragg reﬂections other than those originating from\nthe cathode material can be assigned to aluminum (from the\ncurrent collector and pouch cell foil). A distinct hkl-dependent\nshift is observed during cycling. The reﬂections with h = k = 0\nand l ≠ 0 (e.g., 003) ﬁrst shift to lower 2θ values in the charge\ncycle. However, when the cell reaches a voltage of about 4.0 V,\nthey shift back to the initial positions or to even larger 2θ\nvalues. In contrast, the reﬂections with h ≠ 0, k ≠ 0 and l = 0\n(e.g., 110) show the opposite trend in that they shift almost\nexclusively toward larger 2θ values. Reverse shifts are observed\nupon discharge, and all reﬂections virtually reach their initial\npositions at the end of the cycle. This leads us to conclude that\nthe layered structure is well preserved. However, a slight',
#  'Table 1. Composition of the Diﬀerent Ni Content NCM Cathode Materials before Cycling and at the Beginning and End of the\nFourth Charge Cycle',
#  'sample',
#  'NCM111\nNCM523\nNCM622\nNCM721\nNCM811\nNCM851005',
#  'pristine state',
#  'Li1.02Ni1/3Co1/3Mn1/3O2\nLi1.02Ni0.5Co0.2Mn0.3O2\nLi1.02Ni0.6Co0.2Mn0.2O2\nLi1.02Ni0.7Co0.2Mn0.1O2\nLi1.02Ni0.8Co0.1Mn0.1O2\nLi1.02Ni0.85Co0.1Mn0.05O2',
#  'cycled state (3.0 V)',
#  'Li0.94Ni1/3Co1/3Mn1/3O2\nLi0.93Ni0.5Co0.2Mn0.3O2\nLi0.93Ni0.6Co0.2Mn0.2O2\nLi0.91Ni0.7Co0.2Mn0.1O2\nLi0.90Ni0.8Co0.1Mn0.1O2\nLi0.89Ni0.85Co0.1Mn0.05O2',
#  'cycled state (4.6 V)',
#  'Li0.21Ni1/3Co1/3Mn1/3O2\nLi0.19Ni0.5Co0.2Mn0.3O2\nLi0.18Ni0.6Co0.2Mn0.2O2\nLi0.13Ni0.7Co0.2Mn0.1O2\nLi0.11Ni0.8Co0.1Mn0.1O2\nLi0.09Ni0.85Co0.1Mn0.05O2',
#  '26166',
#  'DOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171',
#  '\x0cThe Journal of Physical Chemistry C',
#  'Article',
#  'Figure 5. Contour plots of operando XRD patterns obtained on a NCM622-based cell showing the evolution of the reﬂection positions and\nintensities in the fourth charge/discharge cycle at C/10.',
#  'broadening of the Bragg reﬂections occurs above 3.9 V and\nbecomes more pronounced with further charging. During\ndischarge a decrease in full width at half-maximum (fwhm) is\nobserved below 3.8 V. As an example, Δfwhm003 is found to be\n0.002° after the charge/discharge cycle, thus emphasizing the\nhigh reversibility of the (de)lithiation process.',
#  'Structural multiphase transitions from hexagonal to mono-\nclinic (H1 → M), monoclinic to hexagonal (M → H2) and\nhexagonal to hexagonal (H2 → H3) typically occur when\nLi1−xNiO2 is delithiated with charging to 4.3 V, as indicated by\nthe splitting of the original H1 10l and 11l reﬂections.30,35 It\nshould be noted that the monoclinic modiﬁcation diﬀers only\nmarginally from the hexagonal arrangement, and this break in\nsymmetry leads to the appearance of additional reﬂections.\nthose assigned to the\nHowever, Yang et al. showed that\nmonoclinic phase can also be interpreted alternatively as two\ncoexisting hexagonal phases.36 In both cases, nevertheless, the\n2θ positions of the newly formed phase−whether hexagonal or\nmonoclinic−would hardly diﬀer\nthe initial\nreﬂections (Figure S2). Overall, we believe that this eﬀect\ncontributes to the observed broadening of the reﬂections.',
#  'from those of',
#  'Analogous XRD measurements were conducted on all NCM\ncathode materials. Figure 6 depicts contour plots of operando\nXRD patterns in the 2θ range around the 003 reﬂection\nobtained during charge (see also contour plots for selected 2θ\nranges in Figure S3). Degradation of the layered structure is not\nobserved in the voltage range studied, and the Bragg reﬂections\nshow similar trends in the evolution with time. Again, the 003\nreﬂection initially shifts to lower 2θ values and then to higher\nangles. Besides, the minimum in 2θ is similar at 8.4−8.5° for all\nsamples. However, there are also signiﬁcant diﬀerences. For\nexample, the turning point (from decrease to increase) is at\nlower cell voltage for the high-Ni NCMs. Furthermore, the\ntotal shift in 2θ to higher angles is much less pronounced for\nthe low- and medium-Ni NCMs (i.e., NCM111 and NCM523),\nwith the position of the 003 reﬂection (8.6° 2θ) being virtually\nthe 003\nidentical before and after charging.',
#  'In contrast,',
#  'Figure 6. Contour plots of operando XRD patterns in the 2θ range of\nthe 003 reﬂection obtained on the diﬀerent Ni content NCM-based\ncells during the charge cycle.',
#  'reﬂection shifts to signiﬁcantly larger 2θ values in the high-\nvoltage region with increasing Ni content and the ﬁnal position\nis much diﬀerent from the starting value.',
#  '26167',
#  'DOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171',
#  '\x0cThe Journal of Physical Chemistry C',
#  'Article',
#  'Parts a and b of Figure 7 show the relative changes in lattice\nparameters a and c versus the voltage with delithiation (charge)',
#  'materials, the severe change along the c-direction presumably\ncauses structural instability of the lattice.',
#  'Because of the excellent time resolution of only 150 s per\npattern we were able to directly correlate structural with\nelectrochemical features. As mentioned above, both NCM811\nand NCM851005 show a subtle plateau in the voltage proﬁle\nabove 4.1 V, appearing as a peak in the diﬀerential capacity\ncurves. On the basis of the XRD data we calculated the\n“diﬀerential unit cell volume”, which is the ﬁrst derivative of the\nto cell voltage (Figure 8).\nunit cell volume with respect',
#  'Figure 7. Relative changes in lattice parameters (a) a and (b) c as a\nfunction of cell voltage during delithiation for the diﬀerent Ni content\nNCM materials.',
#  'obtained from Rietveld reﬁnement (Figure S4 plots the same\ndata against the Li content). Rietveld reﬁnement results for\neach operando XRD measurement at diﬀerent SOC are given in\nTable S1, while Figure S5 shows selected Rietveld plots for\nNCM622. Both a and c strongly change with the voltage. The\na-axis shrinks linearly at ﬁrst, then levels oﬀ between 4.3 and 4.4\nV and ﬁnally increases again slightly. The magnitude of the\nlatter increase is larger for the Ni-rich NCMs. In contrast, the c-\naxis ﬁrst shows an increase by about 1.5%,\nfollowed by a\ndecrease for all samples. This shrinkage always occurs when δ\napproaches 0.4 (Figure S4), and it is particularly severe for\nhigh-Ni NCMs (LiNixCoyMnzO2 with x ≥ 0.8). The general\ntrends observed are in agreement with the study by Ishidzu et\nal.13',
#  'It has been shown that the lattice parameter a reﬂects the\nTM−TM distance (in the TM layer).37,38 The ionic radii of the\nTMs decrease with increasing oxidation state, and therefore the\ndecrease in lattice parameter a is likely associated with the\noxidation of the TMs. The lattice parameter c represents the\ninterslab distance of the Li layers.37,38 The initial increase is\nusually interpreted as a result of increasing Coulomb repulsion\nwith Li extraction from the interlayer galleries. It has also been\nreported that lithium interacts electrostatically with oxygen.38\nThis interaction is apparently accompanied by partial charge\ntransfer, which in turn is believed to eﬀectively screen the\nelectrostatic repulsion between the oxygen layers. The\nscreening eﬀect\nreduced with increasing degree of\ndelithiation, resulting in increased repulsion and expansion\nalong the c-axis. When most of the lithium is removed, a\ncontraction of the interslab distance is observed and with that a\ndecrease in lattice parameter c.19 In particular for Ni-rich NCM',
#  'is',
#  'Figure 8. Diﬀerential capacity (black) and unit cell volume plots\n(blue) in the voltage range between 3.8 and 4.6 V for (a) NCM811\nand (b) NCM851005.',
#  'Interestingly, a distinct peak is observed in the high-voltage\nregion as in the case of the diﬀerential capacity curves. Even\nmore interestingly, the peaks in the diﬀerential capacity and\nunit cell volume curves correlate with each other in terms of\nposition (4.22 V for NCM811; 4.20 V for NCM851005) and\nrelative height. This result thus provides evidence that the\nappearance of the redox peak around 4.2 V is due to structural\neﬀects, and we take it as an indication of an undesired phase\ntransformation.',
#  'From a practical point of view, it is important to note that the\nrelative changes in lattice parameters a and c during charge lead\nto a large decrease in unit cell volume. As is shown in Figures\n9a and S6, this decrease is more severe as the Ni content rises\nor, in other words, the total change in unit cell volume increases\nwith increasing Ni content. Also,\nthe change is highly\nanisotropic, resulting in signiﬁcant strain in the NCM particles\n(see also Figure S7 for the evolution of c/a ratio with cell\nvoltage). All NCM materials employed in this work are found\nto exhibit the most pronounced changes in unit cell volume at\nhigh SOC. This is apparent from the change in slope of the ΔV\nvs U curves, with the onset correlating with the collapse of the\nc-axis when δ ≈ 0.4 (see Figures 7b and S4). It is believed that\nlattice changes with cycling are the major source of mechanical',
#  '26168',
#  'DOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171',
#  '\x0cThe Journal of Physical Chemistry C',
#  'Article',
#  'Figure 9. (a) Relative changes in unit cell volume as a function of cell\nvoltage for the diﬀerent Ni content NCM materials. (b) Relative\nchanges in unit cell volume for Umax = 4.3 V (empty circles) and Umax\nrequired to achieve the gravimetric energy density of NCM811 at 4.3\nV (solid circles).',
#  'fracture, among\nstress in the particles and cause material\nothers.12,15,39,40 Breakage of particles ultimately leads\nto\ndisconnection of a fraction of active cathode material (i.e.,\nloss of electrical contact) and creates new and reactive surfaces,\nthereby accelerating degradation. Consequently,\nis a\nreasonable concern whether high-Ni NCMs have an intrinsic\ndisadvantage over medium-Ni NCMs when it comes to cycling\nstability and longevity.',
#  'it',
#  'To better compare the microstructural stability among the\ndiﬀerent NCM samples, the relative unit cell volume changes\nwith delithiation were evaluated in more detail. Figure 9b shows\nthe corresponding data for Umax = 4.3 V and when operating\nthe cathode materials at a similar speciﬁc energy or, more\nspeciﬁcally, when charging to Umax required to achieve the\ngravimetric energy density of NCM811 at 4.3 V (Figure 3).\nInterestingly, the relative change in unit cell volume increases in\na linear fashion with increasing Ni content when Umax\nis\nadjusted for each composition−as opposed to when the cutoﬀ\nvoltage is set at 4.3 V. From these data, it is evident that Ni-rich\nNCM materials are more prone to structural changes/\nmechanical deformation and therefore likely to fracture during\noperation (due to structural\nstress associated with the\ncontinuous shrinking and swelling of the primary crystallites\nin the secondary cathode particles).',
#  'Finally, the cycling performance of the diﬀerent Ni content\nNCMs was evaluated based on our speciﬁc energy concept\n(Figure 10, parts a and b). Noh et al. performed similar\nexperiments using half-cells, but focused on the stability in the\n3.0−4.3 V range.10 They found that the capacity retention\nsigniﬁcantly decreases with increasing Ni content (Figure 10b),\nwhich was explained by lower structural stability of high-Ni\nNCMs. At ﬁrst glance, this result is not surprising and is also in\nagreement with our data, showing a nonlinear increase in',
#  'Figure 10. (a) Capacity retention based on the second cycle discharge\ncapacity for the diﬀerent Ni content NCM-based cells cycled between\n3.0 V and Umax required to achieve the gravimetric energy density of\nNCM811 at 4.3 V (i.e., 4.6 V, 4.55 V, 4.45 V, 4.4 and 4.25 V for\nNCM111, NCM523, NCM622, NCM721 and NCM851005,\nrespectively). After the ﬁrst cycle at C/10 was completed, the C-\nrates were set to C/4 charge and C/2 discharge for the subsequent\ncycles. (b) Comparison of the capacity retention after 100 cycles\nachieved by tailoring Umax and the results of Noh et al. for Umax = 4.3\nV.10',
#  'relative volume change with increasing Ni content (Figure 9b)\nwhen the voltage on charge is limited to Umax = 4.3 V; so more\nstructural degradation is expected when Umax is not tailored to\nthe speciﬁc energy. However, when doing so, we ﬁnd that Ni-\nrich NCMs show better capacity retention than samples with a\nlow Ni content, although they have a clear disadvantage in\nterms of structural stability. This result provides evidence that\nthe cycle life is also strongly aﬀected by factors other than\nstability of the lattice structure. Particularly when the charge\ncutoﬀ voltage is increased beyond the stability limit of organic\nelectrolytes, electrolyte oxidation occurs (and with that gas\nevolution).41,42 For example, Dahn and co-workers showed\nrecently that ethylene carbonate-containing electrolytes sig-\nniﬁcantly reduce the cell performance and life at high\nvoltages.43,44 Ultimately, this means that new electrolytes and\nadditives are needed for high-voltage battery applications.',
#  'Overall, it is not entirely clear which NCM cell chemistry\nprovides the optimum in terms of energy density and cycling\nstability. To answer this question it is important to better\nunderstand the diﬀerent LIB degradation processes and how\nthey aﬀect each other. Clearly, for high-Ni NCMs, improving\nthe structural stability is one of the major challenges toward\ncommercialization, while for medium-Ni NCMs,\nthe high\n(surface) reactivity toward oxidative electrolyte decomposition\nat high operating voltage must be addressed.',
#  '26169',
#  'DOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171',
#  '\x0cThe Journal of Physical Chemistry C',
#  '■ CONCLUSION',
#  'A comparative study of the electrochemical and structural\nproperties of a series of Li1.02NixCoyMnzO2 cathode materials\nwith x = 1/3, 0.5, 0.6, 0.7, 0.8, and 0.85 in Li cells was\nperformed in an attempt to identify the composition providing\nthe optimum in energy density and stability. It is shown that\nhigh-Ni NCMs (NCM811 and NCM851005) oﬀer the highest\nenergy densities in the state-of-the-art voltage range of 3.0−4.3\nV. However, it is important to note that low- and medium-Ni\nNCMs, in principle, would be capable of delivering competitive\nenergy densities if the maximum cell voltage could be increased\nwithout inducing deleterious side reactions (e.g., NCM111 and\nNCM622 at 4.6 and 4.45 V, respectively).',
#  'in terms of mechanical',
#  'Operando X-ray diﬀraction revealed that, irrespective of the\nNi content, all NCM materials are subjected to structural\nchanges during operation. Yet, most importantly, it was found\nthat the total change in unit cell volume increases virtually\nlinearly with increasing Ni content for similar energy densities\n(here based on that of NCM811 at 4.3 V). This leads us to the\nassumption that increasing the Ni content results in major\nchallenges\nstrain and structural\ndegradation. However, galvanostatic charge/discharge tests\nindicated that Ni-rich NCMs\nshow better capacity\nretention than low- and medium-Ni NCMs charged to higher\ncutoﬀ voltages. This result emphasizes that each and every\nNCM cathode material has its own issues, especially when\napproaching the desired speciﬁc energy range required for\napplication in electric vehicles. Thus, from a scientiﬁc point of\nview, it is a must to recognize and understand the (cell-voltage-\ndependent) limiting factors of the diﬀerent Ni content NCMs\nand to ﬁnd solutions to optimize their performance. Besides,\nthe presence and interplay of degradation processes such as\nelectrolyte decomposition and transition metal dissolution, to\nname a few, need to be thoroughly investigated when dealing\nwith full-cells.',
#  'still',
#  '■ ASSOCIATED CONTENT',
#  '*S Supporting Information\nThe Supporting Information is available free of charge on the\nACS Publications website at DOI: 10.1021/acs.jpcc.7b06363.\nComparison of NCM622-based pouch and coin cell\nvoltage proﬁles, simulated diﬀraction patterns, contour\nplots of operando XRD patterns for selected 2θ ranges,\nrelative changes in lattice parameters and unit cell\nvolume versus the Li content, changes in c/a ratio as a\nfunction of cell voltage, Rietveld plots for NCM622, and\nsummary of Rietveld reﬁnement results for each operando\nXRD measurement (PDF)',
#  '■ AUTHOR INFORMATION',
#  'Corresponding Authors\n*(L.d.B.) Telephone: +49 721 60826870. E-mail: lea.biasi@kit.\nedu.\n*(T.B.) Telephone: +49 721 60828827. E-mail:\nbrezesinski@kit.edu.\n*(P.H.) Telephone: +49 621 6048636. E-mail: pascal.\nhartmann@basf.com.\nORCID\nAleksandr O. Kondrakov: 0000-0003-1465-2854\nTorsten Brezesinski: 0000-0002-4336-263X',
#  'torsten.',
#  'Article',
#  'Notes\nThe authors declare no competing ﬁnancial interest.',
#  '■ ACKNOWLEDGMENTS',
#  'This study is part of the projects being funded within the BASF\nInternational Network for Batteries and Electrochemistry.',
#  '■ REFERENCES',
#  '(1) Armand, M.; Tarascon, J.-M. Building Better Batteries. Nature\n2008, 451, 652−657.\n(2) Yabuuchi, N.; Ohzuku, T. Novel Lithium Insertion Material of\nLiCo1/3Ni1/3Mn1/3O2 for Advanced Lithium-Ion Batteries. J. Power\nSources 2003, 119−121, 171−174.\n(3) Lu, Z.; MacNeil, D. D.; Dahn, J. R. Layered Cathode Materials\nLi[NixLi(1/3−2x/3)Mn(2/3−x/3)]O2 for Lithium-Ion Batteries. Electrochem.\nSolid-State Lett. 2001, 4, A191.\n(4) Lu, Z.; MacNeil, D. D.; Dahn, J. R. Layered Li[NixCo1−2xMnx]O2\nCathode Materials for Lithium-Ion Batteries. Electrochem. Solid-State\nLett. 2001, 4, A200.\n(5) Manthiram, A.; Knight, J. C.; Myung, S.-T.; Oh, S.-M.; Sun, Y.-K.\nNickel-Rich and Lithium-Rich Layered Oxide Cathodes: Progress and\nPerspectives. Adv. Energy Mater. 2016, 6, 1501010.\n(6) MacNeil, D. D.; Lu, Z.; Dahn, J. R. Structure and Electro-\nchemistry of Li[NixCo1−2xMnx]O2 (0 ≤ x ≤ 1/2). J. Electrochem. Soc.\n2002, 149, A1332.\n(7) Kobayashi, H.; Arachi, Y.; Emura, S.; Kageyama, H.; Tatsumi, K.;\nKamiyama, T. Investigation on Lithium de-Intercalation Mechanism\nfor Li1−yNi1/3Mn1/3Co1/3O2. J. Power Sources 2005, 146, 640−644.\n(8) Jeon, Y.-A.; Kim, S.-K.; Kim, Y.-S.; Won, D.-H.; Kim, B.-I.; No,\nK.-S. A First Principles Investigation of New Cathode Materials for\nAdvanced Lithium Batteries. J. Electroceram. 2006, 17, 667−671.\n(9) Jouanneau, S.; Eberman, K. W.; Krause, L. J.; Dahn, J. R.\nSynthesis, Characterization, and Electrochemical Behavior of Im-\nproved Li[NixCo1−2xMnx]O2 (0.1 ≤ x ≤ 0.5). J. Electrochem. Soc. 2003,\n150, A1637.\n(10) Noh, H.-J.; Youn, S.; Yoon, C. S.; Sun, Y.-K. Comparison of the\nStructural and Electrochemical Properties of Layered Li[NixCoyMnz]-\nO2 (x = 1/3, 0.5, 0.6, 0.7, 0.8 and 0.85) Cathode Material for Lithium-\nIon Batteries. J. Power Sources 2013, 233, 121−130.\n(11) Liu, Z.; Yu, A.; Lee, J. Y. Synthesis and Characterization of\nLiNi1‑x‑yCoxMnyO2 as the Cathode Materials of Secondary Lithium\nBatteries. J. Power Sources 1999, 81−82, 416−419.\n(12) Kim, H.-R.; Woo, S.-G.; Kim, J.-H.; Cho, W.; Kim, Y.-J. Capacity\nFading Behavior of Ni-Rich Layered Cathode Materials in Li-Ion Full\nCells. J. Electroanal. Chem. 2016, 782, 168−173.\n(13) Ishidzu, K.; Oka, Y.; Nakamura, T. Lattice Volume Change\nduring Charge/discharge Reaction and Cycle Performance of\nLi[NixCoyMnz]O2. Solid State Ionics 2016, 288, 176−179.\n(14) Ghanty, C.; Markovsky, B.; Erickson, E. M.; Talianker, M.; Haik,\nO.; Tal-Yossef, Y.; Mor, A.; Aurbach, D.; Lampert, J.; Volkov, A.; et al.\nLi+-Ion Extraction/Insertion of Ni-Rich Li1+x(NiyCozMnz)wO2\n(0.005<x < 0.03; y: z = 8:1,w≈1) Electrodes: In Situ XRD and\nRaman Spectroscopy Study. ChemElectroChem 2015, 2, 1479−1486.\n(15) Kondrakov, A. O.; Schmidt, A.; Xu, J.; Geßwein, H.; Mönig, R.;\nHartmann, P.; Sommer, H.; Brezesinski, T.; Janek, J. Anisotropic\nLattice Strain and Mechanical Degradation of High- and Low-Nickel\nNCM Cathode Materials for Li-Ion Batteries. J. Phys. Chem. C 2017,\n121, 3286−3294.\n(16) Bak, S.-M.; Hu, E.; Zhou, Y.; Yu, X.; Senanayake, S. D.; Cho, S.-\nJ.; Kim, K.-B.; Chung, K. Y.; Yang, X.-Q.; Nam, K.-W. Structural\nChanges and Thermal Stability of Charged LiNixMnyCozO2 Cathode\nMaterials Studied by Combined In Situ Time-Resolved XRD and Mass\nSpectroscopy. ACS Appl. Mater. Interfaces 2014, 6, 22594−22601.\n(17) Woo, S.-G.; Han, J.-H.; Kim, K. J.; Kim, J.-H.; Yu, J.-S.; Kim, Y.-\nJ. Surface Modification by Sulfated Zirconia on High-Capacity Nickel-\nBased Cathode Materials for Li-Ion Batteries. Electrochim. Acta 2015,\n153, 115−121.',
#  '26170',
#  'DOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171',
#  '\x0cThe Journal of Physical Chemistry C',
#  'Article',
#  '(36) Yang, X. Q.; Sun, X.; McBreen, J. New Findings on the Phase\nTransitions in Li1‑xNiO2:\nIn Situ Synchrotron X-Ray Diffraction\nStudies. Electrochem. Commun. 1999, 1, 227−232.\n(37) Zhang, X.; Mauger, A.; Lu, Q.; Groult, H.; Perrigaud, L.;\nJulien, C. M. Synthesis and Characterization of\nGendron, F.;\nLiNi1/3Mn1/3Co1/3O2 by Wet-Chemical Method. Electrochim. Acta\n2010, 55, 6440−6449.\n(38) Van der Ven, A.; Aydinol, M. K.; Ceder, G.; Kresse, G.; Hafner,\nJ. First-Principles Investigation of Phase Stability in LixCoO2. Phys.\nRev. B: Condens. Matter Mater. Phys. 1998, 58, 2975−2987.\n(39) Watanabe, S.; Kinoshita, M.; Hosokawa, T.; Morigaki, K.;\nNakura, K. Capacity Fading of LiAlyNi1−x−yCoxO2 Cathode for\nLithium-Ion Batteries during Accelerated Calendar and Cycle Life\nTests (effect of Depth of Discharge in Charge−discharge Cycling on\nthe Suppression of the Micro-Crack Generation of LiAlyNi1−x−yCoxO2\nParticle). J. Power Sources 2014, 260, 50−56.\n(40) Sun, G.; Sui, T.; Song, B.; Zheng, H.; Lu, L.; Korsunsky, A. M.\nOn the Fragmentation of Active Material Secondary Particles in\nLithium Ion Battery Cathodes Induced by Charge Cycling. Extreme\nMech. Lett. 2016, 9, 449−458.\n(41) Michalak, B.; Sommer, H.; Mannes, D.; Kaestner, A.;\nBrezesinski, T.; Janek, J. Gas Evolution in Operating Lithium-Ion\nBatteries Studied In Situ by Neutron Imaging. Sci. Rep. 2015, 5, 15627.\n(42) Berkes, B. B.; Schiele, A.; Sommer, H.; Brezesinski, T.; Janek, J.\nOn the Gassing Behavior of Lithium-Ion Batteries with NCM523\nCathodes. J. Solid State Electrochem. 2016, 20, 2961−2967.\n(43) Petibon, R.; Xia, J.; Ma, L.; Bauer, M. K.; Nelson, K. J.; Dahn, J.\nR. Electrolyte System for High Voltage Li-Ion Cells. J. Electrochem. Soc.\n2016, 163, A2571−A2578.\n(44) Xia, J.; Petibon, R.; Xiong, D.; Ma, L.; Dahn, J. R. Enabling\nLinear Alkyl Carbonate Electrolytes for High Voltage Li-Ion Cells. J.\nPower Sources 2016, 328, 124−135.',
#  '(18) Zhao, X.; Zhuang, Q.-C.; Wu, C.; Wu, K.; Xu, J.-M.; Zhang, M.-\nY.; Sun, X.-L. Impedance Studies on the Capacity Fading Mechanism\nof Li(Ni0.5Co0. 2Mn0. 3)O2 Cathode with High-Voltage and High-\nTemperature. J. Electrochem. Soc. 2015, 162, A2770−A2779.\n(19) Kondrakov, A. O.; Geßwein, H.; Galdina, K.; de Biasi, L.;\nMeded, V.; Filatova, E. O.; Schumacher, G.; Wenzel, W.; Hartmann,\nP.; Brezesinski, T. Charge-Transfer-Induced Lattice Collapse in Ni-\nRich NCM Cathode Materials during Delithiation. J. Phys. Chem. C\n2017, 121, 24381−24388.\n(20) de Biasi, L.; Lieser, G.; Rana, J.; Indris, S.; Dräger, C.; Glatthaar,\nS.; Mönig, R.; Ehrenberg, H.; Schumacher, G.; Binder, J. R.; et al.\nUnravelling the Mechanism of Lithium Insertion into and Extraction\nfrom Trirutile-Type LiNiFeF6 Cathode Material for Li-Ion Batteries.\nCrystEngComm 2015, 17, 6163−6174.\n(21) Thompson, P.; Cox, D. E.; Hastings, J. B. Rietveld Refinement\nof Debye−Scherrer Synchrotron X-Ray Data from Al2O3. J. Appl.\nCrystallogr. 1987, 20, 79−83.\n(22) Balzar, D.; Ledbetter, H. Voigt-Function Modeling in Fourier\nAnalysis of Size- and Strain-Broadened X-Ray Diffraction Peaks. J.\nAppl. Crystallogr. 1993, 26, 97−103.\n(23) Balzar, D.; Audebrand, N.; Daymond, M. R.; Fitch, A.; Hewat,\nA.; Langford, J. I.; Le Bail, A.; Louër, D.; Masson, O.; McCowan, C.\nN.; et al. Size−strain Line-Broadening Analysis of the Ceria Round-\nRobin Sample. J. Appl. Crystallogr. 2004, 37, 911−924.\n(24) Norby, P. Synchrotron Powder Diffraction Using Imaging\nPlates: Crystal Structure Determination and Rietveld Refinement. J.\nAppl. Crystallogr. 1997, 30, 21−30.\n(25) Momma, K.;\nIzumi, F. VESTA 3 for Three-Dimensional\nVisualization of Crystal, Volumetric and Morphology Data. J. Appl.\nCrystallogr. 2011, 44, 1272−1276.\n(26) Kim, D.; Lim, J.-M.; Lim, Y.-G.; Yu, J.-S.; Park, M.-S.; Cho, M.;\nCho, K. Design of Nickel-Rich Layered Oxides Using d Electronic\nDonor for Redox Reactions. Chem. Mater. 2015, 27, 6450−6456.\n(27) Koyama, Y.; Yabuuchi, N.; Tanaka, I.; Adachi, H.; Ohzuku, T.\nSolid-State Chemistry and Electrochemistry of LiCo1/3Ni1/3Mn1/3O2\nfor Advanced Lithium-Ion Batteries. J. Electrochem. Soc. 2004, 151,\nA1545.\n(28) Schipper, F.; Dixit, M.; Kovacheva, D.; Talianker, M.; Haik, O.;\nGrinblat, J.; Erickson, E. M.; Ghanty, C.; Major, D. T.; Markovsky, B.;\net al. Stabilizing Nickel-Rich Layered Cathode Materials by a High-\nCharge Cation Doping Strategy: Zirconium-Doped Li-\nNi0.6Co0.2Mn0.2O2. J. Mater. Chem. A 2016, 4, 16073−16084.\n(29) Luo, G.; Zhao, J.; Ke, X.; Zhang, P.; Sun, H.; Wang, B. Structure,\nElectrode Voltage and Activation Energy of LiMnxCoyNi1‑x‑yO2 Solid\nSolutions as Cathode Materials for Li Batteries from First-Principles. J.\nElectrochem. Soc. 2012, 159, A1203−A1208.\n(30) Li, W.; Reimers, J. N.; Dahn, J. R. In Situ X-Ray Diffraction and\nElectrochemical Studies of Li1‑xNiO2. Solid State Ionics 1993, 67, 123−\n130.\n(31) Lee, K. K.; Yoon, W. S.; Kim, K. B.; Lee, K. Y.; Hong, S. T.\nCharacterization of LiNi0.85Co0.10M0.05O2 (M = Al, Fe) as a Cathode\nMaterial for Lithium Secondary Batteries. J. Power Sources 2001, 97-98,\n308−312.\n(32) Myung, S.-T.; Cho, M. H.; Hong, H. T.; Kang, T. H.; Kim, C.-S.\nElectrochemical Evaluation of Mixed Oxide Electrode for Li-Ion\nSecondary Batteries: Li1.1Mn1.9O4 and LiNi0.8Co0.15Al0.05O2. J. Power\nSources 2005, 146, 222−225.\n(33) Shannon, R. D. Revised Effective Ionic Radii and Systematic\nStudies of Interatomic Distances in Halides and Chalcogenides. Acta\nCrystallogr., Sect. A: Cryst. Phys., Diffr., Theor. Gen. Crystallogr. 1976, 32,\n751−767.\n(34) Park, B.-C.; Bang, H. J.; Yoon, C. S.; Myung, S.-T.; Prakash, J.;\nSun, Y.-K. Structural Transformation of Li[Ni0.5−xCo2xMn0.5−x]O2]\n(2x ≤ 0.1) Charged in High-Voltage Range (4.5 V). J. Electrochem. Soc.\n2007, 154, A520.\n(35) Ohzuku, T.; Ueda, A.; Nagayama, M. Electrochemistry and\nStructural Chemistry of LiNiO2 (R-3m) for 4 V Secondary Lithium\nCells. J. Electrochem.  ...
#  '26171',
#  'DOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171',
#  '\x0c']

# %%
from langchain_experimental.text_splitter import SemanticChunker
from langchain_openai.embeddings import OpenAIEmbeddings

# OpenAI 임베딩을 사용하여 의미론적 청크 분할기를 초기화합니다.
text_splitter = SemanticChunker(OpenAIEmbeddings())
chunks = text_splitter.split_text(pdf_miner_doc)

# %%
chunks
# Out:
# ['Cite This: J. Phys. Chem. C 2017, 121, 26163-26171\n\nArticle\n\npubs.acs.org/JPCC\n\nBetween Scylla and Charybdis: Balancing Among Structural Stability\nand Energy Density of Layered NCM Cathode Materials for Advanced\nLithium-Ion Batteries\nLea de Biasi,*,†\nPascal Hartmann,*,†,⊥\n\nAleksandr O. Kondrakov,\n†,∥\nand Jürgen Janek\n\nTorsten Brezesinski,*,†\n\nHolger Geßwein,\n\n†,⊥\n\n‡,§\n\n†\nBattery and Electrochemistry Laboratory, Institute of Nanotechnology and\nTechnology, Hermann-von-Helmholtz-Platz 1, 76344 Eggenstein-Leopoldshafen, Germany\n§\nHelmholtz Institute Ulm for Electrochemical Energy Storage, Helmholtzstraße 11, 89081 Ulm, Germany\n⊥\nBASF SE, 67056 Ludwigshafen, Germany\nInstitute of Physical Chemistry, Justus-Liebig-University Giessen, Heinrich-Buﬀ-Ring 17, 35392 Giessen, Germany\n*S Supporting Information\n\n∥\n\n‡\nInstitute for Applied Materials, Karlsruhe Institute of\n\nABSTRACT: Two major strategies are currently pursued to\nimprove the energy density of\nlithium-ion batteries using\nLiNixCoyMnzO2 (NCM) cathode materials. One is to increase\nthe fraction of redox active Ni (≥80%), which allows larger\namounts of Li to be extracted at a given cutoﬀ voltage (Umax). The other is to increase Umax,\nin particular for medium-Ni\ncontent NCM materials. However, the accompanying lattice\nchanges ultimately lead to capacity fading in both cases. Here\nthe structural changes occurring in Li1.02NixCoyMnzO2 (with x\n= 1/3, 0.5, 0.6, 0.7, 0.8 and 0.85) during cycling operation in\nthe voltage range between 3.0 and 4.6 V vs Li are quantiﬁed by\nmeans of operando X-ray diﬀraction combined with detailed Rietveld analysis. All samples show a large decrease in unit cell\nvolume upon charging, ranging from 2.4% for NCM111 (33% Ni) to 8.0% for NCM851005 (85% Ni). To make a fair\ncomparison of the structural stability of the diﬀerent NCM materials, energy densities as a function of Umax are estimated and\ncorrelated with X-ray diﬀraction results. It is shown that NCMs with a lower Ni content allow for speciﬁc energies similar to that\nof, e.g., Ni-rich NCM811 (80% Ni) when operated at suﬃciently high Umax, but still undergo less pronounced changes in\nstructure. Nevertheless, as indicated by charge/discharge tests, the capacity retention of low- and medium-Ni content NCMs\ncycled to high Umax is also strongly aﬀected by factors other than stability of the layered crystal lattice (electrolyte decomposition\netc.). Overall, it is demonstrated that the complexity of the degradation processes needs to be better understood to identify\noptimal cycling conditions for speciﬁc cathode compositions. ■ INTRODUCTION\n\nThe continuous development of optimized lithium-ion batteries\n(LIBs) is indispensable on the way to sustainable, cost-eﬃcient\nand long-range electric vehicles (EVs). Besides the quest for\nhigh power performance and good safety characteristics,\nincreasing the energy density appears to be a prime goal in\nthe development of next-generation LIBs.1 Layered LiCoO2\n(LCO) is the state-of-the-art cathode material for commercial\napplication in consumer electronics for more than 25 years. However, because of the high price of cobalt metal, the speciﬁc\ncosts ($/kWh) of LCO-based LIBs do not allow for the\nintroduction of EVs into the mass market. Layered lithium\ntransition metal (TM) oxides of the general formula LiTMO2\n(with TM = 3d transition metals such as Ni, Co and Mn),2−4\nso-called NCMs, allow to cut the costs and surpass the energy\ndensity limit of LCO cells due to the synergetic eﬀect of the\ndiﬀerent TMs.5 Current 18650 cells comprising LCO and\n\nNCM cathode materials reach practical values of 740 Wh/L\n(250 Wh/kg) and 770 Wh/L (270 Wh/kg), respectively. While\nNi increases the speciﬁc capacity, Mn has a stabilizing eﬀect on\nthe layered α-NaFeO2-type crystal structure and Co tends to\nmix less with Li and further reduces the amount of Ni in the Li\nlayers.2,6 Extraction of Li proceeds mainly through ox ...
#  'Chem. C 2017, 121, 26163−26171\n\nDownloaded via CHUNG-ANG UNIV on December 23, 2024 at 08:17:45 (UTC).See https://pubs.acs.org/sharingguidelines for options on how to legitimately share published articles. The Journal of Physical Chemistry C\n\nnot suﬃcient for long-range EVs though. In recent years, it has\nbeen demonstrated that high-Ni LiNixCoyMnzO2 (x ≫ 1/3)\nallow for much higher degrees of delithiation, and therefore\nspeciﬁc capacities in excess of 150 mAh/g.10 Nevertheless,\nincreasing the Ni content is associated with a decrease in\ncapacity retention, which is a major drawback so far.11 Part of\nthe reason for this is the fact that Ni-rich materials suﬀer from\nlarger volumetric changes with delithiation,\nleading to more\nfailure.10,12−15 Besides,\nsevere degradation and mechanical\nincreasing the Ni content results in increased surface reactivity\n(electrolyte decomposition).16−18\n\nAnother strategy to improve the energy density is to increase\nthe charge cutoﬀ voltage to over 4.3 V vs Li. For the sake of\nclarity, all voltages are given with respect to Li/Li+ in the\nfollowing (note that the voltage diﬀerence among cells using\ngraphite [full-cell geometry] and lithium metal anodes [half-cell\ngeometry] is around −100 mV). As an example, NCM111 has\nbeen reported to deliver a speciﬁc capacity of about 200 mAh/g\nin the voltage range from 2.5 to 4.6 V.2 However, charging\nNCM cathode materials to higher states of charge (SOC) is\naccompanied by more pronounced changes\nin lattice\nstructure.10,13,19\n\nFrom both industrial and scientiﬁc points of view,\nthe\nquestion what cathode composition and voltage range provides\nthe optimum in terms of energy density, costs, stability and\nsafety is yet to be answered. For automotive applications, in\nimportant\nparticular, energy density is one of\nparameters. In literature, electrode materials for LIBs are\noften benchmarked for a given voltage range or degree of\n(de)lithiation. For example, Ishidzu et al. studied and compared\nthe volume changes of NCMs of diﬀerent composition in the\nvoltage range of 2.5−4.5 V.13 Nevertheless, from a techno-\nlogical point of view, the mere evaluation of, e.g., cycling\nstability for a given maximum cell voltage may not be suﬃcient. Cells using low-Ni NCMs typically last signiﬁcantly longer than\nhigh-Ni NCM-based cells when operated in the same voltage\nrange. However, for the latter, a signiﬁcantly lower maximum\ncell voltage would be required for achieving similar energy\ndensities. the most\n\nIn this work, we show that NCM111 and NCM811 cells\nprovide virtually the same energy density at 4.6 and 4.3 V,\nrespectively. Furthermore, we demonstrate that\nis very\nimportant to analyze both the performance and structural\ndegradation of diﬀerent Ni content NCM cathodes for a given\nenergy level rather than voltage range in a reference-type LIB. To allow for a reasonable performance assessment, we estimate\nthe energy densities as a function of Umax for a variety of NCMs\nand correlate the results with structural properties of\nthe\nmaterials from operando X-ray diﬀraction. it\n\n■ EXPERIMENTAL SECTION\n\nLi1.02NixMnyCozO2 (x + y + z = 1) cathode materials with x:y:z\n= 1:1:1 (NCM111), 5:2:3 (NCM523), 6:2:2 (NCM622), 7:2:1\n(NCM721), 8:1:1 (NCM811) and 85:10:5 (NCM851005)\nwere obtained from BASF SE (Ludwigshafen, Germany). All\nelectrodes were prepared by slurry casting onto Al foil using a\nKTF-S roll-to-roll coater (Mathis AG). For NCM622,\nNCM721, NCM811 and NCM851005, slurries were obtained\nby dispersing cathode material (94 wt %), Super C65 (1 wt %,\nTimcal) and SFG6L (2 wt %, Timcal) conductive carbon\nadditives as well as Solef 5130 PVDF binder (3 wt %, Solvay) in\n1-ethyl-2-pyrrolidone (NEP). For NCM111 and NCM523,\nslurries were obtained by dispersing cathode material (93 wt\n\nArticle\n\n%), Super C65 (1.5 wt %) and SFG6L (2.5 wt %) conductive\ncarbon additives as well as Solef 5130 PVDF binder (3 wt %) in\nNEP. Electroche ...
#  'Chem. C 2017, 121, 26163−26171\n\n\x0cThe Journal of Physical Chemistry C\n\nArticle\n\nFigure 3. Charge cutoﬀ voltage as a function of Ni content required to\nachieve the gravimetric energy density of NCM811 at Umax = 4.3 V. applications. From a scientiﬁc point of view, this means that the\nmajor degradation processes need to be better understood. In\nthe following we focus on the (crystallographic) volume\nchanges of NCMs occurring in the voltage range between 3.0\nand 4.6 V since these are known to cause mechanical stress,\nwhich in turn leads to material fracture and fatigue. Structural Characteristics. An overview of\n\nthe NCM\nmaterials employed in this work and their composition are\ngiven in Table 1. The samples exhibit a well-developed layered\ncrystalline structure of α-NaFeO2-type (space group R3m̅ , Z =\n3). It can be viewed as a stacking of alternating layers, in which\nTM and Li ions occupy octahedral sites in a cubic close-packed\noxygen lattice (Figure 4). The Ni, Co and Mn ions are\nstatistically distributed over the 3b site in ﬁrst approximation. Li\nions (Wyckoﬀ site 3a) are located in the interslabs between the\nTM layers. We assume that 2% of the 3b site in the TM layer\nare occupied by Li ions because of the small Li excess. The lattice parameters of the pristine materials are given in\nTable 2. An increase in a with increasing Ni content\nis\nobserved, which is due to the larger ionic radii of Ni2+ (0.69 Å)\nand Ni3+ (0.56 Å) compared to Co3+ (0.545 Å) and Mn4+\n(0.530 Å).33 In contrast, c decreases, which is somewhat\nsurprising and seems to be related to the content of all three\nTMs (rather than Ni only). For example, substitution of Mn by\nCo is known to cause a decrease in both lattice parameters.34\nTo gain insight into the evolution of the host structure with\ncycling, a series of operando XRD measurements were\nperformed on the diﬀerent NCM materials. Prior to XRD,\nthe cells were cycled between 3.0 and 4.3 V ﬁrst at C/10 for\ntwo cycles and then at C/5 for another cycle. The Li content δ\nper formula unit was around 1.02 for the pristine samples. To\nestimate δ at the beginning and end of the fourth charge cycle,\nwe assumed that Coulombic eﬃciencies of less than 100% are a\nresult of Li loss from the cathode material only. This loss of\n\nFigure 4. Crystal structure and schematic of the unit cell of layered\nLiNixCoyMnzO2. Table 2. Lattice Parameters and Oxygen Coordinate for the\nDiﬀerent Ni Content NCM Cathode Materials\n\nsample\n\nNCM111\nNCM523\nNCM622\nNCM721\nNCM811\nNCM851005\n\na (Å)\n\n2.8575(1)\n2.8659(1)\n2.8661(1)\n2.8647(1)\n2.8688(1)\n2.8700(1)\n\nc (Å)\n\n14.2166(5)\n14.2234(3)\n14.2062(3)\n14.1808(4)\n14.1867(4)\n14.1795(3)\n\nz\n\n0.2401(1)\n0.2406(1)\n0.2403(1)\n0.2403(1)\n0.2416(1)\n0.2409(1)\n\nactive Li during precycling was taken into account when\ncalculating the amount of transferred Li+ ions. The NCM cells\nexhibited open-circuit voltages ranging from 3.57 to 3.65 V\nprior to the fourth cycle. As can be seen from Table 1, δ was\n≤0.21 after charging (note that a constant voltage step at Umax\n= 4.6 V was applied for 1 h). Figure 5 depicts contour plots of operando XRD patterns for\nthe reﬂection positions and\nNCM622. The evolution of\nintensities is shown together with the voltage proﬁle. We\nnote that Bragg reﬂections other than those originating from\nthe cathode material can be assigned to aluminum (from the\ncurrent collector and pouch cell foil). A distinct hkl-dependent\nshift is observed during cycling. The reﬂections with h = k = 0\nand l ≠ 0 (e.g., 003) ﬁrst shift to lower 2θ values in the charge\ncycle. However, when the cell reaches a voltage of about 4.0 V,\nthey shift back to the initial positions or to even larger 2θ\nvalues. In contrast, the reﬂections with h ≠ 0, k ≠ 0 and l = 0\n(e.g., 110) show the opposite trend in that they shift almost\nexclusively toward larger 2θ values. Reverse shifts are observed\nupon discharge, and all reﬂections virtuall ...
#  'Chem. C 2017, 121, 26163−26171\n\n\x0cThe Journal of Physical Chemistry C\n\nArticle\n\nFigure 5. Contour plots of operando XRD patterns obtained on a NCM622-based cell showing the evolution of the reﬂection positions and\nintensities in the fourth charge/discharge cycle at C/10. broadening of the Bragg reﬂections occurs above 3.9 V and\nbecomes more pronounced with further charging. During\ndischarge a decrease in full width at half-maximum (fwhm) is\nobserved below 3.8 V. As an example, Δfwhm003 is found to be\n0.002° after the charge/discharge cycle, thus emphasizing the\nhigh reversibility of the (de)lithiation process. Structural multiphase transitions from hexagonal to mono-\nclinic (H1 → M), monoclinic to hexagonal (M → H2) and\nhexagonal to hexagonal (H2 → H3) typically occur when\nLi1−xNiO2 is delithiated with charging to 4.3 V, as indicated by\nthe splitting of the original H1 10l and 11l reﬂections.30,35 It\nshould be noted that the monoclinic modiﬁcation diﬀers only\nmarginally from the hexagonal arrangement, and this break in\nsymmetry leads to the appearance of additional reﬂections. those assigned to the\nHowever, Yang et al. showed that\nmonoclinic phase can also be interpreted alternatively as two\ncoexisting hexagonal phases.36 In both cases, nevertheless, the\n2θ positions of the newly formed phase−whether hexagonal or\nmonoclinic−would hardly diﬀer\nthe initial\nreﬂections (Figure S2). Overall, we believe that this eﬀect\ncontributes to the observed broadening of the reﬂections. from those of\n\nAnalogous XRD measurements were conducted on all NCM\ncathode materials. Figure 6 depicts contour plots of operando\nXRD patterns in the 2θ range around the 003 reﬂection\nobtained during charge (see also contour plots for selected 2θ\nranges in Figure S3). Degradation of the layered structure is not\nobserved in the voltage range studied, and the Bragg reﬂections\nshow similar trends in the evolution with time. Again, the 003\nreﬂection initially shifts to lower 2θ values and then to higher\nangles. Besides, the minimum in 2θ is similar at 8.4−8.5° for all\nsamples. However, there are also signiﬁcant diﬀerences. For\nexample, the turning point (from decrease to increase) is at\nlower cell voltage for the high-Ni NCMs. Furthermore, the\ntotal shift in 2θ to higher angles is much less pronounced for\nthe low- and medium-Ni NCMs (i.e., NCM111 and NCM523),\nwith the position of the 003 reﬂection (8.6° 2θ) being virtually\nthe 003\nidentical before and after charging. In contrast,\n\nFigure 6. Contour plots of operando XRD patterns in the 2θ range of\nthe 003 reﬂection obtained on the diﬀerent Ni content NCM-based\ncells during the charge cycle. reﬂection shifts to signiﬁcantly larger 2θ values in the high-\nvoltage region with increasing Ni content and the ﬁnal position\nis much diﬀerent from the starting value. 26167\n\nDOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171\n\n\x0cThe Journal of Physical Chemistry C\n\nArticle\n\nParts a and b of Figure 7 show the relative changes in lattice\nparameters a and c versus the voltage with delithiation (charge)\n\nmaterials, the severe change along the c-direction presumably\ncauses structural instability of the lattice. Because of the excellent time resolution of only 150 s per\npattern we were able to directly correlate structural with\nelectrochemical features. As mentioned above, both NCM811\nand NCM851005 show a subtle plateau in the voltage proﬁle\nabove 4.1 V, appearing as a peak in the diﬀerential capacity\ncurves. On the basis of the XRD data we calculated the\n“diﬀerential unit cell volume”, which is the ﬁrst derivative of the\nto cell voltage (Figure 8). unit cell volume with respect\n\nFigure 7. Relative changes in lattice parameters (a) a and (b) c as a\nfunction of cell voltage during delithiation for the diﬀerent Ni content\nNCM materials. obtained from Rietveld reﬁnement (Figure S4 plots the same\ndata against the Li content). Rietveld reﬁ ...
#  'edu. *(T.B.) Telephone: +49 721 60828827. E-mail:\nbrezesinski@kit.edu. *(P.H.) Telephone: +49 621 6048636. E-mail: pascal. hartmann@basf.com. ORCID\nAleksandr O. Kondrakov: 0000-0003-1465-2854\nTorsten Brezesinski: 0000-0002-4336-263X\n\ntorsten. Article\n\nNotes\nThe authors declare no competing ﬁnancial interest. ■ ACKNOWLEDGMENTS\n\nThis study is part of the projects being funded within the BASF\nInternational Network for Batteries and Electrochemistry. ■ REFERENCES\n\n(1) Armand, M.; Tarascon, J.-M. Building Better Batteries. Nature\n2008, 451, 652−657. (2) Yabuuchi, N.; Ohzuku, T. Novel Lithium Insertion Material of\nLiCo1/3Ni1/3Mn1/3O2 for Advanced Lithium-Ion Batteries. J.',
#  'Power\nSources 2003, 119−121, 171−174. (3) Lu, Z.; MacNeil, D. D.; Dahn, J.',
#  'R. Layered Cathode Materials\nLi[NixLi(1/3−2x/3)Mn(2/3−x/3)]O2 for Lithium-Ion Batteries. Electrochem. Solid-State Lett. 2001, 4, A191. (4) Lu, Z.; MacNeil, D. D.; Dahn, J.',
#  'R. Layered Li[NixCo1−2xMnx]O2\nCathode Materials for Lithium-Ion Batteries. Electrochem. Solid-State\nLett. 2001, 4, A200. (5) Manthiram, A.; Knight, J. C.; Myung, S.-T.; Oh, S.-M.; Sun, Y.-K. Nickel-Rich and Lithium-Rich Layered Oxide Cathodes: Progress and\nPerspectives. Adv. Energy Mater. 2016, 6, 1501010. (6) MacNeil, D. D.; Lu, Z.; Dahn, J. R. Structure and Electro-\nchemistry of Li[NixCo1−2xMnx]O2 (0 ≤ x ≤ 1/2). J. Electrochem. Soc. 2002, 149, A1332. (7) Kobayashi, H.; Arachi, Y.; Emura, S.; Kageyama, H.; Tatsumi, K.;\nKamiyama, T. Investigation on Lithium de-Intercalation Mechanism\nfor Li1−yNi1/3Mn1/3Co1/3O2. J.',
#  'Power Sources 2005, 146, 640−644. (8) Jeon, Y.-A.; Kim, S.-K.; Kim, Y.-S.; Won, D.-H.; Kim, B.-I.; No,\nK.-S. A First Principles Investigation of New Cathode Materials for\nAdvanced Lithium Batteries. J. Electroceram. 2006, 17, 667−671. (9) Jouanneau, S.; Eberman, K. W.; Krause, L. J.; Dahn, J.',
#  'R. Synthesis, Characterization, and Electrochemical Behavior of Im-\nproved Li[NixCo1−2xMnx]O2 (0.1 ≤ x ≤ 0.5). J. Electrochem. Soc. 2003,\n150, A1637. (10) Noh, H.-J.; Youn, S.; Yoon, C.',
#  'S.; Sun, Y.-K. Comparison of the\nStructural and Electrochemical Properties of Layered Li[NixCoyMnz]-\nO2 (x = 1/3, 0.5, 0.6, 0.7, 0.8 and 0.85) Cathode Material for Lithium-\nIon Batteries. J.',
#  'Power Sources 2013, 233, 121−130. (11) Liu, Z.; Yu, A.; Lee, J. Y. Synthesis and Characterization of\nLiNi1‑x‑yCoxMnyO2 as the Cathode Materials of Secondary Lithium\nBatteries. J.',
#  'Power Sources 1999, 81−82, 416−419. (12) Kim, H.-R.; Woo, S.-G.; Kim, J.-H.; Cho, W.; Kim, Y.-J. Capacity\nFading Behavior of Ni-Rich Layered Cathode Materials in Li-Ion Full\nCells. J. Electroanal. Chem. 2016, 782, 168−173. (13) Ishidzu, K.; Oka, Y.; Nakamura, T. Lattice Volume Change\nduring Charge/discharge Reaction and Cycle Performance of\nLi[NixCoyMnz]O2. Solid State Ionics 2016, 288, 176−179. (14) Ghanty, C.; Markovsky, B.; Erickson, E. M.; Talianker, M.; Haik,\nO.; Tal-Yossef, Y.; Mor, A.; Aurbach, D.; Lampert, J.; Volkov, A.; et al. Li+-Ion Extraction/Insertion of Ni-Rich Li1+x(NiyCozMnz)wO2\n(0.005<x < 0.03; y: z = 8:1,w≈1) Electrodes: In Situ XRD and\nRaman Spectroscopy Study. ChemElectroChem 2015, 2, 1479−1486. (15) Kondrakov, A. O.; Schmidt, A.; Xu, J.; Geßwein, H.; Mönig, R.;\nHartmann, P.; Sommer, H.; Brezesinski, T.; Janek, J. Anisotropic\nLattice Strain and Mechanical Degradation of High- and Low-Nickel\nNCM Cathode Materials for Li-Ion Batteries. J.',
#  'Phys. Chem. C 2017,\n121, 3286−3294. (16) Bak, S.-M.; Hu, E.; Zhou, Y.; Yu, X.; Senanayake, S. D.; Cho, S.-\nJ.; Kim, K.-B.; Chung, K. Y.; Yang, X.-Q.; Nam, K.-W. Structural\nChanges and Thermal Stability of Charged LiNixMnyCozO2 Cathode\nMaterials Studied by Combined In Situ Time-Resolved XRD and Mass\nSpectroscopy. ACS Appl.',
#  'Mater. Interfaces 2014, 6, 22594−22601. (17) Woo, S.-G.; Han, J.-H.; Kim, K. J.; Kim, J.-H.; Yu, J.-S.; Kim, Y.-\nJ. Surface Modification by Sulfated Zirconia on High-Capacity Nickel-\nBased Cathode Materials for Li-Ion Batteries. Electrochim. Acta 2015,\n153, 115−121. 26170\n\nDOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171\n\n\x0cThe Journal of Physical Chemistry C\n\nArticle\n\n(36) Yang, X. Q.; Sun, X.; McBreen, J. New Findings on the Phase\nTransitions in Li1‑xNiO2:\nIn Situ Synchrotron X-Ray Diffraction\nStudies. Electrochem. Commun. 1999, 1, 227−232. (37) Zhang, X.; Mauger, A.; Lu, Q.; Groult, H.; Perrigaud, L.;\nJulien, C. M. Synthesis and Characterization of\nGendron, F.;\nLiNi1/3Mn1/3Co1/3O2 by Wet-Chemical Method. Electrochim. Acta\n2010, 55, 6440−6449. (38) Van der Ven, A.; Aydinol, M. K.; Ceder, G.; Kresse, G.; Hafner,\nJ. First-Principles Investigation of Phase Stability in LixCoO2. Phys. Rev. B: Condens. Matter Mater. Phys. 1998, 58, 2975−2987. (39) Watanabe, S.; Kinoshita, M.; Hosokawa, T.; Morigaki, K.;\nNakura, K. Capacity Fading of LiAlyNi1−x−yCoxO2 Cathode for\nLithium-Ion Batteries during Accelerated Calendar and Cycle Life\nTests (effect of Depth of Discharge in Charge−discharge Cycling on\nthe Suppression of the Micro-Crack Generation of LiAlyNi1−x−yCoxO2\nParticle). J.',
#  'Power Sources 2014, 260, 50−56. (40) Sun, G.; Sui, T.; Song, B.; Zheng, H.; Lu, L.; Korsunsky, A. M. On the Fragmentation of Active Material Secondary Particles in\nLithium Ion Battery Cathodes Induced by Charge Cycling. Extreme\nMech. Lett. 2016, 9, 449−458. (41) Michalak, B.; Sommer, H.; Mannes, D.; Kaestner, A.;\nBrezesinski, T.; Janek, J. Gas Evolution in Operating Lithium-Ion\nBatteries Studied In Situ by Neutron Imaging. Sci.',
#  'Rep. 2015, 5, 15627. (42) Berkes, B. B.; Schiele, A.; Sommer, H.; Brezesinski, T.; Janek, J. On the Gassing Behavior of Lithium-Ion Batteries with NCM523\nCathodes. J. Solid State Electrochem. 2016, 20, 2961−2967. (43) Petibon, R.; Xia, J.; Ma, L.; Bauer, M. K.; Nelson, K. J.; Dahn, J. R. Electrolyte System for High Voltage Li-Ion Cells. J. Electrochem. Soc. 2016, 163, A2571−A2578. (44) Xia, J.; Petibon, R.; Xiong, D.; Ma, L.; Dahn, J. R. Enabling\nLinear Alkyl Carbonate Electrolytes for High Voltage Li-Ion Cells. J. Power Sources 2016, 328, 124−135. (18) Zhao, X.; Zhuang, Q.-C.; Wu, C.; Wu, K.; Xu, J.-M.; Zhang, M.-\nY.; Sun, X.-L. Impedance Studies on the Capacity Fading Mechanism\nof Li(Ni0.5Co0. 2Mn0. 3)O2 Cathode with High-Voltage and High-\nTemperature. J. Electrochem. Soc. 2015, 162, A2770−A2779. (19) Kondrakov, A. O.; Geßwein, H.; Galdina, K.; de Biasi, L.;\nMeded, V.; Filatova, E. O.; Schumacher, G.; Wenzel, W.; Hartmann,\nP.; Brezesinski, T. Charge-Transfer-Induced Lattice Collapse in Ni-\nRich NCM Cathode Materials during Delithiation. J. Phys. Chem. C\n2017, 121, 24381−24388. (20) de Biasi, L.; Lieser, G.; Rana, J.; Indris, S.; Dräger, C.; Glatthaar,\nS.; Mönig, R.; Ehrenberg, H.; Schumacher, G.; Binder, J. R.; et al. Unravelling the Mechanism of Lithium Insertion into and Extraction\nfrom Trirutile-Type LiNiFeF6 Cathode Material for Li-Ion Batteries. CrystEngComm 2015, 17, 6163−6174.',
#  '(21) Thompson, P.; Cox, D. E.; Hastings, J.',
#  'B. Rietveld Refinement\nof Debye−Scherrer Synchrotron X-Ray Data from Al2O3. J. Appl. Crystallogr. 1987, 20, 79−83. (22) Balzar, D.; Ledbetter, H. Voigt-Function Modeling in Fourier\nAnalysis of Size- and Strain-Broadened X-Ray Diffraction Peaks. J. Appl. Crystallogr. 1993, 26, 97−103. (23) Balzar, D.; Audebrand, N.; Daymond, M. R.; Fitch, A.; Hewat,\nA.; Langford, J. I.; Le Bail, A.; Louër, D.; Masson, O.; McCowan, C. N.; et al. Size−strain Line-Broadening Analysis of the Ceria Round-\nRobin Sample. J. Appl. Crystallogr. 2004, 37, 911−924. (24) Norby, P. Synchrotron Powder Diffraction Using Imaging\nPlates: Crystal Structure Determination and Rietveld Refinement. J. Appl. Crystallogr. 1997, 30, 21−30. (25) Momma, K.;\nIzumi, F. VESTA 3 for Three-Dimensional\nVisualization of Crystal, Volumetric and Morphology Data. J. Appl. Crystallogr. 2011, 44, 1272−1276. (26) Kim, D.; Lim, J.-M.; Lim, Y.-G.; Yu, J.-S.; Park, M.-S.; Cho, M.;\nCho, K. Design of Nickel-Rich Layered Oxides Using d Electronic\nDonor for Redox Reactions. Chem. Mater. 2015, 27, 6450−6456. (27) Koyama, Y.; Yabuuchi, N.; Tanaka, I.; Adachi, H.; Ohzuku, T. Solid-State Chemistry and Electrochemistry of LiCo1/3Ni1/3Mn1/3O2\nfor Advanced Lithium-Ion Batteries. J. Electrochem. Soc. 2004, 151,\nA1545. (28) Schipper, F.; Dixit, M.; Kovacheva, D.; Talianker, M.; Haik, O.;\nGrinblat, J.; Erickson, E. M.; Ghanty, C.; Major, D.',
#  'T.; Markovsky, B.;\net al. Stabilizing Nickel-Rich Layered Cathode Materials by a High-\nCharge Cation Doping Strategy: Zirconium-Doped Li-\nNi0.6Co0.2Mn0.2O2. J.',
#  'Mater. Chem. A 2016, 4, 16073−16084. (29) Luo, G.; Zhao, J.; Ke, X.; Zhang, P.; Sun, H.; Wang, B. Structure,\nElectrode Voltage and Activation Energy of LiMnxCoyNi1‑x‑yO2 Solid\nSolutions as Cathode Materials for Li Batteries from First-Principles. J. Electrochem. Soc. 2012, 159, A1203−A1208. (30) Li, W.; Reimers, J. N.; Dahn, J. R. In Situ X-Ray Diffraction and\nElectrochemical Studies of Li1‑xNiO2. Solid State Ionics 1993, 67, 123−\n130. (31) Lee, K. K.; Yoon, W. S.; Kim, K. B.; Lee, K. Y.; Hong, S.',
#  'T. Characterization of LiNi0.85Co0.10M0.05O2 (M = Al, Fe) as a Cathode\nMaterial for Lithium Secondary Batteries. J.',
#  'Power Sources 2001, 97-98,\n308−312. (32) Myung, S.-T.; Cho, M. H.; Hong, H. T.; Kang, T.',
#  'H.; Kim, C.-S. Electrochemical Evaluation of Mixed Oxide Electrode for Li-Ion\nSecondary Batteries: Li1.1Mn1.9O4 and LiNi0.8Co0.15Al0.05O2. J.',
#  'Power\nSources 2005, 146, 222−225. (33) Shannon, R.',
#  'D. Revised Effective Ionic Radii and Systematic\nStudies of Interatomic Distances in Halides and Chalcogenides. Acta\nCrystallogr., Sect. A: Cryst. Phys., Diffr., Theor. Gen. Crystallogr. 1976, 32,\n751−767. (34) Park, B.-C.; Bang, H. J.; Yoon, C.',
#  'S.; Myung, S.-T.; Prakash, J.;\nSun, Y.-K. Structural Transformation of Li[Ni0.5−xCo2xMn0.5−x]O2]\n(2x ≤ 0.1) Charged in High-Voltage Range (4.5 V). J. Electrochem. Soc. 2007, 154, A520. (35) Ohzuku, T.; Ueda, A.; Nagayama, M. Electrochemistry and\nStructural Chemistry of LiNiO2 (R-3m) for 4 V Secondary Lithium\nCells. J. Electrochem. Soc. 1993, 140, 1862−1870. 26171\n\nDOI: 10.1021/acs.jpcc.7b06363\nJ. Phys. Chem. C 2017, 121, 26163−26171\n\n\x0c']
