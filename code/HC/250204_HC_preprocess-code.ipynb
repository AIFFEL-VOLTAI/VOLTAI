# %%
import sys
sys.path.append("../../")

import os
from dotenv import load_dotenv
from pprint import pprint

from graph_relevancerag import RelevanceRAG
from graph_ensemblerag import EnsembleRAG
from graph_multiagentrag import MultiAgentRAG

from utils import *

# %%
# .env 파일 로드
load_dotenv(dotenv_path=".env")

# API 키 가져오기
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
LANGCHAIN_API_KEY = os.getenv("LANGCHAIN_API_KEY")

# LangSmith 추적 기능을 활성화합니다. (선택적)
os.environ["LANGCHAIN_TRACING_V2"] = "true"

# %%
def get_rag_instance(
    rag_method, 
    file_folder, 
    file_number, 
    # db_folder,
    chunk_size, 
    chunk_overlap,
    search_k,
    system_prompt, 
    model_name, 
    save_graph_png
):
    """
    RAG 클래스를 동적으로 받아서 인스턴스를 생성하는 함수
    
    Params:
        rag_method: RAG 방법 ("relevance-rag", "ensemble-rag", "multiagent-rag")
        file_folder: 논문 파일이 위치한 폴더 경로
        file_number: 처리할 논문 번호
        system_prompt: system prompt
        model_name: LLM 모델 명 ("gpt-4o", "gpt-4o-mini")
        save_graph_png: graph 저장 결정
        
    Return:
        생성된 RAG 모델 인스턴스
    """
    
    # RAG 모델 인스턴스 생성
    if rag_method == "relevance-rag":
        return RelevanceRAG(file_folder, file_number, chunk_size, chunk_overlap, search_k, system_prompt, model_name, save_graph_png)
        
    elif rag_method == "ensemble-rag":
        return EnsembleRAG(file_folder, file_number, chunk_size, chunk_overlap, search_k, system_prompt, model_name, save_graph_png)
        
    elif rag_method == "multiagent-rag":
        return MultiAgentRAG(file_folder, file_number, chunk_size, chunk_overlap, search_k, system_prompt, model_name, save_graph_png)


def main(
    data_folder:str="./data",
    file_num_list:list=[11],
    category_number:int=1, 
    chunk_size:int=500, 
    chunk_overlap:int=100, 
    search_k:int=10,       
    config_folder:str="./config",
    rag_method:str="multiagent-rag", 
    model_name:str="gpt-4o", 
    save_graph_png:bool=False, 
):
    category_names = ["CAM (Cathode Active Material)", "Electrode (half-cell)", "Morphological Properties", "Cathode Performance"]
    
    ## system_prompt 와 invoke_input 불러오기
    system_prompt = load_system_prompt(config_folder=config_folder, category_number=category_number, rag_method=rag_method)
    invoke_input = load_invoke_input(config_folder=config_folder, category_number=category_number, rag_method=rag_method)
    
    total_answer = []
    
    ## 각 논문에 대해 반복
    for file_number in file_num_list:
        print(f"#####    {file_number}번째 논문    #####")
        print(f"##       rag method     : {rag_method}")
        print(f"##       category name  : {category_names[category_number-1]}")
        
        ## graph 호출
        voltai_graph = get_rag_instance(
            rag_method=rag_method, 
            file_folder=f"{data_folder}/input_data/", 
            file_number=file_number, 
            chunk_size=chunk_size, 
            chunk_overlap=chunk_overlap, 
            search_k=search_k, 
            system_prompt=system_prompt,
            model_name=model_name, 
            save_graph_png=save_graph_png,
        ).graph
        
        ## 질문이 딕셔너리 형태일 경우와 아닌 경우를 처리
        if isinstance(invoke_input, dict):
            result = voltai_graph.invoke(**invoke_input)
        else:
            result = voltai_graph.invoke(*invoke_input)

        ## RAG method에 따른 결과 확인
        if result.get("answer"):
            temp_answer = result["answer"][0][category_names[category_number-1]]
        elif result.get("discussion"):
            temp_answer = result["discussion"][category_names[category_number-1]]
        elif result.get("messages"):
            temp_answer = result["messages"][-1][category_names[category_number-1]]
        
        print(f"##       print {file_number} result")
        print("------------------------------------")
        pprint(temp_answer, sort_dicts=False)
        
        ## json 저장하는 코드
        save_output2json(each_answer=temp_answer,file_num=file_number, rag_method=rag_method, category_number=category_number)
        
        total_answer.append(temp_answer)
        
    return total_answer

# %%
file_num_list = [11, 16, 22]

# %%
multiagent_rag_c1_answer = main(    
    data_folder="../../data",
    file_num_list=file_num_list,
    category_number=1, 
    chunk_size=500, 
    chunk_overlap=100, 
    search_k=10,       
    config_folder="../../config",
    rag_method="multiagent-rag", 
    model_name="gpt-4o", 
    save_graph_png=False
)
# Out:
# ## ../../config/multiagent-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ../../config/multiagent-rag/c1-question.yaml를 불러왔습니다.
# #####    11번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_011 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 11 result
# ------------------------------------
# {'Stoichiometry information': {'LiNi1/3Co1/3Mn1/3O2': {'Li ratio': 1.0,
#                                                        'Ni ratio': 0.33,
#                                                        'Co ratio': 0.33,
#                                                        'Mn ratio': 0.33,
#                                                        'O ratio': 2.0}},
#  'Commercial NCM used': {'LiNi1/3Co1/3Mn1/3O2': 'no'},
#  'Lithium source': 'LiNO3',
#  'Synthesis method': 'solution combustion',
#  'Crystallization method': 'calcination',
#  'Crystallization final temperature': 850,
#  'Crystallization final duration (hours)': 15,
#  'Doping': None,
#  'Coating': 'RGO',
#  'Additional treatment': None}
# ##       ./output/json/multiagent-rag/paper_011_output/category-1-paper_011_output-250204162624.json를 저장했습니다.
# #####    16번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_016 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 16 result
# ------------------------------------
# {'Stoichiometry information': {'NCM': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': None},
#                                'NCM/C': {'Li ratio': 1.03,
#                                          'Ni ratio': 0.32,
#                                          'Co ratio': 0.33,
#                                          'Mn ratio': 0.34,
#                                          'O ratio': None}},
#  'Commercial NCM used': {'NCM': 'yes', 'NCM/C': 'no'},
#  'Lithium source': 'LiAc',
#  'Synthesis method': 'sol-gel',
#  'Crystallization method': None,
#  'Crystallization final temperature': 850,
#  'Crystallization final duration (hours)': 10,
#  'Doping': None,
#  'Coating': 'carbon',
#  'Additional treatment': None}
# ##       ./output/json/multiagent-rag/paper_016_output/category-1-paper_016_output-250204162717.json를 저장했습니다.
# #####    22번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_022 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 22 result
# ------------------------------------
# {'Stoichiometry information': {'LiNi0.84Co0.10Mn0.06O2': {'Li ratio': 1.0,
#                                                           'Ni ratio': 0.84,
#                                                           'Co ratio': 0.1,
#                                                           'Mn ratio': 0.06,
#                                                           'O ratio': 2.0},
#                                'V-doped LiNi0.84Co0.10Mn0.06O2': {'Li ratio': 1.0,
#                                                                   'Ni ratio': 0.84,
#                                                                   'Co ratio': 0.1,
#                                                                   'Mn ratio': 0.06,
#                                                                   'O ratio': 2.0}},
#  'Commercial NCM used': {'LiNi0.84Co0.10Mn0.06O2': 'no',
#                          'V-doped LiNi0.84Co0.10Mn0.06O2': 'no'},
#  'Lithium source': 'LiOH',
#  'Synthesis method': 'solid state',
#  'Crystallization method': None,
#  'Crystallization final temperature': 760,
#  'Crystallization final duration (hours)': 15,
#  'Doping': 'V5+',
#  'Coating': None,
#  'Additional treatment': None}
# ##       ./output/json/multiagent-rag/paper_022_output/category-1-paper_022_output-250204162810.json를 저장했습니다.

# %%
multiagent_rag_c2_answer = main(    
    data_folder="../../data",
    file_num_list=file_num_list,
    category_number=2, 
    chunk_size=500, 
    chunk_overlap=100, 
    search_k=10,       
    config_folder="../../config",
    rag_method="multiagent-rag", 
    model_name="gpt-4o", 
    save_graph_png=False
)
# Out:
# ## ../../config/multiagent-rag/c2-system-prompt.yaml를 불러왔습니다.
# ## ../../config/multiagent-rag/c2-question.yaml를 불러왔습니다.
# #####    11번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Electrode (half-cell)
# ##       paper_011 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 11 result
# ------------------------------------
# {'Active material to Conductive additive to Binder ratio': 'null',
#  'Electrolyte': [{'Salt': 'LiPF6',
#                   'Concentration': '1M',
#                   'Solvent': 'EC:DMC',
#                   'Solvent ratio': '1:1'}],
#  'Additive': 'RGO, 5%',
#  'Loading density (mass loading of NCM)': 'null',
#  'Additional treatment for electrode': 'null'}
# ##       ./output/json/multiagent-rag/paper_011_output/category-2-paper_011_output-250204162839.json를 저장했습니다.
# #####    16번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Electrode (half-cell)
# ##       paper_016 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 16 result
# ------------------------------------
# {'Active material to Conductive additive to Binder ratio': '80:15:5',
#  'Electrolyte': [{'Salt': 'LiPF6',
#                   'Concentration': '1M',
#                   'Solvent': 'EC:DMC',
#                   'Solvent ratio': '1:1'}],
#  'Additive': None,
#  'Loading density (mass loading of NCM)': '5',
#  'Additional treatment for electrode': None}
# ##       ./output/json/multiagent-rag/paper_016_output/category-2-paper_016_output-250204162913.json를 저장했습니다.
# #####    22번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Electrode (half-cell)
# ##       paper_022 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 22 result
# ------------------------------------
# {'Active material to Conductive additive to Binder ratio': '96:2:2',
#  'Electrolyte': [{'Salt': 'LiPF6',
#                   'Concentration': '1M',
#                   'Solvent': 'EC:DMC:EMC',
#                   'Solvent ratio': '1:1:1'}],
#  'Additive': None,
#  'Loading density (mass loading of NCM)': '14.5',
#  'Additional treatment for electrode': 'Dried at 100°C for 10 h in vacuum '
#                                        'oven, then dried at 120°C for 10 h'}
# ##       ./output/json/multiagent-rag/paper_022_output/category-2-paper_022_output-250204162948.json를 저장했습니다.

# %%
multiagent_rag_c3_answer = main(    
    data_folder="../../data",
    file_num_list=file_num_list,
    category_number=3, 
    chunk_size=500, 
    chunk_overlap=100, 
    search_k=10,       
    config_folder="../../config",
    rag_method="multiagent-rag", 
    model_name="gpt-4o", 
    save_graph_png=False
)
# Out:
# ## ../../config/multiagent-rag/c3-system-prompt.yaml를 불러왔습니다.
# ## ../../config/multiagent-rag/c3-question.yaml를 불러왔습니다.
# #####    11번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Morphological Properties
# ##       paper_011 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 11 result
# ------------------------------------
# {'ParticleSize': {'NCM': '200-300 nm'},
#  'ParticleShape': {'NCM': 'faceted morphology, like regular polyhedrons with '
#                           'smooth surfaces'},
#  'ParticleDistribution': {'NCM': 'uniform distribution with no significant '
#                                  'agglomeration'},
#  'CoatingLayerCharacteristics': {'NCM-RGO': 'thin RGO sheets wrapped around '
#                                             'NCM nanoparticles forming a '
#                                             'core-shell-like structure'},
#  'CrystalStructureAndLatticeCharacteristics': {'NCM': 'hexagonal structure '
#                                                       'with principal '
#                                                       'crystallographic planes '
#                                                       'of (003) and (104), '
#                                                       'lattice parameters a = '
#                                                       '2.868 Å, c = 14.233 Å, '
#                                                       'and c/a ratio = 4.963'}}
# ##       ./output/json/multiagent-rag/paper_011_output/category-3-paper_011_output-250204163043.json를 저장했습니다.
# #####    16번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Morphological Properties
# ##       paper_016 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 16 result
# ------------------------------------
# {'ParticleSize': {'NCM': 'particle sizes range from 50 to 200 nm',
#                   'NCM/C': 'homogeneous distribution with a diameter of about '
#                            '150 nm'},
#  'ParticleShape': {'NCM': 'irregular particle shape',
#                    'NCM/C': 'irregular particle shape'},
#  'ParticleDistribution': {'NCM': 'almost every particle can be identified '
#                                  'clearly',
#                           'NCM/C': 'particles appear to aggregate together due '
#                                    'to carbon packaging'},
#  'CoatingLayerCharacteristics': {'NCM/C': 'carbon coating with a thickness '
#                                           'about 10 nm'},
#  'CrystalStructureAndLatticeCharacteristics': {'NCM': 'hexagonal layered '
#                                                       'structure with a c/a '
#                                                       'ratio of 4.9771',
#                                                'NCM/C': 'hexagonal layered '
#                                                         'structure with a c/a '
#                                                         'ratio of 4.9777'}}
# ##       ./output/json/multiagent-rag/paper_016_output/category-3-paper_016_output-250204163120.json를 저장했습니다.
# #####    22번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Morphological Properties
# ##       paper_022 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 22 result
# ------------------------------------
# {'ParticleSize': {'Pristine NCM': 'primary particles have similar size (500 '
#                                   'nm)',
#                   'V-0.005 NCM': 'primary particles have similar size (500 nm)',
#                   'V-0.01 NCM': 'primary particles have similar size (500 nm)',
#                   'V-0.02 NCM': 'primary particles have similar size (500 nm)'},
#  'ParticleShape': {'Pristine NCM': 'spherical morphology',
#                    'V-0.005 NCM': 'spherical morphology',
#                    'V-0.01 NCM': 'spherical morphology',
#                    'V-0.02 NCM': 'spherical morphology'},
#  'ParticleDistribution': {'Pristine NCM': 'composed of numerous primary '
#                                           'particles',
#                           'V-0.005 NCM': 'composed of numerous primary '
#                                          'particles',
#                           'V-0.01 NCM': 'composed of numerous primary '
#                                         'particles',
#                           'V-0.02 NCM': 'composed of numerous primary '
#                                         'particles'},
#  'CoatingLayerCharacteristics': {'Pristine NCM': None,
#                                  'V-0.005 NCM': None,
#                                  'V-0.01 NCM': None,
#                                  'V-0.02 NCM': None},
#  'CrystalStructureAndLatticeCharacteristics': {'Pristine NCM': 'layered '
#                                                                'hexagonal '
#                                                                'α-NaFeO2 '
#                                                                'structure with '
#                                                                'the space '
#                                                                'group R-3m',
#                                                'V-0.005 NCM': 'well-ordered '
#                                                               'layered '
#                                                               'structure with '
#                                                               'a clear peak '
#                                                               'splitting of '
#                                                               'the (006)/(102) '
#                                                               'and (108)/(110)',
#                                                'V-0.01 NCM': 'well-ordered '
#                                                              'layered '
#                                                              'structure with a '
#                                                              'clear peak '
#                                                              'splitting of the '
#                                                              '(006)/(102) and '
#                                                              '(108)/(110)',
#                                                'V-0.02 NCM': 'well-ordered '
#                                                              'layered '
#                                                              'structure with a '
#                                                              'clear peak '
#                                                              'splitting of the '
#                                                              '(006)/(102) and '
#                                                              '(108)/(110)'}}
# ##       ./output/json/multiagent-rag/paper_022_output/category-3-paper_022_output-250204163219.json를 저장했습니다.

# %%
multiagent_rag_c4_answer = main(    
    data_folder="../../data",
    file_num_list=file_num_list,
    category_number=4, 
    chunk_size=500, 
    chunk_overlap=100, 
    search_k=10,       
    config_folder="../../config",
    rag_method="multiagent-rag", 
    model_name="gpt-4o", 
    save_graph_png=False
)
# Out:
# ## ../../config/multiagent-rag/c4-system-prompt.yaml를 불러왔습니다.
# ## ../../config/multiagent-rag/c4-question.yaml를 불러왔습니다.
# #####    11번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Cathode Performance
# ##       paper_011 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 11 result
# ------------------------------------
# {'NR0': [{'Voltage range': '2.5-4.3',
#           'Temperature': 25,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 155.3},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': None},
#                                            {'C-rate': 1.0, 'Capacity': 123},
#                                            {'C-rate': 2.0, 'Capacity': None},
#                                            {'C-rate': 4.0, 'Capacity': None},
#                                            {'Other C-rates and performance': [{'C-rate': 0.05,
#                                                                                'Capacity': 167.6},
#                                                                               {'C-rate': 5.0,
#                                                                                'Capacity': 45.5}]}]}],
#  'NR1': [{'Voltage range': '2.5-4.3',
#           'Temperature': 25,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 154.6},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': None},
#                                            {'C-rate': 1.0, 'Capacity': None},
#                                            {'C-rate': 2.0, 'Capacity': None},
#                                            {'C-rate': 4.0, 'Capacity': None},
#                                            {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                'Capacity': 47.0}]}]}],
#  'NR3': [{'Voltage range': '2.5-4.3',
#           'Temperature': 25,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 166.5},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': None},
#                                            {'C-rate': 1.0, 'Capacity': None},
#                                            {'C-rate': 2.0, 'Capacity': None},
#                                            {'C-rate': 4.0, 'Capacity': None},
#                                            {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                'Capacity': 75.4}]}]}],
#  'NR5': [{'Voltage range': '2.5-4.3',
#           'Temperature': 25,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 175},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': None},
#                                            {'C-rate': 1.0, 'Capacity': None},
#                                            {'C-rate': 2.0, 'Capacity': None},
#                                            {'C-rate': 4.0, 'Capacity': None},
#                                            {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                'Capacity': 95.4}]}]}]}
# ##       ./output/json/multiagent-rag/paper_011_output/category-4-paper_011_output-250204163335.json를 저장했습니다.
# #####    16번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Cathode Performance
# ##       paper_016 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 16 result
# ------------------------------------
# {'NCM': [{'Voltage range': '2.50-4.50',
#           'Temperature': 30,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': 175.7},
#                                            {'C-rate': 1.0, 'Capacity': 154.8},
#                                            {'C-rate': 2.0, 'Capacity': 143.5},
#                                            {'C-rate': 4.0, 'Capacity': None},
#                                            {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                'Capacity': 101.7},
#                                                                               {'C-rate': 10.0,
#                                                                                'Capacity': 71.5},
#                                                                               {'C-rate': 20.0,
#                                                                                'Capacity': 44.5},
#                                                                               {'C-rate': 40.0,
#                                                                                'Capacity': 13.2}]}]}],
#  'NCM/C': [{'Voltage range': '2.50-4.50',
#             'Temperature': 30,
#             'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None},
#                                              {'C-rate': 0.2, 'Capacity': None},
#                                              {'C-rate': 0.5, 'Capacity': 191.2},
#                                              {'C-rate': 1.0, 'Capacity': 178.9},
#                                              {'C-rate': 2.0, 'Capacity': 163.5},
#                                              {'C-rate': 4.0, 'Capacity': None},
#                                              {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                  'Capacity': 135.8},
#                                                                                 {'C-rate': 10.0,
#                                                                                  'Capacity': 109.4},
#                                                                                 {'C-rate': 20.0,
#                                                                                  'Capacity': 81.9},
#                                                                                 {'C-rate': 40.0,
#                                                                                  'Capacity': 54.6}]}]}]}
# ##       ./output/json/multiagent-rag/paper_016_output/category-4-paper_016_output-250204163443.json를 저장했습니다.
# #####    22번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Cathode Performance
# ##       paper_022 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 22 result
# ------------------------------------
# {'pristine NCM': [{'Voltage range': '3.0–4.3',
#                    'Temperature': 25,
#                    'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                      'Capacity': 204.6},
#                                                     {'C-rate': 0.2,
#                                                      'Capacity': None},
#                                                     {'C-rate': 0.5,
#                                                      'Capacity': None},
#                                                     {'C-rate': 1.0,
#                                                      'Capacity': None},
#                                                     {'C-rate': 2.0,
#                                                      'Capacity': None},
#                                                     {'C-rate': 4.0,
#                                                      'Capacity': None},
#                                                     {'Other C-rates and performance': [{'C-rate': 2.0,
#                                                                                         'Capacity': 'significantly '
#                                                                                                     'drops'}]}]}],
#  'V-0.005 NCM': [{'Voltage range': '3.0–4.3',
#                   'Temperature': 25,
#                   'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                     'Capacity': 204.4},
#                                                    {'C-rate': 0.2,
#                                                     'Capacity': None},
#                                                    {'C-rate': 0.5,
#                                                     'Capacity': None},
#                                                    {'C-rate': 1.0,
#                                                     'Capacity': None},
#                                                    {'C-rate': 2.0,
#                                                     'Capacity': 'maintains '
#                                                                 'high'},
#                                                    {'C-rate': 4.0,
#                                                     'Capacity': None},
#                                                    {'Other C-rates and performance': [{'C-rate': None,
#                                                                                        'Capacity': None}]}]}]}
# ##       ./output/json/multiagent-rag/paper_022_output/category-4-paper_022_output-250204163535.json를 저장했습니다.

# %%
import json
import pandas as pd

# %% [markdown]
# ### Category1 전처리

# %%
rag_method = "multiagent-rag"

output_folder_path = []
for file_num in file_num_list:
    json_file_num = f"00{file_num}"[-3:]
    output_folder_path.append(f"./output/json/{rag_method}/paper_{json_file_num}_output")

# %%
output_folder_path[0]
# Out:
# './output/json/multiagent-rag/paper_011_output'

# %%
total_data = {}
for filename in os.listdir(output_folder_path[0]):
    if filename.endswith(".json"):
        json_file_path = os.path.join(output_folder_path[0], filename)
        with open(json_file_path, "r", encoding="utf-8") as f:
            data = json.load(f)
        total_data = total_data | data

# %%
total_data
# Out:
# {'Stoichiometry information': {'LiNi1/3Co1/3Mn1/3O2': {'Li ratio': 1.0,
#    'Ni ratio': 0.33,
#    'Co ratio': 0.33,
#    'Mn ratio': 0.33,
#    'O ratio': 2.0}},
#  'Commercial NCM used': {'LiNi1/3Co1/3Mn1/3O2': 'no'},
#  'Lithium source': 'LiNO3',
#  'Synthesis method': 'solution combustion',
#  'Crystallization method': 'calcination',
#  'Crystallization final temperature': 850,
#  'Crystallization final duration (hours)': 15,
#  'Doping': None,
#  'Coating': 'RGO',
#  'Additional treatment': None,
#  'Active material to Conductive additive to Binder ratio': 'null',
#  'Electrolyte': [{'Salt': 'LiPF6',
#    'Concentration': '1M',
#    'Solvent': 'EC:DMC',
#    'Solvent ratio': '1:1'}],
#  'Additive': 'RGO, 5%',
#  'Loading density (mass loading of NCM)': 'null',
#  'Additional treatment for electrode': 'null',
#  'ParticleSize': {'NCM': '200-300 nm'},
#  'ParticleShape': {'NCM': 'faceted morphology, like regular polyhedrons with smooth surfaces'},
#  'ParticleDistribution': {'NCM': 'uniform distribution with no significant agglomeration'},
#  'CoatingLayerCharacteristics': {'NCM-RGO': 'thin RGO sheets wrapped around NCM nanoparticles forming a core-shell-like structure'},
#  'CrystalStructureAndLatticeCharacteristics': {'NCM': 'hexagonal structure with principal crystallographic planes of (003) and (104), lattice parameters a = 2.868 Å, c = 14.233 Å, and c/a ratio = 4.963'},
#  'NR0': [{'Voltage range': '2.5-4.3',
#    'Temperature': 25,
#    'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 155.3},
#     {'C-rate': 0.2, 'Capacity': None},
#     {'C-rate': 0.5, 'Capacity': None},
#     {'C-rate': 1.0, 'Capacity': 123},
#     {'C-rate': 2.0, 'Capacity': None},
#     {'C-rate': 4.0, 'Capacity': None},
#     {'Other C-rates and performance': [{'C-rate': 0.05, 'Capacity': 167.6},
#       {'C-rate': 5.0, 'Capacity': 45.5}]}]}],
#  'NR1': [{'Voltage range': '2.5-4.3',
#    'Temperature': 25,
#    'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 154.6},
#     {'C-rate': 0.2, 'Capacity': None},
#     {'C-rate': 0.5, 'Capacity': None},
#     {'C-rate': 1.0, 'Capacity': None},
#     {'C-rate': 2.0, 'Capacity': None},
#     {'C-rate': 4.0, 'Capacity': None},
#     {'Other C-rates and performance': [{'C-rate': 5.0, 'Capacity': 47.0}]}]}],
#  'NR3': [{'Voltage range': '2.5-4.3',
#    'Temperature': 25,
#    'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 166.5},
#     {'C-rate': 0.2, 'Capacity': None},
#     {'C-rate': 0.5, 'Capacity': None},
#     {'C-rate': 1.0, 'Capacity': None},
#     {'C-rate': 2.0, 'Capacity': None},
#     {'C-rate': 4.0, 'Capacity': None},
#     {'Other C-rates and performance': [{'C-rate': 5.0, 'Capacity': 75.4}]}]}],
#  'NR5': [{'Voltage range': '2.5-4.3',
#    'Temperature': 25,
#    'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 175},
#     {'C-rate': 0.2, 'Capacity': None},
#     {'C-rate': 0.5, 'Capacity': None},
#     {'C-rate': 1.0, 'Capacity': None},
#     {'C-rate': 2.0, 'Capacity': None},
#     {'C-rate': 4.0, 'Capacity': None},
#     {'Other C-rates and performance': [{'C-rate': 5.0, 'Capacity': 95.4}]}]}]}

# %%
# pd.DataFrame()
pd.DataFrame(json_data_dict["category1"])
# Out:
#                                                                                 paper_011  \
# Stoichiometry information               {'Li(Ni1/3Co1/3Mn1/3)O2': {'Li ratio': 1.0, 'N...
# Commercial NCM used                                       {'Li(Ni1/3Co1/3Mn1/3)O2': 'no'}
# Lithium source                                                                      LiNO3
# Synthesis method                                                      solution combustion
# Crystallization method                                                        calcination
# Crystallization final temperature                                                     850
# Crystallization final duration (hours)                                                 15
# Doping                                                                               None
# Coating                                                                               RGO
# Additional treatment                                                microwave irradiation
#
#                                                                                 paper_016  \
# Stoichiometry information               {'NCM': {'Li ratio': 1.0, 'Ni ratio': 0.33, 'C...
# Commercial NCM used                                          {'NCM': 'no', 'NCM/C': 'no'}
# Lithium source                                                                       LiAc
# Synthesis method                                                                  sol-gel
# Crystallization method                                                               None
# Crystallization final temperature                                                     850
# Crystallization final duration (hours)                                                 10
# Doping                                                                               None
# Coating                                                                            carbon
# Additional treatment                                                                 None
#
#                                                                                 paper_022
# Stoichiometry information               {'LiNi0.84Co0.10Mn0.06O2': {'Li ratio': 1.0, '...
# Commercial NCM used                     {'LiNi0.84Co0.10Mn0.06O2': 'yes', 'V-doped LiN...
# Lithium source                                                                       LiOH
# Synthesis method                                                     solid-state reaction
# Crystallization method                                                        calcination
# Crystallization final temperature                                                     760
# Crystallization final duration (hours)                                                 15
# Doping                                                                                V5+
# Coating                                                                              None
# Additional treatment                                                                 None

# %%
temp_df = pd.DataFrame(json_data_list[0])

# %%
temp_df
# Out:
#                              Stoichiometry information Commercial NCM used  \
# NR0  {'Li ratio': 1.0, 'Ni ratio': 0.33, 'Co ratio'...                  no
# NR1  {'Li ratio': 1.0, 'Ni ratio': 0.33, 'Co ratio'...                  no
# NR3  {'Li ratio': 1.0, 'Ni ratio': 0.33, 'Co ratio'...                  no
# NR5  {'Li ratio': 1.0, 'Ni ratio': 0.33, 'Co ratio'...                  no
#
#     Lithium source     Synthesis method Crystallization method  \
# NR0          LiNO3  solution combustion            calcination
# NR1          LiNO3  solution combustion            calcination
# NR3          LiNO3  solution combustion            calcination
# NR5          LiNO3  solution combustion            calcination
#
#      Crystallization final temperature  \
# NR0                                850
# NR1                                850
# NR3                                850
# NR5                                850
#
#      Crystallization final duration (hours) Doping Coating  \
# NR0                                      15   None    None
# NR1                                      15   None    None
# NR3                                      15   None    None
# NR5                                      15   None    None
#
#     Additional treatment
# NR0         RGO addition
# NR1         RGO addition
# NR3         RGO addition
# NR5         RGO addition

# %%
temp_c1_df = temp_df["Stoichiometry information"].apply(pd.Series).join(temp_df.drop(columns=["Stoichiometry information"])).reset_index(names="Sample name")
# Out:
#   Sample name  Li ratio  Ni ratio  Co ratio  Mn ratio  O ratio  \
# 0         NR0       1.0      0.33      0.33      0.33      2.0
# 1         NR1       1.0      0.33      0.33      0.33      2.0
# 2         NR3       1.0      0.33      0.33      0.33      2.0
# 3         NR5       1.0      0.33      0.33      0.33      2.0
#
#   Commercial NCM used Lithium source     Synthesis method  \
# 0                  no          LiNO3  solution combustion
# 1                  no          LiNO3  solution combustion
# 2                  no          LiNO3  solution combustion
# 3                  no          LiNO3  solution combustion
#
#   Crystallization method  Crystallization final temperature  \
# 0            calcination                                850
# 1            calcination                                850
# 2            calcination                                850
# 3            calcination                                850
#
#    Crystallization final duration (hours) Doping Coating Additional treatment
# 0                                      15   None    None         RGO addition
# 1                                      15   None    None         RGO addition
# 2                                      15   None    None         RGO addition
# 3                                      15   None    None         RGO addition

# %%
pd.DataFrame(json_data_list[0])["Stoichiometry information"].apply(pd.Series)
# Out:
#      Li ratio  Ni ratio  Co ratio  Mn ratio  O ratio
# NR0       1.0      0.33      0.33      0.33      2.0
# NR1       1.0      0.33      0.33      0.33      2.0
# NR3       1.0      0.33      0.33      0.33      2.0
# NR5       1.0      0.33      0.33      0.33      2.0

# %%
pd.DataFrame(json_data_list[0])
# Out:
#                              Stoichiometry information Commercial NCM used  \
# NR0  {'Li ratio': 1.0, 'Ni ratio': 0.33, 'Co ratio'...                  no
# NR1  {'Li ratio': 1.0, 'Ni ratio': 0.33, 'Co ratio'...                  no
# NR3  {'Li ratio': 1.0, 'Ni ratio': 0.33, 'Co ratio'...                  no
# NR5  {'Li ratio': 1.0, 'Ni ratio': 0.33, 'Co ratio'...                  no
#
#     Lithium source     Synthesis method Crystallization method  \
# NR0          LiNO3  solution combustion            calcination
# NR1          LiNO3  solution combustion            calcination
# NR3          LiNO3  solution combustion            calcination
# NR5          LiNO3  solution combustion            calcination
#
#      Crystallization final temperature  \
# NR0                                850
# NR1                                850
# NR3                                850
# NR5                                850
#
#      Crystallization final duration (hours) Doping Coating  \
# NR0                                      15   None    None
# NR1                                      15   None    None
# NR3                                      15   None    None
# NR5                                      15   None    None
#
#     Additional treatment
# NR0         RGO addition
# NR1         RGO addition
# NR3         RGO addition
# NR5         RGO addition
