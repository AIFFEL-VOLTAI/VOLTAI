# %%
# paper_139
input_ = """{'CAM (Cathode Active Material)': {'Additional treatment': 'Freeze drying or '
                                                           'Heat drying',
                                   'Coating': 'Al2O3 coating',
                                   'Commercial NCM': 'No',
                                   'Crystallization method': 'calcination',
                                   'Crystallization temperature': '750°C',
                                   'Crystallization time': '20 hr',
                                   'Doping': 'None',
                                   'Lithium source': 'LiOH·H2O',
                                   'Stoichiometry information': 'Li[Ni0.73Co0.12Mn0.15]O2',
                                   'Synthesis method': 'co-precipitation'},
 'Cathode Performance': {'Capacity at all C-rate, mAh/g (with electrode state)': [{'192 mAh/g': '@0.1C, '
                                                                                                'HD-Al2O3-coated',
                                                                                   '214 mAh/g': '@0.1C, '
                                                                                                'FD-Al2O3-coated',
                                                                                   '226 mAh/g': '@0.1C, '
                                                                                                'pristine'}],
                         'Temperature': 'Room temperature and 55°C',
                         'Voltage range': '3.0–4.3 V'},
 'Electrode (only for coin-cell (half-cell))': {'Active material : Conductive additive : Binder ratio': '80 '
                                                                                                        ': '
                                                                                                        '10 '
                                                                                                        ': '
                                                                                                        '10',
                                                'Additional treatment for electrode': 'None',
                                                'Additive': 'None',
                                                'Electrode thickness': 'None',
                                                'Electrolyte': '1.0 M LiPF6 '
                                                               'solution in '
                                                               'ethylene '
                                                               'carbonate, '
                                                               'diethyl '
                                                               'carbonate and '
                                                               'dimethyl '
                                                               'carbonate '
                                                               '(1:1:1 in '
                                                               'volume)',
                                                'Loading density (mass loading of NCM)': 'None',
                                                'Only Cathode Electrode diameter': '1.5 '
                                                                                   'cm^2'},
 'Morphological results': {'Explanation of SEM results': 'Fig. 2a, b, c; the '
                                                         'pristine, '
                                                         'FD-Al2O3-coated, and '
                                                         'HD-Al2O3-coated '
                                                         'Li[Ni0.73Co0.12Mn0.15]O2 '
                                                         'materials have a '
                                                         'spherical shape with '
                                                         'an average particle '
                                                         'size of '
                                                         'approximately 12 µm, '
                                                         'composed of numerous '
                                                         'primary grains of '
                                                         '100-200 nm that are '
                                                         'aggregated.',
                           'Explanation of TEM results': 'Fig. 3a, b, c; the '
                                                         'pristine material '
                                                         'shows a very smooth '
                                                         'edge line without '
                                                         'any layer on the '
                                                         'surface. For the '
                                                         'FD-Al2O3-coated '
                                                         'material, there is a '
                                                         'uniform and '
                                                         'indistinct coating '
                                                         'layer on the '
                                                         'surface. The '
                                                         'HD-Al2O3-coated '
                                                         'material shows some '
                                                         'Al2O3 nanoparticles '
                                                         'that aggregate and '
                                                         'are non-uniformly '
                                                         'coated on the '
                                                         'surface.'}}"""


answer_  = """{'CAM (Cathode Active Material)': {'Additional treatment': 'None',
                                   'Coating': 'Li3PO4 coating',
                                   'Commercial NCM': 'No',
                                   'Crystallization method': 'sintering',
                                   'Crystallization temperature': '750°C',
                                   'Crystallization time': '15 hr',
                                   'Doping': 'Mg',
                                   'Lithium source': 'LiOH·H2O',
                                   'Stoichiometry information': 'Li[Ni0.8Co0.1Mn0.1]O2',
                                   'Synthesis method': 'co-precipitation'},
 'Cathode Performance': {'Capacity at all C-rate, mAh/g (with electrode state)': [{'203.5 mAh/g': '@0.1C, '
                                                                                                'M-NCM',
                                                                                   '199.1 mAh/g': '@0.1C, '
                                                                                                'pristine',
                                                                                   '180.0 mAh/g': '@5.0C, '
                                                                                                'M-NCM',
										   '159.0 mAh/g': '@5.0C,'
												'pristine',
										   '168.9 mAh/g': '@6.0C,'
												'M-NCM',
										   '169.8 mAh/g': '@4.0C,'
												'pristine',
										   '151.3 mAh/g': '@2.0C,'
												'pristine'}],
                         'Temperature': '25°C',
                         'Voltage range': '3.0–4.3 V'},
 'Electrode (only for coin-cell (half-cell))': {'Active material : Conductive additive : Binder ratio': '96 '
                                                                                                        ': '
                                                                                                        '2 '
                                                                                                        ': '
                                                                                                        '2',
                                                'Additional treatment for electrode': 'None',
                                                'Additive': 'None',
                                                'Electrode thickness': 'None',
                                                'Electrolyte': '1.0 M LiPF6 '
                                                               'solution in '
                                                               'dimethyl '
                                                               'carbonate (DMC), '
                                                               'ethylene '
                                                               'carbonate (EC) and '
                                                               'ethyl '
							       'methyl'
                                                               'carbonate (EMC)'
                                                               '(1:1:1 '
                                                               'vol%)',
                                                'Loading density (mass loading of NCM)': 'None',
                                                'Only Cathode Electrode diameter': 'None'},
'Morphological results': {'Explanation of SEM results': 'Fig. 2A, B; '
							 'spherical secondary particles '
		                                         'with an average size of approximately 11.7 μm '
                                  			 'are observed. These secondary particles are '
   			                                 'composed of primary particles with an average '
                        			         'diameter of 170–230 nm. The MgHPO4 modification '
                                 			 'does not appear to affect the size or morphology '
                                  			 'of the NCM cathode material.',
    				 'Explanation of TEM results': 'Fig. 2C, D; '
							 'a thin Li3PO4 coating layer, '
                                 			 'approximately 1.8 nm thick, '
							 'is formed on the '
                                 			 'surface of the M-NCM particles.'}}"""

# %%
from sentence_transformers import SentenceTransformer, util
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)


# SentenceTransformer 모델 로드
model = SentenceTransformer("all-mpnet-base-v2")

# 문장들을 인코딩
sent1_encoded = model.encode(input_, convert_to_tensor=True)
sent2_encoded = model.encode(answer_, convert_to_tensor=True)


# sent1과 sent2 사이의 코사인 유사도 계산
cosine_similarity = util.pytorch_cos_sim(sent1_encoded, sent2_encoded).item()
print(f"[1] \n[2] \n[score] {cosine_similarity:.5f}")

print("===" * 20)
# Out:
# [1]
# [2]
# [score] 0.96524
# ...

# %%
# paper_56
input_56 = """{'CAM (Cathode Active Material)': {'Additional treatment': 'None',
                                   'Coating': 'Li3PO4 coating',
                                   'Commercial NCM': 'Yes',
                                   'Crystallization method': 'Calcination and '
                                                             'sintering',
                                   'Crystallization temperature': '750°C',
                                   'Crystallization time': '15 hr',
                                   'Doping': 'Mg2+ doping',
                                   'Lithium source': 'LiOH/H2O',
                                   'Stoichiometry information': 'LiNi0.8Co0.1Mn0.1O2',
                                   'Synthesis method': 'Co-precipitation'},
 'Cathode Performance': {'Capacity at all C-rate, mAh/g (with electrode state)': [{'180.0 mAh/g': '@5.0C, '
                                                                                                  'M-NCM',
                                                                                   '203.5 mAh/g': '@0.1C, '
                                                                                                  'M-NCM'}],
                         'Temperature': 'None',
                         'Voltage range': '3.0–4.3 V'},
 'Electrode (only for coin-cell (half-cell))': {'Active material : Conductive additive : Binder ratio': '96 '
                                                                                                        ': '
                                                                                                        '2 '
                                                                                                        ': '
                                                                                                        '2',
                                                'Additional treatment for electrode': 'None',
                                                'Additive': 'None',
                                                'Electrode thickness': 'None',
                                                'Electrolyte': '1 M LiPF6 in '
                                                               'DMC, EC, and '
                                                               'EMC (1:1:1 '
                                                               'vol%)',
                                                'Loading density (mass loading of NCM)': 'None',
                                                'Only Cathode Electrode diameter': 'None'},
 'Morphological results': {'Explanation of SEM results': 'Fig. 9A; the cycled '
                                                         'electrode of the '
                                                         'pristine NCM is '
                                                         'damaged by '
                                                         'intergranular '
                                                         'cracking along the '
                                                         'grain boundaries, '
                                                         'while the M-NCM '
                                                         'particle retains its '
                                                         'mechanical integrity '
                                                         'without any cracks '
                                                         'or defects.',
                           'Explanation of TEM results': 'None'}}"""


answer_56 = """{'CAM (Cathode Active Material)': {'Additional treatment': 'None',
                                   'Coating': 'Li3PO4 coating',
                                   'Commercial NCM': 'No',
                                   'Crystallization method': 'sintering',
                                   'Crystallization temperature': '750°C',
                                   'Crystallization time': '15 hr',
                                   'Doping': 'Mg',
                                   'Lithium source': 'LiOH·H2O',
                                   'Stoichiometry information': 'Li[Ni0.8Co0.1Mn0.1]O2',
                                   'Synthesis method': 'co-precipitation'},
 'Cathode Performance': {'Capacity at all C-rate, mAh/g (with electrode state)': [{'203.5 mAh/g': '@0.1C, '
                                                                                                'M-NCM',
                                                                                   '199.1 mAh/g': '@0.1C, '
                                                                                                'pristine',
                                                                                   '180.0 mAh/g': '@5.0C, '
                                                                                                'M-NCM',
										   '159.0 mAh/g': '@5.0C,'
												'pristine',
										   '168.9 mAh/g': '@6.0C,'
												'M-NCM',
										   '169.8 mAh/g': '@4.0C,'
												'pristine',
										   '151.3 mAh/g': '@2.0C,'
												'pristine'}],
                         'Temperature': '25°C',
                         'Voltage range': '3.0–4.3 V'},
 'Electrode (only for coin-cell (half-cell))': {'Active material : Conductive additive : Binder ratio': '96 '
                                                                                                        ': '
                                                                                                        '2 '
                                                                                                        ': '
                                                                                                        '2',
                                                'Additional treatment for electrode': 'None',
                                                'Additive': 'None',
                                                'Electrode thickness': 'None',
                                                'Electrolyte': '1.0 M LiPF6 '
                                                               'solution in '
                                                               'dimethyl '
                                                               'carbonate (DMC), '
                                                               'ethylene '
                                                               'carbonate (EC) and '
                                                               'ethyl '
							       'methyl'
                                                               'carbonate (EMC)'
                                                               '(1:1:1 '
                                                               'vol%)',
                                                'Loading density (mass loading of NCM)': 'None',
                                                'Only Cathode Electrode diameter': 'None'},
'Morphological results': {'Explanation of SEM results': 'Fig. 2A, B; '
							 'spherical secondary particles '
		                                         'with an average size of approximately 11.7 μm '
                                  			 'are observed. These secondary particles are '
   			                                 'composed of primary particles with an average '
                        			         'diameter of 170–230 nm. The MgHPO4 modification '
                                 			 'does not appear to affect the size or morphology '
                                  			 'of the NCM cathode material.',
    				 'Explanation of TEM results': 'Fig. 2C, D; '
							 'a thin Li3PO4 coating layer, '
                                 			 'approximately 1.8 nm thick, '
							 'is formed on the '
                                 			 'surface of the M-NCM particles.'}}"""

# %%
# SentenceTransformer 모델 로드
model = SentenceTransformer("all-mpnet-base-v2")

# 문장들을 인코딩
sent1_encoded_56 = model.encode(input_56, convert_to_tensor=True)
sent2_encoded_56 = model.encode(answer_56, convert_to_tensor=True)


# sent1과 sent2 사이의 코사인 유사도 계산
cosine_similarity_56 = util.pytorch_cos_sim(sent1_encoded_56, sent2_encoded_56).item()
print(f"[1] \n[2] \n[score] {cosine_similarity_56:.5f}")
# Out:
# [1]
# [2]
# [score] 0.98365
