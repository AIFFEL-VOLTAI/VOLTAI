# %% [markdown]
# # 3가지 모델 비교 실험
#
# relevance, ensemble, mutiagent RAG 3가지 모델에 대해서 결과를 출력하고 Gound Truth를 가지고 평가진행.

# %%
import os
from dotenv import load_dotenv
from pprint import pprint

from langchain_teddynote import logging

from graph_relevancerag import RelevanceRAG
from graph_ensemblerag import EnsembleRAG
from graph_multiagentrag import MultiAgentRAG
from utils import *

# .env 파일 로드
load_dotenv(dotenv_path=".env")

# API 키 가져오기
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
LANGCHAIN_API_KEY = os.getenv("LANGCHAIN_API_KEY")

# LangSmith 추적 기능을 활성화합니다. (선택적)
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "Multi-agent Collaboration"

# 프로젝트 이름을 입력합니다.
logging.langsmith("RAG 0204-Evaluation")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# RAG 0204-Evaluation

# %% [markdown]
# ## eval

# %%
def get_rag_instance(
    rag_method, 
    file_folder, 
    file_number, 
    # db_folder,
    chunk_size, 
    chunk_overlap,
    search_k,
    system_prompt, 
    model_name, 
    save_graph_png
):
    """
    RAG 클래스를 동적으로 받아서 인스턴스를 생성하는 함수
    
    Params:
        rag_method: RAG 방법 ("relevance-rag", "ensemble-rag", "multiagent-rag")
        file_folder: 논문 파일이 위치한 폴더 경로
        file_number: 처리할 논문 번호
        system_prompt: system prompt
        model_name: LLM 모델 명 ("gpt-4o", "gpt-4o-mini")
        save_graph_png: graph 저장 결정
        
    Return:
        생성된 RAG 모델 인스턴스
    """
    
    # RAG 모델 인스턴스 생성
    if rag_method == "relevance-rag":
        return RelevanceRAG(file_folder, file_number, chunk_size, chunk_overlap, search_k, system_prompt, model_name, save_graph_png)
        
    elif rag_method == "ensemble-rag":
        return EnsembleRAG(file_folder, file_number, chunk_size, chunk_overlap, search_k, system_prompt, model_name, save_graph_png)
        
    elif rag_method == "multiagent-rag":
        return MultiAgentRAG(file_folder, file_number, chunk_size, chunk_overlap, search_k, system_prompt, model_name, save_graph_png)


def main(
    data_folder:str="./data",
    file_num_list:list=[11],
    category_number:int=1, 
    chunk_size:int=500, 
    chunk_overlap:int=100, 
    search_k:int=10,       
    config_folder:str="./config",
    rag_method:str="multiagent-rag", 
    model_name:str="gpt-4o", 
    save_graph_png:bool=False, 
):
    category_names = ["CAM (Cathode Active Material)", "Electrode (half-cell)", "Morphological Properties", "Cathode Performance"]
    
    ## system_prompt 와 invoke_input 불러오기
    system_prompt = load_system_prompt(config_folder=config_folder, category_number=category_number, rag_method=rag_method)
    invoke_input = load_invoke_input(config_folder=config_folder, category_number=category_number, rag_method=rag_method)
    
    ## 각 논문에 대해 반복
    for i, file_number in enumerate(file_num_list):
        print(f"#####    {file_number}번째 논문    #####")
        print(f"##       rag method     : {rag_method}")
        print(f"##       category name  : {category_names[category_number-1]}")
        
        ## graph 호출
        voltai_graph = get_rag_instance(
            rag_method=rag_method, 
            file_folder=f"{data_folder}/input_data/", 
            file_number=file_number, 
            chunk_size=chunk_size, 
            chunk_overlap=chunk_overlap, 
            search_k=search_k, 
            system_prompt=system_prompt,
            model_name=model_name, 
            save_graph_png=save_graph_png,
        ).graph
        
        ## 질문이 딕셔너리 형태일 경우와 아닌 경우를 처리
        if isinstance(invoke_input, dict):
            
            result = voltai_graph.invoke(**invoke_input)
        else:
            result = voltai_graph.invoke(*invoke_input)

        ## RAG method에 따른 결과 확인
        if result.get("answer"):
            temp_answer = result["answer"][0][category_names[category_number-1]]
        elif result.get("discussion"):
            temp_answer = result["discussion"][category_names[category_number-1]]
        elif result.get("messages"):
            temp_answer = result["messages"][-1][category_names[category_number-1]]
        
        print(f"##       print {file_number} result")
        print("------------------------------------")
        pprint(temp_answer, sort_dicts=False)
        
        return temp_answer

def eval_df_generator_cat(
    file_folder="./data/input_data/",      ## input 논문이 있는 폴더 위치
    file_list=[11, 16, 22],            ## 아직 8번 논문 안됨
    category_number=1,                     ## question 번호 1,2,3,4 중 하나
):
    print(f"🔍 실행 중: eval_df_generator_cat | file_list: {file_list}")  # 값 확인
    eval_df = pd.DataFrame(columns=["paper_number","type", "result","ground_truth"])
    
    types = ["relevance-rag","ensemble-rag","multiagent-rag"]
    for t in types: 
        df = pd.DataFrame(columns = ["paper_number","category_name","type", "result"])
        
        for i, file_number in enumerate(file_list):
            result= main(file_num_list=[file_number], category_number= category_number, rag_method=t)
            ### result 저장
            ## gt 불러오기기
            if file_number < 10:
                file_name = f"paper_00{file_number}"
            elif file_number < 100:
                file_name = f"paper_0{file_number}"
            else:
                file_name = f"paper_{file_number}"
        
            # JSON 파일 경로
            file_path = f"./data/ground_truth/{file_name}_gt.json"

            # JSON 파일 읽기
            with open(file_path, "r", encoding="utf-8") as file:
                gt = json.load(file)

            ## df에 결과 저장하기       
            if category_number == 1:
                category_name = "CAM (Cathode Active Material)"
            elif category_number == 2:
                category_name = "Electrode (half-cell)"
            elif category_number == 3:
                category_name = "Morphological Properties"
            elif category_number == 4:
                category_name = "Cathode Performance"    
            else:
                raise
            print(f"🔍 gt[{category_name}] 타입:", type(gt[category_name]))
            print(f"🔍 gt[{category_name}] 값:", gt[category_name])
            df.loc[i, "paper_number"] = file_number
            df.loc[i, "type"] = t
            df.loc[i, "category_number"] = category_number
            df.loc[i, "category_name"] = category_name
            df.loc[i, "result"] = [result] 
            df.loc[i, "ground_truth"] = [gt[category_name]]
            
            ## [dict(key = category_name, value = gt[category_name])]
        eval_df = pd.concat([eval_df, df], ignore_index=True)    
    return eval_df



def concat_category_eval(
        f_list:list =[11,42]
):
    category  = [1,2,3,4]
    eval_df = pd.DataFrame(columns= ['paper_number', 'type', 'result', 'ground_truth', 'category_name',
       'category_number'])
    
    for i in category:
        df = eval_df_generator_cat(file_list= f_list, category_number=i)

        eval_df = pd.concat([eval_df, df])

    return eval_df

# %%
file_ = [11,16,22,35,39,40,41,42,44,56,64]
df = concat_category_eval(f_list =file_ )
# Out:
# 🔍 실행 중: eval_df_generator_cat | file_list: [11, 16, 22, 35, 39, 40, 41, 42, 44, 56]
# ## ./config/relevance-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
# #####    11번째 논문    #####
# ##       rag method     : relevance-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_011 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK : yes
# ##       print 11 result
# ------------------------------------
# {'Stoichiometry information': {'NR0': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2.0},
#                                'NR1': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2.0},
#                                'NR3': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2.0},
#                                'NR5': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2.0}},
#  'Commercial NCM used': {'NR0': 'no', 'NR1': 'no', 'NR3': 'no', 'NR5': 'no'},
#  'Lithium source': 'LiNO3',
#  'Synthesis method': 'solution combustion',
#  'Crystallization method': 'calcination',
#  'Crystallization final temperature': 850,
#  'Crystallization final duration (hours)': 15,
#  'Doping': None,
#  'Coating': 'RGO',
#  'Additional treatment': None}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'NR0': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}, 'NR1': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}, 'NR3': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}, 'NR5': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}}, 'Commercial NCM used': {'NR0': 'no', 'NR1': 'no', 'NR3': 'no', 'NR5': 'no'}, 'Lithium source': 'LiNO3', 'Synthesis method': 'solution combustion', 'Crystallization method': 'calcination', 'Crystallization final temperature': '850', 'Crystallization final duration (hours)': '15', 'Doping': None, 'Coating': 'RGO', 'Additional treatment': 'microwave irradiation'}
# ## ./config/relevance-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
# #####    16번째 논문    #####
# ##       rag method     : relevance-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_016 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK : yes
# ##       print 16 result
# ------------------------------------
# {'Stoichiometry information': {'NCM': {'Li ratio': 1.01,
#                                        'Ni ratio': 0.35,
#                                        'Co ratio': 0.32,
#                                        'Mn ratio': 0.32,
#                                        'O ratio': None},
#                                'NCM/C': {'Li ratio': 1.03,
#                                          'Ni ratio': 0.32,
#                                          'Co ratio': 0.33,
#                                          'Mn ratio': 0.34,
#                                          'O ratio': None}},
#  'Commercial NCM used': {'NCM': 'no', 'NCM/C': 'no'},
#  'Lithium source': 'LiAc',
#  'Synthesis method': 'sol-gel',
#  'Crystallization method': None,
#  'Crystallization final temperature': 850,
#  'Crystallization final duration (hours)': 10,
#  'Doping': None,
#  'Coating': 'carbon',
#  'Additional treatment': None}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'NCM': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}, 'NCM/C': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}}, 'Commercial NCM used': {'NCM': 'no', 'NCM/C': 'no'}, 'Lithium source': 'LiAc', 'Synthesis method': 'sol-gel method', 'Crystallization method': 'calcination', 'Crystallization final temperature': '850', 'Crystallization final duration (hours)': '10', 'Doping': None, 'Coating': 'Carbon', 'Additional treatment': None}
# ## ./config/relevance-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
# #####    22번째 논문    #####
# ##       rag method     : relevance-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_022 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK : yes
# ##       print 22 result
# ------------------------------------
# {'Stoichiometry information': {'V-doped NCM': {'Li ratio': 1.05,
#                                                'Ni ratio': 0.84,
#                                                'Co ratio': 0.1,
#                                                'Mn ratio': 0.06,
#                                                'O ratio': None}},
#  'Commercial NCM used': {'V-doped NCM': 'no'},
#  'Lithium source': 'LiOH',
#  'Synthesis method': 'solid state method',
#  'Crystallization method': None,
#  'Crystallization final temperature': 760,
#  'Crystallization final duration (hours)': 15,
#  'Doping': 'V',
#  'Coating': None,
#  'Additional treatment': None}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'Pristine NCM': {'Li ratio': '1', 'Ni ratio': '0.84', 'Co ratio': '0.10', 'Mn ratio': '0.06', 'O ratio': '2'}, 'V-doped NCM': {'Li ratio': '1', 'Ni ratio': '0.84', 'Co ratio': '0.10', 'Mn ratio': '0.06', 'O ratio': '2'}}, 'Commercial NCM used': {'Pristine NCM': 'no', 'V-doped NCM': 'no'}, 'Lithium source': 'LiOH', 'Synthesis method': 'solid state method', 'Crystallization method': 'calcination', 'Crystallization final temperature': '760', 'Crystallization final duration (hours)': '15', 'Doping': 'Vanadium (V)', 'Coating': None, 'Additional treatment': None}
# ## ./config/relevance-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
# #####    35번째 논문    #####
# ##       rag method     : relevance-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_035 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK : yes
# ##       print 35 result
# ------------------------------------
# {'Stoichiometry information': {'S1bare': {'Li ratio': 1.03,
#                                           'Ni ratio': 0.85,
#                                           'Co ratio': 0.1,
#                                           'Mn ratio': 0.05,
#                                           'O ratio': None},
#                                'S2wash': {'Li ratio': 1.03,
#                                           'Ni ratio': 0.85,
#                                           'Co ratio': 0.1,
#                                           'Mn ratio': 0.05,
#                                           'O ratio': None},
#                                'S3coat': {'Li ratio': 1.03,
#                                           'Ni ratio': 0.85,
#                                           'Co ratio': 0.1,
#                                           'Mn ratio': 0.05,
#                                           'O ratio': None}},
#  'Commercial NCM used': {'S1bare': 'no', 'S2wash': 'no', 'S3coat': 'no'},
#  'Lithium source': 'LiOH',
#  'Synthesis method': 'co-precipitation',
#  'Crystallization method': None,
#  'Crystallization final temperature': 750,
#  'Crystallization final duration (hours)': 12,
#  'Doping': None,
#  'Coating': 'boric acid',
#  'Additional treatment': 'water washing'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'S1bare': {'Li ratio': '1', 'Ni ratio': '0.85', 'Co ratio': '0.10', 'Mn ratio': '0.05', 'O ratio': '2'}, 'S2wash': {'Li ratio': '1', 'Ni ratio': '0.85', 'Co ratio': '0.10', 'Mn ratio': '0.05', 'O ratio': '2'}, 'S3coat': {'Li ratio': '1', 'Ni ratio': '0.85', 'Co ratio': '0.10', 'Mn ratio': '0.05', 'O ratio': '2'}}, 'Commercial NCM used': {'S1bare': 'no', 'S2wash': 'no', 'S3coat': 'no'}, 'Lithium source': 'LiOH', 'Synthesis method': 'Co-precipitation', 'Crystallization method': 'air purge', 'Crystallization final temperature': '750', 'Crystallization final duration (hours)': '12', 'Doping': None, 'Coating': 'Boric acid (H3BO3)', 'Additional treatment': 'Water washing for S2wash sample'}
# ## ./config/relevance-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
# #####    39번째 논문    #####
# ##       rag method     : relevance-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_039 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK : yes
# ##       print 39 result
# ------------------------------------
# {'Stoichiometry information': {'N92': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.92,
#                                        'Co ratio': 0.04,
#                                        'Mn ratio': 0.04,
#                                        'O ratio': 2.0},
#                                'WN92 (x = 0.25%)': {'Li ratio': 1.0,
#                                                     'Ni ratio': 0.9175,
#                                                     'Co ratio': 0.04,
#                                                     'Mn ratio': 0.04,
#                                                     'O ratio': 2.0},
#                                'WN92 (x = 0.5%)': {'Li ratio': 1.0,
#                                                    'Ni ratio': 0.915,
#                                                    'Co ratio': 0.04,
#                                                    'Mn ratio': 0.04,
#                                                    'O ratio': 2.0},
#                                'WN92 (x = 1%)': {'Li ratio': 1.0,
#                                                  'Ni ratio': 0.91,
#                                                  'Co ratio': 0.04,
#                                                  'Mn ratio': 0.04,
#                                                  'O ratio': 2.0},
#                                'WN92 (x = 2%)': {'Li ratio': 1.0,
#                                                  'Ni ratio': 0.902,
#                                                  'Co ratio': 0.04,
#                                                  'Mn ratio': 0.04,
#                                                  'O ratio': 2.0}},
#  'Commercial NCM used': {'N92': 'no',
#                          'WN92 (x = 0.25%)': 'no',
#                          'WN92 (x = 0.5%)': 'no',
#                          'WN92 (x = 1%)': 'no',
#                          'WN92 (x = 2%)': 'no'},
#  'Lithium source': 'LiOH',
#  'Synthesis method': 'solid-phase',
#  'Crystallization method': None,
#  'Crystallization final temperature': 780,
#  'Crystallization final duration (hours)': 10,
#  'Doping': 'W6+',
#  'Coating': None,
#  'Additional treatment': 'spray-drying'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'N92': {'Li ratio': '1', 'Ni ratio': '0.92', 'Co ratio': '0.04', 'Mn ratio': '0.04', 'O ratio': '2'}, 'WN92': {'Li ratio': '1', 'Ni ratio': '0.91', 'Co ratio': '0.04', 'Mn ratio': '0.04', 'O ratio': '2', 'W ratio': '1'}}, 'Commercial NCM used': {'N92': 'no', 'WN92': 'no'}, 'Lithium source': 'LiOH', 'Synthesis method': 'solid-phase method', 'Crystallization method': 'calcination', 'Crystallization final temperature': '780', 'Crystallization final duration (hours)': '10', 'Doping': 'W6+', 'Coating': None, 'Additional treatment': 'Grinding, ball milling, and spray drying'}
# ## ./config/relevance-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
# #####    40번째 논문    #####
# ##       rag method     : relevance-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_040 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK : yes
# ##       print 40 result
# ------------------------------------
# {'Stoichiometry information': {'SC-NCM83': {'Li ratio': 1.0,
#                                             'Ni ratio': 0.83,
#                                             'Co ratio': 0.11,
#                                             'Mn ratio': 0.06,
#                                             'O ratio': 2.0}},
#  'Commercial NCM used': {'SC-NCM83': 'no'},
#  'Lithium source': 'LiOH',
#  'Synthesis method': 'mixing',
#  'Crystallization method': None,
#  'Crystallization final temperature': 975,
#  'Crystallization final duration (hours)': 9,
#  'Doping': None,
#  'Coating': None,
#  'Additional treatment': 'post-annealed at 750°C for 3 hours'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'SC-NCM83': {'Li ratio': '1', 'Ni ratio': '0.83', 'Co ratio': '0.11', 'Mn ratio': '0.06', 'O ratio': '2'}, 'PC-NCM': {'Li ratio': '1', 'Ni ratio': '0.83', 'Co ratio': '0.11', 'Mn ratio': '0.06', 'O ratio': '2'}}, 'Commercial NCM used': {'PC-NCM': 'no', 'SC-NCM': 'no'}, 'Lithium source': ['LiOH', 'Li2CO3'], 'Synthesis method': None, 'Crystallization method': 'calcination', 'Crystallization final temperature': '975', 'Crystallization final duration (hours)': '9', 'Doping': None, 'Coating': None, 'Additional treatment': 'Post-annealing at 750 °C for 3 h and washing in water for 15 min to remove excess Li salts'}
# ## ./config/relevance-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
# #####    41번째 논문    #####
# ##       rag method     : relevance-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_041 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK : yes
# ##       print 41 result
# ------------------------------------
# {'Stoichiometry information': {'NCM-811': {'Li ratio': 1.0,
#                                            'Ni ratio': 0.8,
#                                            'Co ratio': 0.1,
#                                            'Mn ratio': 0.1,
#                                            'O ratio': 2.0}},
#  'Commercial NCM used': {'NCM-811': 'yes'},
#  'Lithium source': None,
#  'Synthesis method': 'Sonication-assisted liquid exfoliation, Chemical '
#                      'vaporization-assisted synthesis',
#  'Crystallization method': None,
#  'Crystallization final temperature': None,
#  'Crystallization final duration (hours)': None,
#  'Doping': None,
#  'Coating': 'g-C3N4',
#  'Additional treatment': None}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'NCM-811': {'Li ratio': '1', 'Ni ratio': '0.8', 'Co ratio': '0.1', 'Mn ratio': '0.1', 'O ratio': '2'}, 'g-C3N4@NCM-811': {'Li ratio': '1', 'Ni ratio': '0.8', 'Co ratio': '0.1', 'Mn ratio': '0.1', 'O ratio': '2'}, 'g-C3N4NS@NCM-811': {'Li ratio': '1', 'Ni ratio': '0.8', 'Co ratio': '0.1', 'Mn ratio': '0.1', 'O ratio': '2'}}, 'Commercial NCM used': {'NCM-811': 'yes', 'g-C3N4@NCM-811': 'yes', 'g-C3N4NS@NCM-811': 'yes'}, 'Lithium source': None, 'Synthesis method': None, 'Crystallization method': None, 'Crystallization final temperature': None, 'Crystallization final duration': None, 'Doping': None, 'Coating': 'Graphitic carbon nitride', 'Additional treatment': None}
# ## ./config/relevance-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
# #####    42번째 논문    #####
# ##       rag method     : relevance-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_042 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK : yes
# ##       print 42 result
# ------------------------------------
# {'Stoichiometry information': {'SC-NCM': {'Li ratio': 1.0,
#                                           'Ni ratio': 0.83,
#                                           'Co ratio': 0.12,
#                                           'Mn ratio': 0.05,
#                                           'O ratio': 2.0},
#                                'N-NCM': {'Li ratio': 1.0,
#                                          'Ni ratio': 0.83,
#                                          'Co ratio': 0.12,
#                                          'Mn ratio': 0.05,
#                                          'O ratio': 2.0}},
#  'Commercial NCM used': {'SC-NCM': 'no', 'N-NCM': 'yes'},
#  'Lithium source': 'Li2CO3',
#  'Synthesis method': 'co-precipitation',
#  'Crystallization method': 'Hydrothermal',
#  'Crystallization final temperature': 860,
#  'Crystallization final duration (hours)': 12,
#  'Doping': None,
#  'Coating': None,
#  'Additional treatment': None}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'SC-NCM': {'Li ratio': '1', 'Ni ratio': '0.83', 'Co ratio': '0.12', 'Mn ratio': '0.05', 'O ratio': '2'}, 'N-NCM': {'Li ratio': '1', 'Ni ratio': '0.83', 'Co ratio': '0.12', 'Mn ratio': '0.05', 'O ratio': '2'}}, 'Commercial NCM used': {'SC-NCM': 'no', 'N-NCM': 'yes'}, 'Lithium source': 'LiCO3', 'Synthesis method': 'co-precipitation', 'Crystallization method': 'sintering', 'Crystallization final temperature': '860', 'Crystallization final duration (hours)': '12', 'Doping': None, 'Coating': None, 'Additional treatment': 'PVP added during hydrothermal reaction'}
# ## ./config/relevance-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
# #####    44번째 논문    #####
# ##       rag method     : relevance-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_044 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK : yes
# ##       print 44 result
# ------------------------------------
# {'Stoichiometry information': {'NCM-622': {'Li ratio': 0.9758,
#                                            'Ni ratio': 0.576,
#                                            'Co ratio': 0.2003,
#                                            'Mn ratio': 0.2,
#                                            'O ratio': 1.0001},
#                                'ZrO2-NCM-622 (Z622)': None},
#  'Commercial NCM used': {'NCM-622': 'yes', 'ZrO2-NCM-622 (Z622)': 'no'},
#  'Lithium source': None,
#  'Synthesis method': None,
#  'Crystallization method': None,
#  'Crystallization final temperature': None,
#  'Crystallization final duration (hours)': None,
#  'Doping': None,
#  'Coating': 'Al2O3',
#  'Additional treatment': None}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'pristine NCM622': {'Li ratio': '1', 'Ni ratio': '0.6', 'Co ratio': '0.2', 'Mn ratio': '0.2', 'O ratio': '2'}, 'polymer/γ-Al2O3-coated NCM622': {'Li ratio': '1', 'Ni ratio': '0.6', 'Co ratio': '0.2', 'Mn ratio': '0.2', 'O ratio': '2'}}, 'Commercial NCM used': {'pristine NCM622': 'no', 'polymer/γ-Al2O3-coated NCM622': 'no'}, 'Lithium source': 'LiOH', 'Synthesis method': 'co-precipitation', 'Crystallization method': 'sintering', 'Crystallization final temperature': '875', 'Crystallization final duration': '12', 'Doping': None, 'Coating': 'γ-Al2O3', 'Additional treatment': None}
# ## ./config/relevance-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/relevance-rag/c1-question.yaml를 불러왔습니다.
# #####    56번째 논문    #####
# ##       rag method     : relevance-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_056 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK : yes
# ##       print 56 result
# ------------------------------------
# {'Stoichiometry information': {'NCM': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.8,
#                                        'Co ratio': 0.1,
#                                        'Mn ratio': 0.1,
#                                        'O ratio': None},
#                                'M-NCM': {'Li ratio': 1.0,
#                                          'Ni ratio': 0.8,
#                                          'Co ratio': 0.1,
#                                          'Mn ratio': 0.1,
#                                          'O ratio': None}},
#  'Commercial NCM used': {'NCM': 'yes', 'M-NCM': 'no'},
#  'Lithium source': 'LiOH',
#  'Synthesis method': None,
#  'Crystallization method': None,
#  'Crystallization final temperature': None,
#  'Crystallization final duration (hours)': None,
#  'Doping': 'Mg',
#  'Coating': 'Li3PO4',
#  'Additional treatment': None}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'pristine NCM': {'Li ratio': '1', 'Ni ratio': '0.8', 'Co ratio': '0.1', 'Mn ratio': '0.1', 'O ratio': '2'}, 'M-NCM': {'Li ratio': '1', 'Ni ratio': '0.8', 'Co ratio': '0.1', 'Mn ratio': '0.1', 'O ratio': '2'}}, 'Commercial NCM used': {'pristine NCM': 'no', 'M-NCM': 'no'}, 'Lithium source': 'LiOH', 'Synthesis method': 'co-precipitation', 'Crystallization method': 'sintering', 'Crystallization final temperature': '750', 'Crystallization final duration': '15', 'Doping': 'Mg', 'Coating': 'Li3PO4', 'Additional treatment': None}
# ## ./config/ensemble-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/ensemble-rag/c1-question.yaml를 불러왔습니다.
# #####    11번째 논문    #####
# ##       rag method     : ensemble-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_011 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK for ANSWER 1 : yes
#         RELEVANCE CHECK for ANSWER 2 : yes
#         RELEVANCE CHECK for ANSWER 3 : yes
#         Success Discussion!
# ##       print 11 result
# ------------------------------------
# {'Stoichiometry information': {'NR0': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2.0},
#                                'NR1': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2.0},
#                                'NR3': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2.0},
#                                'NR5': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.33,
#                                        'Co ratio': 0.33,
#                                        'Mn ratio': 0.33,
#                                        'O ratio': 2.0}},
#  'Commercial NCM used': {'NR0': 'no', 'NR1': 'no', 'NR3': 'no', 'NR5': 'no'},
#  'Lithium source': 'LiNO3',
#  'Synthesis method': 'solution combustion',
#  'Crystallization method': 'calcination',
#  'Crystallization final temperature': 850,
#  'Crystallization final duration (hours)': 15,
#  'Doping': None,
#  'Coating': 'RGO',
#  'Additional treatment': 'microwave reduction'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'NR0': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}, 'NR1': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}, 'NR3': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}, 'NR5': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}}, 'Commercial NCM used': {'NR0': 'no', 'NR1': 'no', 'NR3': 'no', 'NR5': 'no'}, 'Lithium source': 'LiNO3', 'Synthesis method': 'solution combustion', 'Crystallization method': 'calcination', 'Crystallization final temperature': '850', 'Crystallization final duration (hours)': '15', 'Doping': None, 'Coating': 'RGO', 'Additional treatment': 'microwave irradiation'}
# ## ./config/ensemble-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/ensemble-rag/c1-question.yaml를 불러왔습니다.
# #####    16번째 논문    #####
# ##       rag method     : ensemble-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_016 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK for ANSWER 3 : yes
#         RELEVANCE CHECK for ANSWER 1 : yes
#         RELEVANCE CHECK for ANSWER 2 : yes
#         Success Discussion!
# ##       print 16 result
# ------------------------------------
# {'Stoichiometry information': {'NCM': {'Li ratio': 1.01,
#                                        'Ni ratio': 0.35,
#                                        'Co ratio': 0.32,
#                                        'Mn ratio': 0.32,
#                                        'O ratio': None},
#                                'NCM/C': {'Li ratio': 1.03,
#                                          'Ni ratio': 0.32,
#                                          'Co ratio': 0.33,
#                                          'Mn ratio': 0.34,
#                                          'O ratio': None}},
#  'Commercial NCM used': {'NCM': 'no', 'NCM/C': 'no'},
#  'Lithium source': 'LiAc',
#  'Synthesis method': 'sol-gel',
#  'Crystallization method': 'sintering',
#  'Crystallization final temperature': 850,
#  'Crystallization final duration (hours)': 10,
#  'Doping': None,
#  'Coating': 'carbon',
#  'Additional treatment': None}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'NCM': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}, 'NCM/C': {'Li ratio': '1', 'Ni ratio': '0.33', 'Co ratio': '0.33', 'Mn ratio': '0.33', 'O ratio': '2'}}, 'Commercial NCM used': {'NCM': 'no', 'NCM/C': 'no'}, 'Lithium source': 'LiAc', 'Synthesis method': 'sol-gel method', 'Crystallization method': 'calcination', 'Crystallization final temperature': '850', 'Crystallization final duration (hours)': '10', 'Doping': None, 'Coating': 'Carbon', 'Additional treatment': None}
# ## ./config/ensemble-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/ensemble-rag/c1-question.yaml를 불러왔습니다.
# #####    22번째 논문    #####
# ##       rag method     : ensemble-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_022 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK for ANSWER 1 : yes
#         RELEVANCE CHECK for ANSWER 3 : yes
#         RELEVANCE CHECK for ANSWER 2 : yes
#         Success Discussion!
# ##       print 22 result
# ------------------------------------
# {'Stoichiometry information': {'V-doped NCM': {'Li ratio': 1.05,
#                                                'Ni ratio': 0.84,
#                                                'Co ratio': 0.1,
#                                                'Mn ratio': 0.06,
#                                                'O ratio': None}},
#  'Commercial NCM used': {'V-doped NCM': 'no'},
#  'Lithium source': 'LiOH',
#  'Synthesis method': 'co-precipitation',
#  'Crystallization method': 'solid state',
#  'Crystallization final temperature': 760,
#  'Crystallization final duration (hours)': 15,
#  'Doping': 'V5+',
#  'Coating': None,
#  'Additional treatment': None}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'Pristine NCM': {'Li ratio': '1', 'Ni ratio': '0.84', 'Co ratio': '0.10', 'Mn ratio': '0.06', 'O ratio': '2'}, 'V-doped NCM': {'Li ratio': '1', 'Ni ratio': '0.84', 'Co ratio': '0.10', 'Mn ratio': '0.06', 'O ratio': '2'}}, 'Commercial NCM used': {'Pristine NCM': 'no', 'V-doped NCM': 'no'}, 'Lithium source': 'LiOH', 'Synthesis method': 'solid state method', 'Crystallization method': 'calcination', 'Crystallization final temperature': '760', 'Crystallization final duration (hours)': '15', 'Doping': 'Vanadium (V)', 'Coating': None, 'Additional treatment': None}
# ## ./config/ensemble-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/ensemble-rag/c1-question.yaml를 불러왔습니다.
# #####    35번째 논문    #####
# ##       rag method     : ensemble-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_035 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK for ANSWER 1 : yes
#         RELEVANCE CHECK for ANSWER 3 : yes
#         RELEVANCE CHECK for ANSWER 2 : yes
#         Success Discussion!
# ##       print 35 result
# ------------------------------------
# {'Stoichiometry information': {'LiNi0.85Co0.10Mn0.05O2': {'Li ratio': 1.03,
#                                                           'Ni ratio': 0.85,
#                                                           'Co ratio': 0.1,
#                                                           'Mn ratio': 0.05,
#                                                           'O ratio': 2.0}},
#  'Commercial NCM used': {'LiNi0.85Co0.10Mn0.05O2': 'no'},
#  'Lithium source': 'LiOH',
#  'Synthesis method': 'co-precipitation',
#  'Crystallization method': None,
#  'Crystallization final temperature': 750,
#  'Crystallization final duration (hours)': 12,
#  'Doping': None,
#  'Coating': 'H3BO3',
#  'Additional treatment': 'washing'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'S1bare': {'Li ratio': '1', 'Ni ratio': '0.85', 'Co ratio': '0.10', 'Mn ratio': '0.05', 'O ratio': '2'}, 'S2wash': {'Li ratio': '1', 'Ni ratio': '0.85', 'Co ratio': '0.10', 'Mn ratio': '0.05', 'O ratio': '2'}, 'S3coat': {'Li ratio': '1', 'Ni ratio': '0.85', 'Co ratio': '0.10', 'Mn ratio': '0.05', 'O ratio': '2'}}, 'Commercial NCM used': {'S1bare': 'no', 'S2wash': 'no', 'S3coat': 'no'}, 'Lithium source': 'LiOH', 'Synthesis method': 'Co-precipitation', 'Crystallization method': 'air purge', 'Crystallization final temperature': '750', 'Crystallization final duration (hours)': '12', 'Doping': None, 'Coating': 'Boric acid (H3BO3)', 'Additional treatment': 'Water washing for S2wash sample'}
# ## ./config/ensemble-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/ensemble-rag/c1-question.yaml를 불러왔습니다.
# #####    39번째 논문    #####
# ##       rag method     : ensemble-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_039 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK for ANSWER 1 : yes
#         RELEVANCE CHECK for ANSWER 2 : yes
#         RELEVANCE CHECK for ANSWER 3 : yes
#         Success Discussion!
# ##       print 39 result
# ------------------------------------
# {'Stoichiometry information': {'N92': {'Li ratio': 1.0,
#                                        'Ni ratio': 0.92,
#                                        'Co ratio': 0.04,
#                                        'Mn ratio': 0.04,
#                                        'O ratio': 2.0},
#                                'WN92 (x = 0.25%)': {'Li ratio': 1.0,
#                                                     'Ni ratio': 0.9175,
#                                                     'Co ratio': 0.04,
#                                                     'Mn ratio': 0.04,
#                                                     'O ratio': 2.0},
#                                'WN92 (x = 0.5%)': {'Li ratio': 1.0,
#                                                    'Ni ratio': 0.915,
#                                                    'Co ratio': 0.04,
#                                                    'Mn ratio': 0.04,
#                                                    'O ratio': 2.0},
#                                'WN92 (x = 1%)': {'Li ratio': 1.0,
#                                                  'Ni ratio': 0.91,
#                                                  'Co ratio': 0.04,
#                                                  'Mn ratio': 0.04,
#                                                  'O ratio': 2.0},
#                                'WN92 (x = 2%)': {'Li ratio': 1.0,
#                                                  'Ni ratio': 0.9,
#                                                  'Co ratio': 0.04,
#                                                  'Mn ratio': 0.04,
#                                                  'O ratio': 2.0}},
#  'Commercial NCM used': {'N92': 'no',
#                          'WN92 (x = 0.25%)': 'no',
#                          'WN92 (x = 0.5%)': 'no',
#                          'WN92 (x = 1%)': 'no',
#                          'WN92 (x = 2%)': 'no'},
#  'Lithium source': 'LiOH',
#  'Synthesis method': 'solid-phase method',
#  'Crystallization method': 'calcination',
#  'Crystallization final temperature': 780,
#  'Crystallization final duration (hours)': 10,
#  'Doping': 'W6+',
#  'Coating': None,
#  'Additional treatment': 'spray-drying'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'N92': {'Li ratio': '1', 'Ni ratio': '0.92', 'Co ratio': '0.04', 'Mn ratio': '0.04', 'O ratio': '2'}, 'WN92': {'Li ratio': '1', 'Ni ratio': '0.91', 'Co ratio': '0.04', 'Mn ratio': '0.04', 'O ratio': '2', 'W ratio': '1'}}, 'Commercial NCM used': {'N92': 'no', 'WN92': 'no'}, 'Lithium source': 'LiOH', 'Synthesis method': 'solid-phase method', 'Crystallization method': 'calcination', 'Crystallization final temperature': '780', 'Crystallization final duration (hours)': '10', 'Doping': 'W6+', 'Coating': None, 'Additional treatment': 'Grinding, ball milling, and spray drying'}
# ## ./config/ensemble-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/ensemble-rag/c1-question.yaml를 불러왔습니다.
# #####    40번째 논문    #####
# ##       rag method     : ensemble-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_040 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK for ANSWER 3 : yes
#         RELEVANCE CHECK for ANSWER 2 : yes
#         RELEVANCE CHECK for ANSWER 1 : yes
#         Success Discussion!
# ##       print 40 result
# ------------------------------------
# {'Stoichiometry information': {'SC-NCM83': {'Li ratio': 1.1,
#                                             'Ni ratio': 0.83,
#                                             'Co ratio': 0.11,
#                                             'Mn ratio': 0.06,
#                                             'O ratio': 2.0}},
#  'Commercial NCM used': {'SC-NCM83': 'no'},
#  'Lithium source': 'LiOH',
#  'Synthesis method': 'simple blending',
#  'Crystallization method': None,
#  'Crystallization final temperature': 975,
#  'Crystallization final duration (hours)': 9,
#  'Doping': None,
#  'Coating': None,
#  'Additional treatment': 'post-annealed at 750 °C for 3 hours'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'SC-NCM83': {'Li ratio': '1', 'Ni ratio': '0.83', 'Co ratio': '0.11', 'Mn ratio': '0.06', 'O ratio': '2'}, 'PC-NCM': {'Li ratio': '1', 'Ni ratio': '0.83', 'Co ratio': '0.11', 'Mn ratio': '0.06', 'O ratio': '2'}}, 'Commercial NCM used': {'PC-NCM': 'no', 'SC-NCM': 'no'}, 'Lithium source': ['LiOH', 'Li2CO3'], 'Synthesis method': None, 'Crystallization method': 'calcination', 'Crystallization final temperature': '975', 'Crystallization final duration (hours)': '9', 'Doping': None, 'Coating': None, 'Additional treatment': 'Post-annealing at 750 °C for 3 h and washing in water for 15 min to remove excess Li salts'}
# ## ./config/ensemble-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/ensemble-rag/c1-question.yaml를 불러왔습니다.
# #####    41번째 논문    #####
# ##       rag method     : ensemble-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_041 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK for ANSWER 2 : yes
#         RELEVANCE CHECK for ANSWER 1 : yes
#         RELEVANCE CHECK for ANSWER 3 : yes
#         Success Discussion!
# ##       print 41 result
# ------------------------------------
# {'Stoichiometry information': {'NCM-811': {'Li ratio': 1.0,
#                                            'Ni ratio': 0.8,
#                                            'Co ratio': 0.1,
#                                            'Mn ratio': 0.1,
#                                            'O ratio': 2.0},
#                                'g-C3N4NS@NCM-811': {'Li ratio': 1.0,
#                                                     'Ni ratio': 0.8,
#                                                     'Co ratio': 0.1,
#                                                     'Mn ratio': 0.1,
#                                                     'O ratio': 2.0},
#                                'g-C3N4@NCM-811': {'Li ratio': 1.0,
#                                                   'Ni ratio': 0.8,
#                                                   'Co ratio': 0.1,
#                                                   'Mn ratio': 0.1,
#                                                   'O ratio': 2.0}},
#  'Commercial NCM used': {'NCM-811': 'yes',
#                          'g-C3N4NS@NCM-811': 'no',
#                          'g-C3N4@NCM-811': 'no'},
#  'Lithium source': None,
#  'Synthesis method': 'sonication-assisted liquid exfoliation, chemical '
#                      'vaporization-assisted synthesis',
#  'Crystallization method': None,
#  'Crystallization final temperature': 550,
#  'Crystallization final duration (hours)': 4,
#  'Doping': None,
#  'Coating': 'g-C3N4',
#  'Additional treatment': 'furnace cooling'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'NCM-811': {'Li ratio': '1', 'Ni ratio': '0.8', 'Co ratio': '0.1', 'Mn ratio': '0.1', 'O ratio': '2'}, 'g-C3N4@NCM-811': {'Li ratio': '1', 'Ni ratio': '0.8', 'Co ratio': '0.1', 'Mn ratio': '0.1', 'O ratio': '2'}, 'g-C3N4NS@NCM-811': {'Li ratio': '1', 'Ni ratio': '0.8', 'Co ratio': '0.1', 'Mn ratio': '0.1', 'O ratio': '2'}}, 'Commercial NCM used': {'NCM-811': 'yes', 'g-C3N4@NCM-811': 'yes', 'g-C3N4NS@NCM-811': 'yes'}, 'Lithium source': None, 'Synthesis method': None, 'Crystallization method': None, 'Crystallization final temperature': None, 'Crystallization final duration': None, 'Doping': None, 'Coating': 'Graphitic carbon nitride', 'Additional treatment': None}
# ## ./config/ensemble-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/ensemble-rag/c1-question.yaml를 불러왔습니다.
# #####    42번째 논문    #####
# ##       rag method     : ensemble-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_042 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK for ANSWER 3 : yes
#         RELEVANCE CHECK for ANSWER 1 : yes
#         RELEVANCE CHECK for ANSWER 2 : yes
#         Success Discussion!
# ##       print 42 result
# ------------------------------------
# {'Stoichiometry information': {'SC-NCM': {'Li ratio': 1.11,
#                                           'Ni ratio': 0.83,
#                                           'Co ratio': 0.12,
#                                           'Mn ratio': 0.05,
#                                           'O ratio': 2.0},
#                                'N-NCM': {'Li ratio': 1.11,
#                                          'Ni ratio': 0.83,
#                                          'Co ratio': 0.12,
#                                          'Mn ratio': 0.05,
#                                          'O ratio': 2.0}},
#  'Commercial NCM used': {'SC-NCM': 'no', 'N-NCM': 'yes'},
#  'Lithium source': 'LiCO3',
#  'Synthesis method': 'co-precipitation',
#  'Crystallization method': 'Calcination',
#  'Crystallization final temperature': 860,
#  'Crystallization final duration (hours)': 12,
#  'Doping': None,
#  'Coating': None,
#  'Additional treatment': 'Hydrothermal'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'SC-NCM': {'Li ratio': '1', 'Ni ratio': '0.83', 'Co ratio': '0.12', 'Mn ratio': '0.05', 'O ratio': '2'}, 'N-NCM': {'Li ratio': '1', 'Ni ratio': '0.83', 'Co ratio': '0.12', 'Mn ratio': '0.05', 'O ratio': '2'}}, 'Commercial NCM used': {'SC-NCM': 'no', 'N-NCM': 'yes'}, 'Lithium source': 'LiCO3', 'Synthesis method': 'co-precipitation', 'Crystallization method': 'sintering', 'Crystallization final temperature': '860', 'Crystallization final duration (hours)': '12', 'Doping': None, 'Coating': None, 'Additional treatment': 'PVP added during hydrothermal reaction'}
# ## ./config/ensemble-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/ensemble-rag/c1-question.yaml를 불러왔습니다.
# #####    44번째 논문    #####
# ##       rag method     : ensemble-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_044 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK for ANSWER 2 : yes
#         RELEVANCE CHECK for ANSWER 3 : yes
#         RELEVANCE CHECK for ANSWER 1 : yes
#         Success Discussion!
# ##       print 44 result
# ------------------------------------
# {'Stoichiometry information': {'NCM-622': {'Li ratio': 0.9758,
#                                            'Ni ratio': 0.576,
#                                            'Co ratio': 0.2003,
#                                            'Mn ratio': 0.2,
#                                            'O ratio': 1.0001}},
#  'Commercial NCM used': {'NCM-622': 'yes'},
#  'Lithium source': 'null',
#  'Synthesis method': 'null',
#  'Crystallization method': 'null',
#  'Crystallization final temperature': 'null',
#  'Crystallization final duration (hours)': 'null',
#  'Doping': 'null',
#  'Coating': 'Al2O3',
#  'Additional treatment': 'null'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'pristine NCM622': {'Li ratio': '1', 'Ni ratio': '0.6', 'Co ratio': '0.2', 'Mn ratio': '0.2', 'O ratio': '2'}, 'polymer/γ-Al2O3-coated NCM622': {'Li ratio': '1', 'Ni ratio': '0.6', 'Co ratio': '0.2', 'Mn ratio': '0.2', 'O ratio': '2'}}, 'Commercial NCM used': {'pristine NCM622': 'no', 'polymer/γ-Al2O3-coated NCM622': 'no'}, 'Lithium source': 'LiOH', 'Synthesis method': 'co-precipitation', 'Crystallization method': 'sintering', 'Crystallization final temperature': '875', 'Crystallization final duration': '12', 'Doping': None, 'Coating': 'γ-Al2O3', 'Additional treatment': None}
# ## ./config/ensemble-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/ensemble-rag/c1-question.yaml를 불러왔습니다.
# #####    56번째 논문    #####
# ##       rag method     : ensemble-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_056 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
#         RELEVANCE CHECK for ANSWER 1 : yes
#         RELEVANCE CHECK for ANSWER 2 : yes
#         RELEVANCE CHECK for ANSWER 3 : yes
#         Success Discussion!
# ##       print 56 result
# ------------------------------------
# {'Stoichiometry information': {'Pristine NCM': {'Li ratio': 1.0,
#                                                 'Ni ratio': 0.8,
#                                                 'Co ratio': 0.1,
#                                                 'Mn ratio': 0.1,
#                                                 'O ratio': 2.0},
#                                'M-NCM': {'Li ratio': 1.0,
#                                          'Ni ratio': 0.7998,
#                                          'Co ratio': 0.1022,
#                                          'Mn ratio': 0.0998,
#                                          'O ratio': 2.0,
#                                          'Mg ratio': 0.0082,
#                                          'P ratio': 0.0074}},
#  'Commercial NCM used': {'Pristine NCM': 'yes', 'M-NCM': 'no'},
#  'Lithium source': 'LiOH',
#  'Synthesis method': None,
#  'Crystallization method': None,
#  'Crystallization final temperature': None,
#  'Crystallization final duration (hours)': None,
#  'Doping': 'Mg',
#  'Coating': 'Li3PO4',
#  'Additional treatment': 'MgHPO4 modification'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# 🔍 gt[CAM (Cathode Active Material)] 값: {'Stoichiometry information': {'pristine NCM': {'Li ratio': '1', 'Ni ratio': '0.8', 'Co ratio': '0.1', 'Mn ratio': '0.1', 'O ratio': '2'}, 'M-NCM': {'Li ratio': '1', 'Ni ratio': '0.8', 'Co ratio': '0.1', 'Mn ratio': '0.1', 'O ratio': '2'}}, 'Commercial NCM used': {'pristine NCM': 'no', 'M-NCM': 'no'}, 'Lithium source': 'LiOH', 'Synthesis method': 'co-precipitation', 'Crystallization method': 'sintering', 'Crystallization final temperature': '750', 'Crystallization final duration': '15', 'Doping': 'Mg', 'Coating': 'Li3PO4', 'Additional treatment': None}
# ## ./config/multiagent-rag/c1-system-prompt.yaml를 불러왔습니다.
# ## ./config/multiagent-rag/c1-question.yaml를 불러왔습니다.
# #####    11번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : CAM (Cathode Active Material)
# ##       paper_011 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 11 result
# ------------------------------------
# {'Stoichiometry information': {'LiNi1/3Co1/3Mn1/3O2': {'Li ratio': 1.0,
#                                                        'Ni ratio': 0.33,
#                                                        'Co ratio': 0.33,
#                                                        'Mn ratio': 0.33,
#                                                        'O ratio': 2.0}},
#  'Commercial NCM used': {'LiNi1/3Co1/3Mn1/3O2': 'no'},
#  'Lithium source': 'LiNO3',
#  'Synthesis method': 'solution combustion',
#  'Crystallization method': 'calcination',
#  'Crystallization final temperature': 850,
#  'Crystallization final duration (hours)': 15,
#  'Doping': None,
#  'Coating': 'RGO',
#  'Additional treatment': 'microwave irradiation'}
# 🔍 gt[CAM (Cathode Active Material)] 타입: <class 'dict'>
# ...
# ## ./config/multiagent-rag/c4-system-prompt.yaml를 불러왔습니다.
# ## ./config/multiagent-rag/c4-question.yaml를 불러왔습니다.
# #####    39번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Cathode Performance
# ##       paper_039 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 39 result
# ------------------------------------
# {'WN92': [{'Voltage range': '2.8–4.3',
#            'Temperature': None,
#            'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 210.83},
#                                             {'C-rate': 0.2, 'Capacity': None},
#                                             {'C-rate': 0.5, 'Capacity': 190.1},
#                                             {'C-rate': 1.0, 'Capacity': None},
#                                             {'C-rate': 2.0, 'Capacity': None},
#                                             {'C-rate': 4.0, 'Capacity': None},
#                                             {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                 'Capacity': 159.11}]}]}],
#  'N92': [{'Voltage range': '2.8–4.3',
#           'Temperature': None,
#           'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 211.93},
#                                            {'C-rate': 0.2, 'Capacity': None},
#                                            {'C-rate': 0.5, 'Capacity': 191.47},
#                                            {'C-rate': 1.0, 'Capacity': None},
#                                            {'C-rate': 2.0, 'Capacity': None},
#                                            {'C-rate': 4.0, 'Capacity': None},
#                                            {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                'Capacity': 64.19}]}]}]}
# 🔍 gt[Cathode Performance] 타입: <class 'dict'>
# 🔍 gt[Cathode Performance] 값: {'N92': [{'Voltage range': '2.8–4.3', 'Temperature': None, 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 211.93}, {'C-rate': 0.2, 'Capacity': None}, {'C-rate': 0.5, 'Capacity': 191.47}, {'C-rate': 1.0, 'Capacity': None}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': [{'C-rate': 5, 'Capacity': 64.19}]}]}], 'WN92': [{'Voltage range': '2.8–4.3', 'Temperature': None, 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 210.83}, {'C-rate': 0.2, 'Capacity': None}, {'C-rate': 0.5, 'Capacity': 190.1}, {'C-rate': 1.0, 'Capacity': None}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': [{'C-rate': 5, 'Capacity': 159.11}]}]}]}
# ## ./config/multiagent-rag/c4-system-prompt.yaml를 불러왔습니다.
# ## ./config/multiagent-rag/c4-question.yaml를 불러왔습니다.
# #####    40번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Cathode Performance
# ##       paper_040 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 40 result
# ------------------------------------
# {'SC-NCM83': [{'Voltage range': '3.0–4.3',
#                'Temperature': 25,
#                'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                  'Capacity': None},
#                                                 {'C-rate': 0.2,
#                                                  'Capacity': None},
#                                                 {'C-rate': 0.5,
#                                                  'Capacity': None},
#                                                 {'C-rate': 1.0,
#                                                  'Capacity': 162},
#                                                 {'C-rate': 2.0,
#                                                  'Capacity': None},
#                                                 {'C-rate': 4.0,
#                                                  'Capacity': None},
#                                                 {'Other C-rates and performance': [{'C-rate': 0.05,
#                                                                                     'Capacity': 199}]}]}]}
# 🔍 gt[Cathode Performance] 타입: <class 'dict'>
# 🔍 gt[Cathode Performance] 값: {'SC-NCM83': [{'Voltage range': '3.0–4.3', 'Temperature': 25, 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None}, {'C-rate': 0.2, 'Capacity': None}, {'C-rate': 0.5, 'Capacity': None}, {'C-rate': 1.0, 'Capacity': 162}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': [{'C-rate': 0.05, 'Capacity': 199}]}]}], 'PC-NCM': [{'Voltage range': None, 'Temperature': None, 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None}, {'C-rate': 0.2, 'Capacity': None}, {'C-rate': 0.5, 'Capacity': None}, {'C-rate': 1.0, 'Capacity': None}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': [{'C-rate': None, 'Capacity': None}]}]}]}
# ## ./config/multiagent-rag/c4-system-prompt.yaml를 불러왔습니다.
# ## ./config/multiagent-rag/c4-question.yaml를 불러왔습니다.
# #####    41번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Cathode Performance
# ##       paper_041 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 41 result
# ------------------------------------
# {'NCM-811': [{'Voltage range': '2.6-4.2',
#               'Temperature': None,
#               'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                 'Capacity': None},
#                                                {'C-rate': 0.2,
#                                                 'Capacity': None},
#                                                {'C-rate': 0.5,
#                                                 'Capacity': None},
#                                                {'C-rate': 1.0, 'Capacity': 170},
#                                                {'C-rate': 2.0,
#                                                 'Capacity': None},
#                                                {'C-rate': 4.0,
#                                                 'Capacity': None},
#                                                {'Other C-rates and performance': [{'C-rate': None,
#                                                                                    'Capacity': None}]}]}]}
# 🔍 gt[Cathode Performance] 타입: <class 'dict'>
# 🔍 gt[Cathode Performance] 값: {'NCM-811': [{'Voltage range': '2.6-4.2', 'Temperature': None, 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 170}, {'C-rate': 0.2, 'Capacity': None}, {'C-rate': 0.5, 'Capacity': None}, {'C-rate': 1.0, 'Capacity': 130}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': [{'C-rate': None, 'Capacity': None}]}]}], 'g-C3N4@NCM-811': [{'Voltage range': '2.6-4.2', 'Temperature': None, 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 170}, {'C-rate': 0.2, 'Capacity': None}, {'C-rate': 0.5, 'Capacity': None}, {'C-rate': 1.0, 'Capacity': 140}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': [{'C-rate': None, 'Capacity': None}]}]}], 'g-C3N4NS@NCM-811': [{'Voltage range': '2.6-4.2', 'Temperature': None, 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None}, {'C-rate': 0.2, 'Capacity': None}, {'C-rate': 0.5, 'Capacity': None}, {'C-rate': 1.0, 'Capacity': None}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': [{'C-rate': None, 'Capacity': None}]}]}]}
# ## ./config/multiagent-rag/c4-system-prompt.yaml를 불러왔습니다.
# ## ./config/multiagent-rag/c4-question.yaml를 불러왔습니다.
# #####    42번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Cathode Performance
# ##       paper_042 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 42 result
# ------------------------------------
# {'SC-NCM': [{'Voltage range': '2.75–4.30',
#              'Temperature': 25,
#              'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                'Capacity': 209.7},
#                                               {'C-rate': 0.2,
#                                                'Capacity': 203.41},
#                                               {'C-rate': 0.5, 'Capacity': None},
#                                               {'C-rate': 1.0, 'Capacity': None},
#                                               {'C-rate': 2.0, 'Capacity': None},
#                                               {'C-rate': 4.0, 'Capacity': None},
#                                               {'Other C-rates and performance': [{'C-rate': 0.3,
#                                                                                   'Capacity': 171.6}]}]}]}
# 🔍 gt[Cathode Performance] 타입: <class 'dict'>
# 🔍 gt[Cathode Performance] 값: {'SC-NCM': [{'Voltage range': '2.75-4.30', 'Temperature': 25, 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 209.7}, {'C-rate': 0.2, 'Capacity': 203.41}, {'C-rate': 0.5, 'Capacity': None}, {'C-rate': 1.0, 'Capacity': None}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': [{'C-rate': 5, 'Capacity': 166.92}]}]}], 'N-NCM': [{'Voltage range': '2.75-4.30', 'Temperature': 25, 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 215.01}, {'C-rate': 0.2, 'Capacity': 191.95}, {'C-rate': 0.5, 'Capacity': None}, {'C-rate': 1.0, 'Capacity': None}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': [{'C-rate': 5, 'Capacity': 160.3}]}]}]}
# ## ./config/multiagent-rag/c4-system-prompt.yaml를 불러왔습니다.
# ## ./config/multiagent-rag/c4-question.yaml를 불러왔습니다.
# #####    44번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Cathode Performance
# ##       paper_044 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 44 result
# ------------------------------------
# {'NCM622': [{'Voltage range': '3.0-4.55',
#              'Temperature': None,
#              'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': None},
#                                               {'C-rate': 0.2, 'Capacity': None},
#                                               {'C-rate': 0.5,
#                                                'Capacity': 196.07},
#                                               {'C-rate': 1.0, 'Capacity': None},
#                                               {'C-rate': 2.0, 'Capacity': None},
#                                               {'C-rate': 4.0, 'Capacity': None},
#                                               {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                   'Capacity': 154.7}]}]}]}
# 🔍 gt[Cathode Performance] 타입: <class 'dict'>
# 🔍 gt[Cathode Performance] 값: {'pristine NCM622': [{'Voltage range': '3.0-4.55', 'Temperature': '25', 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 196.07}, {'C-rate': 0.2, 'Capacity': None}, {'C-rate': 0.5, 'Capacity': None}, {'C-rate': 1.0, 'Capacity': None}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': None}]}], 'polymer/γ-Al2O3-coated NCM622': [{'Voltage range': '3.0-4.55', 'Temperature': '25', 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 203.97}, {'C-rate': 0.2, 'Capacity': None}, {'C-rate': 0.5, 'Capacity': None}, {'C-rate': 1.0, 'Capacity': None}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': None}]}]}
# ## ./config/multiagent-rag/c4-system-prompt.yaml를 불러왔습니다.
# ## ./config/multiagent-rag/c4-question.yaml를 불러왔습니다.
# #####    56번째 논문    #####
# ##       rag method     : multiagent-rag
# ##       category name  : Cathode Performance
# ##       paper_056 retriever를 생성했습니다.
# ##          - chunk_size    :500
# ##          - chunk_overlap :100
# ##          - retrieve_k    :10
# ##       print 56 result
# ------------------------------------
# {'pristine NCM': [{'Voltage range': '3.0-4.3',
#                    'Temperature': 25,
#                    'C-rate and Specific capacity': [{'C-rate': 0.1,
#                                                      'Capacity': 199.1},
#                                                     {'C-rate': 0.2,
#                                                      'Capacity': None},
#                                                     {'C-rate': 0.5,
#                                                      'Capacity': None},
#                                                     {'C-rate': 1.0,
#                                                      'Capacity': None},
#                                                     {'C-rate': 2.0,
#                                                      'Capacity': None},
#                                                     {'C-rate': 4.0,
#                                                      'Capacity': 169.8},
#                                                     {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                         'Capacity': 159.0},
#                                                                                        {'C-rate': 6.0,
#                                                                                         'Capacity': 151.3}]}]}],
#  'M-NCM': [{'Voltage range': '3.0-4.3',
#             'Temperature': 25,
#             'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 203.5},
#                                              {'C-rate': 0.2, 'Capacity': None},
#                                              {'C-rate': 0.5, 'Capacity': None},
#                                              {'C-rate': 1.0, 'Capacity': None},
#                                              {'C-rate': 2.0, 'Capacity': None},
#                                              {'C-rate': 4.0, 'Capacity': None},
#                                              {'Other C-rates and performance': [{'C-rate': 5.0,
#                                                                                  'Capacity': 180.0},
#                                                                                 {'C-rate': 6.0,
#                                                                                  'Capacity': 168.9}]}]}]}
# 🔍 gt[Cathode Performance] 타입: <class 'dict'>
# 🔍 gt[Cathode Performance] 값: {'pristine NCM': [{'Voltage range': '3.0-4.3', 'Temperature': 25, 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 199.1}, {'C-rate': 0.2, 'Capacity': None}, {'C-rate': 0.5, 'Capacity': None}, {'C-rate': 1.0, 'Capacity': None}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': 169.8}, {'Other C-rates and performance': [{'C-rate': 5.0, 'Capacity': 159.0}, {'C-rate': 6.0, 'Capacity': 151.3}]}]}], 'M-NCM': [{'Voltage range': '3.0-4.3', 'Temperature': 25, 'C-rate and Specific capacity': [{'C-rate': 0.1, 'Capacity': 203.5}, {'C-rate': 0.2, 'Capacity': None}, {'C-rate': 0.5, 'Capacity': None}, {'C-rate': 1.0, 'Capacity': None}, {'C-rate': 2.0, 'Capacity': None}, {'C-rate': 4.0, 'Capacity': None}, {'Other C-rates and performance': [{'C-rate': 5.0, 'Capacity': 180.0}, {'C-rate': 6.0, 'Capacity': 168.9}]}]}]}

# %%
df
# Out:
#    paper_number            type  \
# 0            11   relevance-rag
# 1            16   relevance-rag
# 2            22   relevance-rag
# 3            35   relevance-rag
# 4            39   relevance-rag
# ..          ...             ...
# 25           40  multiagent-rag
# 26           41  multiagent-rag
# 27           42  multiagent-rag
# 28           44  multiagent-rag
# 29           56  multiagent-rag
#
#                                                result  \
# 0   [{'Stoichiometry information': {'NR0': {'Li ra...
# 1   [{'Stoichiometry information': {'NCM': {'Li ra...
# 2   [{'Stoichiometry information': {'V-doped NCM':...
# 3   [{'Stoichiometry information': {'S1bare': {'Li...
# 4   [{'Stoichiometry information': {'N92': {'Li ra...
# ..                                                ...
# 25  [{'SC-NCM83': [{'Voltage range': '3.0–4.3', 'T...
# 26  [{'NCM-811': [{'Voltage range': '2.6-4.2', 'Te...
# 27  [{'SC-NCM': [{'Voltage range': '2.75–4.30', 'T...
# 28  [{'NCM622': [{'Voltage range': '3.0-4.55', 'Te...
# 29  [{'pristine NCM': [{'Voltage range': '3.0-4.3'...
#
#                                          ground_truth  \
# 0   [{'Stoichiometry information': {'NR0': {'Li ra...
# 1   [{'Stoichiometry information': {'NCM': {'Li ra...
# 2   [{'Stoichiometry information': {'Pristine NCM'...
# 3   [{'Stoichiometry information': {'S1bare': {'Li...
# 4   [{'Stoichiometry information': {'N92': {'Li ra...
# ..                                                ...
# 25  [{'SC-NCM83': [{'Voltage range': '3.0–4.3', 'T...
# 26  [{'NCM-811': [{'Voltage range': '2.6-4.2', 'Te...
# 27  [{'SC-NCM': [{'Voltage range': '2.75-4.30', 'T...
# 28  [{'pristine NCM622': [{'Voltage range': '3.0-4...
# 29  [{'pristine NCM': [{'Voltage range': '3.0-4.3'...
#
#                     category_name  category_number
# 0   CAM (Cathode Active Material)              1.0
# 1   CAM (Cathode Active Material)              1.0
# 2   CAM (Cathode Active Material)              1.0
# 3   CAM (Cathode Active Material)              1.0
# 4   CAM (Cathode Active Material)              1.0
# ..                            ...              ...
# 25            Cathode Performance              4.0
# 26            Cathode Performance              4.0
# 27            Cathode Performance              4.0
# 28            Cathode Performance              4.0
# 29            Cathode Performance              4.0
#
# [120 rows x 6 columns]

# %%
df.to_csv("eval.csv", index=False)

df = pd.read_csv("eval.csv")

# %%
def eval_sentence_generator(category_number, result_dict):
    if category_number == 1:
        values = list(result_dict.values())
        return f"The {values} is {values[1]} commercially obtained, and synthesized with {values[2]}, and {values[3]}, and, {values[4]} for {values[5]} at {values[6]}, with {values[7]} doping and {values[8]} coating and {values[9]} treatment."
    
    elif category_number == 2:
        values = list(result_dict.values())
        return f"The electrode is manufactured by {values[0]} with {values[1]} and {values[2]} is {values[3]} for {values[4]}."
    
    elif category_number == 3:
        values = list(result_dict.values())
        return f"Particle size is {values[0]}, Particle shape is {values[1]} and Particle distribution is {values[2]}. Also Coating layer characteristics are {values[3]}. Crystal structure and lattice characteristics are {values[4]}."
    
    elif category_number == 4:
        s = ""
        for k, v in result_dict.items():
            for i in range(len(v)):
                s += f"C-rate and Specific capacity of {k} in {v[i]['Voltage range']} voltage range and {v[i]['Temperature']} temperature is {v[i]['C-rate and Specific capacity']}."
        return s

# %%
import ast
# result_sentence와 ground_truth_sentence 리스트 생성
result_sentences = []
ground_truth_sentences = []

for _, row in df.iterrows():
    category_number = int(row['category_number'])
    result_dict = ast.literal_eval(row['result'])[0]
    ground_truth_dict = ast.literal_eval(row['ground_truth'])[0]
    
    result_sentences.append(eval_sentence_generator(category_number, result_dict))
    ground_truth_sentences.append(eval_sentence_generator(category_number, ground_truth_dict))

# 새로운 열 추가
df['result_sentence'] = result_sentences
df['ground_truth_sentence'] = ground_truth_sentences

# %%
df.to_csv("eval_sentence.csv", index=False)

# %% [markdown]
# ## Scoring

# %%
from metrics.metric_eval import evaluate_all_metrics
import pandas as pd
df1 = pd.read_csv('eval_sentence.csv')
df2 = pd.read_csv('eval_sentence_4mini.csv')

# %%
## 모든 metric data frame
metric_df = df1[["ground_truth_sentence", "result_sentence"]].apply(
    lambda row: evaluate_all_metrics(row["ground_truth_sentence"], row["result_sentence"]), 
    axis=1
).apply(pd.Series)

## rouge 수정
rouge_df = metric_df["ROUGE"].apply(pd.Series)

## 최종 evaluation data frame
df_plot1 = pd.concat([df1, metric_df.drop(columns=["ROUGE"]), rouge_df], axis=1)


## 모든 metric data frame
metric_df = df2[["ground_truth_sentence", "result_sentence"]].apply(
    lambda row: evaluate_all_metrics(row["ground_truth_sentence"], row["result_sentence"]), 
    axis=1
).apply(pd.Series)

## rouge 수정
rouge_df = metric_df["ROUGE"].apply(pd.Series)

## 최종 evaluation data frame
df_plot2 = pd.concat([df2, metric_df.drop(columns=["ROUGE"]), rouge_df], axis=1)

# %%
df_plot2.to_csv("score_4o_mini.csv",index=False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_score_comparisons(df):
    metrics = ['BLEU', 'METEOR', 'Semantic Similarity (STS)', 'rouge1', 'rouge2', 'rougeL']
    custom_colors = ["#004823", "#007200", "#38B000", "#70E000", "#9EF01A", "#CCFF33"]
    
    # Type별 점수 비교
    plt.figure(figsize=(12, 6))
    df_melted = df.melt(id_vars=['type'], value_vars=metrics, var_name='Metric', value_name='Score')
    
    # 평균 계산
    df_melted = df_melted.groupby(['type', 'Metric'], as_index=False).mean()
    
    ax = sns.barplot(data=df_melted, x='type', y='Score', hue='Metric', palette=custom_colors)

    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.set_xticklabels([])
    plt.legend(framealpha=0)
    # plt.legend().remove()  # 범례 제거
    plt.show()

    # category_number별 + type별 점수 평균 비교
    plt.figure(figsize=(12, 6))
    df_melted = df.melt(id_vars=['category_number', 'type'], value_vars=metrics, var_name='Metric', value_name='Score')
    
    # 평균 계산
    df_melted = df_melted.groupby(['category_number', 'type', 'Metric'], as_index=False).mean()
    
    ax = sns.barplot(data=df_melted, x='category_number', y='Score', hue='Metric', palette=custom_colors)


    ax.set_xlabel("")
    ax.set_ylabel("")
    ax.set_xticklabels([])
    plt.legend(framealpha=0)
    # plt.legend().remove()  # 범례 제거
    plt.show()

# %%
plot_score_comparisons(df_plot1)

# %%
plot_score_comparisons(df_plot2)

# %% [markdown]
# ## evalutaion notebook codes
# 임의로 문장 템플릿을 생성하여 llm answer의 value들을 넣어서 만든 문장을 비교하여 평가하는 코드입니다.
# `question1` 과 `question2`에 대해서만 진행했습니다.
# `question3` 와 `questino4`의 경우 수정될 수 있어 추후 진행하겠습니다. (금방할 수 있습니다)

# %%
df.to_csv("score.csv",index=False)
