# %%
import pandas as pd
import re

# %%
gt = pd.read_csv("./groundtruth.csv")
answer = pd.read_csv("./output/csv/baseline.csv").drop(columns="Additional treatment")

# %%
Morphological_Properties_col = ['Particle size', 'Particle shape', 'Particle distribution', 'Coating layer characteristics', 'Crystal structure and lattice characteristics']

# %%
gt = gt.drop(columns=Morphological_Properties_col)
answer = answer.drop(columns=Morphological_Properties_col)

# %%
def c_rate_func(x):
    if "C-rate" in x:
        return True
    else: 
        return False

# %%
def combine_duplicated_cols(df):
    int_crate_cols = [
        col for col in df.columns
        if re.fullmatch(r"C-rate\s+[0-9]+", col)
    ]    
    
    int2float_map = {}
    for int_col in int_crate_cols:
        int2float_map[f"{int_col}"] = int_col[:7] + f"{float(int_col[7:])}"

    for int_col, float_col in int2float_map.items():
        if float_col in df.columns:
            df[int_col] = df[int_col].combine_first(df[float_col])
            df.drop(columns=float_col, inplace=True)
        df.rename(columns={int_col: float_col}, inplace=True)
    
    return df

# %%
gt = combine_duplicated_cols(gt)
answer = combine_duplicated_cols(answer)

# %%
gt_c_rate = gt.columns[gt.columns.map(c_rate_func)].to_list()
answer_c_rate = answer.columns[answer.columns.map(c_rate_func)].to_list()

# %%
gt_c_rate
# Out:
# ['C-rate 0.1',
#  'C-rate 0.5',
#  'C-rate 1.0',
#  'C-rate 2.0',
#  'C-rate 0.05',
#  'C-rate 5.0',
#  'C-rate 10.0',
#  'C-rate 20.0',
#  'C-rate 40.0',
#  'C-rate None',
#  'C-rate 0.2',
#  'C-rate 4.0',
#  'C-rate 6.0']

# %%
answer_c_rate
# Out:
# ['C-rate 0.1',
#  'C-rate 0.2',
#  'C-rate 0.5',
#  'C-rate 1.0',
#  'C-rate 2.0',
#  'C-rate 5.0',
#  'C-rate 10.0',
#  'C-rate 20.0',
#  'C-rate 40.0',
#  'C-rate 0.05',
#  'C-rate 0.33',
#  'C-rate None',
#  'C-rate 0.3',
#  'C-rate 4.0',
#  'C-rate 6.0']

# %%
other_c_rate_col = ['C-rate 0.05', 'C-rate 5', 'C-rate 5.0', 'C-rate 10', 'C-rate 20', 
                    'C-rate 40', 'C-rate None', 'C-rate 0.2', 'C-rate 4.0', 'C-rate 6.0', 
                    'C-rate 10.0', 'C-rate 20.0', 'C-rate 40.0', 'C-rate 0.33', 'C-rate 0.3']

# %%
paper_id = gt["Paper ID"].unique()

# %%
gt.head()
# Out:
#    Paper ID Sample  Li ratio  Ni ratio  Co ratio  Mn ratio  O ratio  \
# 0        11    NR0         1      0.33      0.33      0.33        2
# 1        11    NR1         1      0.33      0.33      0.33        2
# 2        11    NR3         1      0.33      0.33      0.33        2
# 3        11    NR5         1      0.33      0.33      0.33        2
# 4        16    NCM         1      0.33      0.33      0.33        2
#
#   Commercial NCM used Lithium source     Synthesis method  ... C-rate 5  \
# 0                  no          LiNO3  solution combustion  ...     45.5
# 1                  no          LiNO3  solution combustion  ...     47.0
# 2                  no          LiNO3  solution combustion  ...     75.4
# 3                  no          LiNO3  solution combustion  ...     95.4
# 4                  no           LiAc       sol-gel method  ...      NaN
#
#    C-rate 5.0  C-rate 10 C-rate 20 C-rate 40 C-rate None C-rate 0.2 W ratio  \
# 0         NaN        NaN       NaN       NaN         NaN        NaN     NaN
# 1         NaN        NaN       NaN       NaN         NaN        NaN     NaN
# 2         NaN        NaN       NaN       NaN         NaN        NaN     NaN
# 3         NaN        NaN       NaN       NaN         NaN        NaN     NaN
# 4       101.7       71.5      44.5      13.2         NaN        NaN     NaN
#
#   C-rate 4.0 C-rate 6.0
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN
#
# [5 rows x 39 columns]

# %%
answer.head()
# Out:
#    Paper ID Sample  Li ratio  Ni ratio  Co ratio  Mn ratio  O ratio  W ratio  \
# 0        11    NR0      1.00      0.33      0.33      0.33      2.0      NaN
# 1        11    NR1      1.00      0.33      0.33      0.33      2.0      NaN
# 2        11    NR3      1.00      0.33      0.33      0.33      2.0      NaN
# 3        11    NR5      1.00      0.33      0.33      0.33      2.0      NaN
# 4        16    NCM      1.01      0.35      0.32      0.32      NaN      NaN
#
#   Commercial NCM used Lithium source  ... C-rate 5.0 C-rate 10.0  C-rate 20.0  \
# 0                  no          LiNO3  ...       45.5         NaN          NaN
# 1                  no          LiNO3  ...       47.0         NaN          NaN
# 2                  no          LiNO3  ...       75.4         NaN          NaN
# 3                  no          LiNO3  ...       95.4         NaN          NaN
# 4                  no           LiAc  ...      101.7        71.5         44.5
#
#    C-rate 40.0 C-rate 0.05 C-rate 0.33 C-rate None C-rate 0.3 C-rate 4.0  \
# 0          NaN         NaN         NaN         NaN        NaN        NaN
# 1          NaN         NaN         NaN         NaN        NaN        NaN
# 2          NaN         NaN         NaN         NaN        NaN        NaN
# 3          NaN         NaN         NaN         NaN        NaN        NaN
# 4         13.2         NaN         NaN         NaN        NaN        NaN
#
#   C-rate 6.0
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 40 columns]

# %%
import pandas as pd

def is_number(val):
    try:
        float(val)
        return True
    except:
        return False

# key column 정의
key_cols = ["Paper ID", "Sample"]

# 모든 열 모음 (비교 대상)
all_cols = set(gt.columns) | set(answer.columns)
compare_cols = [col for col in all_cols if col not in key_cols]

# 결과 저장
results = []

# 모든 논문 처리
all_papers = sorted(set(gt["Paper ID"]) | set(answer["Paper ID"]))

for pid in all_papers:
    gt_group = gt[gt["Paper ID"] == pid].reset_index(drop=True)
    ans_group = answer[answer["Paper ID"] == pid].reset_index(drop=True)

    max_len = max(len(gt_group), len(ans_group))

    def pad_df(df, target_len):
        pad_len = target_len - len(df)
        if pad_len <= 0:
            return df
        empty = pd.DataFrame({col: [None] * pad_len for col in df.columns})
        empty["Paper ID"] = pid
        return pd.concat([df, empty], ignore_index=True)

    gt_group = pad_df(gt_group, max_len)
    ans_group = pad_df(ans_group, max_len)

        
    for i in range(max_len):
        row_gt = gt_group.iloc[i]
        row_ans = ans_group.iloc[i]

        result_row = {
            "Paper ID": pid,
            "Sample": row_gt["Sample"] if pd.notna(row_gt["Sample"]) else row_ans["Sample"]
        }

        for col in compare_cols:
            val_gt = row_gt[col] if col in row_gt and col in gt.columns else None
            val_ans = row_ans[col] if col in row_ans and col in answer.columns else None

            try:
                # C-rate 열이고 둘 다 NaN이면, 결과도 NaN
                if "C-rate" in col and pd.isna(val_gt) and pd.isna(val_ans):
                    match = float('nan')
                elif pd.isna(val_gt) and pd.isna(val_ans):
                    match = True
                elif pd.notna(val_gt) and pd.notna(val_ans):
                    if is_number(val_gt) and is_number(val_ans):
                        match = abs(float(val_gt) - float(val_ans)) < 1e-3
                    else:
                        match = str(val_gt).strip() == str(val_ans).strip()
                else:
                    match = False

            except:
                match = False

            result_row[col] = match

        results.append(result_row)

# 결과 DataFrame
df_result = pd.DataFrame(results)

# 누락된 열 채우기 (혹시라도)
for col in compare_cols:
    if col not in df_result.columns:
        df_result[col] = False

# 컬럼 순서 정렬
sorted_cols = ["Paper ID", "Sample"] + sorted(compare_cols)
df_result = df_result[sorted_cols]

# 저장
df_result.to_csv("comparison_with_full_columns_and_rows.csv", index=False)
# Out:
# C:\Users\ghckd\AppData\Local\Temp\ipykernel_56016\1871376670.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat([df, empty], ignore_index=True)

# %%
sort_col = [
    'Paper ID',
    'Sample',
    'Li ratio',
    'Ni ratio',
    'Co ratio',
    'Mn ratio',
    'O ratio',
    'W ratio',
    'Commercial NCM used',
    'Lithium source',
    'Synthesis method',
    'Crystallization method',
    'Crystallization final temperature',
    'Crystallization final duration (hours)',
    'Doping',
    'Coating',
    'Active material to Conductive additive to Binder ratio',
    'Electrolyte salt',
    'Electrolyte concentration',
    'Electrolyte solvent',
    'Electrolyte solvent ratio',
    'Additive',
    'Loading density (mass loading of NCM)',
    'Voltage range',
    'Temperature',
    'C-rate 0.1',
    'C-rate 0.2',
    'C-rate 0.5',
    'C-rate 1.0',
    'C-rate 2.0',
    'C-rate 5.0',
    'C-rate 0.05',
    'C-rate None',
    'C-rate 4.0',
    'C-rate 6.0'
]

# %%
df_result = df_result[sort_col]

# %%
df_result.loc[df_result["Paper ID"] == 11, "Li ratio":]
# Out:
#    Li ratio  Ni ratio  Co ratio  Mn ratio  O ratio  W ratio  \
# 0      True      True      True      True     True     True
# 1      True      True      True      True     True     True
# 2      True      True      True      True     True     True
# 3      True      True      True      True     True     True
#
#    Commercial NCM used  Lithium source  Synthesis method  \
# 0                 True            True              True
# 1                 True            True              True
# 2                 True            True              True
# 3                 True            True              True
#
#    Crystallization method  ...  C-rate 0.1  C-rate 0.2  C-rate 0.5  \
# 0                    True  ...        True         NaN         NaN
# 1                    True  ...        True         NaN         NaN
# 2                    True  ...        True         NaN         NaN
# 3                    True  ...        True         NaN         NaN
#
#    C-rate 1.0  C-rate 2.0  C-rate 5.0  C-rate 0.05  C-rate None  C-rate 4.0  \
# 0        True         NaN       False        False          NaN         NaN
# 1         NaN         NaN       False        False          NaN         NaN
# 2         NaN         NaN       False        False          NaN         NaN
# 3         NaN         NaN       False        False          NaN         NaN
#
#    C-rate 6.0
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
#
# [4 rows x 33 columns]

# %%
df_result.loc[df_result["Paper ID"] == 11, "Li ratio":].mean().mean()
# Out:
# 0.7407407407407407

# %%
# results = []

# # 공통 key
# key_cols = ["Paper ID", "Sample"]

# # 비교할 column들 (공통 열)
# common_cols = list(set(gt.columns) | set(answer.columns))
# common_cols = [col for col in common_cols if col not in key_cols]

# # gt와 answer 모두 정렬
# gt_sorted = gt.sort_values(by=key_cols).reset_index(drop=True)
# answer_sorted = answer.sort_values(by=key_cols).reset_index(drop=True)

# # 모든 row를 하나씩 비교
# for idx in range(len(gt_sorted)):
#     row_gt = gt_sorted.loc[idx]
#     row_pred = answer_sorted.loc[idx]
    
#     result_row = {
#         "Paper ID": row_gt["Paper ID"],
#         "Sample": row_gt["Sample"]
#     }

#     for col in common_cols:
#         if col not in gt.columns:
#             match = False
#         val_gt = row_gt[col]
#         val_pred = row_pred[col]

#         # 숫자 비교 시 오차 허용
#         try:
#             if pd.isna(val_gt) and pd.isna(val_pred):
#                 match = True
#             elif pd.notna(val_gt) and pd.notna(val_pred):
#                 if isinstance(val_gt, (int, float)) and isinstance(val_pred, (int, float)):
#                     match = abs(float(val_gt) - float(val_pred)) < 1e-3
#                 else:
#                     match = str(val_gt).strip() == str(val_pred).strip()
#             else:
#                 match = False
#         except:
#             match = False

#         result_row[col] = match

#     results.append(result_row)

# # 결과 DataFrame으로 변환
# df_result = pd.DataFrame(results)
# df_result.to_csv("comparison_result.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\ghckd\anaconda3\envs\voltai\Lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\\_libs\\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\\_libs\\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C-rate 10.0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_66804\2742719036.py in <cell line: 0>()
#      23
#      24     for col in common_cols:
# ---> 25         val_gt = row_gt[col]
#      26         val_pred = row_pred[col]
#      27
#
# c:\Users\ghckd\anaconda3\envs\voltai\Lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# c:\Users\ghckd\anaconda3\envs\voltai\Lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# c:\Users\ghckd\anaconda3\envs\voltai\Lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'C-rate 10.0'

# %%
# list(answer.columns)
# Out:
# ['Paper ID',
#  'Sample',
#  'Li ratio',
#  'Ni ratio',
#  'Co ratio',
#  'Mn ratio',
#  'O ratio',
#  'W ratio',
#  'Commercial NCM used',
#  'Lithium source',
#  'Synthesis method',
#  'Crystallization method',
#  'Crystallization final temperature',
#  'Crystallization final duration (hours)',
#  'Doping',
#  'Coating',
#  'Active material to Conductive additive to Binder ratio',
#  'Electrolyte salt',
#  'Electrolyte concentration',
#  'Electrolyte solvent',
#  'Electrolyte solvent ratio',
#  'Additive',
#  'Loading density (mass loading of NCM)',
#  'Voltage range',
#  'Temperature',
#  'C-rate 0.1',
#  'C-rate 0.2',
#  'C-rate 0.5',
#  'C-rate 1.0',
#  'C-rate 2.0',
#  'C-rate 5.0',
#  'C-rate 10.0',
#  'C-rate 20.0',
#  'C-rate 40.0',
#  'C-rate 0.05',
#  'C-rate 0.33',
#  'C-rate None',
#  'C-rate 0.3',
#  'C-rate 4.0',
#  'C-rate 6.0']

# %%
# sort_col = [
#     'Paper ID',
#     'Sample',
#     'Li ratio',
#     'Ni ratio',
#     'Co ratio',
#     'Mn ratio',
#     'O ratio',
#     'W ratio',
#     'Commercial NCM used',
#     'Lithium source',
#     'Synthesis method',
#     'Crystallization method',
#     'Crystallization final temperature',
#     'Crystallization final duration (hours)',
#     'Doping',
#     'Coating',
#     'Active material to Conductive additive to Binder ratio',
#     'Electrolyte salt',
#     'Electrolyte concentration',
#     'Electrolyte solvent',
#     'Electrolyte solvent ratio',
#     'Additive',
#     'Loading density (mass loading of NCM)',
#     'Voltage range',
#     'Temperature',
#     'C-rate 0.1',
#     'C-rate 0.2',
#     'C-rate 0.5',
#     'C-rate 1.0',
#     'C-rate 2.0',
#     'C-rate 5.0',
#     'C-rate 0.05',
#     'C-rate None',
#     'C-rate 4.0',
#     'C-rate 6.0'
# ]

# %%
# df_result[sort_col]
# Out:
#     Paper ID                         Sample  Li ratio  Ni ratio  Co ratio  \
# 0         11                            NR0     False      True      True
# 1         11                            NR1     False      True      True
# 2         11                            NR3     False      True      True
# 3         11                            NR5     False      True      True
# 4         16                            NCM     False     False     False
# 5         16                          NCM/C     False     False      True
# 6         22                       Pristine     False      True      True
# 7         22                        V-0.005     False      True      True
# 8         22                         V-0.01     False      True      True
# 9         22                         V-0.02     False      True      True
# 10        35                         S1bare     False      True      True
# 11        35                         S2wash     False      True      True
# 12        35                         S3coat     False      True      True
# 13        39                            N92     False      True      True
# 14        39                           WN92     False     False      True
# 15        40                         PC-NCM     False      True      True
# 16        40                       SC-NCM83     False     False     False
# 17        41                        NCM-811     False      True      True
# 18        41                 g-C3N4@NCM-811     False      True      True
# 19        41               g-C3N4NS@NCM-811     False     False     False
# 20        42                          N-NCM     False      True      True
# 21        42                         SC-NCM     False     False     False
# 22        44  polymer/γ-Al2O3-coated NCM622     False      True      True
# 23        44                pristine NCM622     False      True      True
# 24        56                          M-NCM     False      True      True
# 25        56                   pristine NCM     False      True      True
#
#     Mn ratio  O ratio  W ratio  Commercial NCM used  Lithium source  ...  \
# 0       True    False     True                 True            True  ...
# 1       True    False     True                 True            True  ...
# 2       True    False     True                 True            True  ...
# 3       True    False     True                 True            True  ...
# 4      False    False     True                 True            True  ...
# 5      False    False     True                 True            True  ...
# 6       True    False     True                 True            True  ...
# 7       True    False     True                 True            True  ...
# 8       True    False     True                 True            True  ...
# 9       True    False     True                False            True  ...
# 10      True    False     True                False            True  ...
# 11      True    False     True                False            True  ...
# 12      True    False     True                False            True  ...
# 13      True    False     True                False            True  ...
# 14      True    False    False                 True            True  ...
# 15      True    False     True                 True           False  ...
# 16     False    False     True                False           False  ...
# 17      True    False     True                 True            True  ...
# 18      True    False     True                 True            True  ...
# 19     False    False     True                 True           False  ...
# 20      True    False     True                False           False  ...
# 21     False    False     True                False           False  ...
# 22      True    False     True                False            True  ...
# 23      True    False     True                False            True  ...
# 24      True    False     True                 True            True  ...
# 25      True    False     True                False            True  ...
#
#     C-rate 0.1  C-rate 0.2  C-rate 0.5  C-rate 1.0  C-rate 2.0  C-rate 5.0  \
# 0         True        True        True       False        True       False
# 1         True        True        True        True        True       False
# 2         True        True        True        True        True       False
# 3         True        True        True        True        True       False
# 4         True        True        True        True        True        True
# 5         True        True        True        True        True        True
# 6        False        True        True        True        True        True
# 7        False        True        True        True        True        True
# 8        False        True        True        True        True        True
# 9        False        True        True        True        True        True
# 10        True       False        True        True       False        True
# 11        True        True        True        True        True        True
# 12        True       False        True        True       False        True
# 13        True        True        True        True        True       False
# 14        True        True        True        True        True       False
# 15        True        True        True       False        True        True
# 16        True        True        True       False        True        True
# 17       False        True        True       False        True        True
# 18       False        True        True       False        True        True
# 19       False       False        True        True        True       False
# 20       False       False        True        True        True       False
# 21       False       False        True        True        True        True
# 22        True        True        True        True        True        True
# 23        True        True        True        True        True        True
# 24        True        True        True        True        True        True
# 25        True        True       False        True        True        True
#
#     C-rate 0.05  C-rate None  C-rate 4.0  C-rate 6.0
# 0         False         True        True        True
# 1         False         True        True        True
# 2         False         True        True        True
# 3         False         True        True        True
# 4          True         True        True        True
# 5          True         True        True        True
# 6          True         True        True        True
# 7          True         True        True        True
# 8          True         True        True        True
# 9          True         True        True        True
# 10        False         True        True        True
# 11        False         True        True        True
# 12        False         True        True        True
# 13         True         True        True        True
# 14         True         True        True        True
# 15        False         True        True        True
# 16        False         True        True        True
# 17         True         True        True        True
# 18         True         True        True        True
# 19         True         True        True        True
# 20         True         True        True        True
# 21         True         True        True        True
# 22         True         True        True        True
# 23         True         True        True        True
# 24         True         True        True        True
# 25         True         True        True        True
#
# [26 rows x 35 columns]

# %%
# gt[[
#  'C-rate 10.0',
#  'C-rate 20.0',
#  'C-rate 40.0',
#  'C-rate 0.33',
# ]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_66804\4153805274.py in <cell line: 0>()
# ----> 1 gt[[
#       2  'C-rate 10.0',
#       3  'C-rate 20.0',
#       4  'C-rate 40.0',
#       5  'C-rate 0.33',
#
# c:\Users\ghckd\anaconda3\envs\voltai\Lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# c:\Users\ghckd\anaconda3\envs\voltai\Lib\site-packages\pandas\core\indexes\base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# c:\Users\ghckd\anaconda3\envs\voltai\Lib\site-packages\pandas\core\indexes\base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['C-rate 10.0', 'C-rate 20.0', 'C-rate 40.0', 'C-rate 0.33'], dtype='object')] are in the [columns]"

# %%
# answer[[
#  'C-rate 10.0',
#  'C-rate 20.0',
#  'C-rate 40.0',
#  'C-rate 0.33',
# ]]
# Out:
#     C-rate 10.0  C-rate 20.0  C-rate 40.0  C-rate 0.33
# 0           NaN          NaN          NaN          NaN
# 1           NaN          NaN          NaN          NaN
# 2           NaN          NaN          NaN          NaN
# 3           NaN          NaN          NaN          NaN
# 4          71.5         44.5         13.2          NaN
# 5         109.4         81.9         54.6          NaN
# 6           NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN        197.0
# 11          NaN          NaN          NaN        202.0
# 12          NaN          NaN          NaN        205.0
# 13          NaN          NaN          NaN          NaN
# 14          NaN          NaN          NaN          NaN
# 15          NaN          NaN          NaN          NaN
# 16          NaN          NaN          NaN          NaN
# 17          NaN          NaN          NaN          NaN
# 18          NaN          NaN          NaN          NaN
# 19          NaN          NaN          NaN          NaN
# 20          NaN          NaN          NaN          NaN
# 21          NaN          NaN          NaN          NaN
# 22          NaN          NaN          NaN          NaN
# 23          NaN          NaN          NaN          NaN
# 24          NaN          NaN          NaN          NaN
# 25          NaN          NaN          NaN          NaN

# %%
# pd.DataFrame(results)
# Out:
#                                             Paper ID  \
# 0  0    True
# 1    True
# 2    True
# 3    True
# Name: ...
# 1    4    True
# 5    True
# Name: Paper ID, dtype: bool
# 2  6    True
# 7    True
# 8    True
# 9    True
# Name: ...
# 3  10    True
# 11    True
# 12    True
# Name: Paper I...
# 4  13    True
# 14    True
# Name: Paper ID, dtype: bool
# 5  15     True
# 16    False
# Name: Paper ID, dtype:...
# 6  17     True
# 18     True
# 19    False
# Name: Pape...
# 7  20     True
# 21    False
# Name: Paper ID, dtype:...
# 8  22    True
# 23    True
# Name: Paper ID, dtype: bool
# 9  24    True
# 25    True
# Name: Paper ID, dtype: bool
#
#                                               Sample  \
# 0  0    True
# 1    True
# 2    True
# 3    True
# Name: ...
# 1      4    True
# 5    True
# Name: Sample, dtype: bool
# 2  6    False
# 7     True
# 8     True
# 9     True
# Na...
# 3  10    True
# 11    True
# 12    True
# Name: Sample,...
# 4    13    True
# 14    True
# Name: Sample, dtype: bool
# 5  15     True
# 16    False
# Name: Sample, dtype: bool
# 6  17    False
# 18    False
# 19    False
# Name: Samp...
# 7  20    False
# 21    False
# Name: Sample, dtype: bool
# 8    22    True
# 23    True
# Name: Sample, dtype: bool
# 9    24    True
# 25    True
# Name: Sample, dtype: bool
#
#                                             Li ratio  \
# 0  0    True
# 1    True
# 2    True
# 3    True
# Name: ...
# 1  4    False
# 5    False
# Name: Li ratio, dtype: bool
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: Li r...
# 4  13    True
# 14    True
# Name: Li ratio, dtype: bool
# 5  15    False
# 16     True
# Name: Li ratio, dtype:...
# 6  17     True
# 18     True
# 19    False
# Name: Li r...
# 7  20    True
# 21    True
# Name: Li ratio, dtype: bool
# 8  22    True
# 23    True
# Name: Li ratio, dtype: bool
# 9  24    False
# 25    False
# Name: Li ratio, dtype:...
#
#                                             Ni ratio  \
# 0  0    True
# 1    True
# 2    True
# 3    True
# Name: ...
# 1  4    False
# 5    False
# Name: Ni ratio, dtype: bool
# 2  6    True
# 7    True
# 8    True
# 9    True
# Name: ...
# 3  10    True
# 11    True
# 12    True
# Name: Ni rati...
# 4  13     True
# 14    False
# Name: Ni ratio, dtype:...
# 5  15     True
# 16    False
# Name: Ni ratio, dtype:...
# 6  17     True
# 18     True
# 19    False
# Name: Ni r...
# 7  20     True
# 21    False
# Name: Ni ratio, dtype:...
# 8  22    True
# 23    True
# Name: Ni ratio, dtype: bool
# 9  24    True
# 25    True
# Name: Ni ratio, dtype: bool
#
#                                             Co ratio  \
# 0  0    True
# 1    True
# 2    True
# 3    True
# Name: ...
# 1  4    False
# 5     True
# Name: Co ratio, dtype: bool
# 2  6    True
# 7    True
# 8    True
# 9    True
# Name: ...
# 3  10    True
# 11    True
# 12    True
# Name: Co rati...
# 4  13    True
# 14    True
# Name: Co ratio, dtype: bool
# 5  15     True
# 16    False
# Name: Co ratio, dtype:...
# 6  17     True
# 18     True
# 19    False
# Name: Co r...
# 7  20     True
# 21    False
# Name: Co ratio, dtype:...
# 8  22    True
# 23    True
# Name: Co ratio, dtype: bool
# 9  24    True
# 25    True
# Name: Co ratio, dtype: bool
#
#                                             Mn ratio  \
# 0  0    True
# 1    True
# 2    True
# 3    True
# Name: ...
# 1  4    False
# 5    False
# Name: Mn ratio, dtype: bool
# 2  6    True
# 7    True
# 8    True
# 9    True
# Name: ...
# 3  10    True
# 11    True
# 12    True
# Name: Mn rati...
# 4  13    True
# 14    True
# Name: Mn ratio, dtype: bool
# 5  15     True
# 16    False
# Name: Mn ratio, dtype:...
# 6  17     True
# 18     True
# 19    False
# Name: Mn r...
# 7  20     True
# 21    False
# Name: Mn ratio, dtype:...
# 8  22    True
# 23    True
# Name: Mn ratio, dtype: bool
# 9  24    True
# 25    True
# Name: Mn ratio, dtype: bool
#
#                                              O ratio  \
# 0  0    True
# 1    True
# 2    True
# 3    True
# Name: ...
# 1   4    False
# 5    False
# Name: O ratio, dtype: bool
# 2  6    True
# 7    True
# 8    True
# 9    True
# Name: ...
# 3  10    True
# 11    True
# 12    True
# Name: O ratio...
# 4   13    True
# 14    True
# Name: O ratio, dtype: bool
# 5  15    False
# 16     True
# Name: O ratio, dtype: ...
# 6  17    True
# 18    True
# 19    True
# Name: O ratio...
# 7   20    True
# 21    True
# Name: O ratio, dtype: bool
# 8   22    True
# 23    True
# Name: O ratio, dtype: bool
# 9   24    True
# 25    True
# Name: O ratio, dtype: bool
#
#                                  Commercial NCM used  \
# 0  0    True
# 1    True
# 2    True
# 3    True
# Name: ...
# 1  4    True
# 5    True
# Name: Commercial NCM used,...
# 2  6    False
# 7     True
# 8     True
# 9     True
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: Comm...
# 4  13    False
# 14     True
# Name: Commercial NCM u...
# 5  15     True
# 16    False
# Name: Commercial NCM u...
# 6  17     True
# 18     True
# 19    False
# Name: Comm...
# 7  20    False
# 21     True
# Name: Commercial NCM u...
# 8  22    False
# 23    False
# Name: Commercial NCM u...
# 9  24    False
# 25     True
# Name: Commercial NCM u...
#
#                                       Lithium source  \
# 0  0    True
# 1    True
# 2    True
# 3    True
# Name: ...
# 1  4    True
# 5    True
# Name: Lithium source, dtyp...
# 2  6    True
# 7    True
# 8    True
# 9    True
# Name: ...
# 3  10    True
# 11    True
# 12    True
# Name: Lithium...
# 4  13    True
# 14    True
# Name: Lithium source, dt...
# 5  15    False
# 16    False
# Name: Lithium source, ...
# 6  17    False
# 18    False
# 19    False
# Name: Lith...
# 7  20    False
# 21    False
# Name: Lithium source, ...
# 8  22    True
# 23    True
# Name: Lithium source, dt...
# 9  24    True
# 25    True
# Name: Lithium source, dt...
#
#                                     Synthesis method  ...  \
# 0  0    True
# 1    True
# 2    True
# 3    True
# Name: ...  ...
# 1  4    False
# 5    False
# Name: Synthesis method, ...  ...
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...  ...
# 3  10    False
# 11    False
# 12    False
# Name: Synt...  ...
# 4  13    True
# 14    True
# Name: Synthesis method, ...  ...
# 5  15    False
# 16    False
# Name: Synthesis method...  ...
# 6  17    False
# 18    False
# 19    False
# Name: Synt...  ...
# 7  20    True
# 21    True
# Name: Synthesis method, ...  ...
# 8  22    True
# 23    True
# Name: Synthesis method, ...  ...
# 9  24    True
# 25    True
# Name: Synthesis method, ...  ...
#
#                                             C-rate 5  \
# 0  0    False
# 1    False
# 2    False
# 3    False
# Na...
# 1  4    False
# 5    False
# Name: C-rate 0.05, dtype...
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: C-ra...
# 4  13    False
# 14    False
# Name: C-rate 0.05, dty...
# 5  15     True
# 16    False
# Name: C-rate 0.05, dty...
# 6  17    False
# 18    False
# 19    False
# Name: C-ra...
# 7  20    False
# 21    False
# Name: C-rate 0.05, dty...
# 8  22    False
# 23    False
# Name: C-rate 0.05, dty...
# 9  24    False
# 25    False
# Name: C-rate 0.05, dty...
#
#                                           C-rate 5.0  \
# 0  0    False
# 1    False
# 2    False
# 3    False
# Na...
# 1  4    True
# 5    True
# Name: C-rate 5.0, dtype: bool
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: C-ra...
# 4  13    False
# 14    False
# Name: C-rate 5.0, dtyp...
# 5  15    False
# 16    False
# Name: C-rate 5.0, dtyp...
# 6  17    False
# 18    False
# 19    False
# Name: C-ra...
# 7  20    False
# 21    False
# Name: C-rate 5.0, dtyp...
# 8  22    False
# 23    False
# Name: C-rate 5.0, dtyp...
# 9  24    True
# 25    True
# Name: C-rate 5.0, dtype:...
#
#                                            C-rate 10  \
# 0  0    False
# 1    False
# 2    False
# 3    False
# Na...
# 1  4    True
# 5    True
# Name: C-rate 5.0, dtype: bool
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: C-ra...
# 4  13    False
# 14    False
# Name: C-rate 5.0, dtyp...
# 5  15    False
# 16    False
# Name: C-rate 5.0, dtyp...
# 6  17    False
# 18    False
# 19    False
# Name: C-ra...
# 7  20    False
# 21    False
# Name: C-rate 5.0, dtyp...
# 8  22    False
# 23    False
# Name: C-rate 5.0, dtyp...
# 9  24    True
# 25    True
# Name: C-rate 5.0, dtype:...
#
#                                            C-rate 20  \
# 0  0    False
# 1    False
# 2    False
# 3    False
# Na...
# 1  4    True
# 5    True
# Name: C-rate 5.0, dtype: bool
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: C-ra...
# 4  13    False
# 14    False
# Name: C-rate 5.0, dtyp...
# 5  15    False
# 16    False
# Name: C-rate 5.0, dtyp...
# 6  17    False
# 18    False
# 19    False
# Name: C-ra...
# 7  20    False
# 21    False
# Name: C-rate 5.0, dtyp...
# 8  22    False
# 23    False
# Name: C-rate 5.0, dtyp...
# 9  24    True
# 25    True
# Name: C-rate 5.0, dtype:...
#
#                                            C-rate 40  \
# 0  0    False
# 1    False
# 2    False
# 3    False
# Na...
# 1  4    True
# 5    True
# Name: C-rate 5.0, dtype: bool
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: C-ra...
# 4  13    False
# 14    False
# Name: C-rate 5.0, dtyp...
# 5  15    False
# 16    False
# Name: C-rate 5.0, dtyp...
# 6  17    False
# 18    False
# 19    False
# Name: C-ra...
# 7  20    False
# 21    False
# Name: C-rate 5.0, dtyp...
# 8  22    False
# 23    False
# Name: C-rate 5.0, dtyp...
# 9  24    True
# 25    True
# Name: C-rate 5.0, dtype:...
#
#                                          C-rate None  \
# 0  0    False
# 1    False
# 2    False
# 3    False
# Na...
# 1  4    False
# 5    False
# Name: C-rate None, dtype...
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: C-ra...
# 4  13    False
# 14    False
# Name: C-rate None, dty...
# 5  15    False
# 16    False
# Name: C-rate None, dty...
# 6  17    False
# 18    False
# 19    False
# Name: C-ra...
# 7  20    False
# 21    False
# Name: C-rate None, dty...
# 8  22    False
# 23    False
# Name: C-rate None, dty...
# 9  24    False
# 25    False
# Name: C-rate None, dty...
#
#                                           C-rate 0.2  \
# 0  0    False
# 1    False
# 2    False
# 3    False
# Na...
# 1  4    False
# 5    False
# Name: C-rate 0.2, dtype:...
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: C-ra...
# 4  13    False
# 14    False
# Name: C-rate 0.2, dtyp...
# 5  15    False
# 16    False
# Name: C-rate 0.2, dtyp...
# 6  17    False
# 18    False
# 19    False
# Name: C-ra...
# 7  20    False
# 21    False
# Name: C-rate 0.2, dtyp...
# 8  22    False
# 23    False
# Name: C-rate 0.2, dtyp...
# 9  24    False
# 25    False
# Name: C-rate 0.2, dtyp...
#
#                                              W ratio  \
# 0  0    False
# 1    False
# 2    False
# 3    False
# Na...
# 1   4    False
# 5    False
# Name: W ratio, dtype: bool
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: W ra...
# 4  13    False
# 14    False
# Name: W ratio, dtype: ...
# 5  15    False
# 16    False
# Name: W ratio, dtype: ...
# 6  17    False
# 18    False
# 19    False
# Name: W ra...
# 7  20    False
# 21    False
# Name: W ratio, dtype: ...
# 8  22    False
# 23    False
# Name: W ratio, dtype: ...
# 9  24    False
# 25    False
# Name: W ratio, dtype: ...
#
#                                           C-rate 4.0  \
# 0  0    False
# 1    False
# 2    False
# 3    False
# Na...
# 1  4    False
# 5    False
# Name: C-rate 4.0, dtype:...
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: C-ra...
# 4  13    False
# 14    False
# Name: C-rate 4.0, dtyp...
# 5  15    False
# 16    False
# Name: C-rate 4.0, dtyp...
# 6  17    False
# 18    False
# 19    False
# Name: C-ra...
# 7  20    False
# 21    False
# Name: C-rate 4.0, dtyp...
# 8  22    False
# 23    False
# Name: C-rate 4.0, dtyp...
# 9  24     True
# 25    False
# Name: C-rate 4.0, dtyp...
#
#                                           C-rate 6.0
# 0  0    False
# 1    False
# 2    False
# 3    False
# Na...
# 1  4    False
# 5    False
# Name: C-rate 6.0, dtype:...
# 2  6    False
# 7    False
# 8    False
# 9    False
# Na...
# 3  10    False
# 11    False
# 12    False
# Name: C-ra...
# 4  13    False
# 14    False
# Name: C-rate 6.0, dtyp...
# 5  15    False
# 16    False
# Name: C-rate 6.0, dtyp...
# 6  17    False
# 18    False
# 19    False
# Name: C-ra...
# 7  20    False
# 21    False
# Name: C-rate 6.0, dtyp...
# 8  22    False
# 23    False
# Name: C-rate 6.0, dtyp...
# 9  24    True
# 25    True
# Name: C-rate 6.0, dtype:...
#
# [10 rows x 39 columns]

# %%
# gt[gt["Paper ID"] == 11]
# Out:
#    Paper ID Sample  Li ratio  Ni ratio  Co ratio  Mn ratio  O ratio  \
# 0        11    NR0         1      0.33      0.33      0.33        2
# 1        11    NR1         1      0.33      0.33      0.33        2
# 2        11    NR3         1      0.33      0.33      0.33        2
# 3        11    NR5         1      0.33      0.33      0.33        2
#
#   Commercial NCM used Lithium source     Synthesis method  ... C-rate 5  \
# 0                  no          LiNO3  solution combustion  ...     45.5
# 1                  no          LiNO3  solution combustion  ...     47.0
# 2                  no          LiNO3  solution combustion  ...     75.4
# 3                  no          LiNO3  solution combustion  ...     95.4
#
#    C-rate 5.0  C-rate 10 C-rate 20 C-rate 40 C-rate None C-rate 0.2 W ratio  \
# 0         NaN        NaN       NaN       NaN         NaN        NaN     NaN
# 1         NaN        NaN       NaN       NaN         NaN        NaN     NaN
# 2         NaN        NaN       NaN       NaN         NaN        NaN     NaN
# 3         NaN        NaN       NaN       NaN         NaN        NaN     NaN
#
#   C-rate 4.0 C-rate 6.0
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
#
# [4 rows x 39 columns]

# %%
# answer
# Out:
#     Paper ID                         Sample  Li ratio  Ni ratio  Co ratio  \
# 0         11                            NR0      1.00     0.330      0.33
# 1         11                            NR1      1.00     0.330      0.33
# 2         11                            NR3      1.00     0.330      0.33
# 3         11                            NR5      1.00     0.330      0.33
# 4         16                            NCM      1.01     0.350      0.32
# 5         16                          NCM/C      1.03     0.320      0.33
# 6         22                       pristine      0.98     0.840      0.10
# 7         22                        V-0.005      0.98     0.840      0.10
# 8         22                         V-0.01      0.98     0.840      0.10
# 9         22                         V-0.02      0.98     0.840      0.10
# 10        35                         S1bare      1.03     0.850      0.10
# 11        35                         S2wash      1.03     0.850      0.10
# 12        35                         S3coat      1.03     0.850      0.10
# 13        39                            N92      1.00     0.920      0.04
# 14        39                           WN92      1.00     0.918      0.04
# 15        40                       SC-NCM83      1.10     0.830      0.11
# 16        41               pristine NCM-811      1.00     0.800      0.10
# 17        41                 g-C3N4@NCM-811      1.00     0.800      0.10
# 18        41              g-C3N4NSs@NCM-811      1.00     0.800      0.10
# 19        42                         SC-NCM      1.11     0.830      0.12
# 20        42                          N-NCM      1.00     0.830      0.12
# 21        44                         NCM622      1.00     0.600      0.20
# 22        44                pristine NCM622      1.00     0.600      0.20
# 23        44  polymer/γ-Al2O3-coated NCM622      1.00     0.600      0.20
# 24        56                   pristine NCM      1.05     0.800      0.10
# 25        56                          M-NCM      1.05     0.800      0.10
#
#     Mn ratio  O ratio  W ratio Commercial NCM used Lithium source  ...  \
# 0       0.33      2.0      NaN                  no          LiNO3  ...
# 1       0.33      2.0      NaN                  no          LiNO3  ...
# 2       0.33      2.0      NaN                  no          LiNO3  ...
# 3       0.33      2.0      NaN                  no          LiNO3  ...
# 4       0.32      NaN      NaN                  no           LiAc  ...
# 5       0.34      NaN      NaN                  no           LiAc  ...
# 6       0.06      2.0      NaN                 yes           LiOH  ...
# 7       0.06      2.0      NaN                  no           LiOH  ...
# 8       0.06      2.0      NaN                  no           LiOH  ...
# 9       0.06      2.0      NaN                  no           LiOH  ...
# 10      0.05      2.0      NaN                 yes           LiOH  ...
# 11      0.05      2.0      NaN                 yes           LiOH  ...
# 12      0.05      2.0      NaN                 yes           LiOH  ...
# 13      0.04      2.0      NaN                 yes           LiOH  ...
# 14      0.04      2.0   0.0025                  no           LiOH  ...
# 15      0.06      NaN      NaN                  no         Li2CO3  ...
# 16      0.10      2.0      NaN                 yes            NaN  ...
# 17      0.10      2.0      NaN                 yes            NaN  ...
# 18      0.10      2.0      NaN                 yes            NaN  ...
# 19      0.05      2.0      NaN                  no         Li2CO3  ...
# 20      0.05      2.0      NaN                 yes         Li2CO3  ...
# 21      0.20      2.0      NaN                 yes           LiOH  ...
# 22      0.20      2.0      NaN                 yes           LiOH  ...
# 23      0.20      2.0      NaN                 yes           LiOH  ...
# 24      0.10      2.0      NaN                 yes           LiOH  ...
# 25      0.10      2.0      NaN                  no           LiOH  ...
#
#    C-rate 5.0 C-rate 10.0  C-rate 20.0  C-rate 40.0 C-rate 0.05 C-rate 0.33  \
# 0       45.50         NaN          NaN          NaN         NaN         NaN
# 1       47.00         NaN          NaN          NaN         NaN         NaN
# 2       75.40         NaN          NaN          NaN         NaN         NaN
# 3       95.40         NaN          NaN          NaN         NaN         NaN
# 4      101.70        71.5         44.5         13.2         NaN         NaN
# 5      135.80       109.4         81.9         54.6         NaN         NaN
# 6         NaN         NaN          NaN          NaN         NaN         NaN
# 7         NaN         NaN          NaN          NaN         NaN         NaN
# 8         NaN         NaN          NaN          NaN         NaN         NaN
# 9         NaN         NaN          NaN          NaN         NaN         NaN
# 10        NaN         NaN          NaN          NaN       181.0       197.0
# 11        NaN         NaN          NaN          NaN       183.0       202.0
# 12        NaN         NaN          NaN          NaN       185.0       205.0
# 13      64.19         NaN          NaN          NaN         NaN         NaN
# 14     159.11         NaN          NaN          NaN         NaN         NaN
# 15        NaN         NaN          NaN          NaN       199.0         NaN
# 16        NaN         NaN          NaN          NaN         NaN         NaN
# 17        NaN         NaN          NaN          NaN         NaN         NaN
# 18        NaN         NaN          NaN          NaN         NaN         NaN
# 19     166.92         NaN          NaN          NaN         NaN         NaN
# 20     160.30         NaN          NaN          NaN         NaN         NaN
# 21        NaN         NaN          NaN          NaN         NaN         NaN
# 22        NaN         NaN          NaN          NaN         NaN         NaN
# 23        NaN         NaN          NaN          NaN         NaN         NaN
# 24     159.00         NaN          NaN          NaN         NaN         NaN
# 25     180.00         NaN          NaN          NaN         NaN         NaN
#
#    C-rate None C-rate 0.3 C-rate 4.0 C-rate 6.0
# 0          NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN
# 3          NaN        NaN        NaN        NaN
# 4          NaN        NaN        NaN        NaN
# 5          NaN        NaN        NaN        NaN
# 6          NaN        NaN        NaN        NaN
# 7          NaN        NaN        NaN        NaN
# 8          NaN        NaN        NaN        NaN
# 9          NaN        NaN        NaN        NaN
# 10         NaN        NaN        NaN        NaN
# 11         NaN        NaN        NaN        NaN
# 12         NaN        NaN        NaN        NaN
# 13         NaN        NaN        NaN        NaN
# 14         NaN        NaN        NaN        NaN
# 15         NaN        NaN        NaN        NaN
# 16         NaN        NaN        NaN        NaN
# 17         NaN        NaN        NaN        NaN
# 18         NaN        NaN        NaN        NaN
# 19         NaN      171.6        NaN        NaN
# 20         NaN      150.1        NaN        NaN
# 21         NaN        NaN        NaN        NaN
# 22         NaN        NaN        NaN        NaN
# 23         NaN        NaN        NaN        NaN
# 24         NaN        NaN      169.8      151.3
# 25         NaN        NaN        NaN      168.9
#
# [26 rows x 40 columns]
